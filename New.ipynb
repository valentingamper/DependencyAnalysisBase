# %% [markdown]
# ## Clone Repos

# %%
import os
import re
import subprocess
from tqdm import tqdm
import xml.etree.ElementTree as ET
from typing import List, Dict, Any
from collections import defaultdict
from git import Repo, BadName
from pathlib import Path
import json

# %%
repo_name = "Checkmk/checkmk"

repo_url = "https://github.com/" + repo_name
destination_path = "./" + repo_name
repo_path = repo_name

commits_with_date = {}

# %%
if not os.path.exists(destination_path) or not os.listdir(destination_path):
	Repo.clone_from(repo_url, destination_path)
else:
	print(f"Directory '{destination_path}' already exists and is not empty. Skipping clone.")

# %%
repo = Repo(destination_path)

# %%
def find_all_files(repo_path):
    found_files = []
    for root, dirs, file_list in os.walk(repo_path):  # renamed 'files' to 'file_list'
        for file in file_list:
            if file == "pom.xml" or file == "requirements.txt" or file == "package.json" or file == "setup.py" or file == "pyproject.toml":
                full_path = os.path.join(root, file)
                found_files.append(full_path)
    return found_files

# %%
import fnmatch


def find_all_gradle_files(repo_path):
    gradle_files = []
    patterns = [
        "build.gradle",
        "settings.gradle",
        "gradle.properties",
        "build.gradle.kts",
        "settings.gradle.kts",
        "*.gradle",
        "*.gradle.kts"
    ]

    for root, dirs, files in os.walk(repo_path):
        for file in files:
            for pattern in patterns:
                if fnmatch.fnmatch(file, pattern):
                    full_path = os.path.join(root, file)
                    gradle_files.append(full_path)
                    break
    return gradle_files

# %%
def find_commits_with_changes(repo_path, file_paths):
    repo = Repo(repo_path)
    commits_with_changes = {}

    for file_path in file_paths:
        rel_path = os.path.relpath(file_path, repo_path)
        commits = list(repo.iter_commits(paths=rel_path))
        
        commits_with_changes[rel_path] = [commit.hexsha for commit in commits]
    
    return commits_with_changes

# %%
# Example usage
repo_path = "./" + repo_name  # Replace with your cloned repo path
file_paths = find_all_files(repo_path)
file_paths_gradle = find_all_gradle_files(repo_path)
file_paths += file_paths_gradle

# Display all found pom.xml paths
for path in file_paths:
    path = path.replace('\\', '/')
    print(path)

print(len(file_paths))
# Out:
# ./Checkmk/checkmk/pyproject.toml
# ./Checkmk/checkmk/requirements.txt
# ./Checkmk/checkmk/agents/modules/windows/tests/pyproject.toml
# ./Checkmk/checkmk/cmk/gui/quick_setup/handlers/setup.py
# ./Checkmk/checkmk/omd/requirements.txt
# ./Checkmk/checkmk/packages/cmk-agent-based/pyproject.toml
# ./Checkmk/checkmk/packages/cmk-agent-receiver/pyproject.toml
# ./Checkmk/checkmk/packages/cmk-ccc/pyproject.toml
# ./Checkmk/checkmk/packages/cmk-crypto/pyproject.toml
# ./Checkmk/checkmk/packages/cmk-events/pyproject.toml
# ./Checkmk/checkmk/packages/cmk-frontend/package.json
# ./Checkmk/checkmk/packages/cmk-frontend-vue/package.json
# ./Checkmk/checkmk/packages/cmk-graphing/pyproject.toml
# ./Checkmk/checkmk/packages/cmk-livestatus-client/pyproject.toml
# ./Checkmk/checkmk/packages/cmk-messaging/pyproject.toml
# ./Checkmk/checkmk/packages/cmk-mkp-tool/pyproject.toml
# ./Checkmk/checkmk/packages/cmk-rulesets/pyproject.toml
# ./Checkmk/checkmk/packages/cmk-server-side-calls/pyproject.toml
# ./Checkmk/checkmk/packages/cmk-shared-typing/package.json
# ./Checkmk/checkmk/packages/cmk-trace/pyproject.toml
# ./Checkmk/checkmk/packages/cmk-werks/pyproject.toml
# ./Checkmk/checkmk/tests/semgrep/requirements.txt
# 22

# %%
def get_all_relevant_commits(repo_path: str, file_paths: List[str]) -> Dict[str, List[str]]:
    repo = Repo(repo_path)
    commits_with_changes = {}

    for file_path in file_paths:
        rel_path = os.path.relpath(file_path, repo_path)

        # Get all commits that modified the file
        result = subprocess.run(
            ["git", "-C", repo_path, "log", "--follow", "--pretty=format:%H", "--name-only", "--", rel_path],
            capture_output=True,
            text=True,
            check=True
        )

        lines = result.stdout.strip().split('\n')
        current_commit = None

        for line in lines:
            stripped_line = line.strip()
            
            if len(stripped_line) == 40 and all(c in '0123456789abcdef' for c in stripped_line):  # Check if it looks like a SHA-1 hash
                current_commit = stripped_line
                if current_commit not in commits_with_changes:
                    commits_with_changes[current_commit] = set()  # Using set to avoid duplicates
            elif current_commit:
                modified_file = stripped_line
                if modified_file:  # Ensure we don't add empty lines
                    commits_with_changes[current_commit].add(modified_file)

    # Convert commits to a sorted list based on commit date
    commit_objects = []
    for commit_hash in commits_with_changes.keys():
        try:
            commit_obj = repo.commit(commit_hash)
            commit_objects.append((commit_obj, commit_hash))
        except BadName:
            print(f"Skipping invalid commit hash: {commit_hash}")  # Warn if a bad commit hash is found

    sorted_commits = sorted(commit_objects, key=lambda x: x[0].committed_date)
    
    # Creating a sorted dictionary of commits with their modified files
    sorted_commits_with_changes = {
        commit_hash: list(commits_with_changes[commit_hash]) for _, commit_hash in sorted_commits
        }
    
    global commits_with_date
    commits_with_date = {
        commit_hash: repo.commit(commit_hash).committed_datetime.strftime("%Y-%m-%d %H:%M:%S")
        for _, commit_hash in sorted_commits
    }

    return sorted_commits_with_changes

# %%
# Example usage
sorted_commit_hashes = get_all_relevant_commits(repo_path, file_paths)

# Display results
print(f"Total number of commits: {len(sorted_commit_hashes)}")
print("Commits (earliest to latest):")
for commit_hash, files in list(sorted_commit_hashes.items())[:10]:  # Displaying the first 10 for brevity
    print(f"{commit_hash}: {files}")
# Out:
# Total number of commits: 601
# Commits (earliest to latest):
# 81726bfbdcf08fdf2fde2517545bfbd2ee36095e: ['package.json']
# 2f1798417e3ee1e1d589242cd61cf52ab09e8864: ['package.json']
# 990bd85041ce07c7aa4f6dcede434c2ce0ea1d80: ['package.json']
# af2297ea7460cb8e7524db1568920e5a7078d671: ['package.json']
# a9fe31ca0fe39a757742f8a20c23e6b63118f8b9: ['package.json']
# 90704ae43d88910336c0e6e7e28cc2193f0c205e: ['package.json']
# 980368866ce18f56cac24b6bd0deb8226ea1d36d: ['package.json']
# 1c67595631f14ebd0f488aaf8a437d8768f208a6: ['package.json']
# cf01ef03d72a2e345f19ade4335b286a1ed253c1: ['package.json']
# e279d5960e21773b5f2d8aeb7f5f633bd843baf8: ['package.json']

# %% [markdown]
# ## java pom.xml parsing

# %%
# Initialize file cache
file_cache = {}
properties_cache = {}
NAMESPACE = {'mvn': 'http://maven.apache.org/POM/4.0.0'}
properties = {}

def parse_pom_xml(content: str, file_path: str, properties: Dict[str, str] = None) -> Dict[str, str]:
    if properties is None:
        properties = {}
    else:
        properties = properties.copy()  # Avoid side effects

    dependencies = {}

    try:
        root = ET.fromstring(content)

        # Update namespace if needed
        if 'xmlns' in root.attrib:
            NAMESPACE['mvn'] = root.attrib['xmlns']

        # Load project properties
        for prop in root.findall(".//mvn:properties/*", NAMESPACE):
            if prop.tag and prop.text:
                prop_name = prop.tag.split('}')[-1]
                properties[prop_name] = prop.text.strip()
                properties_cache[prop_name] = properties[prop_name]
        
        # Load project and parent versions as fallback properties
        project_version = root.find(".//mvn:version", NAMESPACE)
        if project_version is not None and project_version.text:
            properties["project.version"] = project_version.text.strip()

        parent_version = root.find(".//mvn:parent/mvn:version", NAMESPACE)
        if parent_version is not None and parent_version.text:
            properties["parent.version"] = parent_version.text.strip()

        parent_info = {}
        relative_path_elem = root.find(".//mvn:parent/mvn:relativePath", NAMESPACE)
        if relative_path_elem is not None and relative_path_elem.text:
            parent_info = {"parent_pom_path": relative_path_elem.text.strip()}

        # Read dependencies
        for dependency in root.findall(".//mvn:dependency", NAMESPACE):
            group_id = dependency.find("mvn:groupId", NAMESPACE)
            artifact_id = dependency.find("mvn:artifactId", NAMESPACE)
            version = dependency.find("mvn:version", NAMESPACE)

            if group_id is not None and artifact_id is not None:
                dep_key = f"{group_id.text.strip()}:{artifact_id.text.strip()}"
                if "${" in dep_key and "}" in dep_key:
                    dep_key = (resolve_cached(dep_key))

                if version is not None and version.text:
                    version_text = version.text.strip()
                    if version_text.startswith("${") and version_text.endswith("}"):
                        prop_name = version_text[2:-1]
                        resolved_version = properties.get(prop_name, "UNRESOLVED")
                        if resolved_version == "UNRESOLVED":
                            resolved_version = resolve_from_parent(prop_name, file_path, parent_info)
                            if (resolved_version =="UNRESOLVED"):
                                resolved_version = properties_cache.get(prop_name, "UNRESOLVED")
                        if resolved_version.startswith("${") and resolved_version.endswith("}"):
                            resolved_version = resolve_cached(resolved_version)
                        dependencies[dep_key] = resolved_version
                    else:
                        dependencies[dep_key] = version_text
                #else:
                    #dependencies[dep_key] = "UNSPECIFIED"

    except ET.ParseError as e:
        print(f"XML parsing error: {e}")

    return dependencies




def resolve_cached(prop_name, visited=None):
    matches = re.findall(r"\$\{([^}]+)\}", prop_name)
    if not matches:
        return properties_cache.get(prop_name)  # nothing to resolve, return as is

    resolved = prop_name
    for match in matches:
        inner_value = resolve_cached(match)
        if inner_value is None:
            return match
        resolved = resolved.replace(f"${{{match}}}", inner_value)

    return resolved



def resolve_from_parent(prop_name: str, file_path: str, properties: Dict[str, str]) -> str:
    parent_pom_path = properties.get("parent_pom_path")   
    if parent_pom_path is None:
        final_path = "pom.xml"
        parent_file = str(final_path).replace("\\", "/")
        if parent_file not in file_cache:
            return "UNRESOLVED"
        content = file_cache[parent_file]
        parent_prop_value = get_all_properties(content, prop_name, final_path, {})
        return parent_prop_value

    file_path = Path(file_path) if not isinstance(file_path, Path) else file_path
    parent_pom_path = Path(parent_pom_path) if not isinstance(parent_pom_path, Path) else parent_pom_path
    combined = file_path.parent / parent_pom_path

    stack = []
    for part in combined.parts:
        if part == "..":
            if stack and stack[-1] != "..":
                stack.pop()
            else:
                stack.append(part)
        elif part != ".":
            stack.append(part)
    final_path = Path(*stack)
    parent_file = str(final_path).replace("\\", "/")
    if parent_file not in file_cache:
        #print(f"[DEBUG] Skipping missing file: {parent_file}")
        return "UNRESOLVED"
    content = file_cache[parent_file]
    parent_prop_value = get_all_properties(content, prop_name, final_path, {})
    return parent_prop_value

def get_all_properties(content: str, target_prop: str, file_path: str, properties: Dict[str, str] = None):
    if properties is None:
        properties = {}
    else:
        properties = properties.copy()  # Avoid side effects

    try:
        root = ET.fromstring(content)

        if 'xmlns' in root.attrib:
            NAMESPACE['mvn'] = root.attrib['xmlns']

        # Properly assign keys without shadowing target_prop
        for prop in root.findall(".//mvn:properties/*", NAMESPACE):
            if prop.tag and prop.text:
                key = prop.tag.split('}')[-1]
                properties[key] = prop.text.strip()

        return properties.get(target_prop, "UNRESOLVED")
    except Exception as e:
        return "UNRESOLVED"    

def load_file_at_commit(repo, commit_hash, file_path):
    try:
        commit = repo.commit(commit_hash)
        blob = commit.tree / file_path
        content = blob.data_stream.read().decode('utf-8')
        file_cache[file_path] = content
        return content
    except Exception as e:
        print(f"[DEBUG]Error loading file '{file_path}' at commit '{commit_hash}': {e}")
        return None


def process_commit(repo, commit_hash, changed_files, dependencies_snapshot):
    for file_path in changed_files:
        if file_path.endswith("pom.xml"):
            content = load_file_at_commit(repo, commit_hash, file_path)
            if content:
                new_dependencies = parse_pom_xml(content, file_path, properties)
                dependencies_snapshot[file_path] = new_dependencies
    return dependencies_snapshot


def process_commits(repo, commits_with_changes):
    dependencies_over_time = {}
    dependencies_snapshot = {}

    for commit_hash, changed_files in tqdm(commits_with_changes.items(), desc="Processing commits"):
        dependencies_snapshot = process_commit(repo, commit_hash, changed_files, dependencies_snapshot)
        dependencies_over_time[commit_hash] = dependencies_snapshot.copy()

    return dependencies_over_time

dependencies_over_time = process_commits(repo, sorted_commit_hashes)

import json

with open("java_pom.json", "w") as f:
    json.dump(dependencies_over_time, f, indent=4)
# Out:
# Processing commits: 100%|██████████| 601/601 [00:00<00:00, 599899.26it/s]

# %% [markdown]
# ## python and javascript parsing:

# %%
import tomli
import ast


# Initialize cache and data structures
file_cache = {}
unique_entries = set()
dependency_changes = defaultdict(list)

# Supported version specifiers in requirements.txt
VERSION_SPECIFIERS = [
    '==', '>=', '<=', '~=', '!=', '>', '<'
]


def load_file_at_commit(repo_path, commit_hash, file_path):
    try:
        result = subprocess.run(
            ["git", "-C", repo_path, "show", f"{commit_hash}:{file_path}"],
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            text=True,
            check=True
        )
        return result.stdout
    except subprocess.CalledProcessError as e:
        print(f"Error loading file '{file_path}' at commit '{commit_hash}': {e.stderr}")
        return None


def process_commit_file_content(repo_path, sha, file_path, type):
    content = load_file_at_commit(repo_path, sha, file_path)
        
    if content:
        parse_file_content(content, sha, file_path, type)

def parse_pyproject_toml(content: str) -> dict:
    try:
        data = tomli.loads(content)
    except tomli.TOMLDecodeError:
        return {}

    # PEP 621 style
    deps = data.get("project", {}).get("dependencies", [])
    if not deps:
        # Poetry-style
        poetry_deps = data.get("tool", {}).get("poetry", {}).get("dependencies", {})
        deps = [f"{pkg}{v if isinstance(v, str) else ''}" for pkg, v in poetry_deps.items() if pkg.lower() != "python"]

    result = {}
    for dep in deps:
        parts = re.split(r"([<>=!~]+)", dep, maxsplit=1)
        name = parts[0].strip()
        version = ''.join(parts[1:]).strip() if len(parts) > 1 else "latest-version-available"
        result[name] = version

    return result


# === ADDED ===
def parse_setup_py(content: str) -> dict:
    try:
        tree = ast.parse(content)
    except SyntaxError:
        return {}

    class SetupVisitor(ast.NodeVisitor):
        def __init__(self):
            self.install_requires = []

        def visit_Call(self, node):
            if isinstance(node.func, ast.Name) and node.func.id == "setup":
                for keyword in node.keywords:
                    if keyword.arg == "install_requires":
                        if isinstance(keyword.value, (ast.List, ast.Tuple)):
                            for elt in keyword.value.elts:
                                if isinstance(elt, ast.Str):
                                    self.install_requires.append(elt.s)
            self.generic_visit(node)

    visitor = SetupVisitor()
    visitor.visit(tree)

    result = {}
    for dep in visitor.install_requires:
        parts = re.split(r"([<>=!~]+)", dep, maxsplit=1)
        name = parts[0].strip()
        version = ''.join(parts[1:]).strip() if len(parts) > 1 else "latest-version-available"
        result[name] = version

    return result

def parse_file_content(content, sha, filename, type):
    dependencies = {}
    hash_pattern = re.compile(r"--hash=sha256:[a-fA-F0-9]{64}")

    if type == "py" and "requirements.txt" in filename:
        for line in content.splitlines():
            line = line.strip()

            if not line or line.startswith('#') or line.startswith("--"):  # Ignore comments and empty lines
                continue

            # Check if line is a hash
            if hash_pattern.match(line):
                continue

            # Remove inline comments
            if '#' in line:
                line = line.split('#', 1)[0].strip()

            # Find the version specifier used
            version = "UNSPECIFIED"
            for specifier in VERSION_SPECIFIERS:
                if specifier in line:
                    package, version = line.split(specifier, 1)
                    package = package.strip()
                    version = version.strip()
                    dependencies[package] = version
                    break
            else:  # No version specifier found
                package = line
                dependencies[package] = "latest-version-available"

    elif type == "js" and "package.json" in filename:
        import json
        try:
            parsed_json = json.loads(content)
            if "dependencies" in parsed_json:
                dependencies.update(parsed_json["dependencies"])
            if "devDependencies" in parsed_json:
                dependencies.update(parsed_json["devDependencies"])
        except json.JSONDecodeError as e:
            print(f"Error parsing JSON file '{filename}': {e}")
    
    elif type == "py" and "setup.py" in filename:
        dependencies = parse_setup_py(content)
    elif type == "py" and "pyproject.toml" in filename:
        dependencies = parse_pyproject_toml(content)


    # Store the parsed dependencies for this commit
    dependency_changes[sha] = {
        "filename": filename,
        "dependencies": dependencies,
        "ecosystem": type
    }


def process_commits(repo_path, commits_with_files):
    for sha, files in tqdm(commits_with_files.items(), desc="Processing commits"):
        for file_path in files:
            if file_path.endswith("requirements.txt"):
                process_commit_file_content(repo_path, sha, file_path, "py")
            elif file_path.endswith("package.json"):
                process_commit_file_content(repo_path, sha, file_path, "js")
            elif file_path.endswith("setup.py"):
                process_commit_file_content(repo_path, sha, file_path, "py")
            elif file_path.endswith("pyproject.toml"):
                process_commit_file_content(repo_path, sha, file_path, "py")


def save_results(output_file="python_and_javascript.json"):
    import json
    with open(output_file, "w") as f:
        json.dump(dependency_changes, f, indent=4)


process_commits(repo_path, sorted_commit_hashes)
save_results()
# Out:
# Processing commits:   9%|▉         | 55/601 [00:04<00:44, 12.17it/s]
# Error loading file 'pyproject.toml' at commit '46620c5fda243677e84b160fbbed24a2bdddec46': fatal: path 'pyproject.toml' exists on disk, but not in '46620c5fda243677e84b160fbbed24a2bdddec46'
# Processing commits: 100%|██████████| 601/601 [00:43<00:00, 13.87it/s]

# %%
file_cache = {}

def is_gradle_related(file_path):
    return (
        file_path.endswith("build.gradle")
        or file_path.endswith("build.gradle.kts")
        or file_path.endswith("settings.gradle")
        or file_path.endswith("settings.gradle.kts")
        or file_path.endswith("gradle.properties")
        or file_path.endswith(".gradle")
        or file_path.endswith(".gradle.kts")
    )

def parse_gradle_properties(content):
    props = {}
    for line in content.splitlines():
        line = line.strip()
        if line and not line.startswith("#") and "=" in line:
            key, value = line.split("=", 1)
            props[key.strip()] = value.strip()
    return props


def extract_dependencies_block(content: str) -> str:
    """Returns only the content inside dependencies { ... } block(s)."""
    lines = content.splitlines()
    inside = False
    depth = 0
    collected = []

    for line in lines:
        stripped = line.strip()
        if stripped.startswith("dependencies"):
            if "{" in stripped:
                inside = True
                depth = stripped.count("{") - stripped.count("}")
                continue

        if inside:
            if "{" in stripped:
                depth += stripped.count("{")
            if "}" in stripped:
                depth -= stripped.count("}")
            collected.append(line)
            if depth <= 0:
                inside = False

    return "\n".join(collected)


def parse_gradle_dependencies(file_content: str, properties: Dict[str, str], commit_sha: str, file_path: str) -> List[Dict[str, Any]]:
    dependencies = []

    # NEW: extract only content inside dependencies block(s)
    block = extract_dependencies_block(file_content)

    # Patterns for Kotlin + Groovy
    patterns = [
        re.compile(r'(?P<config>\w+)\s*\(\s*["\'](?P<group>[^:\'"]+):(?P<artifact>[^:\'"]+):(?P<version>[^\'"]+)["\']\s*\)'),  # Kotlin DSL
        re.compile(r'(?P<config>\w+)\s+["\'](?P<group>[^:\'"]+):(?P<artifact>[^:\'"]+):(?P<version>[^\'"]+)["\']')  # Groovy DSL
    ]

    for pattern in patterns:
        for match in pattern.finditer(block):
            config = match.group("config")
            group = match.group("group")
            artifact = match.group("artifact")
            version = match.group("version")

            version_source = "literal"
            if version.startswith("$") or "${" in version:
                var_name = version.replace("$", "").replace("{", "").replace("}", "")
                if var_name in properties:
                    version = properties[var_name]
                    version_source = "resolved_from_property"
                else:
                    version_source = "unresolved"

            if "$" not in group and "$" not in artifact and "$" not in version:
                dependencies.append({
                    "commit": commit_sha,
                    "file": file_path,
                    #"tool": "gradle",
                    #"configuration": config,
                    "group": group,
                    "artifact": artifact,
                    "version": version,
                    #"version_source": version_source
                })

    return dependencies


def load_file_at_commit(repo, commit_hash, file_path):
    try:
        commit = repo.commit(commit_hash)
        blob = commit.tree / file_path
        content = blob.data_stream.read().decode('utf-8')
        file_cache[file_path] = content
        return content
    except Exception as e:
        print(f"[DEBUG] Error loading file '{file_path}' at commit '{commit_hash}': {e}")
        return None
    
def parse_local_kotlin_variables(content: str) -> Dict[str, str]:
    props = {}
    # Matches lines like: val log4jVersion = "2.20.0" or var version = "1.0"
    pattern = re.compile(r'(val|var)\s+(\w+)\s*=\s*["\']([^"\']+)["\']')
    for match in pattern.finditer(content):
        var_name = match.group(2)
        value = match.group(3)
        props[var_name] = value
    return props

def process_commit(repo, commit_hash, changed_files, dependencies_snapshot, all_dependencies, properties_by_commit):
    for file_path in changed_files:
        if not is_gradle_related(file_path):
            continue

        content = load_file_at_commit(repo, commit_hash, file_path)
        if content:
            dependencies_snapshot[file_path] = content

            # Parse gradle.properties
            if file_path.endswith("gradle.properties"):
                props = parse_gradle_properties(content)
                properties_by_commit[commit_hash] = props

            # Parse dependencies from .gradle or .gradle.kts files
            elif file_path.endswith(".gradle") or file_path.endswith(".gradle.kts"):
                props = {}
                #props.update(parse_ext_block(content))                  # ext { ... }
                #props.update(parse_extra_assignments(content))          # extra["..."] = ...
                #props.update(extract_project_properties(content))       # group/version/name
                props.update(parse_local_kotlin_variables(content))     # val/var = "..."

                if commit_hash not in properties_by_commit:
                    properties_by_commit[commit_hash] = {}
                properties_by_commit[commit_hash].update(props)

                resolved_props = properties_by_commit[commit_hash]
                parsed_deps = parse_gradle_dependencies(content, resolved_props, commit_hash, file_path)
                all_dependencies.extend(parsed_deps)

    return dependencies_snapshot, all_dependencies

def process_commits(repo, commits_with_changes):
    dependencies_over_time = {}
    dependencies_snapshot = {}
    all_dependencies = []
    properties_by_commit = {}

    for commit_hash, changed_files in tqdm(commits_with_changes.items(), desc="Processing commits"):
        dependencies_snapshot, all_dependencies = process_commit(
            repo, commit_hash, changed_files, dependencies_snapshot, all_dependencies, properties_by_commit
        )
        dependencies_over_time[commit_hash] = dependencies_snapshot.copy()

    return dependencies_over_time, all_dependencies


dependencies_over_time, all_dependencies = process_commits(repo, sorted_commit_hashes)

# Optionally print the parsed dependencies
#for dep in all_dependencies:
    #print(dep)

cleaned_dependencies = [
    dep for dep in all_dependencies
    if "$" not in dep["group"]
    and "$" not in dep["artifact"]
    and "$" not in dep["version"]
]

for dep in cleaned_dependencies [:10]:
    print(dep)
# Out:
# Processing commits: 100%|██████████| 601/601 [00:00<00:00, 301204.05it/s]

# %%
def group_gradle_dependencies(dependencies):
    grouped = defaultdict(lambda: {"gradle": defaultdict(dict)})

    for dep in dependencies:
        commit = dep["commit"]
        file = dep["file"]
        group_artifact = f"{dep['group']}:{dep['artifact']}"
        version = dep["version"]

        grouped[commit]["gradle"][file][group_artifact] = version

    return grouped

grouped_dependencies = group_gradle_dependencies(cleaned_dependencies)
import json
# Convert the defaultdict to a normal dict recursively
def to_dict(d):
    if isinstance(d, defaultdict):
        d = {k: to_dict(v) for k, v in d.items()}
    elif isinstance(d, dict):
        d = {k: to_dict(v) for k, v in d.items()}
    return d

#print(json.dumps(to_dict(grouped_dependencies), indent=2))

def save_results(data, output_file="dependencies_over_time.json"):
    import json
    with open(output_file, "w") as f:
        json.dump(data, f, indent=4)

save_results(to_dict(grouped_dependencies), "java_gradle.json")

# %%
def merge_dependencies(python_and_javascript: Dict, java: Dict, gradle: Dict) -> Dict:
    merged_data = {}

    # Combine all unique commit hashes from both datasets
    all_commits = set(python_and_javascript) | set(java) | set(gradle)

    for commit in all_commits:
        merged_data[commit] = {
            "java": {},
            "gradle": {},
            "python": {},
            "javascript": {}
        }

        # Add Java dependencies if present
        if commit in java:
            for file, content in java[commit].items():
                merged_data[commit]["java"][file] = content  # No renaming!
        
        if commit in gradle:
            gradle_files = gradle[commit].get("gradle", {})  # Extract only the inner part
            for file, content in gradle_files.items():
                merged_data[commit]["gradle"][file] = content

        # Add Python and JavaScript dependencies if present
        if commit in python_and_javascript:
            content = python_and_javascript[commit]

            # Check if it's a Python or JavaScript file based on 'ecosystem'
            if content.get("ecosystem") == "py":
                merged_data[commit]["python"][content["filename"]] = content["dependencies"]
            elif content.get("ecosystem") == "js":
                merged_data[commit]["javascript"][content["filename"]] = content["dependencies"]


    return merged_data

def remove_empty_objects(data):
    if isinstance(data, dict):
        return {
            k: remove_empty_objects(v)
            for k, v in data.items()
            if not (isinstance(v, dict) and not v)  # remove empty dicts
        }
    elif isinstance(data, list):
        return [remove_empty_objects(item) for item in data]
    else:
        return data

def save_merged_data(merged_data: Dict, output_file: str):
    with open(output_file, 'w') as f:
        json.dump(merged_data, f, indent=4)


with open('python_and_javascript.json', 'r') as f:
    python_and_javascript = json.load(f)

with open('java_pom.json', 'r') as f:
    java = json.load(f)

with open('java_gradle.json', 'r') as f:
    gradle = json.load(f)

merged_data = merge_dependencies(python_and_javascript, java, gradle)
new_merged_data = remove_empty_objects(merged_data)
save_merged_data(new_merged_data, 'merged_dependencies.json')

# %%
import json
import copy

# Load input data
with open("merged_dependencies.json", "r") as f:
    data = json.load(f)

# Your commit-to-date mapping
commit_dates = commits_with_date  # assumed to be defined already

# Ensure chronological commit order
sorted_commits = sorted(data.keys(), key=lambda c: commit_dates.get(c))

# Global latest version per dependency
latest_versions = {}

# Last known dependency set per file
last_file_state = {}  # (system, filename) -> {dep: version}

# All changes (add, update, remove)
changes = []

for commit in sorted_commits:
    date = commit_dates.get(commit)
    commit_data = data[commit]

    for system, files in commit_data.items():
        for filename, curr_deps in files.items():
            file_key = (system, filename)
            prev_deps = last_file_state.get(file_key, {})

            # Check for added/updated
            for dep, new_version in curr_deps.items():
                old_version = latest_versions.get(dep)
                if dep not in prev_deps:
                    changes.append({
                        "commit": commit,
                        "date": date,
                        "filename": filename,
                        "system": system,
                        "dependency": dep,
                        "change_type": "added",
                        "old_version": None,
                        "new_version": new_version
                    })
                elif prev_deps[dep] != new_version:
                    changes.append({
                        "commit": commit,
                        "date": date,
                        "filename": filename,
                        "system": system,
                        "dependency": dep,
                        "change_type": "updated",
                        "old_version": prev_deps[dep],
                        "new_version": new_version
                    })

                # Always update the global version
                latest_versions[dep] = new_version

            # Save current state for next round
            last_file_state[file_key] = copy.deepcopy(curr_deps)

# Save all detected changes
with open("dependency_changes_with_removed.json", "w") as f:
    json.dump(changes, f, indent=2)

# %%
import json
import requests
import urllib.parse
from datetime import datetime
from collections import defaultdict
from packaging.version import Version, InvalidVersion


def normalize_system(system):
    mapping = {
        "java": "maven",
        "javascript": "npm",
        "python": "pypi",
        "go": "go"
    }
    return mapping.get(system, system)


def get_major_version(version_str):
    try:
        return Version(version_str).major
    except InvalidVersion:
        return None

cached_versions = defaultdict(dict)

def fetch_package_data(package_name, system):
    encoded_name = urllib.parse.quote(package_name, safe="")
    url = f"https://api.deps.dev/v3alpha/systems/{system}/packages/{encoded_name}"
    response = requests.get(url)
    response.raise_for_status()
    return response.json()

def get_cached_package_data(package_name, system):
    if package_name not in cached_versions[system]:
        try:
            cached_versions[system][package_name] = fetch_package_data(package_name, system)
        except requests.RequestException as e:
            print(f"❌ Failed to fetch data for {package_name} ({system}): {e}")
            cached_versions[system][package_name] = {}  # fallback to empty
    return cached_versions[system][package_name]

def analyze_entry(entry):
    package_name = entry["dependency"]
    raw_new = entry["new_version"]
    has_caret = raw_new.startswith("^")
    new_version = raw_new.lstrip("^")    
    date_str = entry["date"]
    commit_date = datetime.strptime(date_str, "%Y-%m-%d %H:%M:%S")
    system = normalize_system(entry["system"])

    # Get versions once per package
    package_data = get_cached_package_data(package_name, system)
    all_versions = package_data.get("versions", [])

    commit_versions = []
    for v in all_versions:
        ver_str = v.get("versionKey", {}).get("version")
        pub_str = v.get("publishedAt")
        if not ver_str or not pub_str:
            continue
        try:
            pub_date = datetime.strptime(pub_str, "%Y-%m-%dT%H:%M:%SZ")
        except ValueError:
            continue

        # only consider versions published before or at the commit
        if pub_date <= commit_date:
            try:
                commit_versions.append(Version(ver_str))
            except InvalidVersion:
                continue

    if commit_versions:
        # highest major first
        max_major = max(v.major for v in commit_versions)
        # among those, pick highest full version
        highest = max(v for v in commit_versions if v.major == max_major)
        entry["newest_version_at_commit"] = str(highest)
    else:
        entry["newest_version_at_commit"] = None

    released_date = None
    latest_at_commit_time = None
    latest_publish_date = None
    released_date_dt = None

    is_npm = (system == "npm")
    target_major = get_major_version(new_version) if is_npm else None
    
    latency = -1 # Default to -1 for no version found

    for v in all_versions:
        version = v.get("versionKey").get("version")
        v_date_str =  v.get("publishedAt")

        if not v_date_str or not version:
            continue


        try:
            parsed = Version(version)
        except InvalidVersion:
            #continue
            parsed = None

        if is_npm and parsed != None and parsed.major != target_major:
            continue  # npm: nur gleiche Major-Version berücksichtigen

        v_date = datetime.strptime(v_date_str, "%Y-%m-%dT%H:%M:%SZ")

        # Find release date of the version in the change
        if version == new_version:
            released_date = v_date.isoformat()
            released_date_dt = v_date

        # Find latest version before or at commit time
        if v_date <= commit_date:
            if latest_publish_date is None or v_date > latest_publish_date:
                latest_publish_date = v_date
                latest_at_commit_time = version
                

    '''for v in all_versions:
        version = v.get("versionKey").get("version")
        v_date_str =  v.get("publishedAt")
        if not v_date_str or not version:
            continue
        v_date = datetime.strptime(v_date_str, "%Y-%m-%dT%H:%M:%SZ")
        if released_date_dt and v_date >= released_date_dt:
            if v_date <= commit_date:
                latency += 1
    '''

        #print(f"📦 Version {version} released at: {v_date}, {latest_publish_date}, {latest_at_commit_time} ")


    #print(f"🕓 Commit: {commit_date}")
    #print(f"📦 Released: {released_date}")
    #print(f"✅ Latest at commit time: {latest_at_commit_time} ({latest_publish_date})")

    # Add info to the entry
    entry["released_date"] = released_date
    entry["latest_at_commit_time"] = latest_at_commit_time
    #entry["latency"] = latency

    try:
        baseline = Version(new_version)
    except InvalidVersion:
        baseline = None

    if has_caret and baseline:
        same_major = [v for v in commit_versions if v.major == baseline.major]
        if same_major:
            baseline = max(same_major)

    if baseline and commit_versions:
        # count how many versions published ≤ commit_date are strictly > baseline
        entry["latency"] = sum(1 for v in commit_versions if v > baseline)
    else:
        entry["latency"] = -1
    return entry

def process_json_file(input_path, output_path):
    with open(input_path, "r") as f:
        entries = json.load(f)

    total = len(entries)
    enriched = []
    for i, entry in enumerate(entries, start=1):
        enriched_entry = analyze_entry(entry)
        enriched.append(enriched_entry)
        dep = enriched_entry.get("dependency", "???")
        print(f"[{i}/{total}] {dep} → done")

    with open(output_path, "w") as f:
        json.dump(enriched, f, indent=2)

# Run
process_json_file("dependency_changes_with_removed.json", "dependency_changes_enriched.json")
# Out:
# [1/1663] webpack → done
# [2/1663] webpack-cli → done
# [3/1663] @babel/core → done
# [4/1663] @babel/preset-env → done
# [5/1663] babel-loader → done
# [6/1663] eslint → done
# [7/1663] eslint-plugin-compat → done
# [8/1663] script-loader → done
# [9/1663] jquery → done
# [10/1663] select2 → done
# [11/1663] css-loader → done
# [12/1663] mini-css-extract-plugin → done
# [13/1663] style-loader → done
# [14/1663] autoprefixer → done
# [15/1663] extract-loader → done
# [16/1663] file-loader → done
# [17/1663] node-sass → done
# [18/1663] postcss-clean → done
# [19/1663] postcss-loader → done
# [20/1663] sass-lint → done
# [21/1663] sass-loader → done
# [22/1663] webpack-fix-style-only-entries → done
# [23/1663] @yaireo/tagify → done
# [24/1663] sass-lint → done
# [25/1663] @yaireo/tagify → done
# [26/1663] node-sass → done
# [27/1663] jquery → done
# [28/1663] sass-lint → done
# [29/1663] d3 → done
# [30/1663] d3-flextree → done
# [31/1663] @yaireo/tagify → done
# [32/1663] d3 → done
# [33/1663] d3-flextree → done
# [34/1663] select2 → done
# [35/1663] @babel/core → done
# [36/1663] @babel/preset-env → done
# [37/1663] autoprefixer → done
# [38/1663] babel-loader → done
# [39/1663] css-loader → done
# [40/1663] eslint → done
# [41/1663] eslint-plugin-compat → done
# [42/1663] file-loader → done
# [43/1663] mini-css-extract-plugin → done
# [44/1663] sass-loader → done
# [45/1663] style-loader → done
# [46/1663] webpack → done
# [47/1663] webpack-cli → done
# [48/1663] webpack-fix-style-only-entries → done
# [49/1663] sass-loader → done
# [50/1663] @yaireo/tagify → done
# [51/1663] sass-loader → done
# [52/1663] core-js → done
# [53/1663] @babel/core → done
# [54/1663] @babel/preset-env → done
# [55/1663] d3 → done
# [56/1663] @babel/core → done
# [57/1663] @babel/preset-env → done
# [58/1663] eslint → done
# [59/1663] webpack → done
# [60/1663] webpack-cli → done
# [61/1663] element-closest-polyfill → done
# [62/1663] whatwg-fetch → done
# [63/1663] sweetalert2 → done
# [64/1663] d3-sankey → done
# [65/1663] crossfilter2 → done
# [66/1663] dc → done
# [67/1663] redoc → done
# [68/1663] redoc-cli → done
# [69/1663] core-js → done
# [70/1663] d3 → done
# [71/1663] dc → done
# [72/1663] select2 → done
# [73/1663] sweetalert2 → done
# [74/1663] @babel/core → done
# [75/1663] @babel/preset-env → done
# [76/1663] autoprefixer → done
# [77/1663] babel-loader → done
# [78/1663] css-loader → done
# [79/1663] eslint → done
# [80/1663] eslint-plugin-compat → done
# [81/1663] file-loader → done
# [82/1663] mini-css-extract-plugin → done
# [83/1663] node-sass → done
# [84/1663] sass-loader → done
# [85/1663] style-loader → done
# [86/1663] webpack → done
# [87/1663] webpack-cli → done
# [88/1663] jquery → done
# [89/1663] node-sass → done
# [90/1663] redoc → done
# [91/1663] redoc-cli → done
# [92/1663] simplebar → done
# [93/1663] prettier → done
# [94/1663] eslint-config-prettier → done
# [95/1663] eslint-plugin-prettier → done
# [96/1663] redoc-cli → done
# [97/1663] redoc → done
# [98/1663] redoc-cli → done
# [99/1663] redoc-cli → done
# [100/1663] d3-hexbin → done
# [101/1663] @yaireo/tagify → done
# [102/1663] core-js → done
# [103/1663] @babel/core → done
# [104/1663] @babel/preset-env → done
# [105/1663] babel-loader → done
# [106/1663] eslint → done
# [107/1663] eslint-config-prettier → done
# [108/1663] eslint-plugin-compat → done
# [109/1663] eslint-plugin-prettier → done
# [110/1663] extract-loader → done
# [111/1663] file-loader → done
# [112/1663] mini-css-extract-plugin → done
# [113/1663] node-sass → done
# [114/1663] postcss-clean → done
# [115/1663] postcss-loader → done
# [116/1663] prettier → done
# [117/1663] sass-loader → done
# [118/1663] style-loader → done
# [119/1663] webpack-cli → done
# [120/1663] webpack-fix-style-only-entries → done
# [121/1663] core-js → done
# [122/1663] @babel/core → done
# [123/1663] @babel/preset-env → done
# [124/1663] babel-loader → done
# [125/1663] eslint → done
# [126/1663] eslint-config-prettier → done
# [127/1663] eslint-plugin-compat → done
# [128/1663] eslint-plugin-prettier → done
# [129/1663] extract-loader → done
# [130/1663] file-loader → done
# [131/1663] mini-css-extract-plugin → done
# [132/1663] node-sass → done
# [133/1663] postcss-clean → done
# [134/1663] postcss-loader → done
# [135/1663] prettier → done
# [136/1663] sass-loader → done
# [137/1663] style-loader → done
# [138/1663] webpack-cli → done
# [139/1663] webpack-fix-style-only-entries → done
# [140/1663] core-js → done
# [141/1663] @babel/core → done
# [142/1663] @babel/preset-env → done
# [143/1663] babel-loader → done
# [144/1663] eslint → done
# [145/1663] eslint-config-prettier → done
# [146/1663] eslint-plugin-compat → done
# [147/1663] eslint-plugin-prettier → done
# [148/1663] prettier → done
# [149/1663] sweetalert2 → done
# [150/1663] extract-loader → done
# [151/1663] file-loader → done
# [152/1663] mini-css-extract-plugin → done
# [153/1663] node-sass → done
# [154/1663] postcss-clean → done
# [155/1663] postcss-loader → done
# [156/1663] sass-loader → done
# [157/1663] style-loader → done
# [158/1663] webpack-cli → done
# [159/1663] webpack-fix-style-only-entries → done
# [160/1663] core-js → done
# [161/1663] sweetalert2 → done
# [162/1663] @babel/core → done
# [163/1663] @babel/preset-env → done
# [164/1663] babel-loader → done
# [165/1663] eslint → done
# [166/1663] eslint-config-prettier → done
# [167/1663] eslint-plugin-compat → done
# [168/1663] eslint-plugin-prettier → done
# [169/1663] extract-loader → done
# [170/1663] file-loader → done
# [171/1663] mini-css-extract-plugin → done
# [172/1663] node-sass → done
# [173/1663] postcss-clean → done
# [174/1663] postcss-loader → done
# [175/1663] prettier → done
# [176/1663] sass-loader → done
# [177/1663] style-loader → done
# [178/1663] webpack-cli → done
# [179/1663] webpack-fix-style-only-entries → done
# [180/1663] eslint → done
# [181/1663] eslint-config-prettier → done
# [182/1663] eslint-plugin-compat → done
# [183/1663] eslint-plugin-prettier → done
# [184/1663] prettier → done
# [185/1663] core-js → done
# [186/1663] sweetalert2 → done
# [187/1663] @babel/core → done
# [188/1663] @babel/preset-env → done
# [189/1663] autoprefixer → done
# [190/1663] babel-loader → done
# [191/1663] css-loader → done
# [192/1663] cssnano → done
# [193/1663] extract-loader → done
# [194/1663] file-loader → done
# [195/1663] mini-css-extract-plugin → done
# [196/1663] postcss → done
# [197/1663] postcss-loader → done
# [198/1663] sass → done
# [199/1663] sass-loader → done
# [200/1663] style-loader → done
# [201/1663] webpack-cli → done
# [202/1663] webpack-fix-style-only-entries → done
# [203/1663] autoprefixer → done
# [204/1663] css-loader → done
# [205/1663] postcss-clean → done
# [206/1663] autoprefixer → done
# [207/1663] css-loader → done
# [208/1663] cssnano → done
# [209/1663] postcss → done
# [210/1663] terser-webpack-plugin → done
# [211/1663] webpack → done
# [212/1663] sweetalert2 → done
# [213/1663] autoprefixer → done
# [214/1663] eslint → done
# [215/1663] mini-css-extract-plugin → done
# [216/1663] postcss-loader → done
# [217/1663] redoc-cli → done
# [218/1663] sass → done
# [219/1663] webpack → done
# [220/1663] webpack-cli → done
# [221/1663] d3 → done
# [222/1663] canvas-5-polyfill → done
# [223/1663] is-svg → done
# [224/1663] merge → done
# [225/1663] @babel/eslint-parser → done
# [226/1663] prettier → done
# [227/1663] lodash.range → done
# [228/1663] lodash.range → done
# [229/1663] @babel/core → done
# [230/1663] @babel/eslint-parser → done
# [231/1663] @babel/preset-env → done
# [232/1663] autoprefixer → done
# [233/1663] babel-loader → done
# [234/1663] css-loader → done
# [235/1663] cssnano → done
# [236/1663] mini-css-extract-plugin → done
# [237/1663] pkg-dir → done
# [238/1663] postcss-loader → done
# [239/1663] prettier → done
# [240/1663] sass → done
# [241/1663] sass-loader → done
# [242/1663] style-loader → done
# [243/1663] webpack → done
# [244/1663] webpack-cli → done
# [245/1663] webpack-remove-empty-scripts → done
# [246/1663] core-js → done
# [247/1663] element-closest-polyfill → done
# [248/1663] jquery → done
# [249/1663] simplebar → done
# [250/1663] whatwg-fetch → done
# [251/1663] eslint → done
# [252/1663] eslint-config-prettier → done
# [253/1663] eslint-plugin-compat → done
# [254/1663] eslint-plugin-prettier → done
# [255/1663] redoc → done
# [256/1663] redoc-cli → done
# [257/1663] sass → done
# [258/1663] core-js → done
# [259/1663] element-closest-polyfill → done
# [260/1663] whatwg-fetch → done
# [261/1663] eslint → done
# [262/1663] eslint-config-prettier → done
# [263/1663] eslint-plugin-compat → done
# [264/1663] eslint-plugin-prettier → done
# [265/1663] redoc → done
# [266/1663] redoc-cli → done
# [267/1663] sass → done
# [268/1663] core-js → done
# [269/1663] core-js → done
# [270/1663] jquery → done
# [271/1663] simplebar → done
# [272/1663] @babel/core → done
# [273/1663] @babel/eslint-parser → done
# [274/1663] @babel/preset-env → done
# [275/1663] autoprefixer → done
# [276/1663] babel-loader → done
# [277/1663] css-loader → done
# [278/1663] cssnano → done
# [279/1663] mini-css-extract-plugin → done
# [280/1663] postcss-loader → done
# [281/1663] prettier → done
# [282/1663] sass → done
# [283/1663] sass-loader → done
# [284/1663] style-loader → done
# [285/1663] webpack → done
# [286/1663] webpack-cli → done
# [287/1663] webpack-fix-style-only-entries → done
# [288/1663] core-js → done
# [289/1663] element-closest-polyfill → done
# [290/1663] jquery → done
# [291/1663] simplebar → done
# [292/1663] @babel/core → done
# [293/1663] @babel/eslint-parser → done
# [294/1663] @babel/preset-env → done
# [295/1663] autoprefixer → done
# [296/1663] babel-loader → done
# [297/1663] css-loader → done
# [298/1663] cssnano → done
# [299/1663] eslint → done
# [300/1663] eslint-config-prettier → done
# [301/1663] eslint-plugin-compat → done
# [302/1663] eslint-plugin-prettier → done
# [303/1663] mini-css-extract-plugin → done
# [304/1663] pkg-dir → done
# [305/1663] postcss-loader → done
# [306/1663] prettier → done
# [307/1663] redoc → done
# [308/1663] redoc-cli → done
# [309/1663] sass → done
# [310/1663] sass-loader → done
# [311/1663] style-loader → done
# [312/1663] webpack → done
# [313/1663] webpack-cli → done
# [314/1663] webpack-remove-empty-scripts → done
# [315/1663] @yaireo/tagify → done
# [316/1663] whatwg-fetch → done
# [317/1663] sweetalert2 → done
# [318/1663] d3 → done
# [319/1663] d3-flextree → done
# [320/1663] dc → done
# [321/1663] @babel/plugin-proposal-class-properties → done
# [322/1663] @babel/plugin-proposal-object-rest-spread → done
# [323/1663] @babel/preset-typescript → done
# [324/1663] @types/jquery → done
# [325/1663] typescript → done
# [326/1663] @types/jquery → done
# [327/1663] @types/node → done
# [328/1663] debug → done
# [329/1663] ms → done
# [330/1663] yargs-parser → done
# [331/1663] @typescript-eslint/parser → done
# [332/1663] typescript → done
# [333/1663] @typescript-eslint/eslint-plugin → done
# [334/1663] @zxcvbn-ts/core → done
# [335/1663] @zxcvbn-ts/language-common → done
# [336/1663] @zxcvbn-ts/language-en → done
# [337/1663] @types/select2 → done
# [338/1663] browserslist → done
# [339/1663] caniuse-lite → done
# [340/1663] canvas-5-polyfill → done
# [341/1663] @types/d3 → done
# [342/1663] @yaireo/tagify → done
# [343/1663] @types/lodash → done
# [344/1663] @types/yaireo__tagify → done
# [345/1663] npm-force-resolutions → done
# [346/1663] @types/lodash → done
# [347/1663] @types/yaireo__tagify → done
# [348/1663] @types/dc → done
# [349/1663] eslint-plugin-simple-import-sort → done
# [350/1663] @types/crossfilter → done
# [351/1663] @types/lodash.range → done
# [352/1663] @types/d3-hexbin → done
# [353/1663] eslint-plugin-license-header → done
# [354/1663] @types/d3-flextree → done
# [355/1663] @types/d3-sankey → done
# [356/1663] qrcode → done
# [357/1663] @types/qrcode → done
# [358/1663] @zxcvbn-ts/core → done
# [359/1663] @zxcvbn-ts/language-common → done
# [360/1663] @zxcvbn-ts/language-en → done
# [361/1663] @zxcvbn-ts/core → done
# [362/1663] @zxcvbn-ts/language-common → done
# [363/1663] @zxcvbn-ts/language-en → done
# [364/1663] @types/node → done
# [365/1663] vue-loader → done
# [366/1663] vue → done
# [367/1663] cryptography → done
# [368/1663] fastapi → done
# [369/1663] gunicorn → done
# [370/1663] python-dateutil → done
# [371/1663] python-multipart → done
# [372/1663] requests → done
# [373/1663] uvicorn → done
# [374/1663] pydantic → done
# [375/1663] lxml → done
# [376/1663] markdown → done
# [377/1663] pydantic → done
# [378/1663] semver → done
# [379/1663] vnu-jar → done
# [380/1663] npm-groovy-lint → done
# [381/1663] pydantic → done
# [382/1663] cryptography → done
# [383/1663] fastapi → done
# [384/1663] vue → done
# [385/1663] @rushstack/eslint-patch → done
# [386/1663] @tsconfig/node20 → done
# [387/1663] @types/node → done
# [388/1663] @vitejs/plugin-vue → done
# [389/1663] @vue/eslint-config-prettier → done
# [390/1663] @vue/eslint-config-typescript → done
# [391/1663] @vue/tsconfig → done
# [392/1663] eslint → done
# [393/1663] eslint-plugin-vue → done
# [394/1663] npm-run-all2 → done
# [395/1663] prettier → done
# [396/1663] typescript → done
# [397/1663] vite → done
# [398/1663] vue-tsc → done
# [399/1663] @jest/globals → done
# [400/1663] fake-indexeddb → done
# [401/1663] jest-cli → done
# [402/1663] jest-environment-jsdom → done
# [403/1663] mutation-observer → done
# [404/1663] ts-jest → done
# [405/1663] jquery → done
# [406/1663] crossfilter2 → done
# [407/1663] d3 → done
# [408/1663] core-js → done
# [409/1663] vue → done
# [410/1663] jquery → done
# [411/1663] crossfilter2 → done
# [412/1663] d3 → done
# [413/1663] core-js → done
# [414/1663] @rushstack/eslint-patch → done
# [415/1663] @tsconfig/node20 → done
# [416/1663] @types/node → done
# [417/1663] @vitejs/plugin-vue → done
# [418/1663] @vue/eslint-config-prettier → done
# [419/1663] @vue/eslint-config-typescript → done
# [420/1663] @vue/tsconfig → done
# [421/1663] eslint → done
# [422/1663] eslint-plugin-vue → done
# [423/1663] npm-run-all2 → done
# [424/1663] prettier → done
# [425/1663] typescript → done
# [426/1663] vite → done
# [427/1663] vue-tsc → done
# [428/1663] json-schema-to-typescript → done
# [429/1663] python-dateutil → done
# [430/1663] gunicorn → done
# [431/1663] @yaireo/tagify → done
# [432/1663] @zxcvbn-ts/core → done
# [433/1663] @zxcvbn-ts/language-common → done
# [434/1663] @zxcvbn-ts/language-en → done
# [435/1663] core-js → done
# [436/1663] crossfilter2 → done
# [437/1663] d3 → done
# [438/1663] d3-flextree → done
# [439/1663] d3-hexbin → done
# [440/1663] d3-sankey → done
# [441/1663] dc → done
# [442/1663] debug → done
# [443/1663] element-closest-polyfill → done
# [444/1663] jquery → done
# [445/1663] lodash.range → done
# [446/1663] ms → done
# [447/1663] qrcode → done
# [448/1663] select2 → done
# [449/1663] simplebar → done
# [450/1663] sweetalert2 → done
# [451/1663] vnu-jar → done
# [452/1663] yargs-parser → done
# [453/1663] @babel/core → done
# [454/1663] @babel/eslint-parser → done
# [455/1663] @babel/plugin-proposal-class-properties → done
# [456/1663] @babel/plugin-proposal-object-rest-spread → done
# [457/1663] @babel/preset-env → done
# [458/1663] @babel/preset-typescript → done
# [459/1663] @jest/globals → done
# [460/1663] @types/crossfilter → done
# [461/1663] @types/d3 → done
# [462/1663] @types/d3-flextree → done
# [463/1663] @types/d3-hexbin → done
# [464/1663] @types/d3-sankey → done
# [465/1663] @types/dc → done
# [466/1663] @types/jquery → done
# [467/1663] @types/lodash → done
# [468/1663] @types/lodash.range → done
# [469/1663] @types/node → done
# [470/1663] @types/qrcode → done
# [471/1663] @types/select2 → done
# [472/1663] @types/yaireo__tagify → done
# [473/1663] @typescript-eslint/eslint-plugin → done
# [474/1663] @typescript-eslint/parser → done
# [475/1663] autoprefixer → done
# [476/1663] babel-loader → done
# [477/1663] browserslist → done
# [478/1663] caniuse-lite → done
# [479/1663] copy-webpack-plugin → done
# [480/1663] css-loader → done
# [481/1663] cssnano → done
# [482/1663] eslint → done
# [483/1663] eslint-config-prettier → done
# [484/1663] eslint-plugin-compat → done
# [485/1663] eslint-plugin-license-header → done
# [486/1663] eslint-plugin-prettier → done
# [487/1663] eslint-plugin-simple-import-sort → done
# [488/1663] extract-loader → done
# [489/1663] fake-indexeddb → done
# [490/1663] file-loader → done
# [491/1663] jest-cli → done
# [492/1663] jest-environment-jsdom → done
# [493/1663] merge → done
# [494/1663] mini-css-extract-plugin → done
# [495/1663] mutation-observer → done
# [496/1663] npm-groovy-lint → done
# [497/1663] pkg-dir → done
# [498/1663] postcss → done
# [499/1663] postcss-loader → done
# [500/1663] prettier → done
# [501/1663] sass → done
# [502/1663] sass-loader → done
# [503/1663] script-loader → done
# [504/1663] style-loader → done
# [505/1663] terser-webpack-plugin → done
# [506/1663] ts-jest → done
# [507/1663] typescript → done
# [508/1663] webpack → done
# [509/1663] webpack-cli → done
# [510/1663] webpack-remove-empty-scripts → done
# [511/1663] @types/d3 → done
# [512/1663] @types/d3-hierarchy → done
# [513/1663] filemanager-webpack-plugin → done
# [514/1663] core-js → done
# [515/1663] crossfilter2 → done
# [516/1663] d3 → done
# [517/1663] jquery → done
# [518/1663] vue → done
# [519/1663] @rushstack/eslint-patch → done
# [520/1663] @tsconfig/node20 → done
# [521/1663] @types/node → done
# [522/1663] @vitejs/plugin-vue → done
# [523/1663] @vue/eslint-config-prettier → done
# [524/1663] @vue/eslint-config-typescript → done
# [525/1663] eslint → done
# [526/1663] eslint-plugin-vue → done
# [527/1663] npm-run-all2 → done
# [528/1663] prettier → done
# [529/1663] typescript → done
# [530/1663] vite → done
# [531/1663] vue-tsc → done
# [532/1663] @testing-library/vue → done
# [533/1663] chai → done
# [534/1663] jsdom → done
# [535/1663] vitest → done
# [536/1663] class-variance-authority → done
# [537/1663] radix-vue → done
# [538/1663] tailwind-merge → done
# [539/1663] tailwindcss-animate → done
# [540/1663] @zxcvbn-ts/core → done
# [541/1663] @zxcvbn-ts/language-common → done
# [542/1663] @zxcvbn-ts/language-en → done
# [543/1663] clsx → done
# [544/1663] lucide-vue-next → done
# [545/1663] radix-vue → done
# [546/1663] tailwind-merge → done
# [547/1663] opentelemetry-api → done
# [548/1663] opentelemetry-sdk → done
# [549/1663] opentelemetry-exporter-otlp → done
# [550/1663] opentelemetry-semantic-conventions → done
# [551/1663] eslint-import-resolver-typescript → done
# [552/1663] eslint-plugin-import → done
# [553/1663] eslint-plugin-no-unsanitized → done
# [554/1663] @zxcvbn-ts/core → done
# [555/1663] core-js → done
# [556/1663] crossfilter2 → done
# [557/1663] d3 → done
# [558/1663] element-closest-polyfill → done
# [559/1663] jquery → done
# [560/1663] lodash.set → done
# [561/1663] sweetalert2 → done
# [562/1663] @babel/core → done
# [563/1663] @babel/eslint-parser → done
# [564/1663] @babel/preset-env → done
# [565/1663] @babel/preset-typescript → done
# [566/1663] @types/d3 → done
# [567/1663] @types/d3-flextree → done
# [568/1663] @types/dc → done
# [569/1663] @types/jquery → done
# [570/1663] @types/lodash.range → done
# [571/1663] @types/lodash.set → done
# [572/1663] @types/qrcode → done
# [573/1663] @types/select2 → done
# [574/1663] autoprefixer → done
# [575/1663] browserslist → done
# [576/1663] caniuse-lite → done
# [577/1663] mini-css-extract-plugin → done
# [578/1663] npm-groovy-lint → done
# [579/1663] postcss → done
# [580/1663] sass → done
# [581/1663] terser-webpack-plugin → done
# [582/1663] ts-jest → done
# [583/1663] webpack → done
# [584/1663] pika → done
# [585/1663] types-pika-ts → done
# [586/1663] @yaireo/tagify → done
# [587/1663] @types/crossfilter → done
# [588/1663] @types/d3-hexbin → done
# [589/1663] @types/d3-sankey → done
# [590/1663] @types/node → done
# [591/1663] @types/yaireo__tagify → done
# [592/1663] caniuse-lite → done
# [593/1663] css-loader → done
# [594/1663] cssnano → done
# [595/1663] eslint-plugin-license-header → done
# [596/1663] fake-indexeddb → done
# [597/1663] pkg-dir → done
# [598/1663] postcss-loader → done
# [599/1663] opentelemetry-api → done
# [600/1663] axios → done
# [601/1663] pydantic → done
# [602/1663] pytest → done
# [603/1663] cryptography → done
# [604/1663] pytest → done
# [605/1663] bcrypt → done
# [606/1663] python-dateutil → done
# [607/1663] types-python-dateutil → done
# [608/1663] time-machine → done
# [609/1663] axios → done
# [610/1663] core-js → done
# [611/1663] lucide-vue-next → done
# [612/1663] radix-vue → done
# [613/1663] tailwind-merge → done
# [614/1663] vue → done
# [615/1663] @rushstack/eslint-patch → done
# [616/1663] @vitejs/plugin-vue → done
# [617/1663] eslint-plugin-vue → done
# [618/1663] jsdom → done
# [619/1663] npm-run-all2 → done
# [620/1663] prettier → done
# [621/1663] typescript → done
# [622/1663] vite → done
# [623/1663] vue-tsc → done
# [624/1663] pytest → done
# [625/1663] cryptography → done
# [626/1663] fastapi → done
# [627/1663] gunicorn → done
# [628/1663] python-dateutil → done
# [629/1663] python-multipart → done
# [630/1663] requests → done
# [631/1663] uvicorn → done
# [632/1663] prettier → done
# [633/1663] vitest-fail-on-console → done
# [634/1663] @testing-library/jest-dom → done
# [635/1663] vue → done
# [636/1663] pytest → done
# [637/1663] pytest → done
# [638/1663] GitPython → done
# [639/1663] sass-embedded → done
# [640/1663] vue-router → done
# [641/1663] radix-vue → done
# [642/1663] msw → done
# [643/1663] axios → done
# [644/1663] core-js → done
# [645/1663] lucide-vue-next → done
# [646/1663] tailwind-merge → done
# [647/1663] vue → done
# [648/1663] @vitejs/plugin-vue → done
# [649/1663] @vue/eslint-config-prettier → done
# [650/1663] @vue/eslint-config-typescript → done
# [651/1663] eslint → done
# [652/1663] eslint-plugin-vue → done
# [653/1663] jsdom → done
# [654/1663] npm-run-all2 → done
# [655/1663] sass-embedded → done
# [656/1663] typescript → done
# [657/1663] vite → done
# [658/1663] vitest → done
# [659/1663] vue-tsc → done
# [660/1663] lucide-vue-next → done
# [661/1663] radix-vue → done
# [662/1663] tailwind-merge → done
# [663/1663] @testing-library/jest-dom → done
# [664/1663] @types/node → done
# [665/1663] @vue/eslint-config-prettier → done
# [666/1663] @vue/eslint-config-typescript → done
# [667/1663] chai → done
# [668/1663] eslint → done
# [669/1663] eslint-plugin-vue → done
# [670/1663] msw → done
# [671/1663] npm-run-all2 → done
# [672/1663] sass-embedded → done
# [673/1663] vite → done
# [674/1663] vitest → done
# [675/1663] vue-tsc → done
# [676/1663] @yaireo/tagify → done
# [677/1663] core-js → done
# [678/1663] qrcode → done
# [679/1663] sweetalert2 → done
# [680/1663] @babel/core → done
# [681/1663] @babel/eslint-parser → done
# [682/1663] @babel/plugin-proposal-class-properties → done
# [683/1663] @babel/plugin-proposal-object-rest-spread → done
# [684/1663] @babel/preset-env → done
# [685/1663] @babel/preset-typescript → done
# [686/1663] @types/jquery → done
# [687/1663] @types/node → done
# [688/1663] @types/yaireo__tagify → done
# [689/1663] autoprefixer → done
# [690/1663] browserslist → done
# [691/1663] caniuse-lite → done
# [692/1663] cssnano → done
# [693/1663] eslint-import-resolver-typescript → done
# [694/1663] eslint-plugin-import → done
# [695/1663] eslint-plugin-no-unsanitized → done
# [696/1663] mini-css-extract-plugin → done
# [697/1663] postcss → done
# [698/1663] sass → done
# [699/1663] ts-jest → done
# [700/1663] webpack → done
# [701/1663] vnu-jar → done
# [702/1663] semgrep → done
# [703/1663] lucide-vue-next → done
# [704/1663] radix-vue → done
# [705/1663] @testing-library/jest-dom → done
# [706/1663] @types/node → done
# [707/1663] @vitejs/plugin-vue → done
# [708/1663] @vue/tsconfig → done
# [709/1663] eslint → done
# [710/1663] eslint-plugin-vue → done
# [711/1663] msw → done
# [712/1663] sass-embedded → done
# [713/1663] typescript → done
# [714/1663] vite → done
# [715/1663] vitest → done
# [716/1663] vue-tsc → done
# [717/1663] core-js → done
# [718/1663] @testing-library/user-event → done
# [719/1663] sanitize-html → done
# [720/1663] @types/sanitize-html → done
# [721/1663] @yaireo/tagify → done
# [722/1663] core-js → done
# [723/1663] simplebar → done
# [724/1663] sweetalert2 → done
# [725/1663] @types/node → done
# [726/1663] @typescript-eslint/eslint-plugin → done
# [727/1663] @typescript-eslint/parser → done
# [728/1663] babel-loader → done
# [729/1663] caniuse-lite → done
# [730/1663] eslint → done
# [731/1663] eslint-config-prettier → done
# [732/1663] eslint-import-resolver-typescript → done
# [733/1663] eslint-plugin-compat → done
# [734/1663] eslint-plugin-prettier → done
# [735/1663] eslint-plugin-simple-import-sort → done
# [736/1663] mini-css-extract-plugin → done
# [737/1663] npm-groovy-lint → done
# [738/1663] postcss → done
# [739/1663] prettier → done
# [740/1663] sass → done
# [741/1663] sass-loader → done
# [742/1663] style-loader → done
# [743/1663] typescript → done
# [744/1663] webpack → done
# [745/1663] webpack-cli → done
# [746/1663] webpack-remove-empty-scripts → done
# [747/1663] sass → done
# [748/1663] sass-loader → done
# [749/1663] npm-groovy-lint → done
# [750/1663] sass → done
# [751/1663] sass-loader → done
# ❌ Failed to fetch data for cmk-shared-typing (npm): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/npm/packages/cmk-shared-typing
# [752/1663] cmk-shared-typing → done
# [753/1663] axios → done
# [754/1663] class-variance-authority → done
# [755/1663] lucide-vue-next → done
# [756/1663] radix-vue → done
# [757/1663] sanitize-html → done
# [758/1663] vue → done
# [759/1663] vue-router → done
# [760/1663] @rushstack/eslint-patch → done
# [761/1663] @types/node → done
# [762/1663] @vitejs/plugin-vue → done
# [763/1663] @vue/eslint-config-typescript → done
# [764/1663] @vue/tsconfig → done
# [765/1663] eslint → done
# [766/1663] eslint-plugin-vue → done
# [767/1663] msw → done
# [768/1663] npm-run-all2 → done
# [769/1663] prettier → done
# [770/1663] sass-embedded → done
# [771/1663] typescript → done
# [772/1663] vite → done
# [773/1663] vitest → done
# [774/1663] vue-tsc → done
# [775/1663] sphinx → done
# [776/1663] sphinx-autodoc-typehints → done
# [777/1663] sphinx-rtd-theme → done
# [778/1663] checkmk-dev-tools → done
# [779/1663] python-dateutil → done
# [780/1663] checkmk-dev-tools → done
# [781/1663] checkmk-dev-tools → done
# [782/1663] checkmk-dev-tools → done
# [783/1663] checkmk-dev-tools → done
# [784/1663] 3to2 → done
# [785/1663] aiohappyeyeballs → done
# [786/1663] aiohttp → done
# [787/1663] aiosignal → done
# [788/1663] alabaster → done
# [789/1663] annotated-types → done
# [790/1663] anyio → done
# [791/1663] apispec → done
# [792/1663] apispec-oneofschema → done
# [793/1663] argcomplete → done
# [794/1663] arrow → done
# [795/1663] asgiref → done
# [796/1663] astroid → done
# [797/1663] attrs → done
# [798/1663] autoflake → done
# [799/1663] azure-common → done
# [800/1663] azure-core → done
# [801/1663] azure-identity → done
# [802/1663] azure-mgmt-compute → done
# [803/1663] azure-mgmt-core → done
# [804/1663] azure-mgmt-resource → done
# [805/1663] azure-storage-blob → done
# [806/1663] babel → done
# [807/1663] backoff → done
# [808/1663] bandit → done
# [809/1663] bcrypt → done
# [810/1663] beautifulsoup4 → done
# [811/1663] black → done
# [812/1663] blinker → done
# [813/1663] boto3 → done
# ❌ Failed to fetch data for boto3-stubs[logs] (pypi): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/pypi/packages/boto3-stubs%5Blogs%5D
# [814/1663] boto3-stubs[logs] → done
# [815/1663] botocore → done
# [816/1663] botocore-stubs → done
# [817/1663] bson → done
# [818/1663] build → done
# [819/1663] cached-property → done
# [820/1663] cachetools → done
# [821/1663] certifi → done
# [822/1663] cffi → done
# [823/1663] cfgv → done
# [824/1663] chardet → done
# [825/1663] charset-normalizer → done
# [826/1663] check-manifest → done
# [827/1663] checkmk-dev-tools → done
# [828/1663] click → done
# [829/1663] colorama → done
# [830/1663] cryptography → done
# [831/1663] cssselect → done
# [832/1663] cssselect2 → done
# [833/1663] cython → done
# [834/1663] datamodel-code-generator → done
# [835/1663] decorator → done
# [836/1663] defusedxml → done
# [837/1663] deprecated → done
# [838/1663] devpi-client → done
# [839/1663] devpi-common → done
# [840/1663] dill → done
# [841/1663] distlib → done
# [842/1663] dnspython → done
# [843/1663] docker → done
# [844/1663] dockerpty → done
# [845/1663] docstring-parser → done
# [846/1663] docstring-to-markdown → done
# [847/1663] docutils → done
# [848/1663] elementpath → done
# [849/1663] email-validator → done
# [850/1663] exchangelib → done
# [851/1663] execnet → done
# [852/1663] faker → done
# ❌ Failed to fetch data for fakeredis[lua] (pypi): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/pypi/packages/fakeredis%5Blua%5D
# [853/1663] fakeredis[lua] → done
# [854/1663] fastapi → done
# [855/1663] feedparser → done
# [856/1663] fido2 → done
# [857/1663] filelock → done
# [858/1663] flask → done
# [859/1663] fqdn → done
# [860/1663] frozenlist → done
# [861/1663] furo → done
# [862/1663] genson → done
# [863/1663] gevent → done
# [864/1663] gitdb → done
# [865/1663] gitpython → done
# ❌ Failed to fetch data for google-api-core[grpc] (pypi): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/pypi/packages/google-api-core%5Bgrpc%5D
# [866/1663] google-api-core[grpc] → done
# [867/1663] google-api-python-client → done
# [868/1663] google-auth → done
# [869/1663] google-auth-httplib2 → done
# [870/1663] google-cloud-access-context-manager → done
# [871/1663] google-cloud-asset → done
# [872/1663] google-cloud-monitoring → done
# [873/1663] google-cloud-org-policy → done
# [874/1663] google-cloud-os-config → done
# ❌ Failed to fetch data for googleapis-common-protos[grpc] (pypi): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/pypi/packages/googleapis-common-protos%5Bgrpc%5D
# [875/1663] googleapis-common-protos[grpc] → done
# [876/1663] graphql-core → done
# [877/1663] graphviz → done
# [878/1663] greenlet → done
# [879/1663] grequests → done
# [880/1663] grpc-google-iam-v1 → done
# [881/1663] grpcio → done
# [882/1663] grpcio-status → done
# [883/1663] gunicorn → done
# [884/1663] h11 → done
# [885/1663] harfile → done
# [886/1663] httpcore → done
# [887/1663] httplib2 → done
# [888/1663] httpx → done
# [889/1663] hypothesis → done
# [890/1663] hypothesis-graphql → done
# [891/1663] hypothesis-jsonschema → done
# [892/1663] icalendar → done
# [893/1663] id → done
# [894/1663] identify → done
# [895/1663] idna → done
# [896/1663] imagesize → done
# [897/1663] importlib-metadata → done
# [898/1663] inflect → done
# [899/1663] iniconfig → done
# [900/1663] isodate → done
# [901/1663] isoduration → done
# [902/1663] isort → done
# [903/1663] itsdangerous → done
# [904/1663] jaraco-classes → done
# [905/1663] jaraco-context → done
# [906/1663] jaraco-functools → done
# [907/1663] jedi → done
# [908/1663] jeepney → done
# [909/1663] jinja2 → done
# [910/1663] jira → done
# [911/1663] jmespath → done
# [912/1663] jsonpatch → done
# [913/1663] jsonpath-rw → done
# [914/1663] jsonpointer → done
# ❌ Failed to fetch data for jsonschema[format] (pypi): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/pypi/packages/jsonschema%5Bformat%5D
# [915/1663] jsonschema[format] → done
# [916/1663] jsonschema-path → done
# [917/1663] jsonschema-specifications → done
# [918/1663] junit-xml → done
# [919/1663] keyring → done
# [920/1663] kubernetes → done
# [921/1663] lazy → done
# [922/1663] lazy-object-proxy → done
# [923/1663] libcst → done
# [924/1663] lupa → done
# [925/1663] lxml → done
# [926/1663] markdown → done
# [927/1663] markdown-it-py → done
# [928/1663] markupsafe → done
# [929/1663] marshmallow → done
# [930/1663] marshmallow-oneofschema → done
# [931/1663] mccabe → done
# [932/1663] mdurl → done
# [933/1663] meraki → done
# [934/1663] more-itertools → done
# [935/1663] msal → done
# [936/1663] msal-extensions → done
# [937/1663] msrest → done
# [938/1663] multi-key-dict → done
# [939/1663] multidict → done
# [940/1663] multipart → done
# [941/1663] mypy → done
# [942/1663] mypy-boto3-logs → done
# [943/1663] mypy-extensions → done
# [944/1663] mypy-protobuf → done
# [945/1663] netapp-ontap → done
# [946/1663] networkx → done
# [947/1663] nh3 → done
# [948/1663] nodeenv → done
# [949/1663] numpy → done
# [950/1663] oauthlib → done
# [951/1663] openapi-schema-validator → done
# [952/1663] openapi-spec-validator → done
# [953/1663] opentelemetry-api → done
# [954/1663] opentelemetry-container-distro → done
# [955/1663] opentelemetry-exporter-otlp → done
# [956/1663] opentelemetry-exporter-otlp-proto-common → done
# [957/1663] opentelemetry-exporter-otlp-proto-grpc → done
# [958/1663] opentelemetry-exporter-otlp-proto-http → done
# [959/1663] opentelemetry-instrumentation → done
# [960/1663] opentelemetry-instrumentation-asgi → done
# [961/1663] opentelemetry-instrumentation-fastapi → done
# [962/1663] opentelemetry-instrumentation-redis → done
# [963/1663] opentelemetry-instrumentation-requests → done
# [964/1663] opentelemetry-instrumentation-wsgi → done
# [965/1663] opentelemetry-proto → done
# [966/1663] opentelemetry-resourcedetector-docker → done
# [967/1663] opentelemetry-resourcedetector-kubernetes → done
# [968/1663] opentelemetry-resourcedetector-process → done
# [969/1663] opentelemetry-sdk → done
# [970/1663] opentelemetry-semantic-conventions → done
# [971/1663] opentelemetry-util-http → done
# [972/1663] opsgenie-sdk → done
# [973/1663] oracledb → done
# [974/1663] packaging → done
# [975/1663] packaging-legacy → done
# [976/1663] paho-mqtt → done
# [977/1663] paramiko → done
# [978/1663] parso → done
# [979/1663] pathable → done
# [980/1663] pathspec → done
# [981/1663] pbr → done
# [982/1663] pexpect → done
# [983/1663] pika → done
# [984/1663] pillow → done
# [985/1663] pipfile → done
# [986/1663] pkginfo → done
# [987/1663] platformdirs → done
# [988/1663] playwright → done
# [989/1663] pluggy → done
# [990/1663] ply → done
# [991/1663] polyfactory → done
# [992/1663] portalocker → done
# [993/1663] pre-commit → done
# [994/1663] propcache → done
# [995/1663] proto-plus → done
# [996/1663] protobuf → done
# [997/1663] psutil → done
# [998/1663] psycopg2-binary → done
# [999/1663] ptyprocess → done
# [1000/1663] py-import-cycles → done
# [1001/1663] pyasn1 → done
# [1002/1663] pyasn1-modules → done
# [1003/1663] pycparser → done
# [1004/1663] pydantic → done
# ❌ Failed to fetch data for pydantic[email] (pypi): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/pypi/packages/pydantic%5Bemail%5D
# [1005/1663] pydantic[email] → done
# [1006/1663] pydantic-core → done
# [1007/1663] pyee → done
# [1008/1663] pyenchant → done
# [1009/1663] pyflakes → done
# [1010/1663] pyghmi → done
# [1011/1663] pygments → done
# ❌ Failed to fetch data for pyjwt[crypto] (pypi): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/pypi/packages/pyjwt%5Bcrypto%5D
# [1012/1663] pyjwt[crypto] → done
# [1013/1663] pylint → done
# [1014/1663] pylint-plugin-utils → done
# [1015/1663] pylint-pydantic → done
# [1016/1663] pylsp-mypy → done
# [1017/1663] pymongo → done
# [1018/1663] pymssql → done
# [1019/1663] pymysql → done
# [1020/1663] pynacl → done
# [1021/1663] pyopenssl → done
# [1022/1663] pyparsing → done
# [1023/1663] pypdf → done
# [1024/1663] pyprof2calltree → done
# [1025/1663] pyproject-hooks → done
# [1026/1663] pyrate-limiter → done
# [1027/1663] pysaml2 → done
# [1028/1663] pysmb → done
# [1029/1663] pysmi-lextudio → done
# [1030/1663] pysnmp-lextudio → done
# [1031/1663] pysnmpcrypto → done
# [1032/1663] pyspnego → done
# [1033/1663] pytest → done
# [1034/1663] pytest-asyncio → done
# [1035/1663] pytest-check → done
# [1036/1663] pytest-html → done
# [1037/1663] pytest-metadata → done
# [1038/1663] pytest-mock → done
# [1039/1663] pytest-opentelemetry → done
# [1040/1663] pytest-random-order → done
# [1041/1663] pytest-subtests → done
# [1042/1663] pytest-xdist → done
# [1043/1663] python-active-directory → done
# [1044/1663] python-dateutil → done
# [1045/1663] python-jenkins → done
# [1046/1663] python-ldap → done
# [1047/1663] python-lsp-jsonrpc → done
# [1048/1663] python-lsp-server → done
# [1049/1663] python-multipart → done
# [1050/1663] python-snap7 → done
# [1051/1663] pytz → done
# [1052/1663] pyyaml → done
# [1053/1663] readme-renderer → done
# [1054/1663] recurring-ical-events → done
# [1055/1663] redfish → done
# [1056/1663] redis → done
# [1057/1663] referencing → done
# [1058/1663] reportlab → done
# [1059/1663] requests → done
# [1060/1663] requests-ntlm → done
# [1061/1663] requests-oauthlib → done
# [1062/1663] requests-toolbelt → done
# [1063/1663] requests-unixsocket → done
# [1064/1663] requirements-parser → done
# [1065/1663] responses → done
# [1066/1663] rfc3339-validator → done
# [1067/1663] rfc3986 → done
# [1068/1663] rfc3987 → done
# [1069/1663] rich → done
# [1070/1663] robotframework → done
# [1071/1663] roman → done
# [1072/1663] rpds-py → done
# [1073/1663] rsa → done
# [1074/1663] ruff → done
# [1075/1663] s3transfer → done
# [1076/1663] schemathesis → done
# [1077/1663] secretstorage → done
# [1078/1663] semver → done
# [1079/1663] setproctitle → done
# [1080/1663] setuptools → done
# [1081/1663] setuptools-scm → done
# [1082/1663] sgmllib3k → done
# [1083/1663] simplejson → done
# [1084/1663] six → done
# [1085/1663] smmap → done
# [1086/1663] sniffio → done
# [1087/1663] snmpsim-lextudio → done
# [1088/1663] snowballstemmer → done
# [1089/1663] sortedcontainers → done
# [1090/1663] soupsieve → done
# [1091/1663] sphinx → done
# [1092/1663] sphinx-autoapi → done
# [1093/1663] sphinx-autodoc-typehints → done
# [1094/1663] sphinx-basic-ng → done
# [1095/1663] sphinx-rtd-theme → done
# [1096/1663] sphinxcontrib-applehelp → done
# [1097/1663] sphinxcontrib-devhelp → done
# [1098/1663] sphinxcontrib-htmlhelp → done
# [1099/1663] sphinxcontrib-jquery → done
# [1100/1663] sphinxcontrib-jsmath → done
# [1101/1663] sphinxcontrib-plantuml → done
# [1102/1663] sphinxcontrib-qthelp → done
# [1103/1663] sphinxcontrib-serializinghtml → done
# [1104/1663] sphinxcontrib-spelling → done
# [1105/1663] starlette → done
# [1106/1663] starlette-testclient → done
# [1107/1663] stevedore → done
# [1108/1663] svglib → done
# [1109/1663] telnetlib3 → done
# [1110/1663] tenacity → done
# [1111/1663] time-machine → done
# [1112/1663] tinycss2 → done
# [1113/1663] toml → done
# [1114/1663] tomli → done
# [1115/1663] tomli-w → done
# [1116/1663] tomlkit → done
# [1117/1663] tqdm → done
# [1118/1663] trickkiste → done
# [1119/1663] twine → done
# [1120/1663] types-awscrt → done
# [1121/1663] types-beautifulsoup4 → done
# [1122/1663] types-cffi → done
# [1123/1663] types-docutils → done
# [1124/1663] types-html5lib → done
# [1125/1663] types-jsonschema → done
# [1126/1663] types-lxml → done
# [1127/1663] types-markdown → done
# [1128/1663] types-mypy-extensions → done
# [1129/1663] types-oauthlib → done
# [1130/1663] types-paho-mqtt → done
# [1131/1663] types-paramiko → done
# [1132/1663] types-pika-ts → done
# [1133/1663] types-pillow → done
# [1134/1663] types-protobuf → done
# [1135/1663] types-psutil → done
# [1136/1663] types-pyasn1 → done
# [1137/1663] types-pymssql → done
# [1138/1663] types-pymysql → done
# [1139/1663] types-pyopenssl → done
# [1140/1663] types-pysaml2 → done
# [1141/1663] types-python-dateutil → done
# [1142/1663] types-pyyaml → done
# [1143/1663] types-redis → done
# [1144/1663] types-requests → done
# [1145/1663] types-s3transfer → done
# [1146/1663] types-setuptools → done
# [1147/1663] types-simplejson → done
# [1148/1663] types-urllib3 → done
# [1149/1663] typing-extensions → done
# [1150/1663] tzdata → done
# [1151/1663] tzlocal → done
# [1152/1663] ujson → done
# [1153/1663] uri-template → done
# [1154/1663] uritemplate → done
# [1155/1663] urllib3 → done
# [1156/1663] uvicorn → done
# [1157/1663] uvicorn-worker → done
# [1158/1663] vcrpy → done
# [1159/1663] virtualenv → done
# [1160/1663] watchdog → done
# [1161/1663] webcolors → done
# [1162/1663] webencodings → done
# [1163/1663] websocket-client → done
# [1164/1663] werkzeug → done
# [1165/1663] wrapt → done
# [1166/1663] x-wr-timezone → done
# [1167/1663] xmlschema → done
# [1168/1663] yarl → done
# [1169/1663] zipp → done
# [1170/1663] zope-event → done
# [1171/1663] zope-interface → done
# [1172/1663] aiohappyeyeballs → done
# [1173/1663] aiohttp → done
# [1174/1663] alabaster → done
# [1175/1663] argcomplete → done
# [1176/1663] astroid → done
# [1177/1663] azure-identity → done
# [1178/1663] azure-mgmt-resource → done
# [1179/1663] azure-storage-blob → done
# [1180/1663] bcrypt → done
# [1181/1663] boto3 → done
# [1182/1663] boto3-stubs[logs] → done
# [1183/1663] botocore → done
# [1184/1663] botocore-stubs → done
# [1185/1663] cachetools → done
# [1186/1663] checkmk-dev-tools → done
# ❌ Failed to fetch data for coverage[toml] (pypi): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/pypi/packages/coverage%5Btoml%5D
# [1187/1663] coverage[toml] → done
# [1188/1663] cryptography → done
# [1189/1663] cssselect → done
# [1190/1663] cssselect2 → done
# [1191/1663] decorator → done
# [1192/1663] docutils → done
# [1193/1663] durationpy → done
# [1194/1663] elementpath → done
# [1195/1663] exchangelib → done
# [1196/1663] faker → done
# [1197/1663] fastapi → done
# [1198/1663] flask → done
# [1199/1663] google-api-core[grpc] → done
# [1200/1663] google-api-python-client → done
# [1201/1663] google-cloud-asset → done
# [1202/1663] googleapis-common-protos[grpc] → done
# [1203/1663] grpc-google-iam-v1 → done
# [1204/1663] grpcio → done
# [1205/1663] grpcio-status → done
# [1206/1663] hypothesis → done
# [1207/1663] icalendar → done
# [1208/1663] identify → done
# [1209/1663] jeepney → done
# [1210/1663] jinja2 → done
# [1211/1663] kubernetes → done
# [1212/1663] lxml → done
# [1213/1663] meraki → done
# [1214/1663] msal → done
# [1215/1663] msal-extensions → done
# [1216/1663] mypy-boto3-logs → done
# [1217/1663] netapp-ontap → done
# [1218/1663] nh3 → done
# [1219/1663] numpy → done
# [1220/1663] oracledb → done
# [1221/1663] paho-mqtt → done
# [1222/1663] propcache → done
# [1223/1663] proto-plus → done
# [1224/1663] psutil → done
# [1225/1663] psycopg2-binary → done
# [1226/1663] pyasn1 → done
# [1227/1663] pyghmi → done
# [1228/1663] pylint → done
# [1229/1663] pymssql → done
# [1230/1663] pypdf → done
# [1231/1663] pysmb → done
# [1232/1663] pysnmp-lextudio → done
# [1233/1663] pytest → done
# [1234/1663] pytest-cov → done
# [1235/1663] python-ldap → done
# [1236/1663] python-snap7 → done
# [1237/1663] pyyaml → done
# [1238/1663] readme-renderer → done
# [1239/1663] recurring-ical-events → done
# [1240/1663] redfish → done
# [1241/1663] redis → done
# [1242/1663] reportlab → done
# [1243/1663] requests-oauthlib → done
# [1244/1663] requests-unixsocket → done
# [1245/1663] responses → done
# [1246/1663] roman → done
# [1247/1663] roman-numerals-py → done
# [1248/1663] rpds-py → done
# [1249/1663] s3transfer → done
# [1250/1663] schemathesis → done
# [1251/1663] setproctitle → done
# [1252/1663] setuptools-scm → done
# [1253/1663] snmpsim-lextudio → done
# [1254/1663] sphinx → done
# [1255/1663] sphinx-autodoc-typehints → done
# [1256/1663] sphinx-rtd-theme → done
# [1257/1663] starlette → done
# [1258/1663] stevedore → done
# [1259/1663] types-awscrt → done
# [1260/1663] types-cffi → done
# [1261/1663] types-lxml → done
# [1262/1663] types-requests → done
# [1263/1663] types-s3transfer → done
# [1264/1663] types-setuptools → done
# [1265/1663] tzlocal → done
# [1266/1663] virtualenv → done
# [1267/1663] x-wr-timezone → done
# [1268/1663] aiohappyeyeballs → done
# [1269/1663] aiohttp → done
# [1270/1663] alabaster → done
# [1271/1663] argcomplete → done
# [1272/1663] astroid → done
# [1273/1663] azure-identity → done
# [1274/1663] azure-mgmt-resource → done
# [1275/1663] azure-storage-blob → done
# [1276/1663] bcrypt → done
# [1277/1663] boto3 → done
# [1278/1663] boto3-stubs[logs] → done
# [1279/1663] botocore → done
# [1280/1663] botocore-stubs → done
# [1281/1663] cachetools → done
# [1282/1663] checkmk-dev-tools → done
# [1283/1663] cryptography → done
# [1284/1663] cssselect → done
# [1285/1663] cssselect2 → done
# [1286/1663] decorator → done
# [1287/1663] docutils → done
# [1288/1663] elementpath → done
# [1289/1663] exchangelib → done
# [1290/1663] faker → done
# [1291/1663] fastapi → done
# [1292/1663] flask → done
# [1293/1663] google-api-core[grpc] → done
# [1294/1663] google-api-python-client → done
# [1295/1663] google-cloud-asset → done
# [1296/1663] googleapis-common-protos[grpc] → done
# [1297/1663] grpc-google-iam-v1 → done
# [1298/1663] grpcio → done
# [1299/1663] grpcio-status → done
# [1300/1663] hypothesis → done
# [1301/1663] icalendar → done
# [1302/1663] identify → done
# [1303/1663] jeepney → done
# [1304/1663] jinja2 → done
# [1305/1663] kubernetes → done
# [1306/1663] lxml → done
# [1307/1663] meraki → done
# [1308/1663] msal → done
# [1309/1663] msal-extensions → done
# [1310/1663] mypy-boto3-logs → done
# [1311/1663] netapp-ontap → done
# [1312/1663] nh3 → done
# [1313/1663] numpy → done
# [1314/1663] oracledb → done
# [1315/1663] paho-mqtt → done
# [1316/1663] propcache → done
# [1317/1663] proto-plus → done
# [1318/1663] psutil → done
# [1319/1663] psycopg2-binary → done
# [1320/1663] pyasn1 → done
# [1321/1663] pyghmi → done
# [1322/1663] pylint → done
# [1323/1663] pymssql → done
# [1324/1663] pypdf → done
# [1325/1663] pysmb → done
# [1326/1663] pysnmp-lextudio → done
# [1327/1663] pytest → done
# [1328/1663] python-ldap → done
# [1329/1663] python-snap7 → done
# [1330/1663] pyyaml → done
# [1331/1663] readme-renderer → done
# [1332/1663] recurring-ical-events → done
# [1333/1663] redfish → done
# [1334/1663] redis → done
# [1335/1663] reportlab → done
# [1336/1663] requests-oauthlib → done
# [1337/1663] requests-unixsocket → done
# [1338/1663] responses → done
# [1339/1663] roman → done
# [1340/1663] rpds-py → done
# [1341/1663] s3transfer → done
# [1342/1663] schemathesis → done
# [1343/1663] setproctitle → done
# [1344/1663] setuptools-scm → done
# [1345/1663] snmpsim-lextudio → done
# [1346/1663] sphinx → done
# [1347/1663] sphinx-autodoc-typehints → done
# [1348/1663] sphinx-rtd-theme → done
# [1349/1663] starlette → done
# [1350/1663] stevedore → done
# [1351/1663] types-awscrt → done
# [1352/1663] types-cffi → done
# [1353/1663] types-lxml → done
# [1354/1663] types-requests → done
# [1355/1663] types-s3transfer → done
# [1356/1663] types-setuptools → done
# [1357/1663] tzlocal → done
# [1358/1663] virtualenv → done
# [1359/1663] x-wr-timezone → done
# [1360/1663] pytest-repeat → done
# [1361/1663] semgrep → done
# [1362/1663] aiohappyeyeballs → done
# [1363/1663] aiohttp → done
# [1364/1663] alabaster → done
# [1365/1663] anyio → done
# [1366/1663] argcomplete → done
# [1367/1663] astroid → done
# [1368/1663] attrs → done
# [1369/1663] azure-identity → done
# [1370/1663] azure-mgmt-compute → done
# [1371/1663] azure-mgmt-resource → done
# [1372/1663] azure-storage-blob → done
# [1373/1663] bcrypt → done
# [1374/1663] boto3 → done
# [1375/1663] boto3-stubs[logs] → done
# [1376/1663] botocore → done
# [1377/1663] botocore-stubs → done
# [1378/1663] cachetools → done
# [1379/1663] checkmk-dev-tools → done
# [1380/1663] cryptography → done
# [1381/1663] cssselect → done
# [1382/1663] cssselect2 → done
# [1383/1663] decorator → done
# [1384/1663] docutils → done
# [1385/1663] durationpy → done
# [1386/1663] elementpath → done
# [1387/1663] exchangelib → done
# [1388/1663] faker → done
# [1389/1663] fastapi → done
# [1390/1663] filelock → done
# [1391/1663] flask → done
# [1392/1663] google-api-core[grpc] → done
# [1393/1663] google-api-python-client → done
# [1394/1663] google-cloud-access-context-manager → done
# [1395/1663] google-cloud-asset → done
# [1396/1663] google-cloud-monitoring → done
# [1397/1663] google-cloud-org-policy → done
# [1398/1663] google-cloud-os-config → done
# [1399/1663] googleapis-common-protos[grpc] → done
# [1400/1663] grpc-google-iam-v1 → done
# [1401/1663] grpcio → done
# [1402/1663] grpcio-status → done
# [1403/1663] hypothesis → done
# [1404/1663] icalendar → done
# [1405/1663] identify → done
# [1406/1663] importlib-metadata → done
# [1407/1663] iniconfig → done
# [1408/1663] jeepney → done
# [1409/1663] jinja2 → done
# [1410/1663] kubernetes → done
# [1411/1663] libcst → done
# [1412/1663] lxml → done
# [1413/1663] meraki → done
# [1414/1663] msal → done
# [1415/1663] msal-extensions → done
# [1416/1663] multidict → done
# [1417/1663] mypy-boto3-logs → done
# [1418/1663] netapp-ontap → done
# [1419/1663] nh3 → done
# [1420/1663] numpy → done
# [1421/1663] opentelemetry-api → done
# [1422/1663] opentelemetry-exporter-otlp → done
# [1423/1663] opentelemetry-exporter-otlp-proto-common → done
# [1424/1663] opentelemetry-exporter-otlp-proto-grpc → done
# [1425/1663] opentelemetry-exporter-otlp-proto-http → done
# [1426/1663] opentelemetry-instrumentation → done
# [1427/1663] opentelemetry-instrumentation-asgi → done
# [1428/1663] opentelemetry-instrumentation-fastapi → done
# [1429/1663] opentelemetry-instrumentation-redis → done
# [1430/1663] opentelemetry-instrumentation-requests → done
# [1431/1663] opentelemetry-instrumentation-wsgi → done
# [1432/1663] opentelemetry-proto → done
# [1433/1663] opentelemetry-sdk → done
# [1434/1663] opentelemetry-semantic-conventions → done
# [1435/1663] opentelemetry-util-http → done
# [1436/1663] oracledb → done
# [1437/1663] paho-mqtt → done
# [1438/1663] platformdirs → done
# [1439/1663] playwright → done
# [1440/1663] polyfactory → done
# [1441/1663] pre-commit → done
# [1442/1663] propcache → done
# [1443/1663] proto-plus → done
# [1444/1663] psutil → done
# [1445/1663] psycopg2-binary → done
# [1446/1663] pyghmi → done
# [1447/1663] pylint → done
# [1448/1663] pymssql → done
# [1449/1663] pyparsing → done
# [1450/1663] pypdf → done
# [1451/1663] pysmb → done
# [1452/1663] pytest → done
# [1453/1663] pytest-asyncio → done
# [1454/1663] pytest-check → done
# [1455/1663] python-ldap → done
# [1456/1663] python-snap7 → done
# [1457/1663] pytz → done
# [1458/1663] pyyaml → done
# [1459/1663] readme-renderer → done
# [1460/1663] recurring-ical-events → done
# [1461/1663] redfish → done
# [1462/1663] redis → done
# [1463/1663] reportlab → done
# [1464/1663] requests-oauthlib → done
# [1465/1663] requests-unixsocket → done
# [1466/1663] responses → done
# [1467/1663] roman → done
# [1468/1663] roman-numerals-py → done
# [1469/1663] rpds-py → done
# [1470/1663] s3transfer → done
# [1471/1663] schemathesis → done
# [1472/1663] setproctitle → done
# [1473/1663] setuptools-scm → done
# [1474/1663] sphinx → done
# [1475/1663] sphinx-autodoc-typehints → done
# [1476/1663] sphinx-rtd-theme → done
# [1477/1663] starlette → done
# [1478/1663] stevedore → done
# [1479/1663] types-awscrt → done
# [1480/1663] types-cffi → done
# [1481/1663] types-lxml → done
# [1482/1663] types-markdown → done
# [1483/1663] types-protobuf → done
# [1484/1663] types-requests → done
# [1485/1663] types-s3transfer → done
# [1486/1663] types-setuptools → done
# [1487/1663] types-simplejson → done
# [1488/1663] tzdata → done
# [1489/1663] tzlocal → done
# [1490/1663] virtualenv → done
# [1491/1663] wheel → done
# [1492/1663] x-wr-timezone → done
# [1493/1663] checkmk-dev-tools → done
# [1494/1663] aiohttp → done
# [1495/1663] argcomplete → done
# [1496/1663] azure-storage-blob → done
# [1497/1663] boto3 → done
# [1498/1663] boto3-stubs[logs] → done
# [1499/1663] botocore → done
# [1500/1663] botocore-stubs → done
# [1501/1663] checkmk-dev-tools → done
# [1502/1663] docstring-to-markdown → done
# [1503/1663] fakeredis[lua] → done
# [1504/1663] google-api-python-client → done
# [1505/1663] hypothesis → done
# [1506/1663] icalendar → done
# [1507/1663] propcache → done
# [1508/1663] pymssql → done
# [1509/1663] pytest-check → done
# [1510/1663] redfish → done
# [1511/1663] rich → done
# [1512/1663] rpds-py → done
# [1513/1663] tenacity → done
# [1514/1663] types-awscrt → done
# [1515/1663] types-cffi → done
# [1516/1663] types-lxml → done
# [1517/1663] types-mypy-extensions → done
# [1518/1663] types-oauthlib → done
# [1519/1663] types-pika-ts → done
# [1520/1663] types-protobuf → done
# [1521/1663] types-psutil → done
# [1522/1663] types-pyyaml → done
# [1523/1663] types-requests → done
# [1524/1663] types-setuptools → done
# [1525/1663] types-simplejson → done
# [1526/1663] typing-extensions → done
# [1527/1663] virtualenv → done
# [1528/1663] axios → done
# [1529/1663] lucide-vue-next → done
# [1530/1663] radix-vue → done
# [1531/1663] sanitize-html → done
# [1532/1663] @rushstack/eslint-patch → done
# [1533/1663] @testing-library/user-event → done
# [1534/1663] @tsconfig/node20 → done
# [1535/1663] @types/node → done
# [1536/1663] @types/sanitize-html → done
# [1537/1663] @vitejs/plugin-vue → done
# [1538/1663] @vue/eslint-config-prettier → done
# [1539/1663] @vue/eslint-config-typescript → done
# [1540/1663] chai → done
# [1541/1663] eslint → done
# [1542/1663] eslint-plugin-vue → done
# [1543/1663] jsdom → done
# [1544/1663] msw → done
# [1545/1663] prettier → done
# [1546/1663] sass-embedded → done
# [1547/1663] typescript → done
# [1548/1663] vite → done
# [1549/1663] vitest → done
# [1550/1663] vue-tsc → done
# [1551/1663] azure-core → done
# [1552/1663] boto3-stubs[logs] → done
# [1553/1663] botocore → done
# [1554/1663] botocore-stubs → done
# [1555/1663] checkmk-dev-tools → done
# [1556/1663] hypothesis → done
# [1557/1663] lxml → done
# [1558/1663] meraki → done
# [1559/1663] multidict → done
# [1560/1663] opentelemetry-api → done
# [1561/1663] opentelemetry-exporter-otlp → done
# [1562/1663] opentelemetry-exporter-otlp-proto-common → done
# [1563/1663] opentelemetry-exporter-otlp-proto-grpc → done
# [1564/1663] opentelemetry-exporter-otlp-proto-http → done
# [1565/1663] opentelemetry-instrumentation → done
# [1566/1663] opentelemetry-instrumentation-asgi → done
# [1567/1663] opentelemetry-instrumentation-fastapi → done
# [1568/1663] opentelemetry-instrumentation-redis → done
# [1569/1663] opentelemetry-instrumentation-requests → done
# [1570/1663] opentelemetry-instrumentation-wsgi → done
# [1571/1663] opentelemetry-proto → done
# [1572/1663] opentelemetry-sdk → done
# [1573/1663] opentelemetry-semantic-conventions → done
# [1574/1663] opentelemetry-util-http → done
# [1575/1663] oracledb → done
# [1576/1663] py → done
# [1577/1663] pytest-check → done
# [1578/1663] pytest-repeat → done
# [1579/1663] retry → done
# [1580/1663] schemathesis → done
# [1581/1663] types-awscrt → done
# [1582/1663] types-oauthlib → done
# [1583/1663] typing-extensions → done
# [1584/1663] urllib3 → done
# [1585/1663] yarl → done
# [1586/1663] beautifulsoup4 → done
# [1587/1663] boto3-stubs[logs] → done
# [1588/1663] botocore → done
# [1589/1663] checkmk-dev-tools → done
# [1590/1663] dill → done
# [1591/1663] google-api-python-client → done
# [1592/1663] google-auth → done
# [1593/1663] googleapis-common-protos[grpc] → done
# [1594/1663] greenlet → done
# [1595/1663] httpcore → done
# [1596/1663] lazy-object-proxy → done
# [1597/1663] markdown → done
# [1598/1663] opentelemetry-api → done
# [1599/1663] opentelemetry-exporter-otlp → done
# [1600/1663] opentelemetry-exporter-otlp-proto-common → done
# [1601/1663] opentelemetry-exporter-otlp-proto-grpc → done
# [1602/1663] opentelemetry-exporter-otlp-proto-http → done
# [1603/1663] opentelemetry-instrumentation → done
# [1604/1663] opentelemetry-instrumentation-asgi → done
# [1605/1663] opentelemetry-instrumentation-fastapi → done
# [1606/1663] opentelemetry-instrumentation-redis → done
# [1607/1663] opentelemetry-instrumentation-requests → done
# [1608/1663] opentelemetry-instrumentation-wsgi → done
# [1609/1663] opentelemetry-proto → done
# [1610/1663] opentelemetry-sdk → done
# [1611/1663] opentelemetry-semantic-conventions → done
# [1612/1663] opentelemetry-util-http → done
# [1613/1663] pillow → done
# [1614/1663] recurring-ical-events → done
# [1615/1663] rsa → done
# [1616/1663] starlette → done
# [1617/1663] types-markdown → done
# [1618/1663] uvicorn → done
# [1619/1663] yarl → done
# [1620/1663] pillow → done
# [1621/1663] pillow → done
# [1622/1663] aiohttp → done
# [1623/1663] boto3-stubs[logs] → done
# [1624/1663] botocore → done
# [1625/1663] botocore-stubs → done
# [1626/1663] certifi → done
# [1627/1663] checkmk-dev-tools → done
# [1628/1663] frozenlist → done
# [1629/1663] gevent → done
# [1630/1663] google-api-python-client → done
# [1631/1663] google-cloud-asset → done
# [1632/1663] google-cloud-org-policy → done
# [1633/1663] greenlet → done
# [1634/1663] h11 → done
# [1635/1663] httpcore → done
# [1636/1663] hypothesis → done
# [1637/1663] identify → done
# [1638/1663] jsonschema-specifications → done
# [1639/1663] lxml → done
# [1640/1663] meraki → done
# [1641/1663] more-itertools → done
# [1642/1663] msal → done
# [1643/1663] mypy-boto3-logs → done
# [1644/1663] mypy-extensions → done
# [1645/1663] numpy → done
# [1646/1663] packaging → done
# [1647/1663] polyfactory → done
# [1648/1663] pyghmi → done
# [1649/1663] pytest-opentelemetry → done
# [1650/1663] python-jenkins-checkmk-retry-parameter → done
# [1651/1663] recurring-ical-events → done
# [1652/1663] reportlab → done
# [1653/1663] s3transfer → done
# [1654/1663] schemathesis → done
# [1655/1663] setuptools-scm → done
# [1656/1663] soupsieve → done
# [1657/1663] sphinx-autodoc-typehints → done
# [1658/1663] types-mypy-extensions → done
# [1659/1663] types-s3transfer → done
# [1660/1663] types-setuptools → done
# [1661/1663] uvicorn → done
# [1662/1663] py-cpuinfo → done
# [1663/1663] pytest-benchmark → done

# %%
import json
import requests
import urllib.parse
from datetime import datetime
from collections import defaultdict
from packaging.version import Version, InvalidVersion

def normalize_system(system):
    mapping = {
        "java": "maven",
        "javascript": "npm",
        "python": "pypi",
        "go": "go"
    }
    return mapping.get(system, system)

def get_major_version(version_str):
    try:
        return Version(version_str).major
    except InvalidVersion:
        return None

cached_versions = defaultdict(dict)

def fetch_package_data(package_name, system):
    encoded_name = urllib.parse.quote(package_name, safe="")
    url = f"https://api.deps.dev/v3alpha/systems/{system}/packages/{encoded_name}"
    response = requests.get(url)
    response.raise_for_status()
    return response.json()

def get_cached_package_data(package_name, system):
    if package_name not in cached_versions[system]:
        try:
            cached_versions[system][package_name] = fetch_package_data(package_name, system)
        except requests.RequestException as e:
            print(f"❌ Failed to fetch data for {package_name} ({system}): {e}")
            cached_versions[system][package_name] = {}  # fallback to empty
    return cached_versions[system][package_name]

def analyze_entry(entry):
    package_name    = entry["dependency"]
    raw_new         = entry["new_version"]
    has_caret       = raw_new.startswith("^")
    new_version     = raw_new.lstrip("^")
    commit_date     = datetime.strptime(entry["date"], "%Y-%m-%d %H:%M:%S")
    system          = normalize_system(entry["system"])

    # — fetch and filter to versions ≤ commit time —
    pkg_data        = get_cached_package_data(package_name, system)
    all_versions    = pkg_data.get("versions", [])
    commit_versions = []
    for v in all_versions:
        ver_str = v.get("versionKey", {}).get("version")
        pub_str = v.get("publishedAt")
        if not ver_str or not pub_str:
            continue
        try:
            pub_dt = datetime.strptime(pub_str, "%Y-%m-%dT%H:%M:%SZ")
        except ValueError:
            continue
        if pub_dt <= commit_date:
            try:
                commit_versions.append(Version(ver_str))
            except InvalidVersion:
                continue

    # — newest overall at commit time (highest major → highest) —
    if commit_versions:
        max_major = max(v.major for v in commit_versions)
        highest   = max(v for v in commit_versions if v.major == max_major)
        entry["newest_version_at_commit"] = str(highest)
    else:
        entry["newest_version_at_commit"] = None

    # — find release date and latest_at_commit_time (existing logic) —
    released_date         = None
    released_date_dt      = None
    latest_publish_date   = None
    latest_at_commit_time = None

    is_npm       = (system == "npm")
    target_major = get_major_version(new_version) if is_npm else None

    for v in all_versions:
        ver     = v.get("versionKey", {}).get("version")
        pub_str = v.get("publishedAt")
        if not ver or not pub_str:
            continue

        try:
            parsed = Version(ver)
        except InvalidVersion:
            parsed = None

        # npm-only: restrict to same major
        if is_npm and parsed and parsed.major != target_major:
            continue

        pub_dt = datetime.strptime(pub_str, "%Y-%m-%dT%H:%M:%SZ")
        if ver == new_version:
            released_date    = pub_dt.isoformat()
            released_date_dt = pub_dt

        if pub_dt <= commit_date and (latest_publish_date is None or pub_dt > latest_publish_date):
            latest_publish_date   = pub_dt
            latest_at_commit_time = ver

    entry["released_date"]          = released_date
    entry["latest_at_commit_time"]  = latest_at_commit_time

    # — new “caret-aware” latency logic —
    try:
        baseline = Version(new_version)
    except InvalidVersion:
        baseline = None

    # if ^, bump baseline to the highest same-major at commit
    if has_caret and baseline:
        same_major = [v for v in commit_versions if v.major == baseline.major]
        if same_major:
            baseline = max(same_major)

    if baseline and commit_versions:
        entry["latency"] = sum(1 for v in commit_versions if v > baseline)
    else:
        entry["latency"] = -1

    return entry

def process_json_file(input_path, output_path):
    with open(input_path, "r") as f:
        entries = json.load(f)

    total    = len(entries)
    enriched = []
    for i, entry in enumerate(entries, start=1):
        enriched_entry = analyze_entry(entry)
        enriched.append(enriched_entry)
        print(f"[{i}/{total}] {entry['dependency']} → done")

    with open(output_path, "w") as f:
        json.dump(enriched, f, indent=2)

# Run
process_json_file(
    "dependency_changes_with_removed.json",
    "dependency_changes_enriched.json"
)
# Out:
# [1/1663] webpack → done
# [2/1663] webpack-cli → done
# [3/1663] @babel/core → done
# [4/1663] @babel/preset-env → done
# [5/1663] babel-loader → done
# [6/1663] eslint → done
# [7/1663] eslint-plugin-compat → done
# [8/1663] script-loader → done
# [9/1663] jquery → done
# [10/1663] select2 → done
# [11/1663] css-loader → done
# [12/1663] mini-css-extract-plugin → done
# [13/1663] style-loader → done
# [14/1663] autoprefixer → done
# [15/1663] extract-loader → done
# [16/1663] file-loader → done
# [17/1663] node-sass → done
# [18/1663] postcss-clean → done
# [19/1663] postcss-loader → done
# [20/1663] sass-lint → done
# [21/1663] sass-loader → done
# [22/1663] webpack-fix-style-only-entries → done
# [23/1663] @yaireo/tagify → done
# [24/1663] sass-lint → done
# [25/1663] @yaireo/tagify → done
# [26/1663] node-sass → done
# [27/1663] jquery → done
# [28/1663] sass-lint → done
# [29/1663] d3 → done
# [30/1663] d3-flextree → done
# [31/1663] @yaireo/tagify → done
# [32/1663] d3 → done
# [33/1663] d3-flextree → done
# [34/1663] select2 → done
# [35/1663] @babel/core → done
# [36/1663] @babel/preset-env → done
# [37/1663] autoprefixer → done
# [38/1663] babel-loader → done
# [39/1663] css-loader → done
# [40/1663] eslint → done
# [41/1663] eslint-plugin-compat → done
# [42/1663] file-loader → done
# [43/1663] mini-css-extract-plugin → done
# [44/1663] sass-loader → done
# [45/1663] style-loader → done
# [46/1663] webpack → done
# [47/1663] webpack-cli → done
# [48/1663] webpack-fix-style-only-entries → done
# [49/1663] sass-loader → done
# [50/1663] @yaireo/tagify → done
# [51/1663] sass-loader → done
# [52/1663] core-js → done
# [53/1663] @babel/core → done
# [54/1663] @babel/preset-env → done
# [55/1663] d3 → done
# [56/1663] @babel/core → done
# [57/1663] @babel/preset-env → done
# [58/1663] eslint → done
# [59/1663] webpack → done
# [60/1663] webpack-cli → done
# [61/1663] element-closest-polyfill → done
# [62/1663] whatwg-fetch → done
# [63/1663] sweetalert2 → done
# [64/1663] d3-sankey → done
# [65/1663] crossfilter2 → done
# [66/1663] dc → done
# [67/1663] redoc → done
# [68/1663] redoc-cli → done
# [69/1663] core-js → done
# [70/1663] d3 → done
# [71/1663] dc → done
# [72/1663] select2 → done
# [73/1663] sweetalert2 → done
# [74/1663] @babel/core → done
# [75/1663] @babel/preset-env → done
# [76/1663] autoprefixer → done
# [77/1663] babel-loader → done
# [78/1663] css-loader → done
# [79/1663] eslint → done
# [80/1663] eslint-plugin-compat → done
# [81/1663] file-loader → done
# [82/1663] mini-css-extract-plugin → done
# [83/1663] node-sass → done
# [84/1663] sass-loader → done
# [85/1663] style-loader → done
# [86/1663] webpack → done
# [87/1663] webpack-cli → done
# [88/1663] jquery → done
# [89/1663] node-sass → done
# [90/1663] redoc → done
# [91/1663] redoc-cli → done
# [92/1663] simplebar → done
# [93/1663] prettier → done
# [94/1663] eslint-config-prettier → done
# [95/1663] eslint-plugin-prettier → done
# [96/1663] redoc-cli → done
# [97/1663] redoc → done
# [98/1663] redoc-cli → done
# [99/1663] redoc-cli → done
# [100/1663] d3-hexbin → done
# [101/1663] @yaireo/tagify → done
# [102/1663] core-js → done
# [103/1663] @babel/core → done
# [104/1663] @babel/preset-env → done
# [105/1663] babel-loader → done
# [106/1663] eslint → done
# [107/1663] eslint-config-prettier → done
# [108/1663] eslint-plugin-compat → done
# [109/1663] eslint-plugin-prettier → done
# [110/1663] extract-loader → done
# [111/1663] file-loader → done
# [112/1663] mini-css-extract-plugin → done
# [113/1663] node-sass → done
# [114/1663] postcss-clean → done
# [115/1663] postcss-loader → done
# [116/1663] prettier → done
# [117/1663] sass-loader → done
# [118/1663] style-loader → done
# [119/1663] webpack-cli → done
# [120/1663] webpack-fix-style-only-entries → done
# [121/1663] core-js → done
# [122/1663] @babel/core → done
# [123/1663] @babel/preset-env → done
# [124/1663] babel-loader → done
# [125/1663] eslint → done
# [126/1663] eslint-config-prettier → done
# [127/1663] eslint-plugin-compat → done
# [128/1663] eslint-plugin-prettier → done
# [129/1663] extract-loader → done
# [130/1663] file-loader → done
# [131/1663] mini-css-extract-plugin → done
# [132/1663] node-sass → done
# [133/1663] postcss-clean → done
# [134/1663] postcss-loader → done
# [135/1663] prettier → done
# [136/1663] sass-loader → done
# [137/1663] style-loader → done
# [138/1663] webpack-cli → done
# [139/1663] webpack-fix-style-only-entries → done
# [140/1663] core-js → done
# [141/1663] @babel/core → done
# [142/1663] @babel/preset-env → done
# [143/1663] babel-loader → done
# [144/1663] eslint → done
# [145/1663] eslint-config-prettier → done
# [146/1663] eslint-plugin-compat → done
# [147/1663] eslint-plugin-prettier → done
# [148/1663] prettier → done
# [149/1663] sweetalert2 → done
# [150/1663] extract-loader → done
# [151/1663] file-loader → done
# [152/1663] mini-css-extract-plugin → done
# [153/1663] node-sass → done
# [154/1663] postcss-clean → done
# [155/1663] postcss-loader → done
# [156/1663] sass-loader → done
# [157/1663] style-loader → done
# [158/1663] webpack-cli → done
# [159/1663] webpack-fix-style-only-entries → done
# [160/1663] core-js → done
# [161/1663] sweetalert2 → done
# [162/1663] @babel/core → done
# [163/1663] @babel/preset-env → done
# [164/1663] babel-loader → done
# [165/1663] eslint → done
# [166/1663] eslint-config-prettier → done
# [167/1663] eslint-plugin-compat → done
# [168/1663] eslint-plugin-prettier → done
# [169/1663] extract-loader → done
# [170/1663] file-loader → done
# [171/1663] mini-css-extract-plugin → done
# [172/1663] node-sass → done
# [173/1663] postcss-clean → done
# [174/1663] postcss-loader → done
# [175/1663] prettier → done
# [176/1663] sass-loader → done
# [177/1663] style-loader → done
# [178/1663] webpack-cli → done
# [179/1663] webpack-fix-style-only-entries → done
# [180/1663] eslint → done
# [181/1663] eslint-config-prettier → done
# [182/1663] eslint-plugin-compat → done
# [183/1663] eslint-plugin-prettier → done
# [184/1663] prettier → done
# [185/1663] core-js → done
# [186/1663] sweetalert2 → done
# [187/1663] @babel/core → done
# [188/1663] @babel/preset-env → done
# [189/1663] autoprefixer → done
# [190/1663] babel-loader → done
# [191/1663] css-loader → done
# [192/1663] cssnano → done
# [193/1663] extract-loader → done
# [194/1663] file-loader → done
# [195/1663] mini-css-extract-plugin → done
# [196/1663] postcss → done
# [197/1663] postcss-loader → done
# [198/1663] sass → done
# [199/1663] sass-loader → done
# [200/1663] style-loader → done
# [201/1663] webpack-cli → done
# [202/1663] webpack-fix-style-only-entries → done
# [203/1663] autoprefixer → done
# [204/1663] css-loader → done
# [205/1663] postcss-clean → done
# [206/1663] autoprefixer → done
# [207/1663] css-loader → done
# [208/1663] cssnano → done
# [209/1663] postcss → done
# [210/1663] terser-webpack-plugin → done
# [211/1663] webpack → done
# [212/1663] sweetalert2 → done
# [213/1663] autoprefixer → done
# [214/1663] eslint → done
# [215/1663] mini-css-extract-plugin → done
# [216/1663] postcss-loader → done
# [217/1663] redoc-cli → done
# [218/1663] sass → done
# [219/1663] webpack → done
# [220/1663] webpack-cli → done
# [221/1663] d3 → done
# [222/1663] canvas-5-polyfill → done
# [223/1663] is-svg → done
# [224/1663] merge → done
# [225/1663] @babel/eslint-parser → done
# [226/1663] prettier → done
# [227/1663] lodash.range → done
# [228/1663] lodash.range → done
# [229/1663] @babel/core → done
# [230/1663] @babel/eslint-parser → done
# [231/1663] @babel/preset-env → done
# [232/1663] autoprefixer → done
# [233/1663] babel-loader → done
# [234/1663] css-loader → done
# [235/1663] cssnano → done
# [236/1663] mini-css-extract-plugin → done
# [237/1663] pkg-dir → done
# [238/1663] postcss-loader → done
# [239/1663] prettier → done
# [240/1663] sass → done
# [241/1663] sass-loader → done
# [242/1663] style-loader → done
# [243/1663] webpack → done
# [244/1663] webpack-cli → done
# [245/1663] webpack-remove-empty-scripts → done
# [246/1663] core-js → done
# [247/1663] element-closest-polyfill → done
# [248/1663] jquery → done
# [249/1663] simplebar → done
# [250/1663] whatwg-fetch → done
# [251/1663] eslint → done
# [252/1663] eslint-config-prettier → done
# [253/1663] eslint-plugin-compat → done
# [254/1663] eslint-plugin-prettier → done
# [255/1663] redoc → done
# [256/1663] redoc-cli → done
# [257/1663] sass → done
# [258/1663] core-js → done
# [259/1663] element-closest-polyfill → done
# [260/1663] whatwg-fetch → done
# [261/1663] eslint → done
# [262/1663] eslint-config-prettier → done
# [263/1663] eslint-plugin-compat → done
# [264/1663] eslint-plugin-prettier → done
# [265/1663] redoc → done
# [266/1663] redoc-cli → done
# [267/1663] sass → done
# [268/1663] core-js → done
# [269/1663] core-js → done
# [270/1663] jquery → done
# [271/1663] simplebar → done
# [272/1663] @babel/core → done
# [273/1663] @babel/eslint-parser → done
# [274/1663] @babel/preset-env → done
# [275/1663] autoprefixer → done
# [276/1663] babel-loader → done
# [277/1663] css-loader → done
# [278/1663] cssnano → done
# [279/1663] mini-css-extract-plugin → done
# [280/1663] postcss-loader → done
# [281/1663] prettier → done
# [282/1663] sass → done
# [283/1663] sass-loader → done
# [284/1663] style-loader → done
# [285/1663] webpack → done
# [286/1663] webpack-cli → done
# [287/1663] webpack-fix-style-only-entries → done
# [288/1663] core-js → done
# [289/1663] element-closest-polyfill → done
# [290/1663] jquery → done
# [291/1663] simplebar → done
# [292/1663] @babel/core → done
# [293/1663] @babel/eslint-parser → done
# [294/1663] @babel/preset-env → done
# [295/1663] autoprefixer → done
# [296/1663] babel-loader → done
# [297/1663] css-loader → done
# [298/1663] cssnano → done
# [299/1663] eslint → done
# [300/1663] eslint-config-prettier → done
# [301/1663] eslint-plugin-compat → done
# [302/1663] eslint-plugin-prettier → done
# [303/1663] mini-css-extract-plugin → done
# [304/1663] pkg-dir → done
# [305/1663] postcss-loader → done
# [306/1663] prettier → done
# [307/1663] redoc → done
# [308/1663] redoc-cli → done
# [309/1663] sass → done
# [310/1663] sass-loader → done
# [311/1663] style-loader → done
# [312/1663] webpack → done
# [313/1663] webpack-cli → done
# [314/1663] webpack-remove-empty-scripts → done
# [315/1663] @yaireo/tagify → done
# [316/1663] whatwg-fetch → done
# [317/1663] sweetalert2 → done
# [318/1663] d3 → done
# [319/1663] d3-flextree → done
# [320/1663] dc → done
# [321/1663] @babel/plugin-proposal-class-properties → done
# [322/1663] @babel/plugin-proposal-object-rest-spread → done
# [323/1663] @babel/preset-typescript → done
# [324/1663] @types/jquery → done
# [325/1663] typescript → done
# [326/1663] @types/jquery → done
# [327/1663] @types/node → done
# [328/1663] debug → done
# [329/1663] ms → done
# [330/1663] yargs-parser → done
# [331/1663] @typescript-eslint/parser → done
# [332/1663] typescript → done
# [333/1663] @typescript-eslint/eslint-plugin → done
# [334/1663] @zxcvbn-ts/core → done
# [335/1663] @zxcvbn-ts/language-common → done
# [336/1663] @zxcvbn-ts/language-en → done
# [337/1663] @types/select2 → done
# [338/1663] browserslist → done
# [339/1663] caniuse-lite → done
# [340/1663] canvas-5-polyfill → done
# [341/1663] @types/d3 → done
# [342/1663] @yaireo/tagify → done
# [343/1663] @types/lodash → done
# [344/1663] @types/yaireo__tagify → done
# [345/1663] npm-force-resolutions → done
# [346/1663] @types/lodash → done
# [347/1663] @types/yaireo__tagify → done
# [348/1663] @types/dc → done
# [349/1663] eslint-plugin-simple-import-sort → done
# [350/1663] @types/crossfilter → done
# [351/1663] @types/lodash.range → done
# [352/1663] @types/d3-hexbin → done
# [353/1663] eslint-plugin-license-header → done
# [354/1663] @types/d3-flextree → done
# [355/1663] @types/d3-sankey → done
# [356/1663] qrcode → done
# [357/1663] @types/qrcode → done
# [358/1663] @zxcvbn-ts/core → done
# [359/1663] @zxcvbn-ts/language-common → done
# [360/1663] @zxcvbn-ts/language-en → done
# [361/1663] @zxcvbn-ts/core → done
# [362/1663] @zxcvbn-ts/language-common → done
# [363/1663] @zxcvbn-ts/language-en → done
# [364/1663] @types/node → done
# [365/1663] vue-loader → done
# [366/1663] vue → done
# [367/1663] cryptography → done
# [368/1663] fastapi → done
# [369/1663] gunicorn → done
# [370/1663] python-dateutil → done
# [371/1663] python-multipart → done
# [372/1663] requests → done
# [373/1663] uvicorn → done
# [374/1663] pydantic → done
# [375/1663] lxml → done
# [376/1663] markdown → done
# [377/1663] pydantic → done
# [378/1663] semver → done
# [379/1663] vnu-jar → done
# [380/1663] npm-groovy-lint → done
# [381/1663] pydantic → done
# [382/1663] cryptography → done
# [383/1663] fastapi → done
# [384/1663] vue → done
# [385/1663] @rushstack/eslint-patch → done
# [386/1663] @tsconfig/node20 → done
# [387/1663] @types/node → done
# [388/1663] @vitejs/plugin-vue → done
# [389/1663] @vue/eslint-config-prettier → done
# [390/1663] @vue/eslint-config-typescript → done
# [391/1663] @vue/tsconfig → done
# [392/1663] eslint → done
# [393/1663] eslint-plugin-vue → done
# [394/1663] npm-run-all2 → done
# [395/1663] prettier → done
# [396/1663] typescript → done
# [397/1663] vite → done
# [398/1663] vue-tsc → done
# [399/1663] @jest/globals → done
# [400/1663] fake-indexeddb → done
# [401/1663] jest-cli → done
# [402/1663] jest-environment-jsdom → done
# [403/1663] mutation-observer → done
# [404/1663] ts-jest → done
# [405/1663] jquery → done
# [406/1663] crossfilter2 → done
# [407/1663] d3 → done
# [408/1663] core-js → done
# [409/1663] vue → done
# [410/1663] jquery → done
# [411/1663] crossfilter2 → done
# [412/1663] d3 → done
# [413/1663] core-js → done
# [414/1663] @rushstack/eslint-patch → done
# [415/1663] @tsconfig/node20 → done
# [416/1663] @types/node → done
# [417/1663] @vitejs/plugin-vue → done
# [418/1663] @vue/eslint-config-prettier → done
# [419/1663] @vue/eslint-config-typescript → done
# [420/1663] @vue/tsconfig → done
# [421/1663] eslint → done
# [422/1663] eslint-plugin-vue → done
# [423/1663] npm-run-all2 → done
# [424/1663] prettier → done
# [425/1663] typescript → done
# [426/1663] vite → done
# [427/1663] vue-tsc → done
# [428/1663] json-schema-to-typescript → done
# [429/1663] python-dateutil → done
# [430/1663] gunicorn → done
# [431/1663] @yaireo/tagify → done
# [432/1663] @zxcvbn-ts/core → done
# [433/1663] @zxcvbn-ts/language-common → done
# [434/1663] @zxcvbn-ts/language-en → done
# [435/1663] core-js → done
# [436/1663] crossfilter2 → done
# [437/1663] d3 → done
# [438/1663] d3-flextree → done
# [439/1663] d3-hexbin → done
# [440/1663] d3-sankey → done
# [441/1663] dc → done
# [442/1663] debug → done
# [443/1663] element-closest-polyfill → done
# [444/1663] jquery → done
# [445/1663] lodash.range → done
# [446/1663] ms → done
# [447/1663] qrcode → done
# [448/1663] select2 → done
# [449/1663] simplebar → done
# [450/1663] sweetalert2 → done
# [451/1663] vnu-jar → done
# [452/1663] yargs-parser → done
# [453/1663] @babel/core → done
# [454/1663] @babel/eslint-parser → done
# [455/1663] @babel/plugin-proposal-class-properties → done
# [456/1663] @babel/plugin-proposal-object-rest-spread → done
# [457/1663] @babel/preset-env → done
# [458/1663] @babel/preset-typescript → done
# [459/1663] @jest/globals → done
# [460/1663] @types/crossfilter → done
# [461/1663] @types/d3 → done
# [462/1663] @types/d3-flextree → done
# [463/1663] @types/d3-hexbin → done
# [464/1663] @types/d3-sankey → done
# [465/1663] @types/dc → done
# [466/1663] @types/jquery → done
# [467/1663] @types/lodash → done
# [468/1663] @types/lodash.range → done
# [469/1663] @types/node → done
# [470/1663] @types/qrcode → done
# [471/1663] @types/select2 → done
# [472/1663] @types/yaireo__tagify → done
# [473/1663] @typescript-eslint/eslint-plugin → done
# [474/1663] @typescript-eslint/parser → done
# [475/1663] autoprefixer → done
# [476/1663] babel-loader → done
# [477/1663] browserslist → done
# [478/1663] caniuse-lite → done
# [479/1663] copy-webpack-plugin → done
# [480/1663] css-loader → done
# [481/1663] cssnano → done
# [482/1663] eslint → done
# [483/1663] eslint-config-prettier → done
# [484/1663] eslint-plugin-compat → done
# [485/1663] eslint-plugin-license-header → done
# [486/1663] eslint-plugin-prettier → done
# [487/1663] eslint-plugin-simple-import-sort → done
# [488/1663] extract-loader → done
# [489/1663] fake-indexeddb → done
# [490/1663] file-loader → done
# [491/1663] jest-cli → done
# [492/1663] jest-environment-jsdom → done
# [493/1663] merge → done
# [494/1663] mini-css-extract-plugin → done
# [495/1663] mutation-observer → done
# [496/1663] npm-groovy-lint → done
# [497/1663] pkg-dir → done
# [498/1663] postcss → done
# [499/1663] postcss-loader → done
# [500/1663] prettier → done
# [501/1663] sass → done
# [502/1663] sass-loader → done
# [503/1663] script-loader → done
# [504/1663] style-loader → done
# [505/1663] terser-webpack-plugin → done
# [506/1663] ts-jest → done
# [507/1663] typescript → done
# [508/1663] webpack → done
# [509/1663] webpack-cli → done
# [510/1663] webpack-remove-empty-scripts → done
# [511/1663] @types/d3 → done
# [512/1663] @types/d3-hierarchy → done
# [513/1663] filemanager-webpack-plugin → done
# [514/1663] core-js → done
# [515/1663] crossfilter2 → done
# [516/1663] d3 → done
# [517/1663] jquery → done
# [518/1663] vue → done
# [519/1663] @rushstack/eslint-patch → done
# [520/1663] @tsconfig/node20 → done
# [521/1663] @types/node → done
# [522/1663] @vitejs/plugin-vue → done
# [523/1663] @vue/eslint-config-prettier → done
# [524/1663] @vue/eslint-config-typescript → done
# [525/1663] eslint → done
# [526/1663] eslint-plugin-vue → done
# [527/1663] npm-run-all2 → done
# [528/1663] prettier → done
# [529/1663] typescript → done
# [530/1663] vite → done
# [531/1663] vue-tsc → done
# [532/1663] @testing-library/vue → done
# [533/1663] chai → done
# [534/1663] jsdom → done
# [535/1663] vitest → done
# [536/1663] class-variance-authority → done
# [537/1663] radix-vue → done
# [538/1663] tailwind-merge → done
# [539/1663] tailwindcss-animate → done
# [540/1663] @zxcvbn-ts/core → done
# [541/1663] @zxcvbn-ts/language-common → done
# [542/1663] @zxcvbn-ts/language-en → done
# [543/1663] clsx → done
# [544/1663] lucide-vue-next → done
# [545/1663] radix-vue → done
# [546/1663] tailwind-merge → done
# [547/1663] opentelemetry-api → done
# [548/1663] opentelemetry-sdk → done
# [549/1663] opentelemetry-exporter-otlp → done
# [550/1663] opentelemetry-semantic-conventions → done
# [551/1663] eslint-import-resolver-typescript → done
# [552/1663] eslint-plugin-import → done
# [553/1663] eslint-plugin-no-unsanitized → done
# [554/1663] @zxcvbn-ts/core → done
# [555/1663] core-js → done
# [556/1663] crossfilter2 → done
# [557/1663] d3 → done
# [558/1663] element-closest-polyfill → done
# [559/1663] jquery → done
# [560/1663] lodash.set → done
# [561/1663] sweetalert2 → done
# [562/1663] @babel/core → done
# [563/1663] @babel/eslint-parser → done
# [564/1663] @babel/preset-env → done
# [565/1663] @babel/preset-typescript → done
# [566/1663] @types/d3 → done
# [567/1663] @types/d3-flextree → done
# [568/1663] @types/dc → done
# [569/1663] @types/jquery → done
# [570/1663] @types/lodash.range → done
# [571/1663] @types/lodash.set → done
# [572/1663] @types/qrcode → done
# [573/1663] @types/select2 → done
# [574/1663] autoprefixer → done
# [575/1663] browserslist → done
# [576/1663] caniuse-lite → done
# [577/1663] mini-css-extract-plugin → done
# [578/1663] npm-groovy-lint → done
# [579/1663] postcss → done
# [580/1663] sass → done
# [581/1663] terser-webpack-plugin → done
# [582/1663] ts-jest → done
# [583/1663] webpack → done
# [584/1663] pika → done
# [585/1663] types-pika-ts → done
# [586/1663] @yaireo/tagify → done
# [587/1663] @types/crossfilter → done
# [588/1663] @types/d3-hexbin → done
# [589/1663] @types/d3-sankey → done
# [590/1663] @types/node → done
# [591/1663] @types/yaireo__tagify → done
# [592/1663] caniuse-lite → done
# [593/1663] css-loader → done
# [594/1663] cssnano → done
# [595/1663] eslint-plugin-license-header → done
# [596/1663] fake-indexeddb → done
# [597/1663] pkg-dir → done
# [598/1663] postcss-loader → done
# [599/1663] opentelemetry-api → done
# [600/1663] axios → done
# [601/1663] pydantic → done
# [602/1663] pytest → done
# [603/1663] cryptography → done
# [604/1663] pytest → done
# [605/1663] bcrypt → done
# [606/1663] python-dateutil → done
# [607/1663] types-python-dateutil → done
# [608/1663] time-machine → done
# [609/1663] axios → done
# [610/1663] core-js → done
# [611/1663] lucide-vue-next → done
# [612/1663] radix-vue → done
# [613/1663] tailwind-merge → done
# [614/1663] vue → done
# [615/1663] @rushstack/eslint-patch → done
# [616/1663] @vitejs/plugin-vue → done
# [617/1663] eslint-plugin-vue → done
# [618/1663] jsdom → done
# [619/1663] npm-run-all2 → done
# [620/1663] prettier → done
# [621/1663] typescript → done
# [622/1663] vite → done
# [623/1663] vue-tsc → done
# [624/1663] pytest → done
# [625/1663] cryptography → done
# [626/1663] fastapi → done
# [627/1663] gunicorn → done
# [628/1663] python-dateutil → done
# [629/1663] python-multipart → done
# [630/1663] requests → done
# [631/1663] uvicorn → done
# [632/1663] prettier → done
# [633/1663] vitest-fail-on-console → done
# [634/1663] @testing-library/jest-dom → done
# [635/1663] vue → done
# [636/1663] pytest → done
# [637/1663] pytest → done
# [638/1663] GitPython → done
# [639/1663] sass-embedded → done
# [640/1663] vue-router → done
# [641/1663] radix-vue → done
# [642/1663] msw → done
# [643/1663] axios → done
# [644/1663] core-js → done
# [645/1663] lucide-vue-next → done
# [646/1663] tailwind-merge → done
# [647/1663] vue → done
# [648/1663] @vitejs/plugin-vue → done
# [649/1663] @vue/eslint-config-prettier → done
# [650/1663] @vue/eslint-config-typescript → done
# [651/1663] eslint → done
# [652/1663] eslint-plugin-vue → done
# [653/1663] jsdom → done
# [654/1663] npm-run-all2 → done
# [655/1663] sass-embedded → done
# [656/1663] typescript → done
# [657/1663] vite → done
# [658/1663] vitest → done
# [659/1663] vue-tsc → done
# [660/1663] lucide-vue-next → done
# [661/1663] radix-vue → done
# [662/1663] tailwind-merge → done
# [663/1663] @testing-library/jest-dom → done
# [664/1663] @types/node → done
# [665/1663] @vue/eslint-config-prettier → done
# [666/1663] @vue/eslint-config-typescript → done
# [667/1663] chai → done
# [668/1663] eslint → done
# [669/1663] eslint-plugin-vue → done
# [670/1663] msw → done
# [671/1663] npm-run-all2 → done
# [672/1663] sass-embedded → done
# [673/1663] vite → done
# [674/1663] vitest → done
# [675/1663] vue-tsc → done
# [676/1663] @yaireo/tagify → done
# [677/1663] core-js → done
# [678/1663] qrcode → done
# [679/1663] sweetalert2 → done
# [680/1663] @babel/core → done
# [681/1663] @babel/eslint-parser → done
# [682/1663] @babel/plugin-proposal-class-properties → done
# [683/1663] @babel/plugin-proposal-object-rest-spread → done
# [684/1663] @babel/preset-env → done
# [685/1663] @babel/preset-typescript → done
# [686/1663] @types/jquery → done
# [687/1663] @types/node → done
# [688/1663] @types/yaireo__tagify → done
# [689/1663] autoprefixer → done
# [690/1663] browserslist → done
# [691/1663] caniuse-lite → done
# [692/1663] cssnano → done
# [693/1663] eslint-import-resolver-typescript → done
# [694/1663] eslint-plugin-import → done
# [695/1663] eslint-plugin-no-unsanitized → done
# [696/1663] mini-css-extract-plugin → done
# [697/1663] postcss → done
# [698/1663] sass → done
# [699/1663] ts-jest → done
# [700/1663] webpack → done
# [701/1663] vnu-jar → done
# [702/1663] semgrep → done
# [703/1663] lucide-vue-next → done
# [704/1663] radix-vue → done
# [705/1663] @testing-library/jest-dom → done
# [706/1663] @types/node → done
# [707/1663] @vitejs/plugin-vue → done
# [708/1663] @vue/tsconfig → done
# [709/1663] eslint → done
# [710/1663] eslint-plugin-vue → done
# [711/1663] msw → done
# [712/1663] sass-embedded → done
# [713/1663] typescript → done
# [714/1663] vite → done
# [715/1663] vitest → done
# [716/1663] vue-tsc → done
# [717/1663] core-js → done
# [718/1663] @testing-library/user-event → done
# [719/1663] sanitize-html → done
# [720/1663] @types/sanitize-html → done
# [721/1663] @yaireo/tagify → done
# [722/1663] core-js → done
# [723/1663] simplebar → done
# [724/1663] sweetalert2 → done
# [725/1663] @types/node → done
# [726/1663] @typescript-eslint/eslint-plugin → done
# [727/1663] @typescript-eslint/parser → done
# [728/1663] babel-loader → done
# [729/1663] caniuse-lite → done
# [730/1663] eslint → done
# [731/1663] eslint-config-prettier → done
# [732/1663] eslint-import-resolver-typescript → done
# [733/1663] eslint-plugin-compat → done
# [734/1663] eslint-plugin-prettier → done
# [735/1663] eslint-plugin-simple-import-sort → done
# [736/1663] mini-css-extract-plugin → done
# [737/1663] npm-groovy-lint → done
# [738/1663] postcss → done
# [739/1663] prettier → done
# [740/1663] sass → done
# [741/1663] sass-loader → done
# [742/1663] style-loader → done
# [743/1663] typescript → done
# [744/1663] webpack → done
# [745/1663] webpack-cli → done
# [746/1663] webpack-remove-empty-scripts → done
# [747/1663] sass → done
# [748/1663] sass-loader → done
# [749/1663] npm-groovy-lint → done
# [750/1663] sass → done
# [751/1663] sass-loader → done
# ❌ Failed to fetch data for cmk-shared-typing (npm): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/npm/packages/cmk-shared-typing
# [752/1663] cmk-shared-typing → done
# [753/1663] axios → done
# [754/1663] class-variance-authority → done
# [755/1663] lucide-vue-next → done
# [756/1663] radix-vue → done
# [757/1663] sanitize-html → done
# [758/1663] vue → done
# [759/1663] vue-router → done
# [760/1663] @rushstack/eslint-patch → done
# [761/1663] @types/node → done
# [762/1663] @vitejs/plugin-vue → done
# [763/1663] @vue/eslint-config-typescript → done
# [764/1663] @vue/tsconfig → done
# [765/1663] eslint → done
# [766/1663] eslint-plugin-vue → done
# [767/1663] msw → done
# [768/1663] npm-run-all2 → done
# [769/1663] prettier → done
# [770/1663] sass-embedded → done
# [771/1663] typescript → done
# [772/1663] vite → done
# [773/1663] vitest → done
# [774/1663] vue-tsc → done
# [775/1663] sphinx → done
# [776/1663] sphinx-autodoc-typehints → done
# [777/1663] sphinx-rtd-theme → done
# [778/1663] checkmk-dev-tools → done
# [779/1663] python-dateutil → done
# [780/1663] checkmk-dev-tools → done
# [781/1663] checkmk-dev-tools → done
# [782/1663] checkmk-dev-tools → done
# [783/1663] checkmk-dev-tools → done
# [784/1663] 3to2 → done
# [785/1663] aiohappyeyeballs → done
# [786/1663] aiohttp → done
# [787/1663] aiosignal → done
# [788/1663] alabaster → done
# [789/1663] annotated-types → done
# [790/1663] anyio → done
# [791/1663] apispec → done
# [792/1663] apispec-oneofschema → done
# [793/1663] argcomplete → done
# [794/1663] arrow → done
# [795/1663] asgiref → done
# [796/1663] astroid → done
# [797/1663] attrs → done
# [798/1663] autoflake → done
# [799/1663] azure-common → done
# [800/1663] azure-core → done
# [801/1663] azure-identity → done
# [802/1663] azure-mgmt-compute → done
# [803/1663] azure-mgmt-core → done
# [804/1663] azure-mgmt-resource → done
# [805/1663] azure-storage-blob → done
# [806/1663] babel → done
# [807/1663] backoff → done
# [808/1663] bandit → done
# [809/1663] bcrypt → done
# [810/1663] beautifulsoup4 → done
# [811/1663] black → done
# [812/1663] blinker → done
# [813/1663] boto3 → done
# ❌ Failed to fetch data for boto3-stubs[logs] (pypi): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/pypi/packages/boto3-stubs%5Blogs%5D
# [814/1663] boto3-stubs[logs] → done
# [815/1663] botocore → done
# [816/1663] botocore-stubs → done
# [817/1663] bson → done
# [818/1663] build → done
# [819/1663] cached-property → done
# [820/1663] cachetools → done
# [821/1663] certifi → done
# [822/1663] cffi → done
# [823/1663] cfgv → done
# [824/1663] chardet → done
# [825/1663] charset-normalizer → done
# [826/1663] check-manifest → done
# [827/1663] checkmk-dev-tools → done
# [828/1663] click → done
# [829/1663] colorama → done
# [830/1663] cryptography → done
# [831/1663] cssselect → done
# [832/1663] cssselect2 → done
# [833/1663] cython → done
# [834/1663] datamodel-code-generator → done
# [835/1663] decorator → done
# [836/1663] defusedxml → done
# [837/1663] deprecated → done
# [838/1663] devpi-client → done
# [839/1663] devpi-common → done
# [840/1663] dill → done
# [841/1663] distlib → done
# [842/1663] dnspython → done
# [843/1663] docker → done
# [844/1663] dockerpty → done
# [845/1663] docstring-parser → done
# [846/1663] docstring-to-markdown → done
# [847/1663] docutils → done
# [848/1663] elementpath → done
# [849/1663] email-validator → done
# [850/1663] exchangelib → done
# [851/1663] execnet → done
# [852/1663] faker → done
# ❌ Failed to fetch data for fakeredis[lua] (pypi): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/pypi/packages/fakeredis%5Blua%5D
# [853/1663] fakeredis[lua] → done
# [854/1663] fastapi → done
# [855/1663] feedparser → done
# [856/1663] fido2 → done
# [857/1663] filelock → done
# [858/1663] flask → done
# [859/1663] fqdn → done
# [860/1663] frozenlist → done
# [861/1663] furo → done
# [862/1663] genson → done
# [863/1663] gevent → done
# [864/1663] gitdb → done
# [865/1663] gitpython → done
# ❌ Failed to fetch data for google-api-core[grpc] (pypi): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/pypi/packages/google-api-core%5Bgrpc%5D
# [866/1663] google-api-core[grpc] → done
# [867/1663] google-api-python-client → done
# [868/1663] google-auth → done
# [869/1663] google-auth-httplib2 → done
# [870/1663] google-cloud-access-context-manager → done
# [871/1663] google-cloud-asset → done
# [872/1663] google-cloud-monitoring → done
# [873/1663] google-cloud-org-policy → done
# [874/1663] google-cloud-os-config → done
# ❌ Failed to fetch data for googleapis-common-protos[grpc] (pypi): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/pypi/packages/googleapis-common-protos%5Bgrpc%5D
# [875/1663] googleapis-common-protos[grpc] → done
# [876/1663] graphql-core → done
# [877/1663] graphviz → done
# [878/1663] greenlet → done
# [879/1663] grequests → done
# [880/1663] grpc-google-iam-v1 → done
# [881/1663] grpcio → done
# [882/1663] grpcio-status → done
# [883/1663] gunicorn → done
# [884/1663] h11 → done
# [885/1663] harfile → done
# [886/1663] httpcore → done
# [887/1663] httplib2 → done
# [888/1663] httpx → done
# [889/1663] hypothesis → done
# [890/1663] hypothesis-graphql → done
# [891/1663] hypothesis-jsonschema → done
# [892/1663] icalendar → done
# [893/1663] id → done
# [894/1663] identify → done
# [895/1663] idna → done
# [896/1663] imagesize → done
# [897/1663] importlib-metadata → done
# [898/1663] inflect → done
# [899/1663] iniconfig → done
# [900/1663] isodate → done
# [901/1663] isoduration → done
# [902/1663] isort → done
# [903/1663] itsdangerous → done
# [904/1663] jaraco-classes → done
# [905/1663] jaraco-context → done
# [906/1663] jaraco-functools → done
# [907/1663] jedi → done
# [908/1663] jeepney → done
# [909/1663] jinja2 → done
# [910/1663] jira → done
# [911/1663] jmespath → done
# [912/1663] jsonpatch → done
# [913/1663] jsonpath-rw → done
# [914/1663] jsonpointer → done
# ❌ Failed to fetch data for jsonschema[format] (pypi): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/pypi/packages/jsonschema%5Bformat%5D
# [915/1663] jsonschema[format] → done
# [916/1663] jsonschema-path → done
# [917/1663] jsonschema-specifications → done
# [918/1663] junit-xml → done
# [919/1663] keyring → done
# [920/1663] kubernetes → done
# [921/1663] lazy → done
# [922/1663] lazy-object-proxy → done
# [923/1663] libcst → done
# [924/1663] lupa → done
# [925/1663] lxml → done
# [926/1663] markdown → done
# [927/1663] markdown-it-py → done
# [928/1663] markupsafe → done
# [929/1663] marshmallow → done
# [930/1663] marshmallow-oneofschema → done
# [931/1663] mccabe → done
# [932/1663] mdurl → done
# [933/1663] meraki → done
# [934/1663] more-itertools → done
# [935/1663] msal → done
# [936/1663] msal-extensions → done
# [937/1663] msrest → done
# [938/1663] multi-key-dict → done
# [939/1663] multidict → done
# [940/1663] multipart → done
# [941/1663] mypy → done
# [942/1663] mypy-boto3-logs → done
# [943/1663] mypy-extensions → done
# [944/1663] mypy-protobuf → done
# [945/1663] netapp-ontap → done
# [946/1663] networkx → done
# [947/1663] nh3 → done
# [948/1663] nodeenv → done
# [949/1663] numpy → done
# [950/1663] oauthlib → done
# [951/1663] openapi-schema-validator → done
# [952/1663] openapi-spec-validator → done
# [953/1663] opentelemetry-api → done
# [954/1663] opentelemetry-container-distro → done
# [955/1663] opentelemetry-exporter-otlp → done
# [956/1663] opentelemetry-exporter-otlp-proto-common → done
# [957/1663] opentelemetry-exporter-otlp-proto-grpc → done
# [958/1663] opentelemetry-exporter-otlp-proto-http → done
# [959/1663] opentelemetry-instrumentation → done
# [960/1663] opentelemetry-instrumentation-asgi → done
# [961/1663] opentelemetry-instrumentation-fastapi → done
# [962/1663] opentelemetry-instrumentation-redis → done
# [963/1663] opentelemetry-instrumentation-requests → done
# [964/1663] opentelemetry-instrumentation-wsgi → done
# [965/1663] opentelemetry-proto → done
# [966/1663] opentelemetry-resourcedetector-docker → done
# [967/1663] opentelemetry-resourcedetector-kubernetes → done
# [968/1663] opentelemetry-resourcedetector-process → done
# [969/1663] opentelemetry-sdk → done
# [970/1663] opentelemetry-semantic-conventions → done
# [971/1663] opentelemetry-util-http → done
# [972/1663] opsgenie-sdk → done
# [973/1663] oracledb → done
# [974/1663] packaging → done
# [975/1663] packaging-legacy → done
# [976/1663] paho-mqtt → done
# [977/1663] paramiko → done
# [978/1663] parso → done
# [979/1663] pathable → done
# [980/1663] pathspec → done
# [981/1663] pbr → done
# [982/1663] pexpect → done
# [983/1663] pika → done
# [984/1663] pillow → done
# [985/1663] pipfile → done
# [986/1663] pkginfo → done
# [987/1663] platformdirs → done
# [988/1663] playwright → done
# [989/1663] pluggy → done
# [990/1663] ply → done
# [991/1663] polyfactory → done
# [992/1663] portalocker → done
# [993/1663] pre-commit → done
# [994/1663] propcache → done
# [995/1663] proto-plus → done
# [996/1663] protobuf → done
# [997/1663] psutil → done
# [998/1663] psycopg2-binary → done
# [999/1663] ptyprocess → done
# [1000/1663] py-import-cycles → done
# [1001/1663] pyasn1 → done
# [1002/1663] pyasn1-modules → done
# [1003/1663] pycparser → done
# [1004/1663] pydantic → done
# ❌ Failed to fetch data for pydantic[email] (pypi): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/pypi/packages/pydantic%5Bemail%5D
# [1005/1663] pydantic[email] → done
# [1006/1663] pydantic-core → done
# [1007/1663] pyee → done
# [1008/1663] pyenchant → done
# [1009/1663] pyflakes → done
# [1010/1663] pyghmi → done
# [1011/1663] pygments → done
# ❌ Failed to fetch data for pyjwt[crypto] (pypi): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/pypi/packages/pyjwt%5Bcrypto%5D
# [1012/1663] pyjwt[crypto] → done
# [1013/1663] pylint → done
# [1014/1663] pylint-plugin-utils → done
# [1015/1663] pylint-pydantic → done
# [1016/1663] pylsp-mypy → done
# [1017/1663] pymongo → done
# [1018/1663] pymssql → done
# [1019/1663] pymysql → done
# [1020/1663] pynacl → done
# [1021/1663] pyopenssl → done
# [1022/1663] pyparsing → done
# [1023/1663] pypdf → done
# [1024/1663] pyprof2calltree → done
# [1025/1663] pyproject-hooks → done
# [1026/1663] pyrate-limiter → done
# [1027/1663] pysaml2 → done
# [1028/1663] pysmb → done
# [1029/1663] pysmi-lextudio → done
# [1030/1663] pysnmp-lextudio → done
# [1031/1663] pysnmpcrypto → done
# [1032/1663] pyspnego → done
# [1033/1663] pytest → done
# [1034/1663] pytest-asyncio → done
# [1035/1663] pytest-check → done
# [1036/1663] pytest-html → done
# [1037/1663] pytest-metadata → done
# [1038/1663] pytest-mock → done
# [1039/1663] pytest-opentelemetry → done
# [1040/1663] pytest-random-order → done
# [1041/1663] pytest-subtests → done
# [1042/1663] pytest-xdist → done
# [1043/1663] python-active-directory → done
# [1044/1663] python-dateutil → done
# [1045/1663] python-jenkins → done
# [1046/1663] python-ldap → done
# [1047/1663] python-lsp-jsonrpc → done
# [1048/1663] python-lsp-server → done
# [1049/1663] python-multipart → done
# [1050/1663] python-snap7 → done
# [1051/1663] pytz → done
# [1052/1663] pyyaml → done
# [1053/1663] readme-renderer → done
# [1054/1663] recurring-ical-events → done
# [1055/1663] redfish → done
# [1056/1663] redis → done
# [1057/1663] referencing → done
# [1058/1663] reportlab → done
# [1059/1663] requests → done
# [1060/1663] requests-ntlm → done
# [1061/1663] requests-oauthlib → done
# [1062/1663] requests-toolbelt → done
# [1063/1663] requests-unixsocket → done
# [1064/1663] requirements-parser → done
# [1065/1663] responses → done
# [1066/1663] rfc3339-validator → done
# [1067/1663] rfc3986 → done
# [1068/1663] rfc3987 → done
# [1069/1663] rich → done
# [1070/1663] robotframework → done
# [1071/1663] roman → done
# [1072/1663] rpds-py → done
# [1073/1663] rsa → done
# [1074/1663] ruff → done
# [1075/1663] s3transfer → done
# [1076/1663] schemathesis → done
# [1077/1663] secretstorage → done
# [1078/1663] semver → done
# [1079/1663] setproctitle → done
# [1080/1663] setuptools → done
# [1081/1663] setuptools-scm → done
# [1082/1663] sgmllib3k → done
# [1083/1663] simplejson → done
# [1084/1663] six → done
# [1085/1663] smmap → done
# [1086/1663] sniffio → done
# [1087/1663] snmpsim-lextudio → done
# [1088/1663] snowballstemmer → done
# [1089/1663] sortedcontainers → done
# [1090/1663] soupsieve → done
# [1091/1663] sphinx → done
# [1092/1663] sphinx-autoapi → done
# [1093/1663] sphinx-autodoc-typehints → done
# [1094/1663] sphinx-basic-ng → done
# [1095/1663] sphinx-rtd-theme → done
# [1096/1663] sphinxcontrib-applehelp → done
# [1097/1663] sphinxcontrib-devhelp → done
# [1098/1663] sphinxcontrib-htmlhelp → done
# [1099/1663] sphinxcontrib-jquery → done
# [1100/1663] sphinxcontrib-jsmath → done
# [1101/1663] sphinxcontrib-plantuml → done
# [1102/1663] sphinxcontrib-qthelp → done
# [1103/1663] sphinxcontrib-serializinghtml → done
# [1104/1663] sphinxcontrib-spelling → done
# [1105/1663] starlette → done
# [1106/1663] starlette-testclient → done
# [1107/1663] stevedore → done
# [1108/1663] svglib → done
# [1109/1663] telnetlib3 → done
# [1110/1663] tenacity → done
# [1111/1663] time-machine → done
# [1112/1663] tinycss2 → done
# [1113/1663] toml → done
# [1114/1663] tomli → done
# [1115/1663] tomli-w → done
# [1116/1663] tomlkit → done
# [1117/1663] tqdm → done
# [1118/1663] trickkiste → done
# [1119/1663] twine → done
# [1120/1663] types-awscrt → done
# [1121/1663] types-beautifulsoup4 → done
# [1122/1663] types-cffi → done
# [1123/1663] types-docutils → done
# [1124/1663] types-html5lib → done
# [1125/1663] types-jsonschema → done
# [1126/1663] types-lxml → done
# [1127/1663] types-markdown → done
# [1128/1663] types-mypy-extensions → done
# [1129/1663] types-oauthlib → done
# [1130/1663] types-paho-mqtt → done
# [1131/1663] types-paramiko → done
# [1132/1663] types-pika-ts → done
# [1133/1663] types-pillow → done
# [1134/1663] types-protobuf → done
# [1135/1663] types-psutil → done
# [1136/1663] types-pyasn1 → done
# [1137/1663] types-pymssql → done
# [1138/1663] types-pymysql → done
# [1139/1663] types-pyopenssl → done
# [1140/1663] types-pysaml2 → done
# [1141/1663] types-python-dateutil → done
# [1142/1663] types-pyyaml → done
# [1143/1663] types-redis → done
# [1144/1663] types-requests → done
# [1145/1663] types-s3transfer → done
# [1146/1663] types-setuptools → done
# [1147/1663] types-simplejson → done
# [1148/1663] types-urllib3 → done
# [1149/1663] typing-extensions → done
# [1150/1663] tzdata → done
# [1151/1663] tzlocal → done
# [1152/1663] ujson → done
# [1153/1663] uri-template → done
# [1154/1663] uritemplate → done
# [1155/1663] urllib3 → done
# [1156/1663] uvicorn → done
# [1157/1663] uvicorn-worker → done
# [1158/1663] vcrpy → done
# [1159/1663] virtualenv → done
# [1160/1663] watchdog → done
# [1161/1663] webcolors → done
# [1162/1663] webencodings → done
# [1163/1663] websocket-client → done
# [1164/1663] werkzeug → done
# [1165/1663] wrapt → done
# [1166/1663] x-wr-timezone → done
# [1167/1663] xmlschema → done
# [1168/1663] yarl → done
# [1169/1663] zipp → done
# [1170/1663] zope-event → done
# [1171/1663] zope-interface → done
# [1172/1663] aiohappyeyeballs → done
# [1173/1663] aiohttp → done
# [1174/1663] alabaster → done
# [1175/1663] argcomplete → done
# [1176/1663] astroid → done
# [1177/1663] azure-identity → done
# [1178/1663] azure-mgmt-resource → done
# [1179/1663] azure-storage-blob → done
# [1180/1663] bcrypt → done
# [1181/1663] boto3 → done
# [1182/1663] boto3-stubs[logs] → done
# [1183/1663] botocore → done
# [1184/1663] botocore-stubs → done
# [1185/1663] cachetools → done
# [1186/1663] checkmk-dev-tools → done
# ❌ Failed to fetch data for coverage[toml] (pypi): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/pypi/packages/coverage%5Btoml%5D
# [1187/1663] coverage[toml] → done
# [1188/1663] cryptography → done
# [1189/1663] cssselect → done
# [1190/1663] cssselect2 → done
# [1191/1663] decorator → done
# [1192/1663] docutils → done
# [1193/1663] durationpy → done
# [1194/1663] elementpath → done
# [1195/1663] exchangelib → done
# [1196/1663] faker → done
# [1197/1663] fastapi → done
# [1198/1663] flask → done
# [1199/1663] google-api-core[grpc] → done
# [1200/1663] google-api-python-client → done
# [1201/1663] google-cloud-asset → done
# [1202/1663] googleapis-common-protos[grpc] → done
# [1203/1663] grpc-google-iam-v1 → done
# [1204/1663] grpcio → done
# [1205/1663] grpcio-status → done
# [1206/1663] hypothesis → done
# [1207/1663] icalendar → done
# [1208/1663] identify → done
# [1209/1663] jeepney → done
# [1210/1663] jinja2 → done
# [1211/1663] kubernetes → done
# [1212/1663] lxml → done
# [1213/1663] meraki → done
# [1214/1663] msal → done
# [1215/1663] msal-extensions → done
# [1216/1663] mypy-boto3-logs → done
# [1217/1663] netapp-ontap → done
# [1218/1663] nh3 → done
# [1219/1663] numpy → done
# [1220/1663] oracledb → done
# [1221/1663] paho-mqtt → done
# [1222/1663] propcache → done
# [1223/1663] proto-plus → done
# [1224/1663] psutil → done
# [1225/1663] psycopg2-binary → done
# [1226/1663] pyasn1 → done
# [1227/1663] pyghmi → done
# [1228/1663] pylint → done
# [1229/1663] pymssql → done
# [1230/1663] pypdf → done
# [1231/1663] pysmb → done
# [1232/1663] pysnmp-lextudio → done
# [1233/1663] pytest → done
# [1234/1663] pytest-cov → done
# [1235/1663] python-ldap → done
# [1236/1663] python-snap7 → done
# [1237/1663] pyyaml → done
# [1238/1663] readme-renderer → done
# [1239/1663] recurring-ical-events → done
# [1240/1663] redfish → done
# [1241/1663] redis → done
# [1242/1663] reportlab → done
# [1243/1663] requests-oauthlib → done
# [1244/1663] requests-unixsocket → done
# [1245/1663] responses → done
# [1246/1663] roman → done
# [1247/1663] roman-numerals-py → done
# [1248/1663] rpds-py → done
# [1249/1663] s3transfer → done
# [1250/1663] schemathesis → done
# [1251/1663] setproctitle → done
# [1252/1663] setuptools-scm → done
# [1253/1663] snmpsim-lextudio → done
# [1254/1663] sphinx → done
# [1255/1663] sphinx-autodoc-typehints → done
# [1256/1663] sphinx-rtd-theme → done
# [1257/1663] starlette → done
# [1258/1663] stevedore → done
# [1259/1663] types-awscrt → done
# [1260/1663] types-cffi → done
# [1261/1663] types-lxml → done
# [1262/1663] types-requests → done
# [1263/1663] types-s3transfer → done
# [1264/1663] types-setuptools → done
# [1265/1663] tzlocal → done
# [1266/1663] virtualenv → done
# [1267/1663] x-wr-timezone → done
# [1268/1663] aiohappyeyeballs → done
# [1269/1663] aiohttp → done
# [1270/1663] alabaster → done
# [1271/1663] argcomplete → done
# [1272/1663] astroid → done
# [1273/1663] azure-identity → done
# [1274/1663] azure-mgmt-resource → done
# [1275/1663] azure-storage-blob → done
# [1276/1663] bcrypt → done
# [1277/1663] boto3 → done
# [1278/1663] boto3-stubs[logs] → done
# [1279/1663] botocore → done
# [1280/1663] botocore-stubs → done
# [1281/1663] cachetools → done
# [1282/1663] checkmk-dev-tools → done
# [1283/1663] cryptography → done
# [1284/1663] cssselect → done
# [1285/1663] cssselect2 → done
# [1286/1663] decorator → done
# [1287/1663] docutils → done
# [1288/1663] elementpath → done
# [1289/1663] exchangelib → done
# [1290/1663] faker → done
# [1291/1663] fastapi → done
# [1292/1663] flask → done
# [1293/1663] google-api-core[grpc] → done
# [1294/1663] google-api-python-client → done
# [1295/1663] google-cloud-asset → done
# [1296/1663] googleapis-common-protos[grpc] → done
# [1297/1663] grpc-google-iam-v1 → done
# [1298/1663] grpcio → done
# [1299/1663] grpcio-status → done
# [1300/1663] hypothesis → done
# [1301/1663] icalendar → done
# [1302/1663] identify → done
# [1303/1663] jeepney → done
# [1304/1663] jinja2 → done
# [1305/1663] kubernetes → done
# [1306/1663] lxml → done
# [1307/1663] meraki → done
# [1308/1663] msal → done
# [1309/1663] msal-extensions → done
# [1310/1663] mypy-boto3-logs → done
# [1311/1663] netapp-ontap → done
# [1312/1663] nh3 → done
# [1313/1663] numpy → done
# [1314/1663] oracledb → done
# [1315/1663] paho-mqtt → done
# [1316/1663] propcache → done
# [1317/1663] proto-plus → done
# [1318/1663] psutil → done
# [1319/1663] psycopg2-binary → done
# [1320/1663] pyasn1 → done
# [1321/1663] pyghmi → done
# [1322/1663] pylint → done
# [1323/1663] pymssql → done
# [1324/1663] pypdf → done
# [1325/1663] pysmb → done
# [1326/1663] pysnmp-lextudio → done
# [1327/1663] pytest → done
# [1328/1663] python-ldap → done
# [1329/1663] python-snap7 → done
# [1330/1663] pyyaml → done
# [1331/1663] readme-renderer → done
# [1332/1663] recurring-ical-events → done
# [1333/1663] redfish → done
# [1334/1663] redis → done
# [1335/1663] reportlab → done
# [1336/1663] requests-oauthlib → done
# [1337/1663] requests-unixsocket → done
# [1338/1663] responses → done
# [1339/1663] roman → done
# [1340/1663] rpds-py → done
# [1341/1663] s3transfer → done
# [1342/1663] schemathesis → done
# [1343/1663] setproctitle → done
# [1344/1663] setuptools-scm → done
# [1345/1663] snmpsim-lextudio → done
# [1346/1663] sphinx → done
# [1347/1663] sphinx-autodoc-typehints → done
# [1348/1663] sphinx-rtd-theme → done
# [1349/1663] starlette → done
# [1350/1663] stevedore → done
# [1351/1663] types-awscrt → done
# [1352/1663] types-cffi → done
# [1353/1663] types-lxml → done
# [1354/1663] types-requests → done
# [1355/1663] types-s3transfer → done
# [1356/1663] types-setuptools → done
# [1357/1663] tzlocal → done
# [1358/1663] virtualenv → done
# [1359/1663] x-wr-timezone → done
# [1360/1663] pytest-repeat → done
# [1361/1663] semgrep → done
# [1362/1663] aiohappyeyeballs → done
# [1363/1663] aiohttp → done
# [1364/1663] alabaster → done
# [1365/1663] anyio → done
# [1366/1663] argcomplete → done
# [1367/1663] astroid → done
# [1368/1663] attrs → done
# [1369/1663] azure-identity → done
# [1370/1663] azure-mgmt-compute → done
# [1371/1663] azure-mgmt-resource → done
# [1372/1663] azure-storage-blob → done
# [1373/1663] bcrypt → done
# [1374/1663] boto3 → done
# [1375/1663] boto3-stubs[logs] → done
# [1376/1663] botocore → done
# [1377/1663] botocore-stubs → done
# [1378/1663] cachetools → done
# [1379/1663] checkmk-dev-tools → done
# [1380/1663] cryptography → done
# [1381/1663] cssselect → done
# [1382/1663] cssselect2 → done
# [1383/1663] decorator → done
# [1384/1663] docutils → done
# [1385/1663] durationpy → done
# [1386/1663] elementpath → done
# [1387/1663] exchangelib → done
# [1388/1663] faker → done
# [1389/1663] fastapi → done
# [1390/1663] filelock → done
# [1391/1663] flask → done
# [1392/1663] google-api-core[grpc] → done
# [1393/1663] google-api-python-client → done
# [1394/1663] google-cloud-access-context-manager → done
# [1395/1663] google-cloud-asset → done
# [1396/1663] google-cloud-monitoring → done
# [1397/1663] google-cloud-org-policy → done
# [1398/1663] google-cloud-os-config → done
# [1399/1663] googleapis-common-protos[grpc] → done
# [1400/1663] grpc-google-iam-v1 → done
# [1401/1663] grpcio → done
# [1402/1663] grpcio-status → done
# [1403/1663] hypothesis → done
# [1404/1663] icalendar → done
# [1405/1663] identify → done
# [1406/1663] importlib-metadata → done
# [1407/1663] iniconfig → done
# [1408/1663] jeepney → done
# [1409/1663] jinja2 → done
# [1410/1663] kubernetes → done
# [1411/1663] libcst → done
# [1412/1663] lxml → done
# [1413/1663] meraki → done
# [1414/1663] msal → done
# [1415/1663] msal-extensions → done
# [1416/1663] multidict → done
# [1417/1663] mypy-boto3-logs → done
# [1418/1663] netapp-ontap → done
# [1419/1663] nh3 → done
# [1420/1663] numpy → done
# [1421/1663] opentelemetry-api → done
# [1422/1663] opentelemetry-exporter-otlp → done
# [1423/1663] opentelemetry-exporter-otlp-proto-common → done
# [1424/1663] opentelemetry-exporter-otlp-proto-grpc → done
# [1425/1663] opentelemetry-exporter-otlp-proto-http → done
# [1426/1663] opentelemetry-instrumentation → done
# [1427/1663] opentelemetry-instrumentation-asgi → done
# [1428/1663] opentelemetry-instrumentation-fastapi → done
# [1429/1663] opentelemetry-instrumentation-redis → done
# [1430/1663] opentelemetry-instrumentation-requests → done
# [1431/1663] opentelemetry-instrumentation-wsgi → done
# [1432/1663] opentelemetry-proto → done
# [1433/1663] opentelemetry-sdk → done
# [1434/1663] opentelemetry-semantic-conventions → done
# [1435/1663] opentelemetry-util-http → done
# [1436/1663] oracledb → done
# [1437/1663] paho-mqtt → done
# [1438/1663] platformdirs → done
# [1439/1663] playwright → done
# [1440/1663] polyfactory → done
# [1441/1663] pre-commit → done
# [1442/1663] propcache → done
# [1443/1663] proto-plus → done
# [1444/1663] psutil → done
# [1445/1663] psycopg2-binary → done
# [1446/1663] pyghmi → done
# [1447/1663] pylint → done
# [1448/1663] pymssql → done
# [1449/1663] pyparsing → done
# [1450/1663] pypdf → done
# [1451/1663] pysmb → done
# [1452/1663] pytest → done
# [1453/1663] pytest-asyncio → done
# [1454/1663] pytest-check → done
# [1455/1663] python-ldap → done
# [1456/1663] python-snap7 → done
# [1457/1663] pytz → done
# [1458/1663] pyyaml → done
# [1459/1663] readme-renderer → done
# [1460/1663] recurring-ical-events → done
# [1461/1663] redfish → done
# [1462/1663] redis → done
# [1463/1663] reportlab → done
# [1464/1663] requests-oauthlib → done
# [1465/1663] requests-unixsocket → done
# [1466/1663] responses → done
# [1467/1663] roman → done
# [1468/1663] roman-numerals-py → done
# [1469/1663] rpds-py → done
# [1470/1663] s3transfer → done
# [1471/1663] schemathesis → done
# [1472/1663] setproctitle → done
# [1473/1663] setuptools-scm → done
# [1474/1663] sphinx → done
# [1475/1663] sphinx-autodoc-typehints → done
# [1476/1663] sphinx-rtd-theme → done
# [1477/1663] starlette → done
# [1478/1663] stevedore → done
# [1479/1663] types-awscrt → done
# [1480/1663] types-cffi → done
# [1481/1663] types-lxml → done
# [1482/1663] types-markdown → done
# [1483/1663] types-protobuf → done
# [1484/1663] types-requests → done
# [1485/1663] types-s3transfer → done
# [1486/1663] types-setuptools → done
# [1487/1663] types-simplejson → done
# [1488/1663] tzdata → done
# [1489/1663] tzlocal → done
# [1490/1663] virtualenv → done
# [1491/1663] wheel → done
# [1492/1663] x-wr-timezone → done
# [1493/1663] checkmk-dev-tools → done
# [1494/1663] aiohttp → done
# [1495/1663] argcomplete → done
# [1496/1663] azure-storage-blob → done
# [1497/1663] boto3 → done
# [1498/1663] boto3-stubs[logs] → done
# [1499/1663] botocore → done
# [1500/1663] botocore-stubs → done
# [1501/1663] checkmk-dev-tools → done
# [1502/1663] docstring-to-markdown → done
# [1503/1663] fakeredis[lua] → done
# [1504/1663] google-api-python-client → done
# [1505/1663] hypothesis → done
# [1506/1663] icalendar → done
# [1507/1663] propcache → done
# [1508/1663] pymssql → done
# [1509/1663] pytest-check → done
# [1510/1663] redfish → done
# [1511/1663] rich → done
# [1512/1663] rpds-py → done
# [1513/1663] tenacity → done
# [1514/1663] types-awscrt → done
# [1515/1663] types-cffi → done
# [1516/1663] types-lxml → done
# [1517/1663] types-mypy-extensions → done
# [1518/1663] types-oauthlib → done
# [1519/1663] types-pika-ts → done
# [1520/1663] types-protobuf → done
# [1521/1663] types-psutil → done
# [1522/1663] types-pyyaml → done
# [1523/1663] types-requests → done
# [1524/1663] types-setuptools → done
# [1525/1663] types-simplejson → done
# [1526/1663] typing-extensions → done
# [1527/1663] virtualenv → done
# [1528/1663] axios → done
# [1529/1663] lucide-vue-next → done
# [1530/1663] radix-vue → done
# [1531/1663] sanitize-html → done
# [1532/1663] @rushstack/eslint-patch → done
# [1533/1663] @testing-library/user-event → done
# [1534/1663] @tsconfig/node20 → done
# [1535/1663] @types/node → done
# [1536/1663] @types/sanitize-html → done
# [1537/1663] @vitejs/plugin-vue → done
# [1538/1663] @vue/eslint-config-prettier → done
# [1539/1663] @vue/eslint-config-typescript → done
# [1540/1663] chai → done
# [1541/1663] eslint → done
# [1542/1663] eslint-plugin-vue → done
# [1543/1663] jsdom → done
# [1544/1663] msw → done
# [1545/1663] prettier → done
# [1546/1663] sass-embedded → done
# [1547/1663] typescript → done
# [1548/1663] vite → done
# [1549/1663] vitest → done
# [1550/1663] vue-tsc → done
# [1551/1663] azure-core → done
# [1552/1663] boto3-stubs[logs] → done
# [1553/1663] botocore → done
# [1554/1663] botocore-stubs → done
# [1555/1663] checkmk-dev-tools → done
# [1556/1663] hypothesis → done
# [1557/1663] lxml → done
# [1558/1663] meraki → done
# [1559/1663] multidict → done
# [1560/1663] opentelemetry-api → done
# [1561/1663] opentelemetry-exporter-otlp → done
# [1562/1663] opentelemetry-exporter-otlp-proto-common → done
# [1563/1663] opentelemetry-exporter-otlp-proto-grpc → done
# [1564/1663] opentelemetry-exporter-otlp-proto-http → done
# [1565/1663] opentelemetry-instrumentation → done
# [1566/1663] opentelemetry-instrumentation-asgi → done
# [1567/1663] opentelemetry-instrumentation-fastapi → done
# [1568/1663] opentelemetry-instrumentation-redis → done
# [1569/1663] opentelemetry-instrumentation-requests → done
# [1570/1663] opentelemetry-instrumentation-wsgi → done
# [1571/1663] opentelemetry-proto → done
# [1572/1663] opentelemetry-sdk → done
# [1573/1663] opentelemetry-semantic-conventions → done
# [1574/1663] opentelemetry-util-http → done
# [1575/1663] oracledb → done
# [1576/1663] py → done
# [1577/1663] pytest-check → done
# [1578/1663] pytest-repeat → done
# [1579/1663] retry → done
# [1580/1663] schemathesis → done
# [1581/1663] types-awscrt → done
# [1582/1663] types-oauthlib → done
# [1583/1663] typing-extensions → done
# [1584/1663] urllib3 → done
# [1585/1663] yarl → done
# [1586/1663] beautifulsoup4 → done
# [1587/1663] boto3-stubs[logs] → done
# [1588/1663] botocore → done
# [1589/1663] checkmk-dev-tools → done
# [1590/1663] dill → done
# [1591/1663] google-api-python-client → done
# [1592/1663] google-auth → done
# [1593/1663] googleapis-common-protos[grpc] → done
# [1594/1663] greenlet → done
# [1595/1663] httpcore → done
# [1596/1663] lazy-object-proxy → done
# [1597/1663] markdown → done
# [1598/1663] opentelemetry-api → done
# [1599/1663] opentelemetry-exporter-otlp → done
# [1600/1663] opentelemetry-exporter-otlp-proto-common → done
# [1601/1663] opentelemetry-exporter-otlp-proto-grpc → done
# [1602/1663] opentelemetry-exporter-otlp-proto-http → done
# [1603/1663] opentelemetry-instrumentation → done
# [1604/1663] opentelemetry-instrumentation-asgi → done
# [1605/1663] opentelemetry-instrumentation-fastapi → done
# [1606/1663] opentelemetry-instrumentation-redis → done
# [1607/1663] opentelemetry-instrumentation-requests → done
# [1608/1663] opentelemetry-instrumentation-wsgi → done
# [1609/1663] opentelemetry-proto → done
# [1610/1663] opentelemetry-sdk → done
# [1611/1663] opentelemetry-semantic-conventions → done
# [1612/1663] opentelemetry-util-http → done
# [1613/1663] pillow → done
# [1614/1663] recurring-ical-events → done
# [1615/1663] rsa → done
# [1616/1663] starlette → done
# [1617/1663] types-markdown → done
# [1618/1663] uvicorn → done
# [1619/1663] yarl → done
# [1620/1663] pillow → done
# [1621/1663] pillow → done
# [1622/1663] aiohttp → done
# [1623/1663] boto3-stubs[logs] → done
# [1624/1663] botocore → done
# [1625/1663] botocore-stubs → done
# [1626/1663] certifi → done
# [1627/1663] checkmk-dev-tools → done
# [1628/1663] frozenlist → done
# [1629/1663] gevent → done
# [1630/1663] google-api-python-client → done
# [1631/1663] google-cloud-asset → done
# [1632/1663] google-cloud-org-policy → done
# [1633/1663] greenlet → done
# [1634/1663] h11 → done
# [1635/1663] httpcore → done
# [1636/1663] hypothesis → done
# [1637/1663] identify → done
# [1638/1663] jsonschema-specifications → done
# [1639/1663] lxml → done
# [1640/1663] meraki → done
# [1641/1663] more-itertools → done
# [1642/1663] msal → done
# [1643/1663] mypy-boto3-logs → done
# [1644/1663] mypy-extensions → done
# [1645/1663] numpy → done
# [1646/1663] packaging → done
# [1647/1663] polyfactory → done
# [1648/1663] pyghmi → done
# [1649/1663] pytest-opentelemetry → done
# [1650/1663] python-jenkins-checkmk-retry-parameter → done
# [1651/1663] recurring-ical-events → done
# [1652/1663] reportlab → done
# [1653/1663] s3transfer → done
# [1654/1663] schemathesis → done
# [1655/1663] setuptools-scm → done
# [1656/1663] soupsieve → done
# [1657/1663] sphinx-autodoc-typehints → done
# [1658/1663] types-mypy-extensions → done
# [1659/1663] types-s3transfer → done
# [1660/1663] types-setuptools → done
# [1661/1663] uvicorn → done
# [1662/1663] py-cpuinfo → done
# [1663/1663] pytest-benchmark → done
