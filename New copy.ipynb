# %% [markdown]
# ## Clone Repos

# %%
import os
import re
import subprocess
from tqdm import tqdm
import xml.etree.ElementTree as ET
from typing import List, Dict, Any
from collections import defaultdict
from git import Repo, BadName
from pathlib import Path
import json
# Cell 1: Imports and setup
import json
import requests
import urllib.parse
from datetime import datetime
from collections import defaultdict
from packaging.version import Version, InvalidVersion

# Global cache

# %%
cached_versions = defaultdict(dict)

# %%
# Here we are defining the functions that will be used to find all the necesssary files in the repository to extract the version information from the repository and load their commit history.

# %%
def find_all_files(repo_path):
    found_files = []
    for root, dirs, file_list in os.walk(repo_path):  # renamed 'files' to 'file_list'
        for file in file_list:
            if file == "pom.xml" or file == "requirements.txt" or file == "package.json" or file == "setup.py" or file == "pyproject.toml":
                full_path = os.path.join(root, file)
                found_files.append(full_path)
    return found_files

# %%
import fnmatch


def find_all_gradle_files(repo_path):
    gradle_files = []
    patterns = [
        "build.gradle",
        "settings.gradle",
        "gradle.properties",
        "build.gradle.kts",
        "settings.gradle.kts",
        "*.gradle",
        "*.gradle.kts"
    ]

    for root, dirs, files in os.walk(repo_path):
        for file in files:
            for pattern in patterns:
                if fnmatch.fnmatch(file, pattern):
                    full_path = os.path.join(root, file)
                    gradle_files.append(full_path)
                    break
    return gradle_files

# %%
def find_commits_with_changes(repo_path, file_paths):
    repo = Repo(repo_path)
    commits_with_changes = {}

    for file_path in file_paths:
        rel_path = os.path.relpath(file_path, repo_path)
        commits = list(repo.iter_commits(paths=rel_path))
        
        commits_with_changes[rel_path] = [commit.hexsha for commit in commits]
    
    return commits_with_changes

# %%
# Here we deinfe functions for loading the commit hiostroy of the files we found in the previous step and extracting the version information from them.

# %%
def get_all_relevant_commits(repo_path: str, file_paths: List[str]) -> Dict[str, List[str]]:
    repo = Repo(repo_path)
    commits_with_changes = {}

    for file_path in file_paths:
        rel_path = os.path.relpath(file_path, repo_path)

        # Get all commits that modified the file
        result = subprocess.run(
            ["git", "-C", repo_path, "log", "--follow", "--pretty=format:%H", "--name-only", "--", rel_path],
            capture_output=True,
            text=True,
            check=True
        )

        lines = result.stdout.strip().split('\n')
        current_commit = None

        for line in lines:
            stripped_line = line.strip()
            
            if len(stripped_line) == 40 and all(c in '0123456789abcdef' for c in stripped_line):  # Check if it looks like a SHA-1 hash
                current_commit = stripped_line
                if current_commit not in commits_with_changes:
                    commits_with_changes[current_commit] = set()  # Using set to avoid duplicates
            elif current_commit:
                modified_file = stripped_line
                if modified_file:  # Ensure we don't add empty lines
                    commits_with_changes[current_commit].add(modified_file)

    # Convert commits to a sorted list based on commit date
    commit_objects = []
    for commit_hash in commits_with_changes.keys():
        try:
            commit_obj = repo.commit(commit_hash)
            commit_objects.append((commit_obj, commit_hash))
        except BadName:
            print(f"Skipping invalid commit hash: {commit_hash}")  # Warn if a bad commit hash is found

    sorted_commits = sorted(commit_objects, key=lambda x: x[0].committed_date)
    
    # Creating a sorted dictionary of commits with their modified files
    sorted_commits_with_changes = {
        commit_hash: list(commits_with_changes[commit_hash]) for _, commit_hash in sorted_commits
        }
    
    global commits_with_date
    commits_with_date = {
        commit_hash: repo.commit(commit_hash).committed_datetime.strftime("%Y-%m-%d %H:%M:%S")
        for _, commit_hash in sorted_commits
    }

    return sorted_commits_with_changes

# %% [markdown]
# # Here we parse the correct dependencies from the pom.xml file in JAVA

# %%
# Initialize file cache
file_cache = {}
properties_cache = {}
NAMESPACE = {'mvn': 'http://maven.apache.org/POM/4.0.0'}
properties = {}

def parse_pom_xml(content: str, file_path: str, properties: Dict[str, str] = None) -> Dict[str, str]:
    if properties is None:
        properties = {}
    else:
        properties = properties.copy()  # Avoid side effects

    dependencies = {}

    try:
        root = ET.fromstring(content)

        # Update namespace if needed
        if 'xmlns' in root.attrib:
            NAMESPACE['mvn'] = root.attrib['xmlns']

        # Load project properties
        for prop in root.findall(".//mvn:properties/*", NAMESPACE):
            if prop.tag and prop.text:
                prop_name = prop.tag.split('}')[-1]
                properties[prop_name] = prop.text.strip()
                properties_cache[prop_name] = properties[prop_name]
        
        # Load project and parent versions as fallback properties
        project_version = root.find(".//mvn:version", NAMESPACE)
        if project_version is not None and project_version.text:
            properties["project.version"] = project_version.text.strip()

        parent_version = root.find(".//mvn:parent/mvn:version", NAMESPACE)
        if parent_version is not None and parent_version.text:
            properties["parent.version"] = parent_version.text.strip()

        parent_info = {}
        relative_path_elem = root.find(".//mvn:parent/mvn:relativePath", NAMESPACE)
        if relative_path_elem is not None and relative_path_elem.text:
            parent_info = {"parent_pom_path": relative_path_elem.text.strip()}

        # Read dependencies
        for dependency in root.findall(".//mvn:dependency", NAMESPACE):
            group_id = dependency.find("mvn:groupId", NAMESPACE)
            artifact_id = dependency.find("mvn:artifactId", NAMESPACE)
            version = dependency.find("mvn:version", NAMESPACE)

            if group_id is not None and artifact_id is not None:
                dep_key = f"{group_id.text.strip()}:{artifact_id.text.strip()}"
                if "${" in dep_key and "}" in dep_key:
                    dep_key = (resolve_cached(dep_key))

                if version is not None and version.text:
                    version_text = version.text.strip()
                    if version_text.startswith("${") and version_text.endswith("}"):
                        prop_name = version_text[2:-1]
                        resolved_version = properties.get(prop_name, "UNRESOLVED")
                        if resolved_version == "UNRESOLVED":
                            resolved_version = resolve_from_parent(prop_name, file_path, parent_info)
                            if (resolved_version =="UNRESOLVED"):
                                resolved_version = properties_cache.get(prop_name, "UNRESOLVED")
                        if resolved_version.startswith("${") and resolved_version.endswith("}"):
                            resolved_version = resolve_cached(resolved_version)
                        dependencies[dep_key] = resolved_version
                    else:
                        dependencies[dep_key] = version_text
                #else:
                    #dependencies[dep_key] = "UNSPECIFIED"

    except ET.ParseError as e:
        print(f"XML parsing error: {e}")

    return dependencies




def resolve_cached(prop_name, visited=None):
    matches = re.findall(r"\$\{([^}]+)\}", prop_name)
    if not matches:
        return properties_cache.get(prop_name)  # nothing to resolve, return as is

    resolved = prop_name
    for match in matches:
        inner_value = resolve_cached(match)
        if inner_value is None:
            return match
        resolved = resolved.replace(f"${{{match}}}", inner_value)

    return resolved



def resolve_from_parent(prop_name: str, file_path: str, properties: Dict[str, str]) -> str:
    parent_pom_path = properties.get("parent_pom_path")   
    if parent_pom_path is None:
        final_path = "pom.xml"
        parent_file = str(final_path).replace("\\", "/")
        if parent_file not in file_cache:
            return "UNRESOLVED"
        content = file_cache[parent_file]
        parent_prop_value = get_all_properties(content, prop_name, final_path, {})
        return parent_prop_value

    file_path = Path(file_path) if not isinstance(file_path, Path) else file_path
    parent_pom_path = Path(parent_pom_path) if not isinstance(parent_pom_path, Path) else parent_pom_path
    combined = file_path.parent / parent_pom_path

    stack = []
    for part in combined.parts:
        if part == "..":
            if stack and stack[-1] != "..":
                stack.pop()
            else:
                stack.append(part)
        elif part != ".":
            stack.append(part)
    final_path = Path(*stack)
    parent_file = str(final_path).replace("\\", "/")
    if parent_file not in file_cache:
        #print(f"[DEBUG] Skipping missing file: {parent_file}")
        return "UNRESOLVED"
    content = file_cache[parent_file]
    parent_prop_value = get_all_properties(content, prop_name, final_path, {})
    return parent_prop_value

def get_all_properties(content: str, target_prop: str, file_path: str, properties: Dict[str, str] = None):
    if properties is None:
        properties = {}
    else:
        properties = properties.copy()  # Avoid side effects

    try:
        root = ET.fromstring(content)

        if 'xmlns' in root.attrib:
            NAMESPACE['mvn'] = root.attrib['xmlns']

        # Properly assign keys without shadowing target_prop
        for prop in root.findall(".//mvn:properties/*", NAMESPACE):
            if prop.tag and prop.text:
                key = prop.tag.split('}')[-1]
                properties[key] = prop.text.strip()

        return properties.get(target_prop, "UNRESOLVED")
    except Exception as e:
        return "UNRESOLVED"    

def load_file_at_commit(repo, commit_hash, file_path):
    try:
        commit = repo.commit(commit_hash)
        blob = commit.tree / file_path
        content = blob.data_stream.read().decode('utf-8')
        file_cache[file_path] = content
        return content
    except Exception as e:
        print(f"[DEBUG]Error loading file '{file_path}' at commit '{commit_hash}': {e}")
        return None


def process_commit(repo, commit_hash, changed_files, dependencies_snapshot):
    for file_path in changed_files:
        if file_path.endswith("pom.xml"):
            content = load_file_at_commit(repo, commit_hash, file_path)
            if content:
                new_dependencies = parse_pom_xml(content, file_path, properties)
                dependencies_snapshot[file_path] = new_dependencies
    return dependencies_snapshot


def process_commits(repo, commits_with_changes):
    dependencies_over_time = {}
    dependencies_snapshot = {}

    for commit_hash, changed_files in tqdm(commits_with_changes.items(), desc="Processing commits"):
        dependencies_snapshot = process_commit(repo, commit_hash, changed_files, dependencies_snapshot)
        dependencies_over_time[commit_hash] = dependencies_snapshot.copy()

    return dependencies_over_time

# %%
# daten laten und neuseten versionen holen von deps.dev api und proj_version_lag speichern und so.

# %%
# Cell 2: System‐name normalization
def normalize_system(system: str) -> str:
    """
    Map generic system names to the deps.dev API identifiers.
    """
    mapping = {
        "java": "maven",
        "javascript": "npm",
        "python": "pypi",
        "go": "go"
    }
    return mapping.get(system, system)

# %%
# Cell 3: Version parsing helper
def get_major_version(version_str: str):
    """
    Safely extract the major version number, or return None if invalid.
    """
    try:
        return Version(version_str).major
    except InvalidVersion:
        return None

# %%
# Cell 4: Fetching & caching package data
def fetch_package_data(package_name: str, system: str) -> dict:
    """
    Hit the deps.dev API and return the raw JSON for a given package.
    """
    encoded = urllib.parse.quote(package_name, safe="")
    url = f"https://api.deps.dev/v3alpha/systems/{system}/packages/{encoded}"
    resp = requests.get(url)
    resp.raise_for_status()
    return resp.json()

def get_cached_package_data(package_name: str, system: str) -> dict:
    """
    Return cached data if available, otherwise fetch and cache.
    """
    '''if package_name not in cached_versions[system]:
        try:
            cached_versions[system][package_name] = fetch_package_data(package_name, system)
        except requests.RequestException as e:
            print(f"❌ Failed to fetch data for {package_name} ({system}): {e}")
            cached_versions[system][package_name] = {}
    return cached_versions[system][package_name]
    '''
    if package_name not in cached_versions[system]:
        try:
            # 1) root data
            data = fetch_package_data(package_name, system)
            try:
                # 2) pick a version (first in the list)
                versions = data.get("versions", [])
                if not versions:
                    raise RuntimeError(f"No versions found for {package_name}")
                # if versions is a list of strings:
                chosen_version = versions[0].get("versionKey", {}).get("version")
                # if it's list of objects, adjust to versions[0]["version"]

                # 3) fetch version-specific metadata
                pkg_enc = urllib.parse.quote(package_name, safe="")
                ver_url = (
                    f"https://api.deps.dev/v3/systems/{system}"
                    f"/packages/{pkg_enc}/versions/{chosen_version}"
                )
                ver_resp = requests.get(ver_url)
                ver_resp.raise_for_status()
                version_data = ver_resp.json()
                #print(version_data)
                #data["version_data"] = version_data

                # 4) fetch OSSF score if available
                rel = version_data.get("relatedProjects", [])
                if rel:
                    project_key = rel[0].get("projectKey", {}).get("id")
                else:
                    project_key = None

                if project_key and project_key.lower() != "null":
                    pk_enc = urllib.parse.quote(project_key, safe="")
                    ossf_url = f"https://api.deps.dev/v3/projects/{pk_enc}"
                    ossf_resp = requests.get(ossf_url)
                    if ossf_resp.ok:
                        #print(f"OSSF score for {package_name} (npm): {ossf_resp.json()}")
                        #print(ossf_resp.json().get("scorecard").get("overallScore"))
                        data["ossf_score"] = ossf_resp.json().get("scorecard",{}).get("overallScore")
                        cached_versions[system][package_name] = data
                    else:
                        print(f"❌ Failed to fetch OSSF score for {package_name} ({system}): {ossf_resp.status_code}")
                        data["ossf_score"] = None
                        cached_versions[system][package_name] = data
                else:
                    print(f"❌ No related project found for {package_name} ({system})")
                    data["ossf_score"] = None
                    cached_versions[system][package_name] = data
                    
                # 5) cache the combined payload
            except requests.RequestException as e:
                print(f"❌ Failed to fetch version data for {package_name} ({system}): {e}")
                cached_versions[system][package_name] = data

        except (requests.RequestException, RuntimeError) as e:
            print(f"❌ Failed to fetch data for {package_name} ({system}): {e}")
            cached_versions[system][package_name] = {}

    return cached_versions[system][package_name]

# %%
# Cell 5: Core analysis routine
def analyze_entry(entry: dict) -> dict:
    """
    Given a single change entry, enrich it with:
      - newest_version_at_commit
      - released_date
      - latest_at_commit_time
      - proj_version_lag (caret‐aware)
    """
    pkg        = entry["dependency"]
    raw_new    = entry["new_version"]
    has_caret  = raw_new.startswith("^")
    new_ver    = raw_new.lstrip("^")
    commit_dt  = datetime.strptime(entry["date"], "%Y-%m-%d %H:%M:%S")
    sys_name   = normalize_system(entry["system"])
    is_npm = (sys_name == "npm")


    data       = get_cached_package_data(pkg, sys_name)
    if data == {}:
        entry["alpha/beta/rc"] = False
        entry["newest_version_at_commit"]= "N/A"
        entry["released_date"]= "N/A"
        entry["latest_at_commit_time"]= "N/A"
        entry["proj_version_lag"]= "N/A"
        entry["latency"]= "N/A"
        return entry

    all_vers   = data.get("versions", [])
    commit_vs  = []

    # Filter to releases published on or before commit date
    for v in all_vers:
        ver = v.get("versionKey", {}).get("version")
        pub = v.get("publishedAt")
        if not (ver and pub): continue
        try:
            pub_dt = datetime.strptime(pub, "%Y-%m-%dT%H:%M:%SZ")
        except ValueError:
            continue
        if pub_dt <= commit_dt:
            try:
                commit_vs.append(Version(ver))
            except InvalidVersion:
                pass
        

    # Determine newest version at commit time
    entry["alpha/beta/rc"] = False

    if commit_vs and is_npm:
        max_major = max(v.major for v in commit_vs)
        highest   = max(v for v in commit_vs if v.major == max_major)
        entry["newest_version_at_commit"] = str(highest)
        entry["newest_version_at_commit"] = entry["newest_version_at_commit"].replace("a", "-alpha.").replace("b", "-beta.").replace("rc", "-rc.")
        entry["alpha/beta/rc"] = highest.pre is not None
        
        #        print(f"Highest version at commit: {highest}")
    else:
        entry["newest_version_at_commit"] = None

    # Track release date & latest at commit
    entry["released_date"]         = None
    entry["latest_at_commit_time"] = None
    latest_pub_date = None

    target_major = get_major_version(new_ver) if is_npm else None

    try:
        baseline = Version(new_ver)
    except InvalidVersion:
        baseline = None

    if not has_caret:
        for v in all_vers:
            ver = v.get("versionKey", {}).get("version")
            pub = v.get("publishedAt")
            if not (ver and pub): continue
            try:
                parsed = Version(ver)
            except InvalidVersion:
                parsed = None

            # npm: restrict to same major
            if is_npm and parsed and parsed.major != target_major:
                continue

            pub_dt = datetime.strptime(pub, "%Y-%m-%dT%H:%M:%SZ")
            if ver == new_ver:
                entry["released_date"] = pub_dt.isoformat()
            if pub_dt <= commit_dt and (latest_pub_date is None or pub_dt > latest_pub_date):
                latest_pub_date            = pub_dt
                entry["latest_at_commit_time"] = ver
    else:
        release_target = entry["newest_version_at_commit"]
        target_major = Version(release_target).major if release_target else None
        for v in all_vers:
            ver_str = v.get("versionKey", {}).get("version")
            pub = v.get("publishedAt")
            if not (ver_str and pub):
                continue
            try:
                pub_dt = datetime.strptime(pub, "%Y-%m-%dT%H:%M:%SZ")
                ver_obj = Version(ver_str)
            except (ValueError, InvalidVersion):
                continue
            # restrict to same major
            if target_major is not None and ver_obj.major != target_major:
                continue
            if ver_str == release_target:
                entry["released_date"] = pub_dt.isoformat()

    rel_date_str = entry.get("released_date")
    released_date_dt = datetime.fromisoformat(rel_date_str) if rel_date_str else None

    # Compute caret‐aware proj_version_lag
    

    if has_caret and baseline:
        same_maj = [v for v in commit_vs if v.major == baseline.major]
        if same_maj:
            baseline = max(same_maj)

    if baseline and commit_vs:
        entry["proj_version_lag"] = sum(1 for v in commit_vs if v > baseline)
    else:
        entry["proj_version_lag"] = -1
        for v in all_vers:
            version = v.get("versionKey").get("version")
            v_date_str =  v.get("publishedAt")
            if not v_date_str or not version:
                continue
            v_date = datetime.strptime(v_date_str, "%Y-%m-%dT%H:%M:%SZ")
            if released_date_dt and v_date >= released_date_dt:
                if v_date <= commit_dt:
                    entry["proj_version_lag"] += 1
    

    # Handle latency: 
    commit_str = entry.get("date")
    commit_dt  = datetime.strptime(commit_str,  "%Y-%m-%d %H:%M:%S")

    release_str = entry.get("released_date")
    if release_str is None:
        entry["latency"] = "N/A"
        return entry
    
    release_dt = datetime.strptime(release_str,  "%Y-%m-%dT%H:%M:%S")
    if release_dt >= commit_dt:
        entry["latency"] = "future: " + str((commit_dt - release_dt).days)
        entry["proj_version_lag"] = -1
    else:
        entry["latency"] = (commit_dt - release_dt).days

    print(data.get("ossf_score", {}))
    entry["criticality"] = data.get("ossf_score", "N/A")
    return entry

# %%
# Cell 6: Batch processing function
def process_json_file(input_path: str, output_path: str):
    """
    Read the input JSON, enrich each entry, and write to output.
    """
    with open(input_path, "r") as f:
        entries = json.load(f)

    enriched = []
    for i, e in enumerate(entries, 1):
        enriched.append(analyze_entry(e))
        #print(f"[{i}/{len(entries)}] {e['dependency']} → done")

    with open(output_path, "w") as f:
        json.dump(enriched, f, indent=2)

# %% [markdown]
# # Here we start weith the actual execution of the Code

# %%
repo_name = "keycloak/keycloak"

repo_url = "https://github.com/" + repo_name
destination_path = "./" + repo_name
repo_path = repo_name

commits_with_date = {}

# %%
if not os.path.exists(destination_path) or not os.listdir(destination_path):
	Repo.clone_from(repo_url, destination_path)
else:
	print(f"Directory '{destination_path}' already exists and is not empty. Skipping clone.")
# Out:
# Directory './keycloak/keycloak' already exists and is not empty. Skipping clone.

# %%
repo = Repo(destination_path)

# %%
# Example usage
repo_path = "./" + repo_name  # Replace with your cloned repo path
file_paths = find_all_files(repo_path)
file_paths_gradle = find_all_gradle_files(repo_path)
file_paths += file_paths_gradle

# Display all found pom.xml paths
for path in file_paths[:10]:
    path = path.replace('\\', '/')
    print(path)

print(len(file_paths))
# Out:
# ./keycloak/keycloak/pom.xml
# ./keycloak/keycloak/adapters/pom.xml
# ./keycloak/keycloak/adapters/saml/pom.xml
# ./keycloak/keycloak/adapters/saml/core/pom.xml
# ./keycloak/keycloak/adapters/saml/core-public/pom.xml
# ./keycloak/keycloak/adapters/saml/wildfly/pom.xml
# ./keycloak/keycloak/adapters/saml/wildfly/wildfly-subsystem/pom.xml
# ./keycloak/keycloak/adapters/saml/wildfly-elytron/pom.xml
# ./keycloak/keycloak/adapters/spi/pom.xml
# ./keycloak/keycloak/adapters/spi/adapter-spi/pom.xml
# 161

# %%
# Example usage
sorted_commit_hashes = get_all_relevant_commits(repo_path, file_paths)

# Display results
print(f"Total number of commits: {len(sorted_commit_hashes)}")
print("Commits (earliest to latest):")
for commit_hash, files in list(sorted_commit_hashes.items())[:10]:  # Displaying the first 10 for brevity
    print(f"{commit_hash}: {files}")

# %% [markdown]
# ## java pom.xml parsing

# %%
dependencies_over_time = process_commits(repo, sorted_commit_hashes)

import json

with open("java_pom.json", "w") as f:
    json.dump(dependencies_over_time, f, indent=4)
# Out:
# Processing commits:  59%|█████▉    | 2867/4819 [00:37<00:13, 147.66it/s]
# [DEBUG]Error loading file 'pom.xml' at commit '4dcb819c063794f16f0ee6c947dd01cc02e2cf46': "Blob or Tree named 'pom.xml' not found"
# Processing commits:  83%|████████▎ | 4002/4819 [00:45<00:05, 146.41it/s]
# [DEBUG]Error loading file 'distribution/saml-adapters/wildfly-adapter/wildfly-modules/pom.xml' at commit '0ce778061c0bbd96deedf74064e71a1f8f1191a6': "Blob or Tree named 'saml-adapters' not found"
# Processing commits: 100%|██████████| 4819/4819 [00:47<00:00, 101.87it/s]

# %% [markdown]
# ## python and javascript parsing:

# %%
import tomli
import ast

# %%
# Initialize cache and data structures
file_cache = {}
unique_entries = set()
dependency_changes = defaultdict(list)

# Supported version specifiers in requirements.txt
VERSION_SPECIFIERS = [
    '==', '>=', '<=', '~=', '!=', '>', '<'
]


def load_file_at_commit(repo_path, commit_hash, file_path):
    try:
        result = subprocess.run(
            ["git", "-C", repo_path, "show", f"{commit_hash}:{file_path}"],
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            text=True,
            check=True
        )
        return result.stdout
    except subprocess.CalledProcessError as e:
        print(f"Error loading file '{file_path}' at commit '{commit_hash}': {e.stderr}")
        return None


def process_commit_file_content(repo_path, sha, file_path, type):
    content = load_file_at_commit(repo_path, sha, file_path)
        
    if content:
        parse_file_content(content, sha, file_path, type)

def parse_pyproject_toml(content: str) -> dict:
    try:
        data = tomli.loads(content)
    except tomli.TOMLDecodeError:
        return {}

    # PEP 621 style
    deps = data.get("project", {}).get("dependencies", [])
    if not deps:
        # Poetry-style
        poetry_deps = data.get("tool", {}).get("poetry", {}).get("dependencies", {})
        deps = [f"{pkg}{v if isinstance(v, str) else ''}" for pkg, v in poetry_deps.items() if pkg.lower() != "python"]

    result = {}
    for dep in deps:
        parts = re.split(r"([<>=!~]+)", dep, maxsplit=1)
        name = parts[0].strip()
        version = ''.join(parts[1:]).strip() if len(parts) > 1 else "latest-version-available"
        result[name] = version

    return result


# === ADDED ===
def parse_setup_py(content: str) -> dict:
    try:
        tree = ast.parse(content)
    except SyntaxError:
        return {}

    class SetupVisitor(ast.NodeVisitor):
        def __init__(self):
            self.install_requires = []

        def visit_Call(self, node):
            if isinstance(node.func, ast.Name) and node.func.id == "setup":
                for keyword in node.keywords:
                    if keyword.arg == "install_requires":
                        if isinstance(keyword.value, (ast.List, ast.Tuple)):
                            for elt in keyword.value.elts:
                                if isinstance(elt, ast.Str):
                                    self.install_requires.append(elt.s)
            self.generic_visit(node)

    visitor = SetupVisitor()
    visitor.visit(tree)

    result = {}
    for dep in visitor.install_requires:
        parts = re.split(r"([<>=!~]+)", dep, maxsplit=1)
        name = parts[0].strip()
        version = ''.join(parts[1:]).strip() if len(parts) > 1 else "latest-version-available"
        result[name] = version

    return result

def parse_file_content(content, sha, filename, type):
    dependencies = {}
    hash_pattern = re.compile(r"--hash=sha256:[a-fA-F0-9]{64}")

    if type == "py" and "requirements.txt" in filename:
        for line in content.splitlines():
            line = line.strip()

            if not line or line.startswith('#') or line.startswith("--"):  # Ignore comments and empty lines
                continue

            # Check if line is a hash
            if hash_pattern.match(line):
                continue

            # Remove inline comments
            if '#' in line:
                line = line.split('#', 1)[0].strip()

            # Find the version specifier used
            version = "UNSPECIFIED"
            for specifier in VERSION_SPECIFIERS:
                if specifier in line:
                    package, version = line.split(specifier, 1)
                    package = package.strip()
                    version = version.strip()
                    dependencies[package] = version
                    break
            else:  # No version specifier found
                package = line
                dependencies[package] = "latest-version-available"

    elif type == "js" and "package.json" in filename:
        import json
        try:
            parsed_json = json.loads(content)
            if "dependencies" in parsed_json:
                dependencies.update(parsed_json["dependencies"])
            if "devDependencies" in parsed_json:
                dependencies.update(parsed_json["devDependencies"])
        except json.JSONDecodeError as e:
            print(f"Error parsing JSON file '{filename}': {e}")
    
    elif type == "py" and "setup.py" in filename:
        dependencies = parse_setup_py(content)
    elif type == "py" and "pyproject.toml" in filename:
        dependencies = parse_pyproject_toml(content)


    # Store the parsed dependencies for this commit
    dependency_changes[sha] = {
        "filename": filename,
        "dependencies": dependencies,
        "ecosystem": type
    }


def process_commits(repo_path, commits_with_files):
    for sha, files in tqdm(commits_with_files.items(), desc="Processing commits"):
        for file_path in files:
            if file_path.endswith("requirements.txt"):
                process_commit_file_content(repo_path, sha, file_path, "py")
            elif file_path.endswith("package.json"):
                process_commit_file_content(repo_path, sha, file_path, "js")
            elif file_path.endswith("setup.py"):
                process_commit_file_content(repo_path, sha, file_path, "py")
            elif file_path.endswith("pyproject.toml"):
                process_commit_file_content(repo_path, sha, file_path, "py")


def save_results(output_file="python_and_javascript.json"):
    import json
    with open(output_file, "w") as f:
        json.dump(dependency_changes, f, indent=4)

# %%
process_commits(repo_path, sorted_commit_hashes)
save_results()
# Out:
# Processing commits: 100%|██████████| 4819/4819 [03:00<00:00, 26.63it/s]

# %%
file_cache = {}

def is_gradle_related(file_path):
    return (
        file_path.endswith("build.gradle")
        or file_path.endswith("build.gradle.kts")
        or file_path.endswith("settings.gradle")
        or file_path.endswith("settings.gradle.kts")
        or file_path.endswith("gradle.properties")
        or file_path.endswith(".gradle")
        or file_path.endswith(".gradle.kts")
    )

def parse_gradle_properties(content):
    props = {}
    for line in content.splitlines():
        line = line.strip()
        if line and not line.startswith("#") and "=" in line:
            key, value = line.split("=", 1)
            props[key.strip()] = value.strip()
    return props


def extract_dependencies_block(content: str) -> str:
    """Returns only the content inside dependencies { ... } block(s)."""
    lines = content.splitlines()
    inside = False
    depth = 0
    collected = []

    for line in lines:
        stripped = line.strip()
        if stripped.startswith("dependencies"):
            if "{" in stripped:
                inside = True
                depth = stripped.count("{") - stripped.count("}")
                continue

        if inside:
            if "{" in stripped:
                depth += stripped.count("{")
            if "}" in stripped:
                depth -= stripped.count("}")
            collected.append(line)
            if depth <= 0:
                inside = False

    return "\n".join(collected)


def parse_gradle_dependencies(file_content: str, properties: Dict[str, str], commit_sha: str, file_path: str) -> List[Dict[str, Any]]:
    dependencies = []

    # NEW: extract only content inside dependencies block(s)
    block = extract_dependencies_block(file_content)

    # Patterns for Kotlin + Groovy
    patterns = [
        re.compile(r'(?P<config>\w+)\s*\(\s*["\'](?P<group>[^:\'"]+):(?P<artifact>[^:\'"]+):(?P<version>[^\'"]+)["\']\s*\)'),  # Kotlin DSL
        re.compile(r'(?P<config>\w+)\s+["\'](?P<group>[^:\'"]+):(?P<artifact>[^:\'"]+):(?P<version>[^\'"]+)["\']')  # Groovy DSL
    ]

    for pattern in patterns:
        for match in pattern.finditer(block):
            config = match.group("config")
            group = match.group("group")
            artifact = match.group("artifact")
            version = match.group("version")

            version_source = "literal"
            if version.startswith("$") or "${" in version:
                var_name = version.replace("$", "").replace("{", "").replace("}", "")
                if var_name in properties:
                    version = properties[var_name]
                    version_source = "resolved_from_property"
                else:
                    version_source = "unresolved"

            if "$" not in group and "$" not in artifact and "$" not in version:
                dependencies.append({
                    "commit": commit_sha,
                    "file": file_path,
                    #"tool": "gradle",
                    #"configuration": config,
                    "group": group,
                    "artifact": artifact,
                    "version": version,
                    #"version_source": version_source
                })

    return dependencies


def load_file_at_commit(repo, commit_hash, file_path):
    try:
        commit = repo.commit(commit_hash)
        blob = commit.tree / file_path
        content = blob.data_stream.read().decode('utf-8')
        file_cache[file_path] = content
        return content
    except Exception as e:
        print(f"[DEBUG] Error loading file '{file_path}' at commit '{commit_hash}': {e}")
        return None
    
def parse_local_kotlin_variables(content: str) -> Dict[str, str]:
    props = {}
    # Matches lines like: val log4jVersion = "2.20.0" or var version = "1.0"
    pattern = re.compile(r'(val|var)\s+(\w+)\s*=\s*["\']([^"\']+)["\']')
    for match in pattern.finditer(content):
        var_name = match.group(2)
        value = match.group(3)
        props[var_name] = value
    return props

def process_commit(repo, commit_hash, changed_files, dependencies_snapshot, all_dependencies, properties_by_commit):
    for file_path in changed_files:
        if not is_gradle_related(file_path):
            continue

        content = load_file_at_commit(repo, commit_hash, file_path)
        if content:
            dependencies_snapshot[file_path] = content

            # Parse gradle.properties
            if file_path.endswith("gradle.properties"):
                props = parse_gradle_properties(content)
                properties_by_commit[commit_hash] = props

            # Parse dependencies from .gradle or .gradle.kts files
            elif file_path.endswith(".gradle") or file_path.endswith(".gradle.kts"):
                props = {}
                #props.update(parse_ext_block(content))                  # ext { ... }
                #props.update(parse_extra_assignments(content))          # extra["..."] = ...
                #props.update(extract_project_properties(content))       # group/version/name
                props.update(parse_local_kotlin_variables(content))     # val/var = "..."

                if commit_hash not in properties_by_commit:
                    properties_by_commit[commit_hash] = {}
                properties_by_commit[commit_hash].update(props)

                resolved_props = properties_by_commit[commit_hash]
                parsed_deps = parse_gradle_dependencies(content, resolved_props, commit_hash, file_path)
                all_dependencies.extend(parsed_deps)

    return dependencies_snapshot, all_dependencies

def process_commits(repo, commits_with_changes):
    dependencies_over_time = {}
    dependencies_snapshot = {}
    all_dependencies = []
    properties_by_commit = {}

    for commit_hash, changed_files in tqdm(commits_with_changes.items(), desc="Processing commits"):
        dependencies_snapshot, all_dependencies = process_commit(
            repo, commit_hash, changed_files, dependencies_snapshot, all_dependencies, properties_by_commit
        )
        dependencies_over_time[commit_hash] = dependencies_snapshot.copy()

    return dependencies_over_time, all_dependencies

# %%
dependencies_over_time, all_dependencies = process_commits(repo, sorted_commit_hashes)

# Optionally print the parsed dependencies
#for dep in all_dependencies:
    #print(dep)

cleaned_dependencies = [
    dep for dep in all_dependencies
    if "$" not in dep["group"]
    and "$" not in dep["artifact"]
    and "$" not in dep["version"]
]

for dep in cleaned_dependencies [:10]:
    print(dep)
# Out:
# Processing commits: 100%|██████████| 4819/4819 [00:00<00:00, 88515.17it/s]

# %%
def group_gradle_dependencies(dependencies):
    grouped = defaultdict(lambda: {"gradle": defaultdict(dict)})

    for dep in dependencies:
        commit = dep["commit"]
        file = dep["file"]
        group_artifact = f"{dep['group']}:{dep['artifact']}"
        version = dep["version"]

        grouped[commit]["gradle"][file][group_artifact] = version

    return grouped

# %%
grouped_dependencies = group_gradle_dependencies(cleaned_dependencies)
import json
# Convert the defaultdict to a normal dict recursively

# %%
def to_dict(d):
    if isinstance(d, defaultdict):
        d = {k: to_dict(v) for k, v in d.items()}
    elif isinstance(d, dict):
        d = {k: to_dict(v) for k, v in d.items()}
    return d

#print(json.dumps(to_dict(grouped_dependencies), indent=2))

# %%
def save_results(data, output_file="dependencies_over_time.json"):
    import json
    with open(output_file, "w") as f:
        json.dump(data, f, indent=4)

# %%
save_results(to_dict(grouped_dependencies), "java_gradle.json")

# %%
def merge_dependencies(python_and_javascript: Dict, java: Dict, gradle: Dict) -> Dict:
    merged_data = {}

    # Combine all unique commit hashes from both datasets
    all_commits = set(python_and_javascript) | set(java) | set(gradle)

    for commit in all_commits:
        merged_data[commit] = {
            "java": {},
            "gradle": {},
            "python": {},
            "javascript": {}
        }

        # Add Java dependencies if present
        if commit in java:
            for file, content in java[commit].items():
                merged_data[commit]["java"][file] = content  # No renaming!
        
        if commit in gradle:
            gradle_files = gradle[commit].get("gradle", {})  # Extract only the inner part
            for file, content in gradle_files.items():
                merged_data[commit]["gradle"][file] = content

        # Add Python and JavaScript dependencies if present
        if commit in python_and_javascript:
            content = python_and_javascript[commit]

            # Check if it's a Python or JavaScript file based on 'ecosystem'
            if content.get("ecosystem") == "py":
                merged_data[commit]["python"][content["filename"]] = content["dependencies"]
            elif content.get("ecosystem") == "js":
                merged_data[commit]["javascript"][content["filename"]] = content["dependencies"]


    return merged_data

# %%
def remove_empty_objects(data):
    if isinstance(data, dict):
        return {
            k: remove_empty_objects(v)
            for k, v in data.items()
            if not (isinstance(v, dict) and not v)  # remove empty dicts
        }
    elif isinstance(data, list):
        return [remove_empty_objects(item) for item in data]
    else:
        return data

# %%
def save_merged_data(merged_data: Dict, output_file: str):
    with open(output_file, 'w') as f:
        json.dump(merged_data, f, indent=4)

# %%
with open('python_and_javascript.json', 'r') as f:
    python_and_javascript = json.load(f)

with open('java_pom.json', 'r') as f:
    java = json.load(f)

with open('java_gradle.json', 'r') as f:
    gradle = json.load(f)

merged_data = merge_dependencies(python_and_javascript, java, gradle)
new_merged_data = remove_empty_objects(merged_data)
save_merged_data(new_merged_data, 'merged_dependencies.json')

# %%
import json
import copy

# Load input data
with open("merged_dependencies.json", "r") as f:
    data = json.load(f)

# Your commit-to-date mapping
commit_dates = commits_with_date  # assumed to be defined already

# Ensure chronological commit order
sorted_commits = sorted(data.keys(), key=lambda c: commit_dates.get(c))

# Global latest version per dependency
latest_versions = {}

# Last known dependency set per file
last_file_state = {}  # (system, filename) -> {dep: version}

# All changes (add, update, remove)
changes = []

for commit in sorted_commits:
    date = commit_dates.get(commit)
    commit_data = data[commit]

    for system, files in commit_data.items():
        for filename, curr_deps in files.items():
            file_key = (system, filename)
            prev_deps = last_file_state.get(file_key, {})

            # Check for added/updated
            for dep, new_version in curr_deps.items():
                old_version = latest_versions.get(dep)
                if dep not in prev_deps:
                    changes.append({
                        "commit": commit,
                        "date": date,
                        "filename": filename,
                        "system": system,
                        "dependency": dep,
                        "change_type": "added",
                        "old_version": None,
                        "new_version": new_version
                    })
                elif prev_deps[dep] != new_version:
                    changes.append({
                        "commit": commit,
                        "date": date,
                        "filename": filename,
                        "system": system,
                        "dependency": dep,
                        "change_type": "updated",
                        "old_version": prev_deps[dep],
                        "new_version": new_version
                    })

                # Always update the global version
                latest_versions[dep] = new_version

            # Save current state for next round
            last_file_state[file_key] = copy.deepcopy(curr_deps)

# Save all detected changes
with open("dependency_changes_with_removed.json", "w") as f:
    json.dump(changes, f, indent=2)

# %%
# Cell 7: Execute!
process_json_file(
        "dependency_changes_with_removed.json",
        "dependency_changes_enriched.json"
    )
# Out:
# None
# None
# 5.3
# 5.3
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# 8.8
# 8.8
# None
# None
# None
# None
# None
# None
# None
# 8.8
# 8.8
# 0.5
# 1.7
# 1.7
# 0.5
# 0.5
# None
# None
# None
# None
# 0.5
# 1.7
# 1.7
# 0.5
# 0.5
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# None
# None
# None
# 4.6
# 4.6
# None
# None
# None
# None
# None
# None
# 5.5
# 6.1
# 6.1
# None
# 4.6
# 4.6
# 8.8
# None
# 5.6
# 5.6
# None
# None
# None
# None
# 8.8
# 8.8
# 8.8
# 6.6
# 8.8
# None
# None
# None
# None
# None
# None
# None
# None
# 4.6
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# None
# None
# 3
# None
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# None
# None
# None
# None
# None
# None
# None
# None
# 5.5
# 6.1
# 6.1
# 8.8
# 8.8
# None
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# None
# None
# 6.1
# 6.1
# None
# None
# None
# None
# None
# None
# None
# None
# None
# 6.1
# 6.1
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# 5.5
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# None
# None
# None
# None
# None
# None
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 2.7
# 2.6
# 2.6
# 5.8
# 2.6
# 5.8
# 5
# 5
# 2.7
# 5
# None
# 6.1
# 6.1
# 2.6
# 2.6
# 5.8
# 2.6
# 5.8
# None
# 3
# None
# 3
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# None
# None
# None
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# None
# None
# None
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# None
# 0.5
# 1.7
# 1.7
# 0.5
# 0.5
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# 0.5
# 1.7
# 1.7
# 0.5
# 0.5
# None
# None
# None
# None
# None
# None
# None
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# None
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# None
# None
# None
# 2.6
# 2.6
# 5.8
# 2.6
# 5.8
# 6.1
# 6.1
# None
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# 0.5
# 1.7
# 1.7
# 0.5
# 0.5
# None
# 5.5
# None
# None
# None
# None
# None
# None
# None
# None
# 3
# None
# None
# None
# None
# None
# 0.5
# 1.7
# 1.7
# 0.5
# 0.5
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# None
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 6
# 6
# 6
# 0.5
# 1.7
# 1.7
# 0.5
# 0.5
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# None
# 5.5
# 5.3
# 0.5
# 1.7
# 1.7
# 0.5
# 0.5
# 0.5
# None
# 2.7
# 0.5
# 1.7
# 1.7
# 0.5
# 2.7
# 0.5
# 0.5
# 0.5
# 0.5
# None
# None
# None
# None
# 6
# 6
# 6
# 6
# 6
# None
# 6
# 6
# 6
# None
# 0.5
# 1.7
# 1.7
# 0.5
# 2.7
# 0.5
# 0.5
# 0.5
# 0.5
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 5
# 5
# 5
# 6
# 6.1
# 6.1
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 8.8
# 5.8
# 5.8
# None
# None
# None
# None
# None
# None
# None
# None
# 0.5
# 1.7
# 1.7
# 0.5
# 2.7
# None
# None
# None
# None
# 0.5
# 0.5
# 0.5
# 0.5
# None
# None
# None
# None
# None
# None
# None
# None
# None
# 0.5
# 1.7
# 1.7
# 0.5
# 2.7
# None
# None
# None
# None
# 0.5
# 0.5
# 0.5
# 0.5
# None
# ❌ No related project found for org.apache.santuario:xmlsec (maven)
# None
# None
# None
# None
# None
# None
# 5.5
# None
# None
# 5.8
# 6.6
# None
# ❌ Failed to fetch data for org.keycloak:keycloak-testsuite-integration (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-testsuite-integration
# ❌ Failed to fetch data for org.keycloak:keycloak-testsuite-tools (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-testsuite-tools
# ❌ Failed to fetch data for org.keycloak:federation-properties-example (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Afederation-properties-example
# ❌ No related project found for org.slf4j:slf4j-log4j12 (maven)
# None
# ❌ Failed to fetch data for org.keycloak:keycloak-docs-dist (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-docs-dist
# None
# ❌ No related project found for org.apache.httpcomponents:httpmime (maven)
# None
# ❌ No related project found for org.apache.httpcomponents:httpcore (maven)
# None
# None
# 6
# 6
# 6
# 6
# 6
# 5.8
# 5
# None
# 5.8
# 5.8
# 5.8
# ❌ Failed to fetch data for org.keycloak:keycloak-server-subsystem (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-server-subsystem
# ❌ Failed to fetch data for org.keycloak:keycloak-adapter-subsystem (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-adapter-subsystem
# None
# 6
# 2.6
# ❌ No related project found for com.sun.istack:istack-commons-runtime (maven)
# None
# ❌ No related project found for com.sun.istack:istack-commons-tools (maven)
# None
# ❌ No related project found for com.sun.xml.bind.external:rngom (maven)
# None
# ❌ No related project found for com.sun.xsom:xsom (maven)
# None
# ❌ No related project found for org.glassfish.jaxb:jaxb-core (maven)
# None
# ❌ No related project found for org.glassfish.jaxb:jaxb-runtime (maven)
# None
# ❌ No related project found for org.glassfish.jaxb:jaxb-xjc (maven)
# None
# ❌ No related project found for org.glassfish.jaxb:codemodel (maven)
# None
# ❌ No related project found for org.glassfish.jaxb:txw2 (maven)
# None
# ❌ No related project found for joda-time:joda-time (maven)
# None
# ❌ No related project found for org.jboss.spec.javax.xml.bind:jboss-jaxb-api_2.2_spec (maven)
# None
# 6.6
# 3.4
# ❌ No related project found for org.slf4j:jcl-over-slf4j (maven)
# None
# ❌ No related project found for org.apache.james:apache-mime4j (maven)
# None
# 5.8
# 6
# 6
# 5.8
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# ❌ Failed to fetch data for org.keycloak:keycloak-wildfly-adapter-subsystem (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-wildfly-adapter-subsystem
# 5
# 5
# None
# None
# None
# None
# None
# 2.6
# None
# 4.6
# 2.6
# 2.6
# 5.6
# 1.3
# None
# None
# None
# None
# None
# None
# ❌ Failed to fetch data for org.keycloak:keycloak-eap6-server-modules (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-eap6-server-modules
# ❌ Failed to fetch data for org.keycloak:keycloak-wf9-server-overlay (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-wf9-server-overlay
# 5
# None
# None
# 5.8
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# None
# None
# None
# None
# None
# 5.5
# None
# None
# None
# None
# None
# None
# None
# None
# None
# 5.8
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# None
# None
# 3.1
# None
# 5.8
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# ❌ Failed to fetch data for org.keycloak:keycloak-demo-dist (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-demo-dist
# ❌ Failed to fetch data for org.keycloak:keycloak-src-dist (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-src-dist
# None
# None
# None
# 3.5
# None
# 2.6
# None
# 4.6
# 2.6
# 5.6
# 5.6
# ❌ No related project found for javax.servlet:javax.servlet-api (maven)
# None
# ❌ No related project found for org.apache.ant:ant (maven)
# None
# 5
# ❌ Failed to fetch data for org.keycloak:keycloak-undertow-saml-adapter (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-undertow-saml-adapter
# 2.7
# ❌ Failed to fetch data for org.keycloak:keycloak-tomcat6-saml-adapter (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-tomcat6-saml-adapter
# ❌ Failed to fetch data for org.keycloak:keycloak-tomcat-core-saml-adapter (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-tomcat-core-saml-adapter
# ❌ Failed to fetch data for org.keycloak:keycloak-tomcat7-saml-adapter (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-tomcat7-saml-adapter
# ❌ Failed to fetch data for org.keycloak:keycloak-tomcat8-saml-adapter (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-tomcat8-saml-adapter
# ❌ Failed to fetch data for org.keycloak:keycloak-jetty-saml-adapter-core (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-jetty-saml-adapter-core
# ❌ Failed to fetch data for org.keycloak:keycloak-jetty81-saml-adapter (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-jetty81-saml-adapter
# ❌ Failed to fetch data for org.keycloak:keycloak-jetty91-saml-adapter (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-jetty91-saml-adapter
# ❌ Failed to fetch data for org.keycloak:keycloak-jetty92-saml-adapter (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-jetty92-saml-adapter
# 5
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ❌ Failed to fetch data for org.keycloak:keycloak-saml-server-filter-adapter (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-saml-server-filter-adapter
# ❌ No related project found for jline:jline (maven)
# None
# ❌ No related project found for org.apache.sshd:sshd-core (maven)
# None
# ❌ No related project found for org.apache.karaf.shell:org.apache.karaf.shell.console (maven)
# None
# ❌ No related project found for org.apache.karaf:org.apache.karaf.client (maven)
# None
# ❌ No related project found for org.apache.aries.jmx:org.apache.aries.jmx (maven)
# None
# 3.1
# 5.8
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# None
# None
# None
# None
# None
# None
# None
# 5
# 5.6
# 5.8
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# 5.8
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# 5.3
# 6.6
# 3.1
# None
# None
# ❌ No related project found for org.jboss.resteasy:resteasy-jackson2-provider (maven)
# None
# None
# 5.5
# None
# 6.4
# 6.8
# 7.4
# ❌ Failed to fetch data for com.fasterxml.jackson.module:jaxb-annotations (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/com.fasterxml.jackson.module%3Ajaxb-annotations
# ❌ Failed to fetch OSSF score for com.fasterxml.jackson.jaxrs:jackson-jaxrs-json-provider (maven): 404
# None
# 5.6
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-tests-base (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-tests-base
# 5
# None
# None
# None
# None
# None
# 5
# None
# 5
# 6.1
# 6.1
# None
# 5
# None
# None
# None
# 5.8
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# None
# None
# None
# None
# 1.3
# None
# None
# ❌ No related project found for javax.mail:javax.mail-api (maven)
# None
# 6.1
# 6.1
# 3
# 5
# None
# None
# None
# None
# None
# None
# None
# ❌ No related project found for commons-configuration:commons-configuration (maven)
# None
# ❌ No related project found for jfree:jfreechart (maven)
# None
# 3
# 2.6
# None
# 4.6
# 5.6
# 5.6
# 5.6
# 5.6
# 5.6
# 5.6
# 5.6
# 5.6
# 5.6
# 5.6
# 5.6
# 5.6
# 5.6
# 2.6
# None
# 4.6
# 2.6
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-servers-auth-server-undertow (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-servers-auth-server-undertow
# 4.5
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-event-queue (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-event-queue
# 1.7
# ❌ Failed to fetch data for org.keycloak:keycloak-adapter-spi-public (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-adapter-spi-public
# 1.7
# 2.6
# 2.6
# 1.3
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-testsuite-providers (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-testsuite-providers
# 2.6
# None
# ❌ No related project found for org.ops4j.pax.web:pax-web-api (maven)
# None
# 6
# 5
# 5
# 5
# ❌ No related project found for org.subethamail:subethasmtp (maven)
# None
# None
# ❌ Failed to fetch data for org.keycloak:keycloak-authz-policy-resource (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-authz-policy-resource
# ❌ Failed to fetch data for org.keycloak:keycloak-authz-policy-scope (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-authz-policy-scope
# ❌ Failed to fetch data for org.keycloak:keycloak-authz-policy-identity (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-authz-policy-identity
# ❌ Failed to fetch data for org.keycloak:keycloak-authz-policy-js (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-authz-policy-js
# ❌ Failed to fetch data for org.keycloak:keycloak-authz-policy-time (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-authz-policy-time
# ❌ Failed to fetch data for org.keycloak:keycloak-authz-policy-aggregate (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-authz-policy-aggregate
# ❌ Failed to fetch data for org.keycloak:keycloak-authz-policy-user (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-authz-policy-user
# ❌ Failed to fetch data for org.keycloak:keycloak-authz-policy-role (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-authz-policy-role
# ❌ No related project found for org.eclipse.aether:aether-api (maven)
# None
# ❌ No related project found for org.eclipse.aether:aether-connector-basic (maven)
# None
# ❌ No related project found for org.eclipse.aether:aether-spi (maven)
# None
# ❌ No related project found for org.eclipse.aether:aether-impl (maven)
# None
# ❌ No related project found for org.eclipse.aether:aether-transport-file (maven)
# None
# ❌ No related project found for org.eclipse.aether:aether-transport-http (maven)
# None
# ❌ No related project found for org.eclipse.aether:aether-transport-wagon (maven)
# None
# ❌ No related project found for org.eclipse.aether:aether-util (maven)
# None
# None
# ❌ No related project found for org.apache.ant:ant-launcher (maven)
# None
# ❌ No related project found for org.antlr:antlr-runtime (maven)
# None
# ❌ No related project found for aopalliance:aopalliance (maven)
# None
# ❌ No related project found for org.apache.maven:maven-aether-provider (maven)
# None
# ❌ No related project found for org.apache.maven:maven-artifact (maven)
# None
# ❌ No related project found for org.apache.maven:maven-compat (maven)
# None
# ❌ No related project found for org.apache.maven:maven-core (maven)
# None
# ❌ No related project found for org.apache.maven:maven-model (maven)
# None
# ❌ No related project found for org.apache.maven:maven-model-builder (maven)
# None
# ❌ No related project found for org.apache.maven:maven-plugin-api (maven)
# None
# ❌ No related project found for org.apache.maven:maven-repository-metadata (maven)
# None
# ❌ No related project found for org.apache.maven:maven-settings (maven)
# None
# ❌ No related project found for org.apache.maven:maven-settings-builder (maven)
# None
# ❌ No related project found for org.mvel:mvel2 (maven)
# None
# ❌ No related project found for org.eclipse.sisu:org.eclipse.sisu.inject (maven)
# None
# ❌ No related project found for org.eclipse.sisu:org.eclipse.sisu.plexus (maven)
# None
# ❌ No related project found for org.sonatype.plexus:plexus-cipher (maven)
# None
# ❌ No related project found for org.codehaus.plexus:plexus-classworlds (maven)
# None
# ❌ No related project found for org.codehaus.plexus:plexus-component-annotations (maven)
# None
# ❌ No related project found for org.codehaus.plexus:plexus-interpolation (maven)
# None
# ❌ No related project found for org.sonatype.plexus:plexus-sec-dispatcher (maven)
# None
# ❌ No related project found for org.codehaus.plexus:plexus-utils (maven)
# None
# ❌ No related project found for org.apache.maven.wagon:wagon-http (maven)
# None
# ❌ No related project found for org.apache.maven.wagon:wagon-http-shared4 (maven)
# None
# ❌ No related project found for org.apache.maven.wagon:wagon-provider-api (maven)
# None
# ❌ No related project found for com.thoughtworks.xstream:xstream (maven)
# None
# ❌ No related project found for com.google.guava:guava (maven)
# None
# ❌ No related project found for org.eclipse.jdt.core.compiler:ecj (maven)
# None
# None
# None
# ❌ No related project found for com.lowagie:itext (maven)
# None
# ❌ No related project found for org.sonatype.sisu:sisu-guice (maven)
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ❌ No related project found for com.google.inject.extensions:guice-servlet (maven)
# None
# None
# None
# None
# None
# None
# None
# ❌ No related project found for org.apache.maven.wagon:wagon-http-shared (maven)
# None
# None
# None
# None
# 1.7
# 2.6
# 3.1
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-test-utils (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-test-utils
# ❌ No related project found for net.java.dev.jna:jna (maven)
# None
# 4.5
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-test-apps-servlets (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-test-apps-servlets
# None
# 3.8
# None
# None
# None
# None
# None
# ❌ No related project found for org.apache.directory.jdbm:apacheds-jdbm1 (maven)
# None
# 3.8
# ❌ No related project found for com.github.jnr:jnr-unixsocket (maven)
# None
# ❌ Failed to fetch data for org.keycloak:keycloak-ldap-storage (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-ldap-storage
# None
# ❌ No related project found for org.hamcrest:hamcrest-core (maven)
# None
# None
# None
# 5.3
# 3.8
# ❌ Failed to fetch data for org.keycloak:user-storage-properties-example (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Auser-storage-properties-example
# None
# 5
# None
# None
# 3.1
# 3.1
# 3.1
# 3.1
# 5
# None
# 6.6
# None
# ❌ Failed to fetch data for test.jdbc.eap7:mysql57 (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/test.jdbc.eap7%3Amysql57
# None
# 5
# 5
# None
# 4.6
# 5
# None
# 4.6
# 4.6
# 5
# 5
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# None
# None
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 6
# 6
# 6
# 6
# 6
# 6
# 6.1
# 6.1
# 5.3
# 5.3
# 5
# 5
# 5
# 1.8
# 5.4
# ❌ Failed to fetch OSSF score for angular (npm): 404
# None
# 2.6
# 2.7
# 3
# 4.3
# 2.7
# 2.7
# 2.7
# 3
# 3.4
# 3
# ❌ Failed to fetch OSSF score for bootstrap (npm): 404
# None
# 3
# 3.7
# 7.7
# 2.4
# 3.4
# ❌ Failed to fetch OSSF score for org.jboss.arquillian.container:arquillian-wls-remote-12.1.x (maven): 404
# None
# 5.8
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# 5
# 5
# 1.8
# 5
# 5
# 5
# 1.8
# 2.6
# None
# 4.5
# 4.6
# None
# 4.8
# 5
# 5
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5
# 5
# 5.8
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# 5
# 5
# 6.4
# 5.6
# 5.6
# ❌ Failed to fetch data for org.keycloak.documentation:authorization-services (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.documentation%3Aauthorization-services
# ❌ Failed to fetch data for org.keycloak.documentation:getting-started (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.documentation%3Agetting-started
# ❌ Failed to fetch data for org.keycloak.documentation:securing-apps (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.documentation%3Asecuring-apps
# ❌ Failed to fetch data for org.keycloak.documentation:server-admin (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.documentation%3Aserver-admin
# ❌ Failed to fetch data for org.keycloak.documentation:server-development (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.documentation%3Aserver-development
# ❌ Failed to fetch data for org.keycloak.documentation:server-installation (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.documentation%3Aserver-installation
# ❌ Failed to fetch data for org.keycloak:keycloak-testsuite-integration-deprecated (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-testsuite-integration-deprecated
# ❌ Failed to fetch data for org.keycloak:keycloak-testsuite-utils (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-testsuite-utils
# 3
# 6
# ❌ Failed to fetch data for org.keycloak.documentation:api-documentation (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.documentation%3Aapi-documentation
# None
# None
# None
# ❌ No related project found for org.mockito:mockito-all (maven)
# None
# 5.8
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# 5
# 5
# 5.8
# ❌ No related project found for org.glassfish:javax.json (maven)
# None
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# 5
# 5
# 2.6
# 4.6
# 3.8
# 5.3
# 5.3
# 5
# 5
# 5
# None
# 6
# None
# None
# 2.6
# 2.7
# 3
# 4.3
# 2.7
# None
# None
# None
# None
# 5.5
# 6.1
# 6.1
# 5.8
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# 5
# 5
# ❌ No related project found for org.codehaus.groovy:groovy-all (maven)
# None
# 6
# None
# None
# None
# ❌ No related project found for org.apache.maven.plugin-tools:maven-plugin-annotations (maven)
# None
# 5
# 3.1
# 6.4
# 6.8
# 7.4
# 1.3
# None
# 5.6
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# 5
# None
# None
# None
# None
# None
# None
# 2.6
# 2.7
# 3
# 4.3
# 2.7
# 2.7
# 2.7
# 3
# 3.4
# 3
# None
# 3
# 3.7
# 7.7
# 2.4
# 2.5
# 6.4
# 6.8
# 7.4
# 1.3
# None
# 5.6
# None
# None
# 6
# 6
# 6
# 6
# 6
# 6
# None
# 2.6
# 2.7
# 3
# 4.3
# 2.7
# 2.7
# 2.7
# 3
# 3.4
# 3
# None
# 3
# 3.7
# 7.7
# 2.4
# 3.4
# 2.5
# 4.7
# ❌ No related project found for org.apache.maven:maven-project (maven)
# None
# None
# None
# None
# 6
# 4.5
# 3.5
# ❌ Failed to fetch data for org.keycloak:kcinit-dist (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akcinit-dist
# 4.7
# 2.5
# None
# 5
# 5.3
# 5.3
# 3.1
# 3.1
# 5.4
# None
# None
# ❌ No related project found for org.ops4j.pax.web:pax-web-spi (maven)
# None
# 6.8
# 5
# 5
# None
# 5
# 5.3
# 5.3
# 2.6
# None
# 4.5
# 4.6
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-servers-app-server-spi (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-servers-app-server-spi
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-servers-app-server-undertow (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-servers-app-server-undertow
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-servers-app-server-wildfly (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-servers-app-server-wildfly
# 6
# 4.5
# 5.6
# 5.6
# 1.7
# 6
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-servers-app-server-eap (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-servers-app-server-eap
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-servers-app-server-eap6 (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-servers-app-server-eap6
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-servers-util (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-servers-util
# 6
# 1.7
# 4.5
# 6
# ❌ Failed to fetch data for org.keycloak.documentation:release-notes (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.documentation%3Arelease-notes
# 4.5
# 1.7
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-util (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-util
# None
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-servers-app-server-wildfly10 (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-servers-app-server-wildfly10
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-servers-app-server-wildfly9 (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-servers-app-server-wildfly9
# 3.1
# 3.1
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-servers-app-server-fuse63 (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-servers-app-server-fuse63
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-servers-app-server-fuse70 (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-servers-app-server-fuse70
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-servers-app-server-fuse71 (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-servers-app-server-fuse71
# None
# None
# None
# None
# None
# 5.5
# None
# 5.5
# 2.6
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-test-apps-fuse-parent (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-test-apps-fuse-parent
# 3.1
# None
# None
# None
# None
# 5.5
# 6.1
# 6.1
# 5.8
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# 5
# 5
# 5.3
# 5.3
# ❌ No related project found for org.aesh:aesh (maven)
# None
# 3.4
# 6
# 6.5
# ❌ Failed to fetch data for org.keycloak.testsuite:photoz-restful-api (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aphotoz-restful-api
# 5
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-servers-app-server-wildfly-deprecated (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-servers-app-server-wildfly-deprecated
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-servers-app-server-fuse7x (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-servers-app-server-fuse7x
# ❌ No related project found for org.seleniumhq.selenium:selenium-server (maven)
# None
# ❌ No related project found for org.seleniumhq.selenium:selenium-api (maven)
# None
# None
# ❌ No related project found for org.seleniumhq.selenium:selenium-support (maven)
# None
# ❌ No related project found for org.seleniumhq.selenium:selenium-leg-rc (maven)
# None
# 2.1
# None
# ❌ No related project found for org.seleniumhq.selenium:selenium-firefox-driver (maven)
# None
# ❌ No related project found for org.seleniumhq.selenium:selenium-ie-driver (maven)
# None
# ❌ No related project found for org.seleniumhq.selenium:selenium-edge-driver (maven)
# None
# ❌ No related project found for org.seleniumhq.selenium:selenium-safari-driver (maven)
# None
# ❌ No related project found for org.seleniumhq.selenium:selenium-remote-driver (maven)
# None
# 2.1
# ❌ No related project found for org.hibernate:hibernate-c3p0 (maven)
# None
# 5
# None
# None
# None
# None
# None
# None
# 3.1
# 3.1
# None
# None
# None
# None
# 5.5
# 3.3
# 6.1
# 6.1
# 6.4
# 6.8
# 7.4
# 1.3
# None
# 5.6
# 3
# None
# 2.6
# ❌ No related project found for org.hibernate:hibernate-core (maven)
# None
# None
# None
# 5.8
# None
# None
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# 5
# 5
# 5.3
# 5.3
# None
# 3.4
# 6
# None
# None
# 2.6
# 2.7
# 3
# 4.3
# 2.7
# 6.2
# 3
# 4.2
# 4.2
# None
# 6
# None
# ❌ Failed to fetch data for com.oracle:ojdbc7 (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/com.oracle%3Aojdbc7
# 6
# None
# None
# None
# 2.6
# None
# 3.1
# None
# None
# None
# None
# 5.5
# 6.1
# 6.1
# None
# None
# 5.8
# ❌ No related project found for org.dom4j:dom4j (maven)
# None
# None
# None
# None
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# 5
# 5
# 5.3
# 5.3
# None
# 3.4
# 5
# 5
# 5
# 6
# ❌ No related project found for org.jboss.resteasy:resteasy-jaxb-provider (maven)
# None
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-servers-app-server-jetty-94 (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-servers-app-server-jetty-94
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-servers-app-server-jetty-93 (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-servers-app-server-jetty-93
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-servers-app-server-jetty-92 (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-servers-app-server-jetty-92
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-servers-app-server-tomcat7 (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-servers-app-server-tomcat7
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-servers-app-server-tomcat8 (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-servers-app-server-tomcat8
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-servers-app-server-tomcat9 (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-servers-app-server-tomcat9
# ❌ No related project found for org.apache.commons:commons-lang3 (maven)
# None
# None
# 3.1
# None
# None
# None
# None
# None
# 5.5
# 6.1
# 6.1
# 6.4
# 6.8
# 7.4
# 1.3
# None
# 5.6
# None
# None
# 5.8
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# 5
# 5
# 5.3
# 5.3
# None
# 3.4
# 6
# None
# None
# 7.7
# None
# ❌ Failed to fetch data for com.oracle:ojdbc8 (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/com.oracle%3Aojdbc8
# None
# None
# None
# None
# None
# 5.5
# 6.1
# 6.1
# 6.4
# 6.8
# 7.4
# 1.3
# None
# 5.6
# None
# 5
# 5
# None
# None
# None
# 5.8
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# 5
# 5
# 5
# 5.3
# 5.3
# None
# 6
# 3
# 3
# 5.6
# 5.6
# 7.4
# 5.5
# 5.7
# ❌ Failed to fetch data for org.keycloak:keycloak-quarkus-extensions (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-quarkus-extensions
# 5.3
# 5.3
# 5.3
# None
# None
# 5.5
# 5
# 5.3
# ❌ No related project found for org.yaml:snakeyaml (maven)
# None
# 5.7
# 5
# None
# None
# 3.4
# 3
# 3.1
# None
# None
# None
# None
# None
# 5.5
# 3.3
# 3
# 6.1
# 6.1
# 6.4
# 6.8
# 7.4
# 1.3
# None
# 5.6
# None
# 5
# None
# None
# None
# 5.8
# 6.2
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# 5
# 5
# 5.3
# 5.3
# None
# 7.4
# ❌ No related project found for commons-lang:commons-lang (maven)
# None
# None
# None
# 2.6
# 2.7
# 3
# 4.3
# 2.7
# None
# 7.7
# 4.7
# 2.5
# ❌ No related project found for javax.xml.bind:jaxb-api (maven)
# None
# ❌ No related project found for com.sun.xml.ws:rt (maven)
# None
# 2.7
# 5.6
# 5.6
# 8.1
# 4.4
# None
# 6
# 3
# 5.3
# 5.3
# 5.3
# 5.3
# None
# 3.7
# None
# None
# None
# None
# None
# 5.5
# 6.1
# 6.1
# 6.8
# None
# None
# 5.8
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# 5
# 6
# 5.7
# 3.1
# 6.1
# 6.1
# None
# None
# None
# None
# 2.6
# 2.7
# 3
# 4.3
# 2.7
# None
# 7.7
# 4.7
# 2.5
# None
# 2.6
# 2.7
# 3
# 4.3
# 2.7
# 2.7
# 2.7
# None
# 5.5
# None
# None
# None
# None
# 4.5
# ❌ No related project found for org.apache.logging.log4j:log4j-api (maven)
# None
# ❌ No related project found for org.apache.logging.log4j:log4j-core (maven)
# None
# 5.7
# 2.5
# 4.2
# None
# None
# None
# None
# 5.3
# 5.3
# 3.4
# None
# 5.6
# 5.6
# 3.4
# 3
# 5
# 5
# None
# None
# None
# None
# None
# 2.6
# None
# None
# None
# None
# None
# None
# None
# 5.5
# 6.1
# 6.1
# 6.4
# 6.8
# 7.4
# 1.3
# None
# 5.6
# None
# None
# None
# 5.8
# None
# None
# None
# None
# None
# None
# None
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# 5
# 5
# 5
# 5.3
# 5.3
# 7.4
# None
# 6.4
# 6
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# None
# None
# None
# None
# None
# 5.5
# 6.1
# 6.1
# 5.8
# None
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# 5
# 5
# 5.7
# None
# ❌ No related project found for org.apache.directory.server:apacheds-core (maven)
# None
# ❌ No related project found for org.apache.directory.server:apacheds-core-api (maven)
# None
# None
# None
# None
# None
# 5.7
# None
# 5.3
# 5.3
# 5.3
# 5.7
# 5.7
# 5.7
# 5.7
# 5.7
# 5.7
# 5.7
# 5.7
# 5.7
# 5
# 5.7
# None
# 5.3
# 5.3
# 3.4
# None
# None
# 6
# 5.7
# ❌ Failed to fetch data for org.keycloak:keycloak-server-x (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-server-x
# None
# 5.7
# None
# 5.7
# None
# 5.7
# None
# 5.7
# 5.6
# 5.6
# 7.7
# None
# 2.6
# 2.7
# 3
# 4.3
# 2.7
# 7.7
# None
# 7.4
# 5.7
# None
# 5.7
# 5.7
# 5.7
# 5.7
# 5.7
# 5.7
# 5.7
# 5.7
# 5.7
# 5
# 5.7
# None
# 5
# None
# None
# 3.4
# None
# None
# None
# None
# None
# 5.5
# 6.1
# 6.1
# 6.4
# 6.8
# 7.4
# 1.3
# 7.4
# None
# 5.6
# None
# None
# 5.8
# None
# None
# None
# None
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# 5.8
# 5
# 5.3
# 5.3
# 5.3
# 7.4
# 3.6
# 6
# None
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 3.4
# ❌ No related project found for org.apache.httpcomponents.client5:httpclient5 (maven)
# None
# 4.7
# 4
# 4
# 4
# ❌ No related project found for i18next (npm)
# None
# 3.3
# None
# 6.3
# 6.3
# 3.3
# 6.4
# 3.2
# 3.2
# 5.2
# 5.2
# 5.2
# 5.2
# 5.2
# 4.6
# 5.3
# 7
# 7
# 7
# 7
# 6.4
# 4.7
# ❌ No related project found for jest (npm)
# None
# 4.8
# 3.1
# 4.4
# 7.1
# 4.5
# 3.2
# ❌ No related project found for typescript (npm)
# 5.3
# 5.3
# 6.8
# 5.8
# 3.2
# 3
# 5.7
# None
# 5.3
# 5.3
# 6.8
# 5.8
# 3
# 3.8
# 6.4
# 3
# 3.8
# 4.7
# 4
# 4
# 4
# 4.1
# 7
# 4.5
# 4.5
# 2.3
# 3.2
# 3.2
# 7
# 7
# 3.2
# 3.2
# 3.3
# 5.2
# 5.2
# 5.2
# 5.2
# 5.2
# 5.2
# 5.2
# 3.4
# 5.2
# 6.3
# 5.2
# 5.2
# 5.2
# 5.2
# 5.2
# 5.2
# 5.2
# 5.2
# 5.2
# 5.2
# 5.2
# 5.2
# 3.4
# 5.2
# 6.3
# 2.5
# 7
# 5.7
# None
# 6.6
# None
# 5
# 4.7
# 4
# 4
# 4
# 3.2
# 3.2
# 3.2
# 3
# 5.7
# 5.7
# 5.7
# None
# 1.9
# 5.7
# None
# 5
# None
# None
# None
# ❌ No related project found for keycloak-admin (npm)
# None
# 5.7
# None
# None
# 6.6
# None
# None
# None
# None
# None
# None
# None
# 5.5
# 6.1
# 6.1
# 6.4
# 6.8
# 7.4
# 1.3
# 7.4
# None
# 5.6
# None
# None
# 5.8
# None
# None
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# 5.8
# 5
# 5
# 5.3
# 5.3
# 5.3
# 7.4
# None
# 6
# 5.2
# 5.2
# 5.2
# 5.2
# 5.2
# 5.2
# 5.2
# 4.7
# 4
# 4
# 4
# 4.4
# 7
# 3.3
# 4
# None
# 3.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 3
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# None
# 4.7
# 4
# 4
# 4
# 2.9
# 2.9
# 5
# 4.7
# 4
# 4
# 4
# None
# 3
# None
# None
# None
# None
# None
# 4.6
# None
# None
# None
# None
# 4.7
# 4
# 4
# 4
# None
# 5.7
# None
# None
# 4.7
# 4
# 4
# 4
# 4
# 4
# None
# None
# 4.7
# 4
# 4
# 4
# 4
# 4
# None
# 5.7
# None
# None
# 3
# 3.7
# None
# None
# None
# None
# None
# None
# None
# 5.5
# 3.3
# 6.1
# 6.1
# 6.4
# 6.8
# 7.4
# 1.3
# 7.4
# None
# 5.6
# None
# 5.8
# None
# None
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# 5.8
# 5
# 5
# 5
# 5.3
# 5.3
# 5.3
# 7.4
# None
# None
# None
# None
# None
# None
# None
# None
# 5.5
# 6.1
# 6.1
# 6.4
# 6.8
# 7.4
# 1.3
# 7.4
# None
# 5.6
# None
# 5.8
# None
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# 5.8
# 5
# 5
# 5
# 5.3
# 5.3
# 5.3
# 7.4
# None
# None
# None
# None
# None
# None
# None
# 5.5
# 6.1
# 6.1
# 6.4
# 6.8
# 7.4
# 1.3
# 7.4
# None
# 5.6
# None
# 5.8
# None
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# 5.8
# 5
# 5
# 5
# 5.3
# 5.3
# 5.3
# 7.4
# None
# None
# None
# None
# None
# None
# None
# 5.5
# 6.1
# 6.1
# 6.4
# 6.8
# 7.4
# 1.3
# 7.4
# None
# 5.6
# None
# 5.8
# None
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# 5.8
# 5
# 5
# 5
# 5.3
# 5.3
# 5.3
# 7.4
# 5.7
# 5.3
# 5.3
# 5.3
# None
# 3
# 6.2
# 7
# None
# 4.2
# None
# 2.5
# 6.2
# 7
# None
# 4.2
# 7
# 7
# 5.2
# 4
# 5.2
# None
# 3.2
# 3
# None
# None
# None
# None
# None
# None
# None
# 5.5
# 6.1
# 6.1
# 6.4
# 6.8
# 7.4
# 1.3
# 7.4
# None
# 5.6
# None
# 5.8
# None
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 5.8
# 5.8
# 5
# 5
# 5
# 5.3
# 5.3
# 5.3
# 7.4
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# None
# 6
# None
# 6
# None
# 6
# None
# 3
# 5.3
# 5.3
# 5.3
# 6.6
# None
# 5.3
# 5.3
# None
# None
# 6
# 5.2
# 5.8
# 4.8
# None
# 4.8
# None
# None
# 5.3
# 5.2
# 7
# None
# 5.3
# None
# 7
# 4.7
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 7
# 3.2
# 5.2
# 3
# 3
# 4.6
# None
# None
# 6.4
# None
# 6.4
# 4.6
# None
# ❌ No related project found for org.jboss.marshalling:jboss-marshalling (maven)
# None
# ❌ No related project found for org.jboss.marshalling:jboss-marshalling-river (maven)
# None
# None
# 6.3
# 6.4
# 4.6
# None
# 7
# None
# 2.3
# 4.7
# 4
# 4
# 4
# 3
# 7
# 4.5
# 4.8
# 7
# 4.5
# 7
# 4.5
# 5.8
# 5.8
# 5.8
# 6
# 6
# 6
# 6
# 6
# 5
# 5
# 4.9
# 6
# 3.1
# 4.6
# None
# 6.4
# 5.3
# None
# 3.3
# 6.2
# 5.3
# 6.8
# 4
# 4
# 6.2
# 5.3
# 6.8
# 5.3
# 6.2
# 4.7
# 4
# 4
# 4
# 6.8
# 6.8
# 5.3
# 4.4
# 5.3
# None
# 4.8
# 6.3
# 7.1
# 6.4
# 5
# 7
# 6.2
# 3
# 3.2
# 3.2
# 5.8
# 7
# None
# 3.2
# 7.1
# 5.3
# 5.3
# 5.2
# 5.2
# 5.2
# 2.8
# 5.2
# 5.3
# 7
# 3.3
# 7
# 7
# 6.3
# 6.3
# 4.2
# 5.2
# 5.2
# None
# 3.2
# 7
# 7
# 5.2
# 5.2
# 5.2
# 5.2
# 7
# 4.2
# None
# 7
# 6
# 6.3
# 4.5
# 7.2
# 3.2
# 3.2
# 4.7
# 3.2
# 2
# 3.2
# 5.3
# 3.3
# None
# 3.2
# 3.2
# 6.8
# 5.3
# 5.3
# 7.8
# None
# 4.8
# 7.2
# None
# None
# None
# 7
# 7.2
# 5.3
# 3.3
# ❌ Failed to fetch data for org.jboss.eap:wildfly-ee-galleon-pack (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.jboss.eap%3Awildfly-ee-galleon-pack
# ❌ Failed to fetch data for org.jboss.eap:wildfly-servlet-galleon-pack (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.jboss.eap%3Awildfly-servlet-galleon-pack
# None
# None
# 6.8
# 4.7
# 4
# 4
# 4
# 7
# 5.3
# 7.2
# 7
# None
# 2.6
# 4
# 7
# 4.2
# None
# None
# 7
# 5.3
# None
# 5.3
# None
# 7
# 4.2
# 6.3
# 5.3
# 4.5
# 4.7
# 4
# 4
# 4
# 4.1
# 5.8
# 6.2
# None
# 5.3
# 6.3
# None
# 5.8
# 7.4
# 7
# 4
# None
# 4.1
# 5.3
# 6.2
# None
# 4
# 3.3
# 7.1
# 5.7
# 3.3
# ❌ No related project found for com.sun.xml.messaging.saaj:saaj-impl (maven)
# ❌ No related project found for org.jvnet.staxex:stax-ex (maven)
# None
# None
# 5.7
# None
# 5
# None
# None
# 3
# 6.6
# None
# 5.7
# 3.3
# None
# None
# 5.3
# None
# 6.3
# 7.1
# 5.3
# 7
# 7
# 7
# None
# 4.7
# 4
# 4
# 4
# 4
# None
# 7.8
# 5.8
# 4.5
# None
# 4
# 4
# 5.8
# 4
# 3
# 3.8
# 7
# 4.6
# 7
# None
# None
# 5.8
# 5.3
# 4.8
# 7
# 7
# 7
# 5.7
# 7
# 5.3
# None
# None
# 6.2
# None
# 5.3
# None
# 5.7
# 5.7
# 5.7
# 7
# 7
# 5.8
# 5.3
# 5.3
# 5.3
# 5.3
# 7
# 4.8
# 7
# 4.6
# None
# 5.3
# 6.2
# 4
# None
# 7.2
# 4.2
# 7
# None
# 5.3
# 5.3
# 6.8
# 4.2
# 7
# None
# 7
# 4.2
# 3.2
# 4.7
# 4
# 4
# 4
# 4
# None
# 4
# 7
# 7
# 6.8
# None
# 7.8
# 4.7
# 4
# 4
# 4
# 4
# None
# 4
# 7
# 6.8
# None
# 7.8
# None
# None
# 7
# 6.8
# 4
# 4
# 7.8
# 4.7
# 4
# 4
# 4
# None
# 5.7
# 5.7
# 7
# 5.3
# 4.2
# None
# 4.8
# None
# 4.6
# 6.8
# 7
# 7
# 5.3
# 7
# 7.2
# 4.5
# 5.3
# 7
# 7
# 5.3
# 7
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.7
# 7.2
# 3.3
# 4.7
# 4
# 4
# 4
# 4
# 3
# None
# 5.3
# 4
# 4.6
# 5.3
# 5.5
# 5.7
# 7
# 7
# 6.8
# 5.3
# 7
# 5.3
# None
# None
# 4
# 5.8
# None
# 3.3
# 8.4
# 3.3
# 5.7
# 2.5
# 2.7
# 7.2
# 4.5
# 4.7
# 4
# 4
# 4
# 4
# 3.8
# 5.3
# 5.3
# 5.3
# 5.3
# 7
# 7
# 5.3
# 5.8
# 7
# 7.2
# 5.3
# None
# 7
# 6.8
# 7
# 7.2
# 4.5
# 7
# 4.8
# 4.6
# None
# 3.3
# 7.1
# 7.2
# 7
# 4.6
# None
# 4.6
# 4.6
# 4.6
# 4.6
# 5.6
# 4.8
# 4.4
# 7.8
# 4.6
# 4.6
# 4
# 7
# 6.8
# 7.1
# 6.2
# None
# 5.3
# 5.3
# 5.7
# 6.8
# 5.3
# None
# 4.6
# 7
# 5.3
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-tests-console (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-tests-console
# 3.5
# 7
# 5.7
# None
# None
# None
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-tests-base-ui (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-tests-base-ui
# None
# 5.3
# 5.3
# 5.3
# None
# None
# 5.3
# 5.3
# 5.3
# None
# 7.8
# 7
# None
# None
# 4.8
# 3.3
# None
# 5.3
# 5.3
# 5.3
# None
# None
# None
# None
# None
# None
# None
# 5.8
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 6
# 6
# 6
# 5.8
# 5.8
# 5
# 5
# 4.9
# 6
# 5.8
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 6
# 6
# 6
# 5.8
# 5.8
# 6
# 6
# None
# None
# 5.7
# 5.7
# 4
# 4.7
# 5.8
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 6
# 6
# 6
# 5.8
# 5.8
# 6
# None
# None
# 5.8
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 6
# 6
# 6
# 5.8
# 5.8
# 6
# 5
# 5
# 4.9
# 5
# 5
# 4.9
# None
# None
# 4.6
# 1.8
# 5
# 5
# 5
# 4.6
# 4.6
# None
# 5
# 5
# 4.9
# None
# 5
# 5
# 4.9
# None
# 5
# 5
# 4.9
# 5.6
# 5.6
# 5.6
# 5.3
# 5.8
# 7
# None
# 3.3
# 6.8
# 7.8
# 4
# 7
# 5.3
# None
# 7.2
# 3.8
# 4
# 4
# 4
# 7
# 7
# 7.2
# 6.8
# 7
# 5.3
# 7.2
# 3.3
# 5.3
# None
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.7
# 2.5
# None
# 7.2
# 7
# 4
# 5.3
# None
# 5.3
# None
# None
# 4
# 5.3
# 4
# 4
# 7.8
# 6.8
# None
# 5.3
# 7
# 5.3
# 7
# 7
# 7.2
# 5.3
# 4
# None
# 5.8
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 6
# 6
# 6
# 5.8
# 5.8
# 6
# 5.7
# 6.1
# 6.1
# 5.7
# 5.3
# 5.3
# 5.3
# 5.3
# 4.8
# 4.8
# None
# 5.3
# 5.3
# 5.3
# None
# 5.7
# 5.3
# 5.3
# 5.3
# 5.3
# None
# 5.3
# 5.3
# 5.3
# None
# 4.6
# 5.7
# 5.3
# 5.3
# 5.3
# 5.3
# 4.8
# None
# 5.3
# 5.3
# 5.3
# None
# 4.7
# 4
# 4
# 4
# 4
# None
# 7
# 5.3
# 5.3
# 6.8
# 7.2
# 4.7
# 4
# 4
# 4
# 4
# None
# 7
# 5.3
# 6.8
# 7.2
# 5.3
# 6.8
# None
# 7.2
# 7
# 5.7
# 4.7
# 4
# 4
# 4
# 4
# 3
# 7
# 3
# 4.8
# 4.8
# None
# 4.6
# 6.2
# 7
# 4.6
# 7
# 5.3
# 7.2
# 7
# 5.3
# 3
# None
# 6.2
# 4.4
# None
# 6.2
# 4.4
# 6
# 5.6
# 5.6
# 5.3
# 5.7
# 6.8
# 4.2
# None
# 3.3
# 7.2
# 5.3
# 4
# 7
# 4.6
# 6.2
# None
# 3.8
# 5.3
# None
# 5.3
# 5.3
# 6
# 7
# 3
# 5.3
# 4.7
# 4
# 4
# 4
# 4
# 5.7
# 5.7
# 5.7
# 4.6
# 4.6
# 5.6
# 4.8
# None
# 5.8
# 6.8
# 3.3
# 5.3
# 4.8
# None
# 5.3
# 7
# 5.3
# 5.8
# 4.2
# None
# 7.2
# 5.3
# 7
# 6
# 5.3
# None
# 4.8
# 5.7
# 4.8
# 4.8
# None
# 4.8
# 4.7
# 4
# 4
# 4
# 4
# 3.2
# 5.7
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.8
# 7
# 5.3
# 3.3
# None
# 6.8
# 5.3
# 3.6
# None
# None
# None
# 7
# 4
# 4.8
# 7.1
# 5.3
# None
# 3.3
# 5.3
# 7.2
# 4
# 5.7
# 5.3
# 5.3
# 5.3
# 5.7
# 4.4
# 5.7
# 5.3
# None
# None
# 7
# 4.4
# 5.3
# 5.3
# 7
# 7.1
# 3.3
# 7.8
# 6.8
# 4.6
# 5.3
# 5.3
# None
# 4.8
# 6.1
# 6.1
# 5.3
# 5.3
# 5.3
# 5.3
# 7.1
# 4.6
# 3.3
# 4.6
# 4.7
# 4
# 4
# 4
# 4
# 6.8
# 7
# 7
# 3.2
# 5.4
# 4.2
# 5
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 6.8
# 4.6
# 7
# 5.3
# None
# 3.3
# 4
# 4
# 4
# 4
# 4.6
# 5.3
# 4.6
# 7
# 5
# 5.3
# 5.3
# 5.3
# 6.1
# 6.1
# 6.8
# 5
# 4.8
# 4.8
# 4.6
# 3.3
# None
# 7
# 5.3
# 3.3
# 5.3
# 7.2
# 7
# None
# 4.8
# 4.1
# 5.3
# 5.8
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 6
# 6
# 6
# 5.8
# 5.8
# 5
# 6
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-testsuite-providers-deployment (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-testsuite-providers-deployment
# 7
# 5.3
# 3.3
# 7.2
# 8.8
# 8.8
# 7
# 6.8
# 7
# 4.6
# 6.2
# 3.3
# 6
# 3
# 5.3
# 5.3
# 5.3
# 5.3
# 6
# 4.6
# 6.2
# 5.4
# 7
# 5.3
# 7
# 7.2
# 5.3
# None
# 3.3
# 4.8
# None
# None
# 7.8
# None
# 7.8
# None
# 7
# None
# 6.8
# 5.3
# 3.3
# None
# 4.5
# 5.3
# 4.7
# 4
# 4
# 4
# 4
# 7
# 7
# None
# 7
# 4.7
# 4
# 4
# 4
# 4
# 4.4
# 5.3
# 7
# 5.3
# 4.1
# 5.6
# 5.6
# 5.6
# 5.6
# 5.6
# 5.6
# 3
# 4.1
# 4.8
# 4.2
# None
# 6.8
# 5.8
# 7
# 5.2
# 5.3
# 5.3
# 5.3
# 4
# 7
# 7.8
# 4.4
# 5.3
# 7.2
# None
# 5.3
# 3.3
# None
# 5.6
# 5.6
# 5.4
# 4.2
# 3.3
# 5.3
# 4.5
# 7
# 6.8
# None
# 7.2
# 7.8
# 5.3
# 5.8
# 6
# 6
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 6
# 6
# 6
# 5.8
# 5.8
# 6
# 6.1
# 6.1
# 6.1
# 6.1
# 6.1
# 6.1
# 5.7
# 5.7
# None
# 5.4
# None
# 5.3
# 7
# 3.3
# 3.8
# None
# 7.2
# None
# 5.7
# 5.7
# 6.4
# 6.8
# 7.4
# 1.3
# 7.4
# None
# 5.6
# 7.4
# 6
# 5.3
# 6.8
# 3.3
# 7.2
# 4.6
# 7.1
# 7.8
# 7
# None
# 5.3
# 4.8
# 4.8
# 4.8
# 4.8
# ❌ No related project found for org.bouncycastle:bc-fips (maven)
# None
# ❌ No related project found for org.bouncycastle:bctls-fips (maven)
# None
# ❌ No related project found for org.bouncycastle:bcpkix-fips (maven)
# None
# ❌ Failed to fetch data for org.keycloak:keycloak-fips1402 (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-fips1402
# 4.8
# 4.7
# 4
# 4
# 4
# 4
# 5.8
# 5.3
# None
# 3.3
# 7.2
# 5.3
# 4.8
# 3
# 4.8
# 3
# None
# 6.8
# None
# 3.3
# 7
# None
# 4.2
# 6.3
# 5.3
# None
# 5.3
# 4.7
# 4
# 4
# 4
# 4
# 7
# None
# 3.2
# None
# 6.8
# 5.3
# 3.3
# 7
# 5.3
# None
# 3.2
# None
# None
# None
# 5.5
# None
# None
# None
# None
# 5.5
# None
# ❌ No related project found for net.jcip:jcip-annotations (maven)
# None
# None
# None
# None
# None
# None
# 5.5
# None
# 5.5
# None
# None
# None
# None
# 5.5
# None
# None
# 2.7
# None
# 2.7
# 2.7
# 7.7
# 4.3
# 2.7
# 3
# 2.6
# 4.7
# 2.5
# 7
# None
# 4.2
# 5.3
# None
# 3.3
# None
# 5.4
# 7
# 6.8
# 5.3
# None
# 5.3
# 5.4
# 4.4
# None
# 7
# 6.4
# 6.4
# 3
# 3.8
# 6.4
# 5.5
# 7
# 5.3
# 5.3
# 5.3
# 5.3
# 5.5
# 5.3
# 7
# 7
# 7
# 5.3
# 3.3
# None
# 8.8
# None
# None
# None
# 5.4
# 7
# 4.2
# 5.4
# 6.8
# None
# 4.6
# 5.3
# None
# 6.4
# 7
# 6.4
# 5.3
# 5.4
# 5.3
# 6.8
# 3.8
# None
# 7
# None
# 7
# 7
# 7
# 5.3
# 3.8
# 7
# None
# 5.3
# 3.3
# None
# 7
# 6.8
# 5.3
# None
# 5.6
# 5.6
# 4.7
# 4
# 4
# 4
# 4
# 7
# None
# None
# 7
# 7
# 5
# 8.8
# 4.7
# 4
# 4
# 4
# 4
# 2.6
# 2.5
# 3.5
# None
# 3.3
# None
# 3
# 6.3
# 6.3
# 3
# 4
# 5
# 3.3
# 3
# 3
# 6.4
# 6.4
# 3
# 3.8
# 6.8
# 4.5
# 4.6
# 5.3
# 4.6
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 6.4
# None
# 3.2
# 4.4
# 3.2
# 2
# 5.4
# 2.7
# 4.2
# 4.2
# 7
# 4.2
# None
# 5.5
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.4
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 7.7
# 5.3
# 5.3
# 6.8
# 5.8
# 3.3
# 6.4
# 7
# 7
# 4.2
# 5.3
# 7
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 7
# 7
# None
# 7
# 5.8
# 7
# 4.7
# 4
# 4
# 4
# 4
# 4.2
# 4.4
# None
# 6.4
# 7
# 5.3
# 3.3
# 5.8
# 5.3
# 7
# 5.3
# 5.3
# 4.1
# 7
# ❌ Failed to fetch OSSF score for wireit (npm): 404
# None
# 8.8
# None
# None
# None
# None
# None
# 6.4
# 7
# 6.4
# 4.7
# 4
# 4
# 4
# 4
# None
# None
# 7
# 5
# 4.8
# None
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 3.3
# 7
# None
# 7
# 5.3
# 6.8
# 4.8
# 6.1
# 6.1
# 5.3
# 6.4
# None
# 7
# 7
# 7
# 5.3
# 6.4
# 5.3
# 6.1
# 6.1
# 3.8
# 7
# 5.3
# 4.2
# 4.7
# 4
# 4
# None
# 3.3
# 6.3
# 6.3
# 3.3
# 2.6
# 4.1
# 7
# 7
# 7
# 7
# 4.2
# 5.8
# None
# 7
# None
# 8.8
# 6.4
# 6.8
# 7
# 4.1
# 1.7
# None
# None
# None
# None
# 5.3
# 7
# None
# 4.4
# 7
# 5.8
# 6.4
# 6.8
# 7.4
# 1.3
# 7.4
# None
# 5.6
# 7.4
# 5.7
# 5.3
# 6.8
# None
# 4.7
# 4
# 4
# 4
# 4
# None
# 5.8
# 5.8
# 4.8
# 6.1
# 6.1
# 6.4
# 3.8
# 7
# None
# 5.3
# 5.3
# 6.8
# 5.7
# 6.8
# 5.7
# 6.8
# 6.8
# 5.7
# 3.3
# 2.9
# 6.4
# 5.3
# 3.3
# None
# 7
# 7
# 7
# 7
# 5.3
# None
# 5.3
# 4.1
# 3.8
# 3.3
# None
# 5.4
# None
# None
# None
# None
# 4
# 6.3
# 6.3
# 7
# 7
# 7
# 2.1
# 7
# 4.2
# 4
# None
# 4.7
# 4
# 4
# 4
# 4
# 3.8
# 5.3
# 7
# 4.7
# 4
# 4
# None
# 3.3
# ❌ Failed to fetch data for keycloak-masthead (npm): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/npm/packages/keycloak-masthead
# 5
# 3.3
# 2.6
# 4.1
# 7
# 7
# 6.4
# 6.8
# 6.4
# 4
# 5.4
# 2.9
# None
# None
# 4
# 4
# 3.8
# 5.3
# 4
# 4.5
# 7
# 5.5
# 5.4
# 5.3
# 5.3
# 2.6
# 3
# 3.7
# 3.6
# 3
# 7
# 7
# 7
# 7
# ❌ No related project found for chai (npm)
# None
# 7.1
# 4.2
# None
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.7
# 5.3
# 5.3
# 4
# 7
# 4
# None
# 4.5
# 4.7
# 4
# 4
# 4
# 4
# 5.3
# None
# 7
# None
# 6.8
# 6.2
# 5.7
# 6.8
# 7
# 5.8
# None
# ❌ No related project found for com.oracle.database.jdbc:ojdbc11 (maven)
# 5.5
# None
# None
# None
# None
# 5.5
# 5.7
# 5.3
# 5.3
# 5.3
# 5.3
# None
# None
# None
# None
# None
# None
# None
# None
# 3.3
# 5.3
# 7.2
# 5.3
# None
# None
# None
# None
# 3
# 3
# None
# 5.3
# 7
# 6.4
# 5
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 4.2
# 5.3
# 7.1
# 4.8
# None
# 5.4
# 5.4
# 6.8
# 3
# 7.2
# 3.8
# 7
# 3.8
# None
# None
# None
# 5
# 3.6
# 3
# None
# 5.7
# 3
# 5.4
# 5.4
# 3.8
# None
# 7
# None
# 5.3
# 7.1
# 3.8
# 5.3
# 3.3
# 5.3
# 5.3
# 7.1
# 5.3
# 4.1
# 7
# 4.2
# 7
# None
# 7
# 5.3
# 5.3
# 7
# 5.3
# 7
# 7
# 3
# 2.6
# 7
# 7
# 7
# 5.4
# 7
# 3
# 4.7
# 4
# 4
# 4
# 4
# 5.3
# 5.3
# 7.7
# 7
# 6.8
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.7
# 4.1
# 5.3
# 4.2
# 3.3
# 6.4
# 3.8
# 7
# 5.3
# 6.8
# 7
# 3.8
# 5.3
# 5.3
# 5.3
# 5.3
# 6.8
# 7
# 7
# 3.2
# 4.2
# 5.3
# 5.3
# 6
# None
# 5.3
# 5.3
# None
# 5.3
# None
# 6.4
# 5.3
# 7.1
# 4.5
# 4.8
# None
# None
# 6.6
# 6.6
# None
# 5
# 6.8
# 5.7
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# None
# None
# 5
# 6.8
# None
# 5.3
# 5.3
# 6.8
# 6.2
# 5.8
# 6.8
# 5.3
# 5.3
# 6.8
# 6.8
# 5.8
# 5.3
# 6.8
# 5.3
# 6.8
# 5.8
# 7.1
# 5.3
# 6.8
# 7.1
# 7
# 3
# 5.3
# 6.8
# 6.2
# 5.8
# 7.1
# 5.3
# 5.3
# 6.2
# 5.8
# 6.2
# 3
# 4.7
# None
# 7
# 7
# 4
# 7
# 7
# 7
# 7
# None
# 4.2
# 6.8
# 7
# 5
# None
# 3.3
# 5.3
# 5.8
# None
# 5.3
# None
# 4.2
# 4.1
# 4.7
# 4
# 4
# 4
# 4
# 5.8
# 6.8
# None
# 4.1
# 4
# 4
# 4
# None
# 4.8
# None
# 4.8
# None
# 4.8
# 7
# None
# None
# 3.3
# 5.3
# 7
# 5.3
# 4
# 7
# 7
# 7
# 4.2
# 4
# 7
# 3.8
# 7
# 5.3
# 5.3
# 3.3
# 3.8
# None
# ❌ No related project found for org.apache.sshd:sshd-common (maven)
# None
# 5.3
# 4
# 5
# 6.3
# 6.3
# 7
# 7
# 7
# 2.1
# 7
# 4.2
# 4
# None
# 3.3
# 3.8
# None
# None
# None
# 5.3
# 7.2
# 4.1
# 4.5
# None
# 3.8
# 7
# 7
# 7.1
# 5.3
# 5
# 6.3
# 6.3
# 5.3
# 7
# 7
# 2.6
# 7
# 6.8
# None
# None
# 5.3
# 5.3
# 7.2
# 5
# 6.3
# 6.3
# 7
# 7
# 4
# None
# 7
# 7
# 4.2
# None
# None
# 7
# 5.3
# None
# 7
# 7
# 5
# 3.3
# 4.1
# None
# 7
# None
# 7
# 7
# 5.3
# 6.8
# 5.3
# 3.3
# 4.1
# None
# 7
# 3.3
# None
# 5.3
# 5.3
# 7
# None
# 7
# 4.2
# 4
# 4.1
# ❌ No related project found for ui-shared (npm)
# 7
# 4.7
# 4
# 4
# None
# 3.3
# 3
# 6.3
# 6.3
# 5
# 3.3
# 4.1
# 7
# 7
# 7
# None
# 7
# 4.2
# 7
# None
# None
# None
# None
# None
# 5.7
# 5.7
# 7
# None
# 7
# 4.7
# 4
# 4
# 4
# 4
# 2.6
# 2.5
# 3.5
# None
# 3.3
# 3
# 6.3
# 6.3
# 4.4
# 3
# 5
# 3.3
# 4.1
# None
# 3
# 3
# 4.5
# 4.6
# 5.3
# 7
# 7
# 7
# 7
# 7
# 7
# None
# None
# 7
# 2.9
# 4.2
# 7
# 4.2
# None
# 3
# 5.6
# 5.6
# 8.1
# 5.3
# 7
# 5.3
# 5.3
# 6.8
# 6
# 6.8
# 6.3
# 6.2
# 3
# 5
# 6.3
# 5.8
# 4.5
# 7.2
# 7.1
# None
# None
# 5
# 7
# 4
# 5
# 6.3
# 6.3
# 7
# 7
# None
# 2.1
# 7
# 4.2
# 4
# None
# 7.2
# 7
# 4.7
# 4
# 4
# None
# 3.3
# 3
# 6.3
# 6.3
# 5
# 3.3
# 4.1
# 7
# 7
# 7
# None
# 7
# 4.2
# 7.7
# None
# None
# None
# None
# 8.4
# None
# None
# None
# 4.4
# None
# 7
# 5.3
# 7.1
# None
# 3.3
# 5
# 7
# None
# 3.3
# 7
# 5
# 4.1
# None
# 5.3
# 7.1
# 7
# 7.1
# 7
# None
# None
# None
# None
# 5.3
# 5.3
# 3.3
# 3.5
# 7
# 6
# 7.1
# 6
# 7.1
# None
# 3.3
# 6
# 5.3
# 7.1
# None
# None
# 7.1
# 7
# 5
# 7
# ❌ Failed to fetch data for org.keycloak.documentation:upgrading (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.documentation%3Aupgrading
# ❌ Failed to fetch data for org.keycloak.documentation:aggregation (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.documentation%3Aaggregation
# 4
# 7
# 4
# 4
# 4
# 5
# 7
# None
# 7
# 7
# 7
# None
# 6.8
# None
# 5.3
# 7
# 5.3
# 7
# 6.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 4
# 5
# 7
# 7
# 4
# None
# 4.1
# 6.8
# 6.3
# 5
# 7
# 6.8
# None
# 5
# 7
# 4
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 4
# 5.3
# 5.3
# 5.3
# 5.3
# 5.6
# 5.6
# 5.6
# 5.9
# 5.5
# 5.3
# None
# None
# None
# None
# None
# 5
# 4.1
# 7
# None
# 5.3
# 5.3
# 6.8
# 7.2
# 5.3
# 5.3
# 6.8
# 7.2
# 5.3
# None
# 5
# 7
# 6.8
# None
# 7.2
# 5.3
# 6.8
# 7
# 2.6
# 3
# 3.7
# 3.6
# 3
# 7
# 7
# 7
# 7
# None
# 7.1
# 4.2
# 5.3
# 7
# None
# None
# 5
# 7
# None
# 4
# 5.9
# 5.8
# 6
# 5
# 5.3
# 7
# 7
# None
# 7
# 5.3
# None
# 7.1
# 7
# ...
# 7
# None
# 3.3
# 4.2
# 4.2
# None
# None
# 4.2
# 5.3
# 6.1
# 4.7
# 4.8
# 6.3
# 6.3
# 4.8
# 6.3
# 6.3
# 4.8
# 6.8
# 7.2
# 3.3
# 7
# 4.2
# 4.8
# None
# 3.3
# 4
# 5
# 7
# 7
# None
# 7
# 4.2
# 4
# None
# 7
# 6.8
# 3.3
# 4.8
# 6.8
# 6.3
# 6.3
# 5.7
# 5.7
# 5.3
# 5.3
# 5.3
# None
# 3.3
# None
# 7
# 5.3
# 3.3
# 4
# None
# None
# 5.3
# 7
# 7
# 4
# 7
# 5.4
# ❌ No related project found for org.jboss.threads:jboss-threads (maven)
# None
# 5.3
# 5.3
# 5.3
# 5.3
# 5.4
# None
# None
# 5.7
# 6.1
# 3.7
# 5.1
# 5.9
# 6.4
# 6.8
# 7.4
# 1.3
# 7.4
# None
# 5.6
# None
# 5
# 5
# 5
# 6.3
# None
# None
# None
# 5
# None
# None
# 7.4
# None
# None
# 5.2
# 3.6
# 4.7
# None
# None
# None
# 5.7
# 5.9
# 5.7
# 5.3
# 5.3
# 5.3
# 5.3
# None
# None
# 4.8
# 6.1
# 6.1
# 6.1
# 5.9
# 5.4
# None
# 5.3
# 5.3
# 5.3
# 5.3
# 5.4
# None
# None
# 7
# None
# None
# None
# 7
# None
# None
# None
# ❌ Failed to fetch data for mysql:mysql-connector-j (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/mysql%3Amysql-connector-j
# 7
# None
# 7
# 4
# None
# 7
# None
# 5.3
# 5.3
# None
# 5.3
# 5.3
# 3.3
# 5.3
# 3.3
# None
# 7
# 5.3
# 6.3
# 7.1
# 5.3
# 5.3
# 4.1
# 7
# 4.1
# 6.8
# 5
# 7
# 7
# None
# 7
# 7
# 7
# 6.8
# 7
# 7
# 7
# 4
# 7
# 7
# 5
# 5.3
# 4.1
# 5.3
# None
# 4.1
# 4.6
# 7
# 7
# 7
# 7
# None
# None
# None
# 6
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 7
# None
# 7
# 7
# 5.8
# 7
# 5.3
# 5.3
# 3.3
# 7
# 7
# 5.3
# 5.3
# 5.3
# 5
# 7
# 5.3
# 5
# 7
# 7
# 7
# ❌ No related project found for org.fusesource.jansi:jansi (maven)
# None
# 5.4
# 6.3
# 6.3
# 7
# None
# 6
# 5
# 7
# 7
# 4
# 5.3
# 6.2
# 5.8
# 6.2
# 5.8
# 3.3
# 7
# None
# 5.8
# 6.8
# 6.2
# None
# 3.3
# 7
# None
# 7
# None
# 5.3
# 7
# None
# 7
# 7
# 5.4
# 6
# 7.1
# 7
# None
# 7.1
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.6
# 5.6
# 5.6
# 5.6
# 5.4
# 5.6
# 5.6
# 5.3
# 5.3
# 5.3
# 5.3
# 5.4
# 6.2
# 7.1
# 3.3
# 4.2
# 4.6
# 4.2
# None
# 5.8
# 5.3
# None
# 5
# 7
# 6
# 7.2
# 7
# None
# 7
# 5
# None
# None
# None
# None
# 7
# None
# 7
# 7
# 5.3
# 6.3
# None
# 4.1
# 7
# 5
# 7
# 7
# 4.2
# 4
# None
# 7
# 5.3
# 6.8
# 5.3
# 6.8
# 4.1
# 7
# 7
# 5.3
# 3.3
# 4.1
# 6.8
# 6.8
# 7.1
# 7
# 7
# None
# 3.3
# 4.1
# 4.6
# 7
# 7
# None
# None
# None
# 3
# 7
# 7
# None
# 6.8
# 7
# 7.7
# 5.3
# 5.3
# 5.3
# 4
# None
# 5.3
# None
# 7.1
# 3.3
# 5.4
# 5.4
# None
# 3.3
# None
# 7
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.7
# 5.7
# 5.7
# 7
# 3.5
# 3.3
# 7
# None
# 3.3
# 7
# 3.3
# 3.3
# 5
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.7
# 5.7
# 5.7
# None
# 5
# 5.3
# 5.3
# 5
# 5.3
# 7
# 7
# 7
# 5.3
# 5.3
# 5.3
# 5.3
# 5.8
# 6
# 6
# 5.8
# 5.8
# 5.8
# 6
# 5.8
# 6
# 6
# 6
# 6
# 6
# 5.8
# 5.8
# 5
# 5
# 4.9
# 6
# 5.8
# 6
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# 5.8
# None
# 3.3
# 5
# 3.3
# 4.6
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# None
# 7
# 5.3
# 6.8
# 5.3
# 5.3
# 4.5
# None
# None
# 3
# 3
# None
# None
# 5
# 5
# None
# None
# 7
# 5.4
# 5.3
# 5.3
# 5.3
# 5.3
# 4.4
# 3.5
# 3
# None
# 3
# 7
# None
# 7
# 5.3
# 5.4
# 7
# 5
# 7
# 5
# 7
# None
# 5.3
# 5.3
# 6.3
# 5.3
# 6.3
# 5
# 7
# 7
# 5
# 7
# 4
# None
# 5
# None
# 7
# 5.3
# 6.3
# 6.8
# 7
# None
# None
# 7
# 5.3
# 6.8
# 7
# None
# 7
# 7
# None
# None
# 7
# 5
# 5.3
# 7
# None
# 6.8
# 5
# 7
# None
# 7
# 4
# None
# None
# 7
# 5
# 5
# 7
# 6.8
# None
# 7
# 7
# None
# 7
# 7
# 5.3
# 7
# 5.3
# None
# None
# 7
# 5.3
# 7
# 7
# 7
# 7
# None
# 4.6
# 7
# 7
# None
# 7
# 7
# 6.3
# 7
# 7
# 7
# None
# 7
# 7
# 5.3
# 7
# 5.3
# 3.3
# 7.2
# 3.3
# None
# 3
# 5
# None
# 7
# 7
# 7
# 7
# None
# 7
# None
# 7
# None
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 5.4
# 7.2
# 3.3
# None
# 6.8
# 7
# 5.3
# 5.3
# 6.2
# 5.3
# 6.2
# 6.2
# 7
# 5.3
# 5
# 7
# 7
# 7
# 4
# None
# 3.3
# 7
# 7
# None
# 7
# 3.3
# 7
# 7
# 4
# 3.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 4
# None
# 5.3
# None
# 3.3
# 7
# None
# None
# 5.3
# 7
# None
# 7
# 4.1
# 5.4
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# None
# 5.3
# 5.7
# 3
# 7
# 7
# None
# ❌ Failed to fetch OSSF score for vite-plugin-lib-inject-css (npm): 404
# None
# 3.3
# 4.7
# 4
# 4
# 4
# 4.7
# 4
# 4
# 4
# None
# 4
# 3.3
# 4.1
# 5.3
# 7
# 6.8
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# None
# None
# 3.3
# 7.2
# 5.3
# 5.3
# None
# 7
# 7
# 5
# 3.3
# 7
# 5
# 7
# 7
# 5.3
# None
# 7
# 7
# 5
# 7
# 7
# 7
# 5.3
# 7.1
# None
# 5
# 7
# 7
# None
# None
# 3
# 7
# 7
# 3.3
# 4.1
# None
# 5.8
# 7
# 5
# 7
# 7
# 3.3
# 4.1
# 5.3
# None
# 7
# 6.8
# 5.4
# 6.3
# 7.7
# 4.7
# 6.3
# 6.3
# 3.8
# 3.8
# 3.8
# 3.8
# 6.8
# 3.8
# 5.3
# 5.3
# 7
# 7
# 3.3
# 7
# 3.3
# None
# 7
# 7
# 7
# 6.8
# 5
# 5
# 4.9
# 5
# 5
# ❌ No related project found for org.jboss.shrinkwrap:shrinkwrap-api (maven)
# None
# ❌ No related project found for org.jboss.shrinkwrap:shrinkwrap-impl-base (maven)
# None
# 6
# 7
# 7
# 4.7
# 4
# 7
# 4.1
# 7
# 7
# 7
# 7
# 7
# 4.1
# 7
# 7
# 7
# 7
# 7
# 5.3
# None
# None
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-test-apps-servlets-jakarta (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-test-apps-servlets-jakarta
# ❌ Failed to fetch data for org.keycloak.testsuite:integration-arquillian-servers-app-server-jboss-galleon (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.testsuite%3Aintegration-arquillian-servers-app-server-jboss-galleon
# 5.3
# 7
# 5.3
# None
# 5
# 7
# None
# 5
# 5
# 7
# 7.4
# 4
# 4
# 5
# 7
# 7
# 7
# None
# 7
# 4
# None
# 4.6
# 7
# 7
# 7
# None
# 3.3
# ❌ No related project found for @patternfly-v5/patternfly (npm)
# 7
# 6
# 7.2
# 7
# None
# 7
# 5.3
# 5.3
# 7
# 7
# 7
# 5.3
# 7
# None
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# 5.3
# None
# 7
# 5.3
# 6.8
# 7
# None
# 7
# 7
# None
# 7
# None
# 7
# 4.2
# 7
# 7
# 7
# None
# 5
# 5.3
# 7.1
# 7
# 5.3
# 7
# None
# 7
# 5.3
# 5.3
# 6.8
# 5
# 3.6
# 7
# 4.2
# 5
# 7
# 4.1
# 7
# 7
# 6.2
# None
# None
# 5
# 7
# 7
# 7
# 4
# None
# 5.3
# 5.3
# 6.8
# 6.3
# 7
# None
# 5
# 4.1
# 7
# 7
# None
# 7
# 7
# 6.8
# 6.3
# 6.3
# 4.1
# 4.1
# None
# 4.6
# 3.3
# 7
# 5.3
# 6.8
# None
# 3.3
# 7
# None
# 5.3
# None
# 6.8
# 7
# 7
# None
# 7
# None
# None
# 4.6
# None
# 7
# 5.3
# 6.8
# 7
# 7
# 7
# 5.3
# 7
# 7
# None
# 5.3
# 5
# 7
# 5.3
# 5.3
# None
# 5
# 5.3
# None
# 6.3
# None
# 7
# 7
# 4.1
# 5.3
# 4.1
# None
# 7.1
# 6.8
# 5.3
# 7
# None
# 5
# 3.3
# 7
# 7
# 4
# None
# 5.3
# 7
# None
# 7
# 5
# 7
# None
# None
# 7.1
# None
# None
# 4.1
# 7
# None
# None
# 4.1
# 7
# 7
# 5
# 3.3
# 6.8
# 5.3
# 3.3
# 4.6
# 5.3
# None
# None
# None
# 4.6
# None
# 3.3
# 7
# 4
# None
# 7
# 3
# 7
# 7
# None
# 7
# None
# None
# None
# None
# 5.3
# None
# None
# 4.6
# 5.3
# 7
# None
# 5.3
# None
# 5.4
# None
# 5.4
# None
# None
# None
# 7
# 4.5
# 7.2
# 7
# None
# 3.3
# 4.2
# 4.5
# 7.2
# None
# 4.2
# 4.2
# 7.2
# 7
# 4.5
# None
# 3.3
# 4.6
# 4.2
# None
# 7
# 5
# 7
# 5.4
# None
# None
# 7
# 7.1
# 3.3
# 7
# 5
# 3.3
# 5.3
# 7
# None
# 4.1
# None
# None
# 4.5
# None
# 4.5
# None
# 4.5
# 7.2
# 5.3
# 7
# 3.3
# 3.3
# 4.1
# 4.6
# 7
# 5.3
# 5.5
# None
# None
# None
# None
# 5.5
# 7
# 5
# 3.3
# ❌ No related project found for org.osgi:osgi.core (maven)
# None
# None
# None
# None
# None
# 5.5
# 5.4
# 5.5
# None
# 5.4
# 3
# None
# 6
# 7.4
# 5.4
# 7
# 7
# 7.1
# 5
# 3.3
# 7
# 7
# 7
# 3
# 7
# 5.3
# 5.3
# 5.3
# 7
# 4.2
# 6.8
# 5.4
# 4.5
# 7
# 7
# None
# 5.3
# 5.4
# None
# 7
# 7
# 6.8
# 7
# 4.1
# 4.1
# 7
# None
# 7
# 5
# None
# 6.8
# 7
# None
# 7
# None
# 4
# 7
# 5.4
# 5.4
# 3.3
# 4
# 3.3
# 5.4
# None
# 3.3
# None
# 5
# 3.3
# 7
# 7
# None
# 7
# 4.2
# 4
# None
# None
# 7
# 3.3
# None
# 7
# None
# 7
# 7
# 6.8
# 7
# 5.3
# 5.3
# 5.3
# 7
# 7
# 7
# 5
# 5.4
# 4.1
# 7
# 7
# 7
# 5
# 5
# 4.3
# 5.8
# 7
# 5.4
# 7
# 7
# 4.3
# None
# 5
# 7
# None
# None
# 7
# 7
# 7
# 7
# 3.3
# 6.8
# 7
# 7
# None
# 5
# None
# 5.2
# 3.3
# 7
# 7
# 4.3
# 3.3
# 7
# 7
# 7
# 4.1
# 3.8
# 3.3
# 4.1
# 7
# 7
# 6.8
# 5.3
# 5.3
# 5.3
# 5.4
# 3
# None
# 6.6
# 3
# None
# 7
# 7
# None
# None
# 5.8
# 5
# 7
# 5.3
# 5.3
# 5.3
# 7
# 7
# 5
# 5.3
# 7
# 2.1
# 5.4
# 7
# 7
# 7
# 3
# 6
# None
# 7
# 7
# None
# 5
# 3.3
# 7
# 7
# 7
# None
# None
# 7.1
# 5
# 4
# 4
# 7
# 7
# 4
# 7
# 5
# None
# 7
# 7
# 4.3
# 6.8
# 7
# 7
# None
# 7
# 6.8
# 7
# 7
# 7
# 6.8
# 7
# 7
# 5.3
# 5.3
# 6.8
# 6
# 6.8
# 6.3
# 6.2
# 5
# 6.3
# 5.8
# 6.3
# 4.5
# 7.2
# 7.1
# 3.3
# None
# 7
# None
# 7
# 7
# 4.7
# 4
# 4
# 4
# 7
# 6.8
# 7
# 4.7
# 4
# 4
# 4
# None
# 4
# 7
# None
# None
# 5.3
# 7
# None
# None
# 7
# None
# 7
# None
# 5.3
# 6.3
# 6.8
# 7
# 6.8
# 5.3
# 5
# None
# 5
# 7
# 7
# 5
# 7
# 7
# None
# 5.3
# None
# 5
# 5
# 5.3
# 7
# None
# 7
# 7
# 6.8
# 4
# 5.3
# 7
# 6.3
# 6.8
# 7
# 5.4
# None
# ❌ No related project found for @keycloak/keycloak-ui-shared (npm)
# 7
# 7
# 4.7
# 4
# 4
# 4
# None
# 4
# 3.3
# 3.3
# 4.1
# None
# 5.3
# None
# 7
# 5.4
# 6
# 4.7
# 4
# 4
# 4
# None
# 4
# None
# 5
# None
# 4.6
# 5.3
# 7
# 7
# None
# 7
# None
# 5.3
# None
# None
# 7
# 7
# None
# 4
# 4
# None
# None
# 5
# 3.3
# 7
# 7
# 7
# 4
# None
# None
# 4.7
# 4
# 4
# 4
# None
# 3.3
# 5
# 3.3
# 4.1
# 7
# 7
# 7
# 4
# 4.1
# 7
# 6.8
# 7
# 6.3
# 5
# 5.3
# None
# 7
# None
# 7
# None
# None
# None
# None
# 6.3
# 7
# 6.8
# 3.3
# None
# 5.3
# None
# 5.3
# None
# 3.3
# 4.1
# 7
# None
# None
# 7.2
# 5
# 4.3
# 6.8
# 5.5
# 5.5
# 5.5
# 3.8
# 3.3
# None
# 6.8
# None
# 7.2
# 5
# 3.3
# None
# None
# None
# 7
# 7
# ❌ Failed to fetch data for org.keycloak.test:keycloak-test-junit5-framework (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.test%3Akeycloak-test-junit5-framework
# 8.4
# 5.3
# 5.4
# ❌ Failed to fetch data for org.keycloak:keycloak-operator (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-operator
# 5.8
# None
# None
# None
# 2.1
# None
# None
# None
# None
# None
# None
# 4.8
# ❌ No related project found for commons-validator:commons-validator (maven)
# None
# 4.6
# 5.6
# 5.6
# 6.5
# None
# None
# 5.6
# 5.6
# 6.5
# 4.6
# 4.6
# 5.6
# 4.8
# None
# 5.6
# 1.3
# 5.6
# 6.5
# 6.3
# 7
# None
# 4.5
# 7
# 7.1
# 6.8
# 3.4
# 7
# 7.4
# None
# 6.8
# 7
# 5.3
# 7
# 7
# 3.3
# None
# 7
# None
# 5.4
# None
# 6.8
# 5.8
# 5.3
# None
# 3.8
# 7
# 3.8
# 7
# 7.1
# 7
# None
# 7
# 5.3
# 4.6
# 7.1
# 7.2
# 6.8
# 4.2
# 6.8
# 7
# 6
# 7
# 7.2
# 5
# 7
# 5.3
# 5
# None
# 7
# 4.3
# 5.3
# 7
# 7
# 5.8
# 7
# None
# 7
# 6.8
# None
# None
# None
# None
# None
# 5.4
# None
# None
# None
# None
# 7
# 7
# 7
# 7
# 7.1
# 7
# 5.3
# 5
# 5.8
# 4.1
# None
# None
# 7.1
# 7
# 7.1
# None
# ❌ Failed to fetch data for org.keycloak:keycloak-admin-client-jee-tests (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-admin-client-jee-tests
# None
# 7
# 7
# 5.7
# 5.7
# 5.7
# 5
# 4.1
# 5.8
# None
# 7
# 4.2
# 4
# 5
# 5
# 4.2
# 7.1
# 7
# 5
# 5.8
# 4.2
# 5
# 4.2
# 5
# 6.8
# 7
# 7
# 5.3
# 4.1
# 4.2
# None
# 4.2
# 4
# 4
# 5.3
# 4
# 4
# 5
# 4.1
# 5.8
# 4.2
# 4
# None
# 6.8
# None
# 4
# None
# 5.8
# 6.8
# 4.2
# None
# 7.1
# 3.3
# None
# 4.2
# None
# 5.3
# 5.8
# 7
# 6.8
# 3.3
# None
# 7
# 5
# ❌ Failed to fetch data for org.keycloak:keycloak-policy-enforcer-tests (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-policy-enforcer-tests
# ❌ Failed to fetch data for org.keycloak:keycloak-authz-client-tests (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak%3Akeycloak-authz-client-tests
# 7
# 3.3
# 7
# 4.5
# 6.3
# 7.1
# 6.8
# None
# 5.8
# 8.4
# None
# 3.3
# 7
# 4.5
# 5.8
# 5.3
# 5.3
# 4.6
# 5
# None
# 7
# 7
# 6.3
# 5.3
# 4.5
# 7
# None
# 4.5
# 6.8
# 6.8
# 4.5
# 7
# ❌ Failed to fetch OSSF score for fs-extra (npm): 404
# None
# 2.7
# 3.8
# 5.3
# 7
# 5
# 4.5
# 5.3
# 7
# 4.5
# 5.3
# 7
# None
# 7
# None
# 7
# 6.8
# 3
# 4.5
# 5.3
# 5.3
# 5.3
# None
# None
# None
# 7
# 6.8
# 3.3
# None
# 7
# 7.2
# 7
# 5
# 4
# None
# 6.8
# 5.3
# None
# 4
# 7.1
# 6.8
# 6.8
# 6.8
# None
# 7
# 4
# 6.3
# 5.3
# None
# 7.2
# None
# 5
# 3.3
# None
# None
# 7
# 4
# 4
# 7
# 4.1
# None
# 4.1
# 7
# 4.1
# 7
# 7
# 5.4
# 5.5
# 5.5
# None
# None
# None
# None
# 5.5
# 5.5
# None
# None
# 4.1
# 6.8
# 6.8
# None
# None
# None
# None
# 7
# 5.3
# 3.3
# 7
# None
# 4
# 4
# None
# 5
# 3.3
# 7
# None
# 7
# 4.2
# 4
# None
# 3
# 7
# 7
# 4.5
# 7
# None
# 3
# 3
# 4.7
# 4.7
# 2.1
# 3.8
# 3.8
# 3.8
# 3.8
# 6.8
# 3.8
# 5.3
# 5.3
# 5.7
# 5.7
# 5.7
# None
# None
# None
# 4.8
# 3.3
# 7
# 7
# 3.3
# None
# 3.3
# 4.1
# 4.6
# 7
# 7
# 4
# None
# 5.2
# 5.4
# 6.8
# 5
# 6.8
# 5
# 7
# 7
# 6.8
# 5.3
# 4
# 4
# None
# None
# None
# None
# None
# 4.8
# None
# 4
# 7
# 4
# 4
# 4
# 4
# 7
# 5.3
# None
# 6.8
# 7
# 7
# 7.2
# 3.8
# 4
# 7
# 4.7
# 7
# 5.3
# 5.8
# 7
# 5.8
# None
# 4.7
# 7
# None
# 7
# 4
# 7
# 3
# 4.2
# 5
# 4
# 6.8
# 7
# 6.8
# None
# 4.1
# 4.1
# 5.3
# None
# 4.1
# None
# None
# 7
# 4.5
# 5.3
# 5.4
# None
# 4.1
# None
# 7
# 4.2
# 4
# None
# 7
# 5.8
# 6.8
# 5.4
# None
# 5.5
# None
# 3
# 7
# 3.3
# 5
# 7
# 3.3
# 5
# 5
# 7
# 3.3
# 7
# None
# 3.3
# 7
# 7
# 5.4
# None
# 7
# 7
# 5.3
# 3.8
# 4
# 5.2
# 7
# 7
# 7
# 6.8
# 4
# 6.8
# 6.8
# 5
# 7
# 3.8
# 4
# 7
# 7
# 6.8
# 6.8
# 7
# 6.8
# 5.3
# 3.8
# 3.8
# 3
# 7
# 3.8
# 7
# 6.8
# None
# 3
# 3.8
# 6.8
# 6.8
# 6.8
# 7
# 7
# 7
# 4
# 7
# None
# None
# None
# ❌ No related project found for org.bouncycastle:bcutil-fips (maven)
# None
# 7
# 7
# None
# 7
# 4
# 7
# 5.4
# 4
# 4
# 7
# 5.3
# 4
# None
# 3
# 5.8
# 6.8
# 4
# 4
# 4
# None
# 4
# ❌ No related project found for io.micrometer:micrometer-core (maven)
# None
# ❌ No related project found for io.micrometer:micrometer-commons (maven)
# None
# ❌ No related project found for io.micrometer:micrometer-observation (maven)
# None
# ❌ No related project found for io.micrometer:micrometer-registry-prometheus-simpleclient (maven)
# None
# 7
# None
# 6.8
# None
# None
# None
# 4.4
# 7
# 6.8
# None
# 5.3
# 5.3
# None
# None
# None
# 2.1
# None
# None
# None
# 4.8
# 7
# 6.8
# 5.3
# 4.7
# 3.3
# 7
# 6.8
# 7
# 7
# 4.7
# None
# 3.3
# 5
# 7
# 6.8
# None
# 3.4
# 6.3
# 4
# 7
# 3.3
# 3.3
# 7
# None
# 3.3
# 7
# 7
# None
# 3.3
# 7
# 7
# 4
# None
# 3.3
# None
# 4.6
# None
# 7
# 5.3
# 7
# 4.6
# 4.6
# 5.3
# 6.8
# None
# 3.4
# 4.4
# None
# 7
# 6.8
# 4.7
# 3.8
# 7
# 5
# 4.7
# 5.3
# 4
# 3.4
# 3.3
# 4
# 4
# None
# 5
# 3.3
# 4
# 4
# 4
# 5.8
# 7
# 4
# 7
# 7
# 3.4
# 7
# None
# 4
# 7
# None
# 7
# 4
# None
# None
# None
# None
# None
# None
# None
# None
# 6.8
# 6.3
# 7
# None
# 7
# 6.3
# None
# 7
# 5.3
# 4
# 4
# 4
# None
# None
# None
# None
# 5.3
# 4
# None
# 4
# None
# 3
# 7.1
# 5.3
# 7
# None
# 7
# 6.3
# 4
# 7.1
# ❌ Failed to fetch data for org.keycloak.test:keycloak-test-framework-core (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.test%3Akeycloak-test-framework-core
# None
# None
# None
# 4.8
# ❌ Failed to fetch data for org.keycloak.test:keycloak-test-framework-ui (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.test%3Akeycloak-test-framework-ui
# 8.4
# 8.4
# None
# 3
# 6.8
# 6.8
# 3.3
# None
# 6.8
# 3.3
# 4
# 4.6
# None
# 3.3
# None
# None
# None
# 4.8
# ❌ Failed to fetch data for org.keycloak.test:keycloak-test-framework-bom (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.test%3Akeycloak-test-framework-bom
# ❌ Failed to fetch data for org.keycloak.test:keycloak-test-framework-db-mariadb (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.test%3Akeycloak-test-framework-db-mariadb
# ❌ Failed to fetch data for org.keycloak.test:keycloak-test-framework-db-mssql (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.test%3Akeycloak-test-framework-db-mssql
# ❌ Failed to fetch data for org.keycloak.test:keycloak-test-framework-db-mysql (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.test%3Akeycloak-test-framework-db-mysql
# ❌ Failed to fetch data for org.keycloak.test:keycloak-test-framework-db-oracle (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.test%3Akeycloak-test-framework-db-oracle
# ❌ Failed to fetch data for org.keycloak.test:keycloak-test-framework-db-postgres (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.test%3Akeycloak-test-framework-db-postgres
# 6.8
# 5.3
# 6.3
# 7
# ❌ Failed to fetch data for org.keycloak.test:keycloak-test-framework-example-providers (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.test%3Akeycloak-test-framework-example-providers
# None
# 7
# 3.4
# 3.3
# 5
# 5
# 3.3
# None
# None
# None
# 7
# 5.3
# None
# 7
# None
# None
# 5.3
# 5.3
# ❌ Failed to fetch data for org.keycloak.test:keycloak-test-framework-oauth-nimbus-poc (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.test%3Akeycloak-test-framework-oauth-nimbus-poc
# None
# 6.3
# 6.8
# 3.4
# 4.5
# 5.3
# 6.3
# 3.4
# 4.5
# 5.3
# 4.5
# 6.8
# 5.3
# 3.4
# 6.3
# 6.8
# ❌ Failed to fetch data for org.keycloak.test:keycloak-test-framework-email-server (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.test%3Akeycloak-test-framework-email-server
# None
# 4
# 4
# None
# 4
# None
# 4
# 4
# None
# 7
# 4
# 4
# None
# 3.3
# 4
# None
# 3.3
# 4
# 7
# 4
# None
# 3.3
# None
# None
# 6.8
# 6.8
# 7
# None
# None
# None
# None
# 7
# 7
# 5.3
# 3.3
# None
# 7.1
# 7
# None
# None
# 3.3
# 3.3
# None
# None
# None
# None
# 4.7
# 4.7
# 2.1
# None
# 3.8
# 3.8
# 3.8
# 3.8
# 6.8
# 7
# 7
# 7
# 4.7
# 3.3
# 7
# None
# 6.3
# 6.8
# 7
# 6.8
# 6.3
# 3
# 5
# 3.4
# 6.3
# 5.8
# 6.3
# 4.5
# 7.2
# 7.1
# 3.3
# 5.3
# None
# ❌ Failed to fetch data for org.keycloak.test:keycloak-test-framework-remote (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.test%3Akeycloak-test-framework-remote
# ❌ Failed to fetch data for org.keycloak.test:keycloak-test-framework-remote-providers (maven): 404 Client Error: Not Found for url: https://api.deps.dev/v3alpha/systems/maven/packages/org.keycloak.test%3Akeycloak-test-framework-remote-providers
# 4.7
# 3.3
# 4.3
# 3
# 4
# 6.8
# None
# 6.8
# 3
# 7.1
# 6.8
# 7.1
# 7
# 4
# 5.3
# 7
# None
# 7
# None
# 5.3
# 7
# None
# None
# 5
# 5
# 3.3
# 6.3
# 3.3
# 5.3
# 7.2
# 2.1
# 6.8
# 7
# None
# 5
# 3.3
# 5
# 3.8
# 3.8
# 3.8
# 6.8
# 3.8
# 3.8
# 6.8
# 6.3
# 5.3
# None
# 5
# 3.3
# None
# None
# 5
# 6.3
# 4.5
# 7
# 4
# 7
# 4.5
# 5
# 4.1
# 7
# 6.3
# 5.3
# 3.8
# 3.8
# 4.1
# 5.8
# None
# 4.1
# 4
# 7
# 7
# 4
# None
# 5
# 4.1
# None
# 7
# 4
# 3.3
# 7
# 4
# 4
# None
# 4
# None
# 5
# 3.3
# 7
# 7
# None
# 7
# 4.2
# 4
# None
# None
# 7.2
# 7
# 5.3
# 6.3
# 3.3
# 7
# None
# None
# 3.3
# None
# 5.4
# None
# 7
# 5.4
# 7
# 5.3
# 5.4
# 6.8
# 3
# None
# 6
# 7.4
# 6.8
# 4.2
# 6.8
# 6.8
# 7
# 6
# 5.8
# None
# None
# None
# 3.3
# 7
# 7
# 7
# 4
# None
# 6
# 5.8
# 5.8
# None
# 4
# 4.2
# None
# 3
# 7
# None
# 6
# 6.3
# 4
# 5.3
# None
# 4
# 7.2
# None
# 4.1
# 4.1
# None
# 7
# None
# None
# 6.3
# 7
# 7
# 7
# 7
# None
# 4.5
# 5.3
# 5.3
# 7
# 7.1
# 7
# 3.4
# 7.2
# 3.3
# 7
# 3.4
# 3.4
# 5
# 6.8
# 6.8
# 7
# None
# 7.2
# None
# 3.3
# 7
# None
# 6.8
# 5.4
# 5.5
# 5.5
# None
# None
# None
# None
# 5.5
# None
# None
# 5.5
# None
# None
# 4
# 5.3
# 4
# 4.1
# 3
# 3.5
# 4.1
# 3
# 4.1
# 7
# 4.1
# 3
# None
# 6.8
# 6.3
# 7
# 5.3
# 7
# None
# 7
# None
# 7
# 6.8
# 5
# None
# None
# 7
# 6.8
# 6.8
# None
# 7.1
# 6.8
# 7.1
# None
# 6.8
# None
# None
# 6.8
# 7.1
# 5.3
# 5.3
# 5.3
# 3
# 7
# None
# 6.8
# ❌ No related project found for org.jgroups:jgroups (maven)
# None
# None
# None
# None
# None
# None
# 8.4
# 4.5
# 3.8
# None
# 7
# 7
# 7
# 7.1
# 6.8
# 6.8
# None
# 7
# None
# 5.4
# 5.3
# 6.8
# 5.4
# 2.6
# None
# 5.5
# ❌ No related project found for org.apache.commons:commons-text (maven)
# None
# 4
# None
# 7
# 7
# 4
# 4
# 4
# None
# None
# None
# 7
# 4.2
# 3.3
# 3.3
# 7
# 4.2
# 4.2
# 7.1
# 6.8
# None
# 3.3
# None
# 7
# 4.2
# None
# 6.3
# 6.8
# 7
# 6.3
# 7
# None
# 5.4
# ❌ No related project found for com.oracle.database.jdbc:ojdbc17 (maven)
# None
# None
# 6.3
# 7
# 5.3
# 4
# 3.3
# 7
# 4
# 4
# 4
# 7
# 4.6
# 7
# None
# 6
# 4.1
# 5.3
# 5.3
# 6.8
# 3
# 7
# 4
# 5.4
# 5.4
# 5.4
# 7
# 7.1
# 5.3
# 7.1
# 5.3
# 7.1
# 5.3
# 5.4
# 6.8
# 6
# 5.3
# 6.8
# 6
# 3
# 7
# 6.8
# 6.8
# 4.6
# 4.1
# 4
# None
# 7
# 6
# 3.8
# 7
# 7
# None
# 4
# 6.8
# 3.8
# 7
# 7.2
# None
# None
# None
# 2.1
# None
# None
# None
# 4.8
# None
# None
# 5.4
# 7
# None
# None
# 5.4
# None
# ❌ Failed to fetch OSSF score for @axe-core/playwright (npm): 404
# None
# None
# None
# 7
# 4
# None
# 6.8
# 4.2
# None
# None
# None
# 5.3
# 4.4
# 6.3
# 6.8
# 7
# 6.8
# 6.3
# 6.8
# 6.8
# 6.3
# 6.8
# 7
# 6.8
# 6.3
# 5.3
# 6.8
# 7
# 7
# 7
# 7
# 5.3
# 5.3
# 7
# 6.3
# 5.4
# 7
# None
# 4.4
# 7
# 4.2
# None
# 5.3
# 6.8
# None
# 7
# 7
# 7
# 6.8
# 7
# 6.3
# 5.3
# 7
# 7
# 5.8
# 7
# 6.8
# 6.8
# 6
# 6
# 5.3
# 7
# 6
# 5.3
# 6
# 4
# 4
# None
# None
# 3.3
# 7
# 7
# None
# 7
# 4.2
# 4
# None
# None
# None
# 3
# 7
# 7
# 7
# None
# 6.8
# 7.2
# 5.3
# 5.4
