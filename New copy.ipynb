# %% [markdown]
# ## Clone Repos

# %%
import os
import re
import subprocess
from tqdm import tqdm
import xml.etree.ElementTree as ET
from typing import List, Dict, Any
from collections import defaultdict
from git import Repo, BadName
from pathlib import Path
import json
# Cell 1: Imports and setup
import json
import requests
import urllib.parse
from datetime import datetime
from collections import defaultdict
from packaging.version import Version, InvalidVersion

# Global cache

# %%
cached_versions = defaultdict(dict)

# %%
# Here we are defining the functions that will be used to find all the necesssary files in the repository to extract the version information from the repository and load their commit history.

# %%
def find_all_files(repo_path):
    found_files = []
    for root, dirs, file_list in os.walk(repo_path):  # renamed 'files' to 'file_list'
        for file in file_list:
            if file == "pom.xml" or file == "requirements.txt" or file == "package.json" or file == "setup.py" or file == "pyproject.toml":
                full_path = os.path.join(root, file)
                found_files.append(full_path)
    return found_files

# %%
import fnmatch


def find_all_gradle_files(repo_path):
    gradle_files = []
    patterns = [
        "build.gradle",
        "settings.gradle",
        "gradle.properties",
        "build.gradle.kts",
        "settings.gradle.kts",
        "*.gradle",
        "*.gradle.kts"
    ]

    for root, dirs, files in os.walk(repo_path):
        for file in files:
            for pattern in patterns:
                if fnmatch.fnmatch(file, pattern):
                    full_path = os.path.join(root, file)
                    gradle_files.append(full_path)
                    break
    return gradle_files

# %%
def find_commits_with_changes(repo_path, file_paths):
    repo = Repo(repo_path)
    commits_with_changes = {}

    for file_path in file_paths:
        rel_path = os.path.relpath(file_path, repo_path)
        commits = list(repo.iter_commits(paths=rel_path))
        
        commits_with_changes[rel_path] = [commit.hexsha for commit in commits]
    
    return commits_with_changes

# %%
# Here we deinfe functions for loading the commit hiostroy of the files we found in the previous step and extracting the version information from them.

# %%
def get_all_relevant_commits(repo_path: str, file_paths: List[str]) -> Dict[str, List[str]]:
    repo = Repo(repo_path)
    commits_with_changes = {}

    for file_path in file_paths:
        rel_path = os.path.relpath(file_path, repo_path)

        # Get all commits that modified the file
        result = subprocess.run(
            ["git", "-C", repo_path, "log", "--follow", "--pretty=format:%H", "--name-only", "--", rel_path],
            capture_output=True,
            text=True,
            check=True
        )

        lines = result.stdout.strip().split('\n')
        current_commit = None

        for line in lines:
            stripped_line = line.strip()
            
            if len(stripped_line) == 40 and all(c in '0123456789abcdef' for c in stripped_line):  # Check if it looks like a SHA-1 hash
                current_commit = stripped_line
                if current_commit not in commits_with_changes:
                    commits_with_changes[current_commit] = set()  # Using set to avoid duplicates
            elif current_commit:
                modified_file = stripped_line
                if modified_file:  # Ensure we don't add empty lines
                    commits_with_changes[current_commit].add(modified_file)

    # Convert commits to a sorted list based on commit date
    commit_objects = []
    for commit_hash in commits_with_changes.keys():
        try:
            commit_obj = repo.commit(commit_hash)
            commit_objects.append((commit_obj, commit_hash))
        except BadName:
            print(f"Skipping invalid commit hash: {commit_hash}")  # Warn if a bad commit hash is found

    sorted_commits = sorted(commit_objects, key=lambda x: x[0].committed_date)
    
    # Creating a sorted dictionary of commits with their modified files
    sorted_commits_with_changes = {
        commit_hash: list(commits_with_changes[commit_hash]) for _, commit_hash in sorted_commits
        }
    
    global commits_with_date
    commits_with_date = {
        commit_hash: repo.commit(commit_hash).committed_datetime.strftime("%Y-%m-%d %H:%M:%S")
        for _, commit_hash in sorted_commits
    }

    return sorted_commits_with_changes

# %% [markdown]
# # Here we parse the correct dependencies from the pom.xml file in JAVA

# %%
# Initialize file cache
file_cache = {}
properties_cache = {}
NAMESPACE = {'mvn': 'http://maven.apache.org/POM/4.0.0'}
properties = {}

def parse_pom_xml(content: str, file_path: str, properties: Dict[str, str] = None) -> Dict[str, str]:
    if properties is None:
        properties = {}
    else:
        properties = properties.copy()  # Avoid side effects

    dependencies = {}

    try:
        root = ET.fromstring(content)

        # Update namespace if needed
        if 'xmlns' in root.attrib:
            NAMESPACE['mvn'] = root.attrib['xmlns']

        # Load project properties
        for prop in root.findall(".//mvn:properties/*", NAMESPACE):
            if prop.tag and prop.text:
                prop_name = prop.tag.split('}')[-1]
                properties[prop_name] = prop.text.strip()
                properties_cache[prop_name] = properties[prop_name]
        
        # Load project and parent versions as fallback properties
        project_version = root.find(".//mvn:version", NAMESPACE)
        if project_version is not None and project_version.text:
            properties["project.version"] = project_version.text.strip()

        parent_version = root.find(".//mvn:parent/mvn:version", NAMESPACE)
        if parent_version is not None and parent_version.text:
            properties["parent.version"] = parent_version.text.strip()

        parent_info = {}
        relative_path_elem = root.find(".//mvn:parent/mvn:relativePath", NAMESPACE)
        if relative_path_elem is not None and relative_path_elem.text:
            parent_info = {"parent_pom_path": relative_path_elem.text.strip()}

        # Read dependencies
        for dependency in root.findall(".//mvn:dependency", NAMESPACE):
            group_id = dependency.find("mvn:groupId", NAMESPACE)
            artifact_id = dependency.find("mvn:artifactId", NAMESPACE)
            version = dependency.find("mvn:version", NAMESPACE)

            if group_id is not None and artifact_id is not None:
                dep_key = f"{group_id.text.strip()}:{artifact_id.text.strip()}"
                if "${" in dep_key and "}" in dep_key:
                    dep_key = (resolve_cached(dep_key))

                if version is not None and version.text:
                    version_text = version.text.strip()
                    if version_text.startswith("${") and version_text.endswith("}"):
                        prop_name = version_text[2:-1]
                        resolved_version = properties.get(prop_name, "UNRESOLVED")
                        if resolved_version == "UNRESOLVED":
                            resolved_version = resolve_from_parent(prop_name, file_path, parent_info)
                            if (resolved_version =="UNRESOLVED"):
                                resolved_version = properties_cache.get(prop_name, "UNRESOLVED")
                        if resolved_version.startswith("${") and resolved_version.endswith("}"):
                            resolved_version = resolve_cached(resolved_version)
                        dependencies[dep_key] = resolved_version
                    else:
                        dependencies[dep_key] = version_text
                #else:
                    #dependencies[dep_key] = "UNSPECIFIED"

    except ET.ParseError as e:
        print(f"XML parsing error: {e}")

    return dependencies




def resolve_cached(prop_name, visited=None):
    matches = re.findall(r"\$\{([^}]+)\}", prop_name)
    if not matches:
        return properties_cache.get(prop_name)  # nothing to resolve, return as is

    resolved = prop_name
    for match in matches:
        inner_value = resolve_cached(match)
        if inner_value is None:
            return match
        resolved = resolved.replace(f"${{{match}}}", inner_value)

    return resolved



def resolve_from_parent(prop_name: str, file_path: str, properties: Dict[str, str]) -> str:
    parent_pom_path = properties.get("parent_pom_path")   
    if parent_pom_path is None:
        final_path = "pom.xml"
        parent_file = str(final_path).replace("\\", "/")
        if parent_file not in file_cache:
            return "UNRESOLVED"
        content = file_cache[parent_file]
        parent_prop_value = get_all_properties(content, prop_name, final_path, {})
        return parent_prop_value

    file_path = Path(file_path) if not isinstance(file_path, Path) else file_path
    parent_pom_path = Path(parent_pom_path) if not isinstance(parent_pom_path, Path) else parent_pom_path
    combined = file_path.parent / parent_pom_path

    stack = []
    for part in combined.parts:
        if part == "..":
            if stack and stack[-1] != "..":
                stack.pop()
            else:
                stack.append(part)
        elif part != ".":
            stack.append(part)
    final_path = Path(*stack)
    parent_file = str(final_path).replace("\\", "/")
    if parent_file not in file_cache:
        #print(f"[DEBUG] Skipping missing file: {parent_file}")
        return "UNRESOLVED"
    content = file_cache[parent_file]
    parent_prop_value = get_all_properties(content, prop_name, final_path, {})
    return parent_prop_value

def get_all_properties(content: str, target_prop: str, file_path: str, properties: Dict[str, str] = None):
    if properties is None:
        properties = {}
    else:
        properties = properties.copy()  # Avoid side effects

    try:
        root = ET.fromstring(content)

        if 'xmlns' in root.attrib:
            NAMESPACE['mvn'] = root.attrib['xmlns']

        # Properly assign keys without shadowing target_prop
        for prop in root.findall(".//mvn:properties/*", NAMESPACE):
            if prop.tag and prop.text:
                key = prop.tag.split('}')[-1]
                properties[key] = prop.text.strip()

        return properties.get(target_prop, "UNRESOLVED")
    except Exception as e:
        return "UNRESOLVED"    

def load_file_at_commit(repo, commit_hash, file_path):
    try:
        commit = repo.commit(commit_hash)
        blob = commit.tree / file_path
        content = blob.data_stream.read().decode('utf-8')
        file_cache[file_path] = content
        return content
    except Exception as e:
        print(f"[DEBUG]Error loading file '{file_path}' at commit '{commit_hash}': {e}")
        return None


def process_commit(repo, commit_hash, changed_files, dependencies_snapshot):
    for file_path in changed_files:
        if file_path.endswith("pom.xml"):
            content = load_file_at_commit(repo, commit_hash, file_path)
            if content:
                new_dependencies = parse_pom_xml(content, file_path, properties)
                dependencies_snapshot[file_path] = new_dependencies
    return dependencies_snapshot


def process_commits(repo, commits_with_changes):
    dependencies_over_time = {}
    dependencies_snapshot = {}

    for commit_hash, changed_files in tqdm(commits_with_changes.items(), desc="Processing commits"):
        dependencies_snapshot = process_commit(repo, commit_hash, changed_files, dependencies_snapshot)
        dependencies_over_time[commit_hash] = dependencies_snapshot.copy()

    return dependencies_over_time

# %%
# daten laten und neuseten versionen holen von deps.dev api und proj_version_lag speichern und so.

# %%
# Cell 2: System‐name normalization
def normalize_system(system: str) -> str:
    """
    Map generic system names to the deps.dev API identifiers.
    """
    mapping = {
        "java": "maven",
        "javascript": "npm",
        "python": "pypi",
        "go": "go"
    }
    return mapping.get(system, system)

# %%
# Cell 3: Version parsing helper
def get_major_version(version_str: str):
    """
    Safely extract the major version number, or return None if invalid.
    """
    try:
        return Version(version_str).major
    except InvalidVersion:
        return None

# %%
# Cell 4: Fetching & caching package data
def fetch_package_data(package_name: str, system: str) -> dict:
    """
    Hit the deps.dev API and return the raw JSON for a given package.
    """
    encoded = urllib.parse.quote(package_name, safe="")
    url = f"https://api.deps.dev/v3alpha/systems/{system}/packages/{encoded}"
    resp = requests.get(url)
    resp.raise_for_status()
    return resp.json()

def get_cached_package_data(package_name: str, system: str) -> dict:
    """
    Return cached data if available, otherwise fetch and cache.
    """
    if package_name not in cached_versions[system]:
        try:
            cached_versions[system][package_name] = fetch_package_data(package_name, system)
        except requests.RequestException as e:
            print(f"❌ Failed to fetch data for {package_name} ({system}): {e}")
            cached_versions[system][package_name] = {}
    return cached_versions[system][package_name]

# %%
# Cell 5: Core analysis routine
def analyze_entry(entry: dict) -> dict:
    """
    Given a single change entry, enrich it with:
      - newest_version_at_commit
      - released_date
      - latest_at_commit_time
      - proj_version_lag (caret‐aware)
    """
    pkg        = entry["dependency"]
    raw_new    = entry["new_version"]
    has_caret  = raw_new.startswith("^")
    new_ver    = raw_new.lstrip("^")
    commit_dt  = datetime.strptime(entry["date"], "%Y-%m-%d %H:%M:%S")
    sys_name   = normalize_system(entry["system"])
    is_npm = (sys_name == "npm")


    data       = get_cached_package_data(pkg, sys_name)
    all_vers   = data.get("versions", [])
    commit_vs  = []

    # Filter to releases published on or before commit date
    for v in all_vers:
        ver = v.get("versionKey", {}).get("version")
        pub = v.get("publishedAt")
        if not (ver and pub): continue
        try:
            pub_dt = datetime.strptime(pub, "%Y-%m-%dT%H:%M:%SZ")
        except ValueError:
            continue
        if pub_dt <= commit_dt:
            try:
                commit_vs.append(Version(ver))
            except InvalidVersion:
                pass
        

    # Determine newest version at commit time
    entry["alpha/beta/rc"] = False

    if commit_vs and is_npm:
        max_major = max(v.major for v in commit_vs)
        highest   = max(v for v in commit_vs if v.major == max_major)
        entry["newest_version_at_commit"] = str(highest)
        entry["newest_version_at_commit"] = entry["newest_version_at_commit"].replace("a", "-alpha.").replace("b", "-beta.").replace("rc", "-rc.")
        entry["alpha/beta/rc"] = highest.pre is not None
        
        #        print(f"Highest version at commit: {highest}")
    else:
        entry["newest_version_at_commit"] = None

    # Track release date & latest at commit
    entry["released_date"]         = None
    entry["latest_at_commit_time"] = None
    latest_pub_date = None

    target_major = get_major_version(new_ver) if is_npm else None

    try:
        baseline = Version(new_ver)
    except InvalidVersion:
        baseline = None

    if not has_caret:
        for v in all_vers:
            ver = v.get("versionKey", {}).get("version")
            pub = v.get("publishedAt")
            if not (ver and pub): continue
            try:
                parsed = Version(ver)
            except InvalidVersion:
                parsed = None

            # npm: restrict to same major
            if is_npm and parsed and parsed.major != target_major:
                continue

            pub_dt = datetime.strptime(pub, "%Y-%m-%dT%H:%M:%SZ")
            if ver == new_ver:
                entry["released_date"] = pub_dt.isoformat()
            if pub_dt <= commit_dt and (latest_pub_date is None or pub_dt > latest_pub_date):
                latest_pub_date            = pub_dt
                entry["latest_at_commit_time"] = ver
    else:
        release_target = entry["newest_version_at_commit"]
        target_major = Version(release_target).major if release_target else None
        for v in all_vers:
            ver_str = v.get("versionKey", {}).get("version")
            pub = v.get("publishedAt")
            if not (ver_str and pub):
                continue
            try:
                pub_dt = datetime.strptime(pub, "%Y-%m-%dT%H:%M:%SZ")
                ver_obj = Version(ver_str)
            except (ValueError, InvalidVersion):
                continue
            # restrict to same major
            if target_major is not None and ver_obj.major != target_major:
                continue
            if ver_str == release_target:
                entry["released_date"] = pub_dt.isoformat()

    rel_date_str = entry.get("released_date")
    released_date_dt = datetime.fromisoformat(rel_date_str) if rel_date_str else None

    # Compute caret‐aware proj_version_lag
    

    if has_caret and baseline:
        same_maj = [v for v in commit_vs if v.major == baseline.major]
        if same_maj:
            baseline = max(same_maj)

    if baseline and commit_vs:
        entry["proj_version_lag"] = sum(1 for v in commit_vs if v > baseline)
    else:
        entry["proj_version_lag"] = -1
        for v in all_vers:
            version = v.get("versionKey").get("version")
            v_date_str =  v.get("publishedAt")
            if not v_date_str or not version:
                continue
            v_date = datetime.strptime(v_date_str, "%Y-%m-%dT%H:%M:%SZ")
            if released_date_dt and v_date >= released_date_dt:
                if v_date <= commit_dt:
                    entry["proj_version_lag"] += 1
    

    # Handle latency: 
    commit_str = entry.get("date")
    commit_dt  = datetime.strptime(commit_str,  "%Y-%m-%d %H:%M:%S")

    release_str = entry.get("released_date")
    if release_str is None:
        entry["latency"] = "N/A"
        return entry
    
    release_dt = datetime.strptime(release_str,  "%Y-%m-%dT%H:%M:%S")
    if release_dt >= commit_dt:
        entry["latency"] = "future: " + str((commit_dt - release_dt).days)
        entry["proj_version_lag"] = -1
    else:
        entry["latency"] = (commit_dt - release_dt).days

    return entry

# %%
# Cell 6: Batch processing function
def process_json_file(input_path: str, output_path: str):
    """
    Read the input JSON, enrich each entry, and write to output.
    """
    with open(input_path, "r") as f:
        entries = json.load(f)

    enriched = []
    for i, e in enumerate(entries, 1):
        enriched.append(analyze_entry(e))
        print(f"[{i}/{len(entries)}] {e['dependency']} → done")

    with open(output_path, "w") as f:
        json.dump(enriched, f, indent=2)

# %% [markdown]
# # Here we start weith the actual execution of the Code

# %%
repo_name = "keycloak/keycloak"

repo_url = "https://github.com/" + repo_name
destination_path = "./" + repo_name
repo_path = repo_name

commits_with_date = {}

# %%
if not os.path.exists(destination_path) or not os.listdir(destination_path):
	Repo.clone_from(repo_url, destination_path)
else:
	print(f"Directory '{destination_path}' already exists and is not empty. Skipping clone.")
# Out:
# Directory './keycloak/keycloak' already exists and is not empty. Skipping clone.

# %%
repo = Repo(destination_path)

# %%
# Example usage
repo_path = "./" + repo_name  # Replace with your cloned repo path
file_paths = find_all_files(repo_path)
file_paths_gradle = find_all_gradle_files(repo_path)
file_paths += file_paths_gradle

# Display all found pom.xml paths
for path in file_paths:
    path = path.replace('\\', '/')
    print(path)

print(len(file_paths))
# Out:
# ./keycloak/keycloak/pom.xml
# ./keycloak/keycloak/adapters/pom.xml
# ./keycloak/keycloak/adapters/saml/pom.xml
# ./keycloak/keycloak/adapters/saml/core/pom.xml
# ./keycloak/keycloak/adapters/saml/core-public/pom.xml
# ./keycloak/keycloak/adapters/saml/wildfly/pom.xml
# ./keycloak/keycloak/adapters/saml/wildfly/wildfly-subsystem/pom.xml
# ./keycloak/keycloak/adapters/saml/wildfly-elytron/pom.xml
# ./keycloak/keycloak/adapters/spi/pom.xml
# ./keycloak/keycloak/adapters/spi/adapter-spi/pom.xml
# ./keycloak/keycloak/adapters/spi/jboss-adapter-core/pom.xml
# ./keycloak/keycloak/authz/pom.xml
# ./keycloak/keycloak/authz/client/pom.xml
# ./keycloak/keycloak/authz/policy/pom.xml
# ./keycloak/keycloak/authz/policy/common/pom.xml
# ./keycloak/keycloak/boms/pom.xml
# ./keycloak/keycloak/boms/spi/pom.xml
# ./keycloak/keycloak/common/pom.xml
# ./keycloak/keycloak/core/pom.xml
# ./keycloak/keycloak/crypto/pom.xml
# ./keycloak/keycloak/crypto/default/pom.xml
# ./keycloak/keycloak/crypto/elytron/pom.xml
# ./keycloak/keycloak/crypto/fips1402/pom.xml
# ./keycloak/keycloak/dependencies/pom.xml
# ./keycloak/keycloak/dependencies/server-all/pom.xml
# ./keycloak/keycloak/dependencies/server-min/pom.xml
# ./keycloak/keycloak/distribution/pom.xml
# ./keycloak/keycloak/distribution/api-docs-dist/pom.xml
# ./keycloak/keycloak/distribution/downloads/pom.xml
# ./keycloak/keycloak/distribution/galleon-feature-packs/pom.xml
# ./keycloak/keycloak/distribution/galleon-feature-packs/saml-adapter-galleon-pack/pom.xml
# ./keycloak/keycloak/distribution/galleon-feature-packs/saml-adapter-galleon-pack-layer-metadata-tests/pom.xml
# ./keycloak/keycloak/distribution/licenses-common/pom.xml
# ./keycloak/keycloak/distribution/maven-plugins/pom.xml
# ./keycloak/keycloak/distribution/maven-plugins/licenses-processor/pom.xml
# ./keycloak/keycloak/distribution/saml-adapters/pom.xml
# ./keycloak/keycloak/distribution/saml-adapters/wildfly-adapter/pom.xml
# ./keycloak/keycloak/distribution/saml-adapters/wildfly-adapter/wildfly-adapter-zip/pom.xml
# ./keycloak/keycloak/distribution/saml-adapters/wildfly-adapter/wildfly-modules/pom.xml
# ./keycloak/keycloak/docs/pom.xml
# ./keycloak/keycloak/docs/documentation/pom.xml
# ./keycloak/keycloak/docs/documentation/aggregation/pom.xml
# ./keycloak/keycloak/docs/documentation/api_documentation/pom.xml
# ./keycloak/keycloak/docs/documentation/authorization_services/pom.xml
# ./keycloak/keycloak/docs/documentation/dist/pom.xml
# ./keycloak/keycloak/docs/documentation/header-maven-plugin/pom.xml
# ./keycloak/keycloak/docs/documentation/release_notes/pom.xml
# ./keycloak/keycloak/docs/documentation/server_admin/pom.xml
# ./keycloak/keycloak/docs/documentation/server_development/pom.xml
# ./keycloak/keycloak/docs/documentation/tests/pom.xml
# ./keycloak/keycloak/docs/documentation/upgrading/pom.xml
# ./keycloak/keycloak/docs/guides/pom.xml
# ./keycloak/keycloak/docs/maven-plugin/pom.xml
# ./keycloak/keycloak/federation/pom.xml
# ./keycloak/keycloak/federation/ipatuura/pom.xml
# ./keycloak/keycloak/federation/kerberos/pom.xml
# ./keycloak/keycloak/federation/ldap/pom.xml
# ./keycloak/keycloak/federation/sssd/pom.xml
# ./keycloak/keycloak/integration/pom.xml
# ./keycloak/keycloak/integration/admin-client/pom.xml
# ./keycloak/keycloak/integration/client-cli/pom.xml
# ./keycloak/keycloak/integration/client-cli/admin-cli/pom.xml
# ./keycloak/keycloak/integration/client-cli/client-cli-dist/pom.xml
# ./keycloak/keycloak/integration/client-registration/pom.xml
# ./keycloak/keycloak/js/package.json
# ./keycloak/keycloak/js/pom.xml
# ./keycloak/keycloak/js/apps/account-ui/package.json
# ./keycloak/keycloak/js/apps/account-ui/pom.xml
# ./keycloak/keycloak/js/apps/admin-ui/package.json
# ./keycloak/keycloak/js/apps/admin-ui/pom.xml
# ./keycloak/keycloak/js/apps/create-keycloak-theme/package.json
# ./keycloak/keycloak/js/apps/keycloak-server/package.json
# ./keycloak/keycloak/js/libs/keycloak-admin-client/package.json
# ./keycloak/keycloak/js/libs/keycloak-admin-client/pom.xml
# ./keycloak/keycloak/js/libs/ui-shared/package.json
# ./keycloak/keycloak/js/libs/ui-shared/pom.xml
# ./keycloak/keycloak/js/themes-vendor/package.json
# ./keycloak/keycloak/js/themes-vendor/pom.xml
# ./keycloak/keycloak/misc/theme-verifier/pom.xml
# ./keycloak/keycloak/model/pom.xml
# ./keycloak/keycloak/model/infinispan/pom.xml
# ./keycloak/keycloak/model/jpa/pom.xml
# ./keycloak/keycloak/model/storage/pom.xml
# ./keycloak/keycloak/model/storage-private/pom.xml
# ./keycloak/keycloak/model/storage-services/pom.xml
# ./keycloak/keycloak/operator/pom.xml
# ./keycloak/keycloak/quarkus/pom.xml
# ./keycloak/keycloak/quarkus/config-api/pom.xml
# ./keycloak/keycloak/quarkus/deployment/pom.xml
# ./keycloak/keycloak/quarkus/dist/pom.xml
# ./keycloak/keycloak/quarkus/runtime/pom.xml
# ./keycloak/keycloak/quarkus/server/pom.xml
# ./keycloak/keycloak/quarkus/tests/pom.xml
# ./keycloak/keycloak/quarkus/tests/integration/pom.xml
# ./keycloak/keycloak/quarkus/tests/junit5/pom.xml
# ./keycloak/keycloak/rest/pom.xml
# ./keycloak/keycloak/rest/admin-ui-ext/pom.xml
# ./keycloak/keycloak/saml-core/pom.xml
# ./keycloak/keycloak/saml-core-api/pom.xml
# ./keycloak/keycloak/server-spi/pom.xml
# ./keycloak/keycloak/server-spi-private/pom.xml
# ./keycloak/keycloak/services/pom.xml
# ./keycloak/keycloak/test-framework/pom.xml
# ./keycloak/keycloak/test-framework/bom/pom.xml
# ./keycloak/keycloak/test-framework/core/pom.xml
# ./keycloak/keycloak/test-framework/db-mariadb/pom.xml
# ./keycloak/keycloak/test-framework/db-mssql/pom.xml
# ./keycloak/keycloak/test-framework/db-mysql/pom.xml
# ./keycloak/keycloak/test-framework/db-oracle/pom.xml
# ./keycloak/keycloak/test-framework/db-postgres/pom.xml
# ./keycloak/keycloak/test-framework/email-server/pom.xml
# ./keycloak/keycloak/test-framework/examples/pom.xml
# ./keycloak/keycloak/test-framework/examples/providers/pom.xml
# ./keycloak/keycloak/test-framework/examples/tests/pom.xml
# ./keycloak/keycloak/test-framework/junit5-config/pom.xml
# ./keycloak/keycloak/test-framework/oauth/pom.xml
# ./keycloak/keycloak/test-framework/remote/pom.xml
# ./keycloak/keycloak/test-framework/remote-providers/pom.xml
# ./keycloak/keycloak/test-framework/ui/pom.xml
# ./keycloak/keycloak/tests/pom.xml
# ./keycloak/keycloak/tests/base/pom.xml
# ./keycloak/keycloak/tests/custom-providers/pom.xml
# ./keycloak/keycloak/tests/migration-util/pom.xml
# ./keycloak/keycloak/tests/utils/pom.xml
# ./keycloak/keycloak/tests/utils-shared/pom.xml
# ./keycloak/keycloak/testsuite/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/servers/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/servers/app-server/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/servers/app-server/app-server-spi/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/servers/app-server/jboss/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/servers/app-server/jboss/galleon/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/servers/app-server/jboss/wildfly/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/servers/auth-server/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/servers/auth-server/quarkus/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/servers/auth-server/services/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/servers/auth-server/services/testsuite-providers/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/servers/auth-server/services/testsuite-providers-deployment/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/servers/auth-server/undertow/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/servers/cache-server/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/servers/cache-server/infinispan/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/servers/cache-server/infinispan/datagrid/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/servers/cache-server/infinispan/infinispan/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/servers/cache-server/legacy/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/servers/cache-server/legacy/datagrid/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/servers/cache-server/legacy/infinispan/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/servers/migration/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/test-apps/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/test-apps/servlets/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/tests/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/tests/base/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/tests/other/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/tests/other/jpa-performance/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/tests/other/sssd/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/tests/other/webauthn/pom.xml
# ./keycloak/keycloak/testsuite/integration-arquillian/util/pom.xml
# ./keycloak/keycloak/testsuite/model/pom.xml
# ./keycloak/keycloak/testsuite/utils/pom.xml
# ./keycloak/keycloak/themes/pom.xml
# ./keycloak/keycloak/util/pom.xml
# ./keycloak/keycloak/util/embedded-ldap/pom.xml
# 161

# %%
# Example usage
sorted_commit_hashes = get_all_relevant_commits(repo_path, file_paths)

# Display results
print(f"Total number of commits: {len(sorted_commit_hashes)}")
print("Commits (earliest to latest):")
for commit_hash, files in list(sorted_commit_hashes.items())[:10]:  # Displaying the first 10 for brevity
    print(f"{commit_hash}: {files}")
# Out:
# Total number of commits: 4819
# Commits (earliest to latest):
# 7a1c825dcbeaa939a744f8b77facef25782501da: ['core/pom.xml', 'services/pom.xml', 'pom.xml']
# 1548065b7f953523fd3783cdfda519e4e0c989da: ['services/pom.xml', 'pom.xml']
# 5ce263c2b5cc9492532e698559f7beff51909e70: ['integration/pom.xml', 'pom.xml', 'integration/as7-eap6/adapter/pom.xml']
# f7b3f2998dc0b4fd734ee5ce7567cfd92840aa08: ['pom.xml']
# 79e6f46183a33b2ed85546f506a6ff49db480221: ['examples/as7-eap-demo/server/pom.xml', 'examples/pom.xml', 'services/pom.xml', 'pom.xml']
# e1fe001a22000dcd7d4523d39ad64406d1423bc1: ['examples/as7-eap-demo/server/pom.xml']
# b77ceeac56a4df8839f82052ab16b3e850cc90cb: ['social/pom.xml', 'pom.xml']
# 729d9afac306fcae9d89ed608ec85a9c211ac6d2: ['examples/pom.xml', 'examples/as7-eap-demo/database-service/pom.xml', 'integration/as7-eap6/adapter/pom.xml']
# 74b121539d2a1b2ae29e0851bef8055f030b2e35: ['services/pom.xml']
# ec227c3d2ab11cf937cf68d91ae607dd48cd38a8: ['pom.xml', 'examples/as7-eap-demo/database-service/pom.xml']

# %% [markdown]
# ## java pom.xml parsing

# %%
dependencies_over_time = process_commits(repo, sorted_commit_hashes)

import json

with open("java_pom.json", "w") as f:
    json.dump(dependencies_over_time, f, indent=4)
# Out:
# Processing commits:   0%|          | 0/4819 [00:00<?, ?it/s]
# Processing commits:  59%|█████▉    | 2844/4819 [00:26<00:09, 199.54it/s]
# [DEBUG]Error loading file 'pom.xml' at commit '4dcb819c063794f16f0ee6c947dd01cc02e2cf46': "Blob or Tree named 'pom.xml' not found"
# Processing commits:  84%|████████▎ | 4027/4819 [00:31<00:04, 183.22it/s]
# [DEBUG]Error loading file 'distribution/saml-adapters/wildfly-adapter/wildfly-modules/pom.xml' at commit '0ce778061c0bbd96deedf74064e71a1f8f1191a6': "Blob or Tree named 'saml-adapters' not found"
# Processing commits: 100%|██████████| 4819/4819 [00:32<00:00, 146.21it/s]

# %% [markdown]
# ## python and javascript parsing:

# %%
import tomli
import ast

# %%
# Initialize cache and data structures
file_cache = {}
unique_entries = set()
dependency_changes = defaultdict(list)

# Supported version specifiers in requirements.txt
VERSION_SPECIFIERS = [
    '==', '>=', '<=', '~=', '!=', '>', '<'
]


def load_file_at_commit(repo_path, commit_hash, file_path):
    try:
        result = subprocess.run(
            ["git", "-C", repo_path, "show", f"{commit_hash}:{file_path}"],
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            text=True,
            check=True
        )
        return result.stdout
    except subprocess.CalledProcessError as e:
        print(f"Error loading file '{file_path}' at commit '{commit_hash}': {e.stderr}")
        return None


def process_commit_file_content(repo_path, sha, file_path, type):
    content = load_file_at_commit(repo_path, sha, file_path)
        
    if content:
        parse_file_content(content, sha, file_path, type)

def parse_pyproject_toml(content: str) -> dict:
    try:
        data = tomli.loads(content)
    except tomli.TOMLDecodeError:
        return {}

    # PEP 621 style
    deps = data.get("project", {}).get("dependencies", [])
    if not deps:
        # Poetry-style
        poetry_deps = data.get("tool", {}).get("poetry", {}).get("dependencies", {})
        deps = [f"{pkg}{v if isinstance(v, str) else ''}" for pkg, v in poetry_deps.items() if pkg.lower() != "python"]

    result = {}
    for dep in deps:
        parts = re.split(r"([<>=!~]+)", dep, maxsplit=1)
        name = parts[0].strip()
        version = ''.join(parts[1:]).strip() if len(parts) > 1 else "latest-version-available"
        result[name] = version

    return result


# === ADDED ===
def parse_setup_py(content: str) -> dict:
    try:
        tree = ast.parse(content)
    except SyntaxError:
        return {}

    class SetupVisitor(ast.NodeVisitor):
        def __init__(self):
            self.install_requires = []

        def visit_Call(self, node):
            if isinstance(node.func, ast.Name) and node.func.id == "setup":
                for keyword in node.keywords:
                    if keyword.arg == "install_requires":
                        if isinstance(keyword.value, (ast.List, ast.Tuple)):
                            for elt in keyword.value.elts:
                                if isinstance(elt, ast.Str):
                                    self.install_requires.append(elt.s)
            self.generic_visit(node)

    visitor = SetupVisitor()
    visitor.visit(tree)

    result = {}
    for dep in visitor.install_requires:
        parts = re.split(r"([<>=!~]+)", dep, maxsplit=1)
        name = parts[0].strip()
        version = ''.join(parts[1:]).strip() if len(parts) > 1 else "latest-version-available"
        result[name] = version

    return result

def parse_file_content(content, sha, filename, type):
    dependencies = {}
    hash_pattern = re.compile(r"--hash=sha256:[a-fA-F0-9]{64}")

    if type == "py" and "requirements.txt" in filename:
        for line in content.splitlines():
            line = line.strip()

            if not line or line.startswith('#') or line.startswith("--"):  # Ignore comments and empty lines
                continue

            # Check if line is a hash
            if hash_pattern.match(line):
                continue

            # Remove inline comments
            if '#' in line:
                line = line.split('#', 1)[0].strip()

            # Find the version specifier used
            version = "UNSPECIFIED"
            for specifier in VERSION_SPECIFIERS:
                if specifier in line:
                    package, version = line.split(specifier, 1)
                    package = package.strip()
                    version = version.strip()
                    dependencies[package] = version
                    break
            else:  # No version specifier found
                package = line
                dependencies[package] = "latest-version-available"

    elif type == "js" and "package.json" in filename:
        import json
        try:
            parsed_json = json.loads(content)
            if "dependencies" in parsed_json:
                dependencies.update(parsed_json["dependencies"])
            if "devDependencies" in parsed_json:
                dependencies.update(parsed_json["devDependencies"])
        except json.JSONDecodeError as e:
            print(f"Error parsing JSON file '{filename}': {e}")
    
    elif type == "py" and "setup.py" in filename:
        dependencies = parse_setup_py(content)
    elif type == "py" and "pyproject.toml" in filename:
        dependencies = parse_pyproject_toml(content)


    # Store the parsed dependencies for this commit
    dependency_changes[sha] = {
        "filename": filename,
        "dependencies": dependencies,
        "ecosystem": type
    }


def process_commits(repo_path, commits_with_files):
    for sha, files in tqdm(commits_with_files.items(), desc="Processing commits"):
        for file_path in files:
            if file_path.endswith("requirements.txt"):
                process_commit_file_content(repo_path, sha, file_path, "py")
            elif file_path.endswith("package.json"):
                process_commit_file_content(repo_path, sha, file_path, "js")
            elif file_path.endswith("setup.py"):
                process_commit_file_content(repo_path, sha, file_path, "py")
            elif file_path.endswith("pyproject.toml"):
                process_commit_file_content(repo_path, sha, file_path, "py")


def save_results(output_file="python_and_javascript.json"):
    import json
    with open(output_file, "w") as f:
        json.dump(dependency_changes, f, indent=4)

# %%
process_commits(repo_path, sorted_commit_hashes)
save_results()
# Out:
# Processing commits: 100%|██████████| 4819/4819 [02:35<00:00, 31.01it/s]

# %%
file_cache = {}

def is_gradle_related(file_path):
    return (
        file_path.endswith("build.gradle")
        or file_path.endswith("build.gradle.kts")
        or file_path.endswith("settings.gradle")
        or file_path.endswith("settings.gradle.kts")
        or file_path.endswith("gradle.properties")
        or file_path.endswith(".gradle")
        or file_path.endswith(".gradle.kts")
    )

def parse_gradle_properties(content):
    props = {}
    for line in content.splitlines():
        line = line.strip()
        if line and not line.startswith("#") and "=" in line:
            key, value = line.split("=", 1)
            props[key.strip()] = value.strip()
    return props


def extract_dependencies_block(content: str) -> str:
    """Returns only the content inside dependencies { ... } block(s)."""
    lines = content.splitlines()
    inside = False
    depth = 0
    collected = []

    for line in lines:
        stripped = line.strip()
        if stripped.startswith("dependencies"):
            if "{" in stripped:
                inside = True
                depth = stripped.count("{") - stripped.count("}")
                continue

        if inside:
            if "{" in stripped:
                depth += stripped.count("{")
            if "}" in stripped:
                depth -= stripped.count("}")
            collected.append(line)
            if depth <= 0:
                inside = False

    return "\n".join(collected)


def parse_gradle_dependencies(file_content: str, properties: Dict[str, str], commit_sha: str, file_path: str) -> List[Dict[str, Any]]:
    dependencies = []

    # NEW: extract only content inside dependencies block(s)
    block = extract_dependencies_block(file_content)

    # Patterns for Kotlin + Groovy
    patterns = [
        re.compile(r'(?P<config>\w+)\s*\(\s*["\'](?P<group>[^:\'"]+):(?P<artifact>[^:\'"]+):(?P<version>[^\'"]+)["\']\s*\)'),  # Kotlin DSL
        re.compile(r'(?P<config>\w+)\s+["\'](?P<group>[^:\'"]+):(?P<artifact>[^:\'"]+):(?P<version>[^\'"]+)["\']')  # Groovy DSL
    ]

    for pattern in patterns:
        for match in pattern.finditer(block):
            config = match.group("config")
            group = match.group("group")
            artifact = match.group("artifact")
            version = match.group("version")

            version_source = "literal"
            if version.startswith("$") or "${" in version:
                var_name = version.replace("$", "").replace("{", "").replace("}", "")
                if var_name in properties:
                    version = properties[var_name]
                    version_source = "resolved_from_property"
                else:
                    version_source = "unresolved"

            if "$" not in group and "$" not in artifact and "$" not in version:
                dependencies.append({
                    "commit": commit_sha,
                    "file": file_path,
                    #"tool": "gradle",
                    #"configuration": config,
                    "group": group,
                    "artifact": artifact,
                    "version": version,
                    #"version_source": version_source
                })

    return dependencies


def load_file_at_commit(repo, commit_hash, file_path):
    try:
        commit = repo.commit(commit_hash)
        blob = commit.tree / file_path
        content = blob.data_stream.read().decode('utf-8')
        file_cache[file_path] = content
        return content
    except Exception as e:
        print(f"[DEBUG] Error loading file '{file_path}' at commit '{commit_hash}': {e}")
        return None
    
def parse_local_kotlin_variables(content: str) -> Dict[str, str]:
    props = {}
    # Matches lines like: val log4jVersion = "2.20.0" or var version = "1.0"
    pattern = re.compile(r'(val|var)\s+(\w+)\s*=\s*["\']([^"\']+)["\']')
    for match in pattern.finditer(content):
        var_name = match.group(2)
        value = match.group(3)
        props[var_name] = value
    return props

def process_commit(repo, commit_hash, changed_files, dependencies_snapshot, all_dependencies, properties_by_commit):
    for file_path in changed_files:
        if not is_gradle_related(file_path):
            continue

        content = load_file_at_commit(repo, commit_hash, file_path)
        if content:
            dependencies_snapshot[file_path] = content

            # Parse gradle.properties
            if file_path.endswith("gradle.properties"):
                props = parse_gradle_properties(content)
                properties_by_commit[commit_hash] = props

            # Parse dependencies from .gradle or .gradle.kts files
            elif file_path.endswith(".gradle") or file_path.endswith(".gradle.kts"):
                props = {}
                #props.update(parse_ext_block(content))                  # ext { ... }
                #props.update(parse_extra_assignments(content))          # extra["..."] = ...
                #props.update(extract_project_properties(content))       # group/version/name
                props.update(parse_local_kotlin_variables(content))     # val/var = "..."

                if commit_hash not in properties_by_commit:
                    properties_by_commit[commit_hash] = {}
                properties_by_commit[commit_hash].update(props)

                resolved_props = properties_by_commit[commit_hash]
                parsed_deps = parse_gradle_dependencies(content, resolved_props, commit_hash, file_path)
                all_dependencies.extend(parsed_deps)

    return dependencies_snapshot, all_dependencies

def process_commits(repo, commits_with_changes):
    dependencies_over_time = {}
    dependencies_snapshot = {}
    all_dependencies = []
    properties_by_commit = {}

    for commit_hash, changed_files in tqdm(commits_with_changes.items(), desc="Processing commits"):
        dependencies_snapshot, all_dependencies = process_commit(
            repo, commit_hash, changed_files, dependencies_snapshot, all_dependencies, properties_by_commit
        )
        dependencies_over_time[commit_hash] = dependencies_snapshot.copy()

    return dependencies_over_time, all_dependencies

# %%
dependencies_over_time, all_dependencies = process_commits(repo, sorted_commit_hashes)

# Optionally print the parsed dependencies
#for dep in all_dependencies:
    #print(dep)

cleaned_dependencies = [
    dep for dep in all_dependencies
    if "$" not in dep["group"]
    and "$" not in dep["artifact"]
    and "$" not in dep["version"]
]

for dep in cleaned_dependencies [:10]:
    print(dep)
# Out:
# Processing commits: 100%|██████████| 4819/4819 [00:00<00:00, 283280.56it/s]

# %%
def group_gradle_dependencies(dependencies):
    grouped = defaultdict(lambda: {"gradle": defaultdict(dict)})

    for dep in dependencies:
        commit = dep["commit"]
        file = dep["file"]
        group_artifact = f"{dep['group']}:{dep['artifact']}"
        version = dep["version"]

        grouped[commit]["gradle"][file][group_artifact] = version

    return grouped

# %%
grouped_dependencies = group_gradle_dependencies(cleaned_dependencies)
import json
# Convert the defaultdict to a normal dict recursively

# %%
def to_dict(d):
    if isinstance(d, defaultdict):
        d = {k: to_dict(v) for k, v in d.items()}
    elif isinstance(d, dict):
        d = {k: to_dict(v) for k, v in d.items()}
    return d

#print(json.dumps(to_dict(grouped_dependencies), indent=2))

# %%
def save_results(data, output_file="dependencies_over_time.json"):
    import json
    with open(output_file, "w") as f:
        json.dump(data, f, indent=4)

# %%
save_results(to_dict(grouped_dependencies), "java_gradle.json")

# %%
def merge_dependencies(python_and_javascript: Dict, java: Dict, gradle: Dict) -> Dict:
    merged_data = {}

    # Combine all unique commit hashes from both datasets
    all_commits = set(python_and_javascript) | set(java) | set(gradle)

    for commit in all_commits:
        merged_data[commit] = {
            "java": {},
            "gradle": {},
            "python": {},
            "javascript": {}
        }

        # Add Java dependencies if present
        if commit in java:
            for file, content in java[commit].items():
                merged_data[commit]["java"][file] = content  # No renaming!
        
        if commit in gradle:
            gradle_files = gradle[commit].get("gradle", {})  # Extract only the inner part
            for file, content in gradle_files.items():
                merged_data[commit]["gradle"][file] = content

        # Add Python and JavaScript dependencies if present
        if commit in python_and_javascript:
            content = python_and_javascript[commit]

            # Check if it's a Python or JavaScript file based on 'ecosystem'
            if content.get("ecosystem") == "py":
                merged_data[commit]["python"][content["filename"]] = content["dependencies"]
            elif content.get("ecosystem") == "js":
                merged_data[commit]["javascript"][content["filename"]] = content["dependencies"]


    return merged_data

# %%
def remove_empty_objects(data):
    if isinstance(data, dict):
        return {
            k: remove_empty_objects(v)
            for k, v in data.items()
            if not (isinstance(v, dict) and not v)  # remove empty dicts
        }
    elif isinstance(data, list):
        return [remove_empty_objects(item) for item in data]
    else:
        return data

# %%
def save_merged_data(merged_data: Dict, output_file: str):
    with open(output_file, 'w') as f:
        json.dump(merged_data, f, indent=4)

# %%
with open('python_and_javascript.json', 'r') as f:
    python_and_javascript = json.load(f)

with open('java_pom.json', 'r') as f:
    java = json.load(f)

with open('java_gradle.json', 'r') as f:
    gradle = json.load(f)

merged_data = merge_dependencies(python_and_javascript, java, gradle)
new_merged_data = remove_empty_objects(merged_data)
save_merged_data(new_merged_data, 'merged_dependencies.json')

# %%
import json
import copy

# Load input data
with open("merged_dependencies.json", "r") as f:
    data = json.load(f)

# Your commit-to-date mapping
commit_dates = commits_with_date  # assumed to be defined already

# Ensure chronological commit order
sorted_commits = sorted(data.keys(), key=lambda c: commit_dates.get(c))

# Global latest version per dependency
latest_versions = {}

# Last known dependency set per file
last_file_state = {}  # (system, filename) -> {dep: version}

# All changes (add, update, remove)
changes = []

for commit in sorted_commits:
    date = commit_dates.get(commit)
    commit_data = data[commit]

    for system, files in commit_data.items():
        for filename, curr_deps in files.items():
            file_key = (system, filename)
            prev_deps = last_file_state.get(file_key, {})

            # Check for added/updated
            for dep, new_version in curr_deps.items():
                old_version = latest_versions.get(dep)
                if dep not in prev_deps:
                    changes.append({
                        "commit": commit,
                        "date": date,
                        "filename": filename,
                        "system": system,
                        "dependency": dep,
                        "change_type": "added",
                        "old_version": None,
                        "new_version": new_version
                    })
                elif prev_deps[dep] != new_version:
                    changes.append({
                        "commit": commit,
                        "date": date,
                        "filename": filename,
                        "system": system,
                        "dependency": dep,
                        "change_type": "updated",
                        "old_version": prev_deps[dep],
                        "new_version": new_version
                    })

                # Always update the global version
                latest_versions[dep] = new_version

            # Save current state for next round
            last_file_state[file_key] = copy.deepcopy(curr_deps)

# Save all detected changes
with open("dependency_changes_with_removed.json", "w") as f:
    json.dump(changes, f, indent=2)

# %%
# Cell 7: Execute!
process_json_file(
        "dependency_changes_with_removed.json",
        "dependency_changes_enriched.json"
    )
# Out:
# [1/14309] org.bouncycastle:bcprov-jdk16 → done
# [2/14309] org.bouncycastle:bcmail-jdk16 → done
# [3/14309] org.infinispan:infinispan-core → done
# [4/14309] org.infinispan:infinispan-tree → done
# [5/14309] org.jboss.resteasy:jaxrs-api → done
# [6/14309] org.jboss.resteasy:resteasy-jaxrs → done
# [7/14309] org.jboss.resteasy:resteasy-client → done
# [8/14309] org.jboss.resteasy:jose-jwt → done
# [9/14309] org.jboss.resteasy:resteasy-crypto → done
# [10/14309] org.codehaus.jackson:jackson-core-asl → done
# [11/14309] org.codehaus.jackson:jackson-mapper-asl → done
# [12/14309] org.codehaus.jackson:jackson-xc → done
# [13/14309] org.codehaus.jackson:jackson-jaxrs → done
# [14/14309] javax.servlet:servlet-api → done
# [15/14309] org.jboss.resteasy:tjws → done
# [16/14309] org.picketlink:picketlink-idm-api → done
# [17/14309] org.picketlink:picketlink-idm-impl → done
# [18/14309] org.picketlink:picketlink-idm-schema → done
# [19/14309] org.picketlink:picketlink-config → done
# [20/14309] junit:junit → done
# [21/14309] org.hibernate.javax.persistence:hibernate-jpa-2.0-api → done
# [22/14309] org.jboss.resteasy:jaxrs-api → done
# [23/14309] org.jboss.resteasy:resteasy-jaxrs → done
# [24/14309] org.jboss.resteasy:resteasy-client → done
# [25/14309] org.jboss.resteasy:jose-jwt → done
# [26/14309] org.jboss.resteasy:resteasy-crypto → done
# [27/14309] org.jboss.resteasy:tjws → done
# [28/14309] org.picketlink:picketlink-common → done
# [29/14309] org.jboss.logging:jboss-logging → done
# [30/14309] org.keycloak:keycloak-core → done
# [31/14309] org.keycloak:keycloak-services → done
# [32/14309] junit:junit → done
# [33/14309] com.h2database:h2 → done
# [34/14309] com.google.api-client:google-api-client → done
# [35/14309] com.google.http-client:google-http-client-jackson → done
# [36/14309] com.google.apis:google-api-services-oauth2 → done
# [37/14309] org.twitter4j:twitter4j-core → done
# [38/14309] junit:junit → done
# [39/14309] org.keycloak:keycloak-core → done
# [40/14309] org.keycloak:keycloak-as7-adapter → done
# [41/14309] org.picketlink:picketlink-common → done
# [42/14309] org.picketlink:picketlink-idm-api → done
# [43/14309] org.picketlink:picketlink-idm-impl → done
# [44/14309] org.picketlink:picketlink-idm-schema → done
# [45/14309] org.picketlink:picketlink-config → done
# [46/14309] com.google.api-client:google-api-client → done
# [47/14309] com.google.http-client:google-http-client-jackson → done
# [48/14309] com.google.apis:google-api-services-oauth2 → done
# [49/14309] org.twitter4j:twitter4j-core → done
# [50/14309] org.picketlink:picketlink-common → done
# [51/14309] org.picketlink:picketlink-idm-api → done
# [52/14309] org.picketlink:picketlink-idm-impl → done
# [53/14309] org.picketlink:picketlink-idm-simple-schema → done
# [54/14309] org.picketlink:picketlink-config → done
# [55/14309] org.keycloak:keycloak-social-core → done
# [56/14309] org.keycloak:keycloak-social-google → done
# [57/14309] org.keycloak:keycloak-social-twitter → done
# [58/14309] org.keycloak:keycloak-sdk-html → done
# [59/14309] org.keycloak:keycloak-social-facebook → done
# [60/14309] org.keycloak:keycloak-forms → done
# [61/14309] com.google.zxing:core → done
# [62/14309] com.google.zxing:javase → done
# [63/14309] org.jboss.arquillian:arquillian-bom → done
# [64/14309] org.jboss.arquillian.extension:arquillian-drone-bom → done
# [65/14309] org.jboss.arquillian.extension:arquillian-drone-bom → done
# [66/14309] org.jboss.resteasy:jaxrs-api → done
# [67/14309] org.jboss.resteasy:resteasy-jaxrs → done
# [68/14309] org.jboss.resteasy:resteasy-client → done
# [69/14309] org.jboss.resteasy:jose-jwt → done
# [70/14309] org.jboss.resteasy:resteasy-crypto → done
# [71/14309] org.jboss.resteasy:tjws → done
# [72/14309] org.jboss.resteasy:resteasy-undertow → done
# [73/14309] io.undertow:undertow-servlet → done
# [74/14309] io.undertow:undertow-core → done
# [75/14309] org.jboss.spec.javax.servlet:jboss-servlet-api_3.0_spec → done
# [76/14309] org.jboss.arquillian.extension:arquillian-drone-bom → done
# [77/14309] org.jboss.arquillian.extension:arquillian-drone-bom → done
# [78/14309] org.keycloak:keycloak-admin-ui-styles → done
# [79/14309] com.icegreen:greenmail → done
# [80/14309] org.jboss.arquillian.graphene:graphene-webdriver → done
# [81/14309] org.jboss.arquillian.graphene:graphene-webdriver → done
# [82/14309] org.freemarker:freemarker → done
# [83/14309] org.seleniumhq.selenium:selenium-java → done
# [84/14309] org.seleniumhq.selenium:selenium-java → done
# [85/14309] org.seleniumhq.selenium:selenium-chrome-driver → done
# [86/14309] org.keycloak:keycloak-model-api → done
# [87/14309] org.keycloak:keycloak-model-picketlink → done
# [88/14309] org.keycloak:keycloak-admin-ui → done
# [89/14309] org.mongodb:mongo-java-driver → done
# [90/14309] de.flapdoodle.embed:de.flapdoodle.embed.mongo → done
# [91/14309] org.keycloak:keycloak-admin-ui → done
# [92/14309] com.h2database:h2 → done
# [93/14309] org.hibernate:hibernate-entitymanager → done
# [94/14309] de.flapdoodle.embed:de.flapdoodle.embed.mongo → done
# [95/14309] org.apache.jmeter:ApacheJMeter_java → done
# [96/14309] dom4j:dom4j → done
# [97/14309] org.slf4j:slf4j-api → done
# [98/14309] mysql:mysql-connector-java → done
# [99/14309] org.jboss.arquillian:arquillian-bom → done
# [100/14309] org.jboss.arquillian.extension:arquillian-drone-bom → done
# [101/14309] org.keycloak:keycloak-core → done
# [102/14309] org.keycloak:keycloak-model-api → done
# [103/14309] org.keycloak:keycloak-core → done
# [104/14309] org.keycloak:keycloak-services → done
# [105/14309] org.keycloak:keycloak-model-api → done
# [106/14309] org.keycloak:keycloak-model-picketlink → done
# [107/14309] org.keycloak:keycloak-social-core → done
# [108/14309] org.keycloak:keycloak-social-google → done
# [109/14309] org.keycloak:keycloak-social-twitter → done
# [110/14309] org.keycloak:keycloak-social-facebook → done
# [111/14309] org.keycloak:keycloak-forms → done
# [112/14309] com.h2database:h2 → done
# [113/14309] junit:junit → done
# [114/14309] org.jboss.spec.javax.servlet:jboss-servlet-api_3.1_spec → done
# [115/14309] log4j:log4j → done
# [116/14309] org.keycloak:keycloak-admin-ui → done
# [117/14309] org.keycloak:keycloak-admin-ui-styles → done
# [118/14309] org.keycloak:keycloak-core → done
# [119/14309] org.keycloak:keycloak-services → done
# [120/14309] org.keycloak:keycloak-model-api → done
# [121/14309] org.keycloak:keycloak-model-picketlink → done
# [122/14309] org.keycloak:keycloak-model-jpa → done
# [123/14309] org.keycloak:keycloak-social-core → done
# [124/14309] org.keycloak:keycloak-social-google → done
# [125/14309] org.keycloak:keycloak-social-twitter → done
# [126/14309] org.keycloak:keycloak-social-facebook → done
# [127/14309] org.keycloak:keycloak-forms → done
# [128/14309] com.h2database:h2 → done
# [129/14309] junit:junit → done
# [130/14309] org.jboss.resteasy:jaxrs-api → done
# [131/14309] org.jboss.resteasy:resteasy-jaxrs → done
# [132/14309] org.jboss.resteasy:resteasy-client → done
# [133/14309] org.jboss.resteasy:jose-jwt → done
# [134/14309] org.jboss.resteasy:resteasy-crypto → done
# [135/14309] org.jboss.resteasy:tjws → done
# [136/14309] org.jboss.resteasy:resteasy-undertow → done
# [137/14309] io.undertow:undertow-servlet → done
# [138/14309] io.undertow:undertow-core → done
# [139/14309] org.keycloak:keycloak-core → done
# [140/14309] org.keycloak:keycloak-undertow-adapter → done
# [141/14309] org.hibernate:hibernate-entitymanager → done
# [142/14309] org.keycloak:keycloak-core → done
# [143/14309] org.keycloak:keycloak-model-api → done
# [144/14309] org.keycloak:keycloak-admin-ui → done
# [145/14309] org.keycloak:keycloak-admin-ui-styles → done
# [146/14309] org.keycloak:keycloak-core → done
# [147/14309] org.keycloak:keycloak-services → done
# [148/14309] org.keycloak:keycloak-model-api → done
# [149/14309] org.keycloak:keycloak-model-jpa → done
# [150/14309] org.keycloak:keycloak-social-core → done
# [151/14309] org.keycloak:keycloak-social-google → done
# [152/14309] org.keycloak:keycloak-social-twitter → done
# [153/14309] org.keycloak:keycloak-social-facebook → done
# [154/14309] org.keycloak:keycloak-forms → done
# [155/14309] org.keycloak:keycloak-core → done
# [156/14309] org.keycloak:keycloak-undertow-adapter → done
# [157/14309] org.keycloak:keycloak-core → done
# [158/14309] org.keycloak:keycloak-model-api → done
# [159/14309] org.keycloak:keycloak-admin-ui → done
# [160/14309] org.keycloak:keycloak-admin-ui-styles → done
# [161/14309] org.keycloak:keycloak-core → done
# [162/14309] org.keycloak:keycloak-services → done
# [163/14309] org.keycloak:keycloak-model-api → done
# [164/14309] org.keycloak:keycloak-model-jpa → done
# [165/14309] org.keycloak:keycloak-social-core → done
# [166/14309] org.keycloak:keycloak-social-google → done
# [167/14309] org.keycloak:keycloak-social-twitter → done
# [168/14309] org.keycloak:keycloak-social-facebook → done
# [169/14309] org.keycloak:keycloak-forms → done
# [170/14309] org.keycloak:keycloak-core → done
# [171/14309] org.keycloak:keycloak-undertow-adapter → done
# [172/14309] org.jboss.resteasy:resteasy-multipart-provider → done
# [173/14309] org.keycloak:keycloak-adapter-core → done
# [174/14309] org.jboss.resteasy:resteasy-jackson-provider → done
# [175/14309] io.undertow:undertow-servlet → done
# [176/14309] io.undertow:undertow-core → done
# [177/14309] org.keycloak:keycloak-core-jaxrs → done
# [178/14309] junit:junit → done
# [179/14309] org.jboss.resteasy:resteasy-jaxrs → done
# [180/14309] org.jboss.resteasy:resteasy-multipart-provider → done
# [181/14309] org.jboss.resteasy:resteasy-client → done
# [182/14309] org.jboss.resteasy:async-http-servlet-3.0 → done
# [183/14309] org.jboss.resteasy:jaxrs-api → done
# [184/14309] org.jboss.resteasy:resteasy-jackson-provider → done
# [185/14309] org.keycloak:keycloak-core → done
# [186/14309] org.keycloak:keycloak-adapter-core → done
# [187/14309] org.keycloak:keycloak-as7-adapter → done
# [188/14309] org.keycloak:keycloak-undertow-adapter → done
# [189/14309] org.jboss:jandex → done
# [190/14309] ant-contrib:ant-contrib → done
# [191/14309] io.undertow:undertow-servlet → done
# [192/14309] io.undertow:undertow-core → done
# [193/14309] org.json:json → done
# [194/14309] org.keycloak:keycloak-core → done
# [195/14309] org.keycloak:keycloak-adapter-core → done
# [196/14309] org.apache.httpcomponents:httpclient → done
# [197/14309] org.twitter4j:twitter4j-core → done
# [198/14309] org.jboss.resteasy:jaxrs-api → done
# [199/14309] org.jboss.resteasy:resteasy-jaxrs → done
# [200/14309] org.jboss.resteasy:resteasy-multipart-provider → done
# [201/14309] org.jboss.resteasy:resteasy-jackson-provider → done
# [202/14309] org.jboss.resteasy:resteasy-client → done
# [203/14309] org.jboss.resteasy:resteasy-crypto → done
# [204/14309] org.jboss.resteasy:tjws → done
# [205/14309] org.jboss.resteasy:resteasy-undertow → done
# [206/14309] org.keycloak:keycloak-core → done
# [207/14309] org.keycloak:keycloak-model-api → done
# [208/14309] org.keycloak:keycloak-core → done
# [209/14309] org.keycloak:keycloak-core-jaxrs → done
# [210/14309] org.keycloak:keycloak-services → done
# [211/14309] org.keycloak:keycloak-model-api → done
# [212/14309] org.keycloak:keycloak-model-jpa → done
# [213/14309] org.keycloak:keycloak-social-core → done
# [214/14309] org.keycloak:keycloak-social-google → done
# [215/14309] org.keycloak:keycloak-social-twitter → done
# [216/14309] org.keycloak:keycloak-social-facebook → done
# [217/14309] org.keycloak:keycloak-forms → done
# [218/14309] org.keycloak:keycloak-admin-ui → done
# [219/14309] org.keycloak:keycloak-admin-ui-styles → done
# [220/14309] org.keycloak:keycloak-core → done
# [221/14309] org.keycloak:keycloak-adapter-core → done
# [222/14309] org.keycloak:keycloak-as7-adapter → done
# [223/14309] org.keycloak:keycloak-undertow-adapter → done
# [224/14309] org.keycloak:keycloak-core → done
# [225/14309] org.keycloak:keycloak-adapter-core → done
# [226/14309] org.keycloak:keycloak-core → done
# [227/14309] org.keycloak:keycloak-core-jaxrs → done
# [228/14309] org.keycloak:keycloak-services → done
# [229/14309] org.keycloak:keycloak-model-api → done
# [230/14309] org.keycloak:keycloak-model-jpa → done
# [231/14309] org.keycloak:keycloak-social-core → done
# [232/14309] org.keycloak:keycloak-social-google → done
# [233/14309] org.keycloak:keycloak-social-twitter → done
# [234/14309] org.keycloak:keycloak-social-facebook → done
# [235/14309] org.keycloak:keycloak-forms → done
# [236/14309] org.keycloak:keycloak-admin-ui → done
# [237/14309] org.keycloak:keycloak-admin-ui-styles → done
# [238/14309] org.jboss.resteasy:resteasy-jaxrs → done
# [239/14309] org.jboss.resteasy:resteasy-multipart-provider → done
# [240/14309] org.jboss.resteasy:resteasy-client → done
# [241/14309] org.jboss.resteasy:async-http-servlet-3.0 → done
# [242/14309] org.jboss.resteasy:jaxrs-api → done
# [243/14309] org.jboss.resteasy:resteasy-jackson-provider → done
# [244/14309] org.keycloak:keycloak-core → done
# [245/14309] org.keycloak:keycloak-adapter-core → done
# [246/14309] org.keycloak:keycloak-as7-adapter → done
# [247/14309] org.keycloak:keycloak-undertow-adapter → done
# [248/14309] org.keycloak:keycloak-core → done
# [249/14309] org.keycloak:keycloak-adapter-core → done
# [250/14309] org.keycloak:keycloak-core → done
# [251/14309] org.keycloak:keycloak-core-jaxrs → done
# [252/14309] org.keycloak:keycloak-services → done
# [253/14309] org.keycloak:keycloak-model-api → done
# [254/14309] org.keycloak:keycloak-model-jpa → done
# [255/14309] org.keycloak:keycloak-social-core → done
# [256/14309] org.keycloak:keycloak-social-google → done
# [257/14309] org.keycloak:keycloak-social-twitter → done
# [258/14309] org.keycloak:keycloak-social-facebook → done
# [259/14309] org.keycloak:keycloak-forms → done
# [260/14309] org.keycloak:keycloak-admin-ui → done
# [261/14309] org.keycloak:keycloak-admin-ui-styles → done
# [262/14309] org.keycloak:keycloak-core → done
# [263/14309] org.keycloak:keycloak-adapter-core → done
# [264/14309] org.keycloak:keycloak-as7-adapter → done
# [265/14309] org.keycloak:keycloak-undertow-adapter → done
# [266/14309] org.keycloak:keycloak-core → done
# [267/14309] org.keycloak:keycloak-adapter-core → done
# [268/14309] org.keycloak:keycloak-core → done
# [269/14309] org.keycloak:keycloak-core-jaxrs → done
# [270/14309] org.keycloak:keycloak-services → done
# [271/14309] org.keycloak:keycloak-model-api → done
# [272/14309] org.keycloak:keycloak-model-jpa → done
# [273/14309] org.keycloak:keycloak-social-core → done
# [274/14309] org.keycloak:keycloak-social-google → done
# [275/14309] org.keycloak:keycloak-social-twitter → done
# [276/14309] org.keycloak:keycloak-social-facebook → done
# [277/14309] org.keycloak:keycloak-forms → done
# [278/14309] org.keycloak:keycloak-admin-ui → done
# [279/14309] org.keycloak:keycloak-admin-ui-styles → done
# [280/14309] org.keycloak:keycloak-core → done
# [281/14309] org.keycloak:keycloak-adapter-core → done
# [282/14309] org.keycloak:keycloak-as7-adapter → done
# [283/14309] org.keycloak:keycloak-undertow-adapter → done
# [284/14309] org.keycloak:keycloak-core → done
# [285/14309] org.keycloak:keycloak-adapter-core → done
# [286/14309] net.iharder:base64 → done
# [287/14309] org.wildfly:wildfly-controller → done
# [288/14309] org.wildfly:wildfly-server → done
# [289/14309] org.wildfly:wildfly-ee → done
# [290/14309] org.wildfly:wildfly-subsystem-test → done
# [291/14309] org.wildfly:wildfly-undertow → done
# [292/14309] org.jboss.logging:jboss-logging-processor → done
# [293/14309] org.jboss.logging:jboss-logging-annotations → done
# [294/14309] org.keycloak:keycloak-forms-common-freemarker → done
# [295/14309] org.keycloak:keycloak-forms-common-themes → done
# [296/14309] org.keycloak:keycloak-account-api → done
# [297/14309] org.keycloak:keycloak-account-freemarker → done
# [298/14309] org.keycloak:keycloak-login-api → done
# [299/14309] org.keycloak:keycloak-login-freemarker → done
# [300/14309] org.keycloak:keycloak-social-github → done
# [301/14309] net.iharder:base64 → done
# [302/14309] org.jboss.logging:jboss-logging-annotations → done
# [303/14309] org.keycloak:keycloak-wildfly-subsystem → done
# [304/14309] org.keycloak:keycloak-js-adapter → done
# [305/14309] org.keycloak:keycloak-as7-subsystem → done
# [306/14309] de.flapdoodle.embed:de.flapdoodle.embed.mongo → done
# [307/14309] org.keycloak:keycloak-core → done
# [308/14309] org.keycloak:keycloak-model-api → done
# [309/14309] org.keycloak:keycloak-model-tests → done
# [310/14309] io.undertow:undertow-servlet → done
# [311/14309] io.undertow:undertow-core → done
# [312/14309] org.wildfly:wildfly-controller → done
# [313/14309] org.wildfly:wildfly-server → done
# [314/14309] org.wildfly:wildfly-ee → done
# [315/14309] org.wildfly:wildfly-subsystem-test → done
# [316/14309] org.wildfly:wildfly-undertow → done
# [317/14309] org.postgresql:postgresql → done
# [318/14309] xml-apis:xml-apis → done
# [319/14309] org.postgresql:postgresql → done
# [320/14309] org.postgresql:postgresql → done
# [321/14309] org.keycloak:keycloak-model-mongo → done
# [322/14309] xml-apis:xml-apis → done
# [323/14309] org.postgresql:postgresql → done
# [324/14309] org.keycloak:keycloak-core → done
# [325/14309] org.keycloak:keycloak-model-api → done
# [326/14309] org.keycloak:keycloak-model-tests → done
# [327/14309] org.keycloak:keycloak-core → done
# [328/14309] org.keycloak:keycloak-core-jaxrs → done
# [329/14309] org.keycloak:keycloak-services → done
# [330/14309] org.keycloak:keycloak-model-api → done
# [331/14309] org.keycloak:keycloak-model-jpa → done
# [332/14309] org.keycloak:keycloak-social-core → done
# [333/14309] org.keycloak:keycloak-social-github → done
# [334/14309] org.keycloak:keycloak-social-google → done
# [335/14309] org.keycloak:keycloak-social-twitter → done
# [336/14309] org.keycloak:keycloak-social-facebook → done
# [337/14309] org.keycloak:keycloak-forms-common-freemarker → done
# [338/14309] org.keycloak:keycloak-forms-common-themes → done
# [339/14309] org.keycloak:keycloak-account-api → done
# [340/14309] org.keycloak:keycloak-account-freemarker → done
# [341/14309] org.keycloak:keycloak-login-api → done
# [342/14309] org.keycloak:keycloak-login-freemarker → done
# [343/14309] org.keycloak:keycloak-admin-ui → done
# [344/14309] org.keycloak:keycloak-admin-ui-styles → done
# [345/14309] org.keycloak:keycloak-js-adapter → done
# [346/14309] org.keycloak:keycloak-model-mongo → done
# [347/14309] org.keycloak:keycloak-core → done
# [348/14309] org.keycloak:keycloak-adapter-core → done
# [349/14309] org.keycloak:keycloak-as7-adapter → done
# [350/14309] org.keycloak:keycloak-undertow-adapter → done
# [351/14309] org.keycloak:keycloak-wildfly-subsystem → done
# [352/14309] org.keycloak:keycloak-as7-subsystem → done
# [353/14309] org.keycloak:keycloak-core → done
# [354/14309] org.keycloak:keycloak-adapter-core → done
# [355/14309] org.keycloak:keycloak-core → done
# [356/14309] org.keycloak:keycloak-model-api → done
# [357/14309] org.keycloak:keycloak-model-tests → done
# [358/14309] org.keycloak:keycloak-core → done
# [359/14309] org.keycloak:keycloak-core-jaxrs → done
# [360/14309] org.keycloak:keycloak-services → done
# [361/14309] org.keycloak:keycloak-model-api → done
# [362/14309] org.keycloak:keycloak-model-jpa → done
# [363/14309] org.keycloak:keycloak-social-core → done
# [364/14309] org.keycloak:keycloak-social-github → done
# [365/14309] org.keycloak:keycloak-social-google → done
# [366/14309] org.keycloak:keycloak-social-twitter → done
# [367/14309] org.keycloak:keycloak-social-facebook → done
# [368/14309] org.keycloak:keycloak-forms-common-freemarker → done
# [369/14309] org.keycloak:keycloak-forms-common-themes → done
# [370/14309] org.keycloak:keycloak-account-api → done
# [371/14309] org.keycloak:keycloak-account-freemarker → done
# [372/14309] org.keycloak:keycloak-login-api → done
# [373/14309] org.keycloak:keycloak-login-freemarker → done
# [374/14309] org.keycloak:keycloak-admin-ui → done
# [375/14309] org.keycloak:keycloak-admin-ui-styles → done
# [376/14309] org.keycloak:keycloak-js-adapter → done
# [377/14309] org.keycloak:keycloak-model-mongo → done
# [378/14309] org.keycloak:keycloak-core → done
# [379/14309] org.keycloak:keycloak-adapter-core → done
# [380/14309] org.keycloak:keycloak-as7-adapter → done
# [381/14309] org.keycloak:keycloak-undertow-adapter → done
# [382/14309] org.keycloak:keycloak-wildfly-subsystem → done
# [383/14309] org.keycloak:keycloak-as7-subsystem → done
# [384/14309] org.keycloak:keycloak-core → done
# [385/14309] org.keycloak:keycloak-adapter-core → done
# [386/14309] org.keycloak:keycloak-core → done
# [387/14309] org.keycloak:keycloak-social-core → done
# [388/14309] org.keycloak:keycloak-services → done
# [389/14309] org.keycloak:keycloak-jboss-adapter-core → done
# [390/14309] org.keycloak:keycloak-wildfly-adapter → done
# [391/14309] org.apache.ant:ant-apache-bsf → done
# [392/14309] org.apache.bsf:bsf-api → done
# [393/14309] rhino:js → done
# [394/14309] org.keycloak:keycloak-core → done
# [395/14309] org.keycloak:keycloak-model-api → done
# [396/14309] org.keycloak:keycloak-model-tests → done
# [397/14309] org.keycloak:keycloak-core → done
# [398/14309] org.keycloak:keycloak-core-jaxrs → done
# [399/14309] org.keycloak:keycloak-services → done
# [400/14309] org.keycloak:keycloak-model-api → done
# [401/14309] org.keycloak:keycloak-model-jpa → done
# [402/14309] org.keycloak:keycloak-social-core → done
# [403/14309] org.keycloak:keycloak-social-github → done
# [404/14309] org.keycloak:keycloak-social-google → done
# [405/14309] org.keycloak:keycloak-social-twitter → done
# [406/14309] org.keycloak:keycloak-social-facebook → done
# [407/14309] org.keycloak:keycloak-forms-common-freemarker → done
# [408/14309] org.keycloak:keycloak-forms-common-themes → done
# [409/14309] org.keycloak:keycloak-account-api → done
# [410/14309] org.keycloak:keycloak-account-freemarker → done
# [411/14309] org.keycloak:keycloak-login-api → done
# [412/14309] org.keycloak:keycloak-login-freemarker → done
# [413/14309] org.keycloak:keycloak-admin-ui → done
# [414/14309] org.keycloak:keycloak-admin-ui-styles → done
# [415/14309] org.keycloak:keycloak-js-adapter → done
# [416/14309] org.keycloak:keycloak-model-mongo → done
# [417/14309] org.keycloak:keycloak-core → done
# [418/14309] org.keycloak:keycloak-adapter-core → done
# [419/14309] org.keycloak:keycloak-jboss-adapter-core → done
# [420/14309] org.keycloak:keycloak-as7-adapter → done
# [421/14309] org.keycloak:keycloak-undertow-adapter → done
# [422/14309] org.keycloak:keycloak-wildfly-adapter → done
# [423/14309] org.keycloak:keycloak-wildfly-subsystem → done
# [424/14309] org.keycloak:keycloak-as7-subsystem → done
# [425/14309] org.keycloak:keycloak-core → done
# [426/14309] org.keycloak:keycloak-social-core → done
# [427/14309] org.keycloak:keycloak-services → done
# [428/14309] org.keycloak:keycloak-core → done
# [429/14309] org.keycloak:keycloak-model-api → done
# [430/14309] org.keycloak:keycloak-model-tests → done
# [431/14309] org.keycloak:keycloak-core → done
# [432/14309] org.keycloak:keycloak-core-jaxrs → done
# [433/14309] org.keycloak:keycloak-services → done
# [434/14309] org.keycloak:keycloak-model-api → done
# [435/14309] org.keycloak:keycloak-model-jpa → done
# [436/14309] org.keycloak:keycloak-social-core → done
# [437/14309] org.keycloak:keycloak-social-github → done
# [438/14309] org.keycloak:keycloak-social-google → done
# [439/14309] org.keycloak:keycloak-social-twitter → done
# [440/14309] org.keycloak:keycloak-social-facebook → done
# [441/14309] org.keycloak:keycloak-forms-common-freemarker → done
# [442/14309] org.keycloak:keycloak-forms-common-themes → done
# [443/14309] org.keycloak:keycloak-account-api → done
# [444/14309] org.keycloak:keycloak-account-freemarker → done
# [445/14309] org.keycloak:keycloak-login-api → done
# [446/14309] org.keycloak:keycloak-login-freemarker → done
# [447/14309] org.keycloak:keycloak-admin-ui → done
# [448/14309] org.keycloak:keycloak-admin-ui-styles → done
# [449/14309] org.keycloak:keycloak-js-adapter → done
# [450/14309] org.keycloak:keycloak-model-mongo → done
# [451/14309] org.keycloak:keycloak-core → done
# [452/14309] org.keycloak:keycloak-adapter-core → done
# [453/14309] org.keycloak:keycloak-jboss-adapter-core → done
# [454/14309] org.keycloak:keycloak-as7-adapter → done
# [455/14309] org.keycloak:keycloak-undertow-adapter → done
# [456/14309] org.keycloak:keycloak-wildfly-adapter → done
# [457/14309] org.keycloak:keycloak-wildfly-subsystem → done
# [458/14309] org.keycloak:keycloak-as7-subsystem → done
# [459/14309] org.apache.ant:ant-apache-bsf → done
# [460/14309] org.apache.bsf:bsf-api → done
# [461/14309] rhino:js → done
# [462/14309] org.keycloak:keycloak-core → done
# [463/14309] org.keycloak:keycloak-social-core → done
# [464/14309] org.keycloak:keycloak-services → done
# [465/14309] org.keycloak:keycloak-core → done
# [466/14309] org.keycloak:keycloak-model-api → done
# [467/14309] org.keycloak:keycloak-model-tests → done
# [468/14309] org.keycloak:keycloak-core → done
# [469/14309] org.keycloak:keycloak-core-jaxrs → done
# [470/14309] org.keycloak:keycloak-services → done
# [471/14309] org.keycloak:keycloak-model-api → done
# [472/14309] org.keycloak:keycloak-model-jpa → done
# [473/14309] org.keycloak:keycloak-social-core → done
# [474/14309] org.keycloak:keycloak-social-github → done
# [475/14309] org.keycloak:keycloak-social-google → done
# [476/14309] org.keycloak:keycloak-social-twitter → done
# [477/14309] org.keycloak:keycloak-social-facebook → done
# [478/14309] org.keycloak:keycloak-forms-common-freemarker → done
# [479/14309] org.keycloak:keycloak-forms-common-themes → done
# [480/14309] org.keycloak:keycloak-account-api → done
# [481/14309] org.keycloak:keycloak-account-freemarker → done
# [482/14309] org.keycloak:keycloak-login-api → done
# [483/14309] org.keycloak:keycloak-login-freemarker → done
# [484/14309] org.keycloak:keycloak-admin-ui → done
# [485/14309] org.keycloak:keycloak-admin-ui-styles → done
# [486/14309] org.keycloak:keycloak-js-adapter → done
# [487/14309] org.keycloak:keycloak-model-mongo → done
# [488/14309] org.keycloak:keycloak-core → done
# [489/14309] org.keycloak:keycloak-adapter-core → done
# [490/14309] org.keycloak:keycloak-jboss-adapter-core → done
# [491/14309] org.keycloak:keycloak-as7-adapter → done
# [492/14309] org.keycloak:keycloak-undertow-adapter → done
# [493/14309] org.keycloak:keycloak-wildfly-adapter → done
# [494/14309] org.keycloak:keycloak-wildfly-subsystem → done
# [495/14309] org.keycloak:keycloak-as7-subsystem → done
# [496/14309] org.keycloak:keycloak-core → done
# [497/14309] org.keycloak:keycloak-social-core → done
# [498/14309] org.keycloak:keycloak-services → done
# [499/14309] org.keycloak:keycloak-core → done
# [500/14309] org.keycloak:keycloak-model-api → done
# [501/14309] org.keycloak:keycloak-model-tests → done
# [502/14309] org.keycloak:keycloak-core → done
# [503/14309] org.keycloak:keycloak-core-jaxrs → done
# [504/14309] org.keycloak:keycloak-services → done
# [505/14309] org.keycloak:keycloak-model-api → done
# [506/14309] org.keycloak:keycloak-model-jpa → done
# [507/14309] org.keycloak:keycloak-social-core → done
# [508/14309] org.keycloak:keycloak-social-github → done
# [509/14309] org.keycloak:keycloak-social-google → done
# [510/14309] org.keycloak:keycloak-social-twitter → done
# [511/14309] org.keycloak:keycloak-social-facebook → done
# [512/14309] org.keycloak:keycloak-forms-common-freemarker → done
# [513/14309] org.keycloak:keycloak-forms-common-themes → done
# [514/14309] org.keycloak:keycloak-account-api → done
# [515/14309] org.keycloak:keycloak-account-freemarker → done
# [516/14309] org.keycloak:keycloak-login-api → done
# [517/14309] org.keycloak:keycloak-login-freemarker → done
# [518/14309] org.keycloak:keycloak-admin-ui → done
# [519/14309] org.keycloak:keycloak-admin-ui-styles → done
# [520/14309] org.keycloak:keycloak-js-adapter → done
# [521/14309] org.keycloak:keycloak-model-mongo → done
# [522/14309] org.keycloak:keycloak-core → done
# [523/14309] org.keycloak:keycloak-adapter-core → done
# [524/14309] org.keycloak:keycloak-jboss-adapter-core → done
# [525/14309] org.keycloak:keycloak-as7-adapter → done
# [526/14309] org.keycloak:keycloak-undertow-adapter → done
# [527/14309] org.keycloak:keycloak-wildfly-adapter → done
# [528/14309] org.keycloak:keycloak-wildfly-subsystem → done
# [529/14309] org.keycloak:keycloak-as7-subsystem → done
# [530/14309] org.keycloak:keycloak-core → done
# [531/14309] org.keycloak:keycloak-social-core → done
# [532/14309] org.keycloak:keycloak-services → done
# [533/14309] org.keycloak:keycloak-installed → done
# [534/14309] org.hamcrest:hamcrest-all → done
# [535/14309] org.picketlink:picketlink-common → done
# [536/14309] org.picketlink:picketlink-idm-api → done
# [537/14309] org.picketlink:picketlink-idm-impl → done
# [538/14309] org.picketlink:picketlink-idm-simple-schema → done
# [539/14309] org.picketlink:picketlink-config → done
# [540/14309] org.picketbox:picketbox-ldap → done
# [541/14309] org.slf4j:slf4j-api → done
# [542/14309] org.slf4j:slf4j-simple → done
# [543/14309] org.keycloak:keycloak-core → done
# [544/14309] org.keycloak:keycloak-model-api → done
# [545/14309] org.keycloak:keycloak-authentication-spi → done
# [546/14309] org.keycloak:keycloak-core → done
# [547/14309] org.keycloak:keycloak-model-api → done
# [548/14309] org.keycloak:keycloak-authentication-spi → done
# [549/14309] org.keycloak:keycloak-authentication-model → done
# [550/14309] org.keycloak:keycloak-authentication-picketlink → done
# [551/14309] org.keycloak:keycloak-core → done
# [552/14309] org.keycloak:keycloak-core-jaxrs → done
# [553/14309] org.keycloak:keycloak-forms-common-freemarker → done
# [554/14309] org.keycloak:keycloak-account-api → done
# [555/14309] org.keycloak:keycloak-login-api → done
# [556/14309] org.keycloak:keycloak-model-api → done
# [557/14309] org.keycloak:keycloak-jaxrs-oauth-client → done
# [558/14309] org.keycloak:keycloak-social-core → done
# [559/14309] org.keycloak:keycloak-authentication-spi → done
# [560/14309] org.keycloak:keycloak-core → done
# [561/14309] org.jboss.logging:jboss-logging → done
# [562/14309] org.keycloak:keycloak-core → done
# [563/14309] org.apache.httpcomponents:httpclient → done
# [564/14309] org.keycloak:keycloak-core → done
# [565/14309] org.keycloak:keycloak-adapter-core → done
# [566/14309] org.apache.httpcomponents:httpclient → done
# [567/14309] org.keycloak:keycloak-as7-adapter → done
# [568/14309] org.jboss.logging:jboss-logging → done
# [569/14309] org.keycloak:keycloak-core → done
# [570/14309] org.keycloak:keycloak-adapter-core → done
# [571/14309] org.apache.httpcomponents:httpclient → done
# [572/14309] org.picketbox:picketbox → done
# [573/14309] org.keycloak:keycloak-core → done
# [574/14309] org.keycloak:keycloak-adapter-core → done
# [575/14309] org.apache.httpcomponents:httpclient → done
# [576/14309] org.keycloak:keycloak-audit-api → done
# [577/14309] org.keycloak:keycloak-audit-jpa → done
# [578/14309] org.keycloak:keycloak-audit-jboss-logging → done
# [579/14309] org.keycloak:keycloak-audit-mongo → done
# [580/14309] org.keycloak:keycloak-audit-api → done
# [581/14309] org.keycloak:keycloak-timer-api → done
# [582/14309] org.keycloak:keycloak-timer-basic → done
# [583/14309] org.keycloak:keycloak-timer-api → done
# [584/14309] org.keycloak:keycloak-timer-basic → done
# [585/14309] org.keycloak:keycloak-authentication-api → done
# [586/14309] org.keycloak:keycloak-picketlink-api → done
# [587/14309] org.apache.httpcomponents:httpclient → done
# [588/14309] org.keycloak:keycloak-authentication-api → done
# [589/14309] org.keycloak:keycloak-picketlink-api → done
# [590/14309] org.keycloak:keycloak-picketlink-realm → done
# [591/14309] org.keycloak:keycloak-core → done
# [592/14309] org.keycloak:keycloak-model-api → done
# [593/14309] org.keycloak:keycloak-core → done
# [594/14309] org.keycloak:keycloak-model-api → done
# [595/14309] org.keycloak:keycloak-authentication-api → done
# [596/14309] org.keycloak:keycloak-picketlink-api → done
# [597/14309] org.keycloak:keycloak-core → done
# [598/14309] org.keycloak:keycloak-model-api → done
# [599/14309] org.keycloak:keycloak-picketlink-api → done
# [600/14309] org.keycloak:keycloak-picketlink-api → done
# [601/14309] org.keycloak:keycloak-picketlink-realm → done
# [602/14309] org.keycloak:keycloak-picketlink-api → done
# [603/14309] org.jboss.resteasy:jaxrs-api → done
# [604/14309] org.jboss.resteasy:resteasy-jaxrs → done
# [605/14309] org.jboss.resteasy:resteasy-multipart-provider → done
# [606/14309] org.jboss.resteasy:resteasy-jackson-provider → done
# [607/14309] org.jboss.resteasy:resteasy-client → done
# [608/14309] org.jboss.resteasy:resteasy-crypto → done
# [609/14309] org.jboss.resteasy:tjws → done
# [610/14309] org.jboss.resteasy:resteasy-undertow → done
# [611/14309] org.apache.httpcomponents:httpclient → done
# [612/14309] commons-io:commons-io → done
# [613/14309] org.keycloak:keycloak-audit-api → done
# [614/14309] org.keycloak:keycloak-audit-jboss-logging → done
# [615/14309] org.jboss.resteasy:resteasy-jaxrs → done
# [616/14309] org.jboss.resteasy:resteasy-multipart-provider → done
# [617/14309] org.jboss.resteasy:async-http-servlet-3.0 → done
# [618/14309] org.jboss.resteasy:jaxrs-api → done
# [619/14309] org.jboss.resteasy:resteasy-jackson-provider → done
# [620/14309] org.picketlink:picketlink-common → done
# [621/14309] org.picketlink:picketlink-idm-api → done
# [622/14309] org.picketlink:picketlink-idm-impl → done
# [623/14309] org.picketlink:picketlink-idm-simple-schema → done
# [624/14309] org.picketlink:picketlink-config → done
# [625/14309] org.keycloak:keycloak-core → done
# [626/14309] org.keycloak:keycloak-core-jaxrs → done
# [627/14309] org.keycloak:keycloak-services → done
# [628/14309] org.keycloak:keycloak-model-api → done
# [629/14309] org.keycloak:keycloak-model-jpa → done
# [630/14309] org.keycloak:keycloak-audit-api → done
# [631/14309] org.keycloak:keycloak-audit-jpa → done
# [632/14309] org.keycloak:keycloak-audit-jboss-logging → done
# [633/14309] org.keycloak:keycloak-social-core → done
# [634/14309] org.keycloak:keycloak-social-github → done
# [635/14309] org.keycloak:keycloak-social-google → done
# [636/14309] org.keycloak:keycloak-social-twitter → done
# [637/14309] org.keycloak:keycloak-social-facebook → done
# [638/14309] org.keycloak:keycloak-forms-common-freemarker → done
# [639/14309] org.keycloak:keycloak-forms-common-themes → done
# [640/14309] org.keycloak:keycloak-account-api → done
# [641/14309] org.keycloak:keycloak-account-freemarker → done
# [642/14309] org.keycloak:keycloak-login-api → done
# [643/14309] org.keycloak:keycloak-login-freemarker → done
# [644/14309] org.keycloak:keycloak-js-adapter → done
# [645/14309] org.keycloak:keycloak-authentication-api → done
# [646/14309] org.keycloak:keycloak-authentication-model → done
# [647/14309] org.keycloak:keycloak-timer-api → done
# [648/14309] org.keycloak:keycloak-timer-basic → done
# [649/14309] org.jboss.resteasy:resteasy-jaxrs → done
# [650/14309] org.jboss.resteasy:resteasy-multipart-provider → done
# [651/14309] org.jboss.resteasy:async-http-servlet-3.0 → done
# [652/14309] org.jboss.resteasy:jaxrs-api → done
# [653/14309] org.jboss.resteasy:resteasy-jackson-provider → done
# [654/14309] org.keycloak:keycloak-social-github → done
# [655/14309] org.keycloak:keycloak-social-google → done
# [656/14309] org.keycloak:keycloak-social-twitter → done
# [657/14309] org.keycloak:keycloak-social-facebook → done
# [658/14309] org.keycloak:keycloak-export-import-api → done
# [659/14309] de.idyl:winzipaes → done
# [660/14309] org.keycloak:keycloak-export-import-api → done
# [661/14309] org.keycloak:keycloak-export-import-impl → done
# [662/14309] org.keycloak:keycloak-email-api → done
# [663/14309] javax.mail:mail → done
# [664/14309] org.keycloak:keycloak-email-api → done
# [665/14309] org.keycloak:keycloak-email-freemarker → done
# [666/14309] org.keycloak:keycloak-core → done
# [667/14309] org.keycloak:keycloak-model-api → done
# [668/14309] org.keycloak:keycloak-authentication-api → done
# [669/14309] org.keycloak:keycloak-installed-adapter → done
# [670/14309] org.keycloak:keycloak-core → done
# [671/14309] org.keycloak:keycloak-core-jaxrs → done
# [672/14309] org.keycloak:keycloak-forms-common-freemarker → done
# [673/14309] org.keycloak:keycloak-audit-api → done
# [674/14309] org.keycloak:keycloak-account-api → done
# [675/14309] org.keycloak:keycloak-email-api → done
# [676/14309] org.keycloak:keycloak-login-api → done
# [677/14309] org.keycloak:keycloak-model-api → done
# [678/14309] org.keycloak:keycloak-social-core → done
# [679/14309] org.keycloak:keycloak-timer-api → done
# [680/14309] org.keycloak:keycloak-timer-basic → done
# [681/14309] org.keycloak:keycloak-authentication-api → done
# [682/14309] org.keycloak:keycloak-export-import-api → done
# [683/14309] org.keycloak:keycloak-picketlink-api → done
# [684/14309] org.jboss.resteasy:resteasy-client → done
# [685/14309] org.keycloak:keycloak-core → done
# [686/14309] org.keycloak:keycloak-core → done
# [687/14309] org.keycloak:keycloak-model-api → done
# [688/14309] org.keycloak:keycloak-model-tests → done
# [689/14309] org.keycloak:keycloak-core → done
# [690/14309] org.keycloak:keycloak-core → done
# [691/14309] org.keycloak:keycloak-adapter-core → done
# [692/14309] org.keycloak:keycloak-as7-adapter → done
# [693/14309] org.keycloak:keycloak-core → done
# [694/14309] org.keycloak:keycloak-adapter-core → done
# [695/14309] org.keycloak:keycloak-jboss-adapter-core → done
# [696/14309] org.keycloak:keycloak-as7-adapter → done
# [697/14309] org.keycloak:keycloak-undertow-adapter → done
# [698/14309] org.keycloak:keycloak-wildfly-adapter → done
# [699/14309] org.keycloak:keycloak-wildfly-subsystem → done
# [700/14309] org.keycloak:keycloak-as7-subsystem → done
# [701/14309] org.keycloak:keycloak-installed-adapter → done
# [702/14309] org.keycloak:keycloak-core → done
# [703/14309] org.keycloak:keycloak-adapter-core → done
# [704/14309] org.keycloak:keycloak-core → done
# [705/14309] org.keycloak:keycloak-adapter-core → done
# [706/14309] org.keycloak:keycloak-core → done
# [707/14309] org.keycloak:keycloak-model-api → done
# [708/14309] org.keycloak:keycloak-authentication-api → done
# [709/14309] org.keycloak:keycloak-picketlink-api → done
# [710/14309] org.keycloak:keycloak-core → done
# [711/14309] org.keycloak:keycloak-model-api → done
# [712/14309] org.keycloak:keycloak-core → done
# [713/14309] org.keycloak:keycloak-core-jaxrs → done
# [714/14309] org.keycloak:keycloak-services → done
# [715/14309] org.keycloak:keycloak-model-api → done
# [716/14309] org.keycloak:keycloak-model-jpa → done
# [717/14309] org.keycloak:keycloak-audit-api → done
# [718/14309] org.keycloak:keycloak-audit-jpa → done
# [719/14309] org.keycloak:keycloak-audit-jboss-logging → done
# [720/14309] org.keycloak:keycloak-social-core → done
# [721/14309] org.keycloak:keycloak-forms-common-freemarker → done
# [722/14309] org.keycloak:keycloak-forms-common-themes → done
# [723/14309] org.keycloak:keycloak-account-api → done
# [724/14309] org.keycloak:keycloak-account-freemarker → done
# [725/14309] org.keycloak:keycloak-login-api → done
# [726/14309] org.keycloak:keycloak-login-freemarker → done
# [727/14309] org.keycloak:keycloak-email-api → done
# [728/14309] org.keycloak:keycloak-email-freemarker → done
# [729/14309] org.keycloak:keycloak-js-adapter → done
# [730/14309] org.keycloak:keycloak-authentication-api → done
# [731/14309] org.keycloak:keycloak-authentication-model → done
# [732/14309] org.keycloak:keycloak-timer-api → done
# [733/14309] org.keycloak:keycloak-timer-basic → done
# [734/14309] org.keycloak:keycloak-export-import-api → done
# [735/14309] org.keycloak:keycloak-export-import-impl → done
# [736/14309] org.keycloak:keycloak-core → done
# [737/14309] org.keycloak:keycloak-model-api → done
# [738/14309] org.keycloak:keycloak-authentication-api → done
# [739/14309] org.keycloak:keycloak-core → done
# [740/14309] org.keycloak:keycloak-core-jaxrs → done
# [741/14309] org.keycloak:keycloak-forms-common-freemarker → done
# [742/14309] org.keycloak:keycloak-audit-api → done
# [743/14309] org.keycloak:keycloak-account-api → done
# [744/14309] org.keycloak:keycloak-email-api → done
# [745/14309] org.keycloak:keycloak-login-api → done
# [746/14309] org.keycloak:keycloak-model-api → done
# [747/14309] org.keycloak:keycloak-social-core → done
# [748/14309] org.keycloak:keycloak-timer-api → done
# [749/14309] org.keycloak:keycloak-timer-basic → done
# [750/14309] org.keycloak:keycloak-authentication-api → done
# [751/14309] org.keycloak:keycloak-export-import-api → done
# [752/14309] org.keycloak:keycloak-picketlink-api → done
# [753/14309] org.jboss.resteasy:resteasy-client → done
# [754/14309] org.keycloak:keycloak-core → done
# [755/14309] org.keycloak:keycloak-core → done
# [756/14309] org.keycloak:keycloak-model-api → done
# [757/14309] org.keycloak:keycloak-model-tests → done
# [758/14309] org.keycloak:keycloak-core → done
# [759/14309] org.keycloak:keycloak-core → done
# [760/14309] org.keycloak:keycloak-adapter-core → done
# [761/14309] org.keycloak:keycloak-as7-adapter → done
# [762/14309] org.keycloak:keycloak-core → done
# [763/14309] org.keycloak:keycloak-adapter-core → done
# [764/14309] org.keycloak:keycloak-jboss-adapter-core → done
# [765/14309] org.keycloak:keycloak-as7-adapter → done
# [766/14309] org.keycloak:keycloak-undertow-adapter → done
# [767/14309] org.keycloak:keycloak-wildfly-adapter → done
# [768/14309] org.keycloak:keycloak-wildfly-subsystem → done
# [769/14309] org.keycloak:keycloak-as7-subsystem → done
# [770/14309] org.keycloak:keycloak-installed-adapter → done
# [771/14309] org.keycloak:keycloak-core → done
# [772/14309] org.keycloak:keycloak-adapter-core → done
# [773/14309] org.keycloak:keycloak-core → done
# [774/14309] org.keycloak:keycloak-adapter-core → done
# [775/14309] org.keycloak:keycloak-core → done
# [776/14309] org.keycloak:keycloak-model-api → done
# [777/14309] org.keycloak:keycloak-authentication-api → done
# [778/14309] org.keycloak:keycloak-picketlink-api → done
# [779/14309] org.keycloak:keycloak-core → done
# [780/14309] org.keycloak:keycloak-model-api → done
# [781/14309] org.keycloak:keycloak-core → done
# [782/14309] org.keycloak:keycloak-core-jaxrs → done
# [783/14309] org.keycloak:keycloak-services → done
# [784/14309] org.keycloak:keycloak-model-api → done
# [785/14309] org.keycloak:keycloak-model-jpa → done
# [786/14309] org.keycloak:keycloak-audit-api → done
# [787/14309] org.keycloak:keycloak-audit-jpa → done
# [788/14309] org.keycloak:keycloak-audit-jboss-logging → done
# [789/14309] org.keycloak:keycloak-social-core → done
# [790/14309] org.keycloak:keycloak-forms-common-freemarker → done
# [791/14309] org.keycloak:keycloak-forms-common-themes → done
# [792/14309] org.keycloak:keycloak-account-api → done
# [793/14309] org.keycloak:keycloak-account-freemarker → done
# [794/14309] org.keycloak:keycloak-login-api → done
# [795/14309] org.keycloak:keycloak-login-freemarker → done
# [796/14309] org.keycloak:keycloak-email-api → done
# [797/14309] org.keycloak:keycloak-email-freemarker → done
# [798/14309] org.keycloak:keycloak-js-adapter → done
# [799/14309] org.keycloak:keycloak-authentication-api → done
# [800/14309] org.keycloak:keycloak-authentication-model → done
# [801/14309] org.keycloak:keycloak-timer-api → done
# [802/14309] org.keycloak:keycloak-timer-basic → done
# [803/14309] org.keycloak:keycloak-export-import-api → done
# [804/14309] org.keycloak:keycloak-export-import-impl → done
# [805/14309] org.keycloak:keycloak-core → done
# [806/14309] org.keycloak:keycloak-model-api → done
# [807/14309] org.keycloak:keycloak-authentication-api → done
# [808/14309] org.keycloak:keycloak-core → done
# [809/14309] org.keycloak:keycloak-core-jaxrs → done
# [810/14309] org.keycloak:keycloak-forms-common-freemarker → done
# [811/14309] org.keycloak:keycloak-audit-api → done
# [812/14309] org.keycloak:keycloak-account-api → done
# [813/14309] org.keycloak:keycloak-email-api → done
# [814/14309] org.keycloak:keycloak-login-api → done
# [815/14309] org.keycloak:keycloak-model-api → done
# [816/14309] org.keycloak:keycloak-social-core → done
# [817/14309] org.keycloak:keycloak-timer-api → done
# [818/14309] org.keycloak:keycloak-timer-basic → done
# [819/14309] org.keycloak:keycloak-authentication-api → done
# [820/14309] org.keycloak:keycloak-export-import-api → done
# [821/14309] org.keycloak:keycloak-picketlink-api → done
# [822/14309] org.jboss.resteasy:resteasy-client → done
# [823/14309] org.keycloak:keycloak-core → done
# [824/14309] org.keycloak:keycloak-core → done
# [825/14309] org.keycloak:keycloak-model-api → done
# [826/14309] org.keycloak:keycloak-model-tests → done
# [827/14309] org.keycloak:keycloak-core → done
# [828/14309] org.keycloak:keycloak-core → done
# [829/14309] org.keycloak:keycloak-adapter-core → done
# [830/14309] org.keycloak:keycloak-as7-adapter → done
# [831/14309] org.keycloak:keycloak-core → done
# [832/14309] org.keycloak:keycloak-adapter-core → done
# [833/14309] org.keycloak:keycloak-jboss-adapter-core → done
# [834/14309] org.keycloak:keycloak-as7-adapter → done
# [835/14309] org.keycloak:keycloak-undertow-adapter → done
# [836/14309] org.keycloak:keycloak-wildfly-adapter → done
# [837/14309] org.keycloak:keycloak-wildfly-subsystem → done
# [838/14309] org.keycloak:keycloak-as7-subsystem → done
# [839/14309] org.keycloak:keycloak-installed-adapter → done
# [840/14309] org.keycloak:keycloak-core → done
# [841/14309] org.keycloak:keycloak-adapter-core → done
# [842/14309] org.keycloak:keycloak-core → done
# [843/14309] org.keycloak:keycloak-adapter-core → done
# [844/14309] org.keycloak:keycloak-core → done
# [845/14309] org.keycloak:keycloak-model-api → done
# [846/14309] org.keycloak:keycloak-authentication-api → done
# [847/14309] org.keycloak:keycloak-picketlink-api → done
# [848/14309] org.keycloak:keycloak-core → done
# [849/14309] org.keycloak:keycloak-model-api → done
# [850/14309] org.keycloak:keycloak-core → done
# [851/14309] org.keycloak:keycloak-core-jaxrs → done
# [852/14309] org.keycloak:keycloak-services → done
# [853/14309] org.keycloak:keycloak-model-api → done
# [854/14309] org.keycloak:keycloak-model-jpa → done
# [855/14309] org.keycloak:keycloak-audit-api → done
# [856/14309] org.keycloak:keycloak-audit-jpa → done
# [857/14309] org.keycloak:keycloak-audit-jboss-logging → done
# [858/14309] org.keycloak:keycloak-social-core → done
# [859/14309] org.keycloak:keycloak-forms-common-freemarker → done
# [860/14309] org.keycloak:keycloak-forms-common-themes → done
# [861/14309] org.keycloak:keycloak-account-api → done
# [862/14309] org.keycloak:keycloak-account-freemarker → done
# [863/14309] org.keycloak:keycloak-login-api → done
# [864/14309] org.keycloak:keycloak-login-freemarker → done
# [865/14309] org.keycloak:keycloak-email-api → done
# [866/14309] org.keycloak:keycloak-email-freemarker → done
# [867/14309] org.keycloak:keycloak-js-adapter → done
# [868/14309] org.keycloak:keycloak-authentication-api → done
# [869/14309] org.keycloak:keycloak-authentication-model → done
# [870/14309] org.keycloak:keycloak-timer-api → done
# [871/14309] org.keycloak:keycloak-timer-basic → done
# [872/14309] org.keycloak:keycloak-export-import-api → done
# [873/14309] org.keycloak:keycloak-export-import-impl → done
# [874/14309] org.keycloak:keycloak-core → done
# [875/14309] org.keycloak:keycloak-model-api → done
# [876/14309] org.keycloak:keycloak-authentication-api → done
# [877/14309] org.freemarker:freemarker → done
# [878/14309] org.freemarker:freemarker → done
# [879/14309] org.wildfly:wildfly-controller → done
# [880/14309] org.wildfly:wildfly-server → done
# [881/14309] org.wildfly:wildfly-ee → done
# [882/14309] org.wildfly:wildfly-subsystem-test → done
# [883/14309] org.wildfly:wildfly-undertow → done
# [884/14309] io.undertow:undertow-servlet → done
# [885/14309] io.undertow:undertow-core → done
# [886/14309] org.freemarker:freemarker → done
# [887/14309] org.keycloak:keycloak-core → done
# [888/14309] org.keycloak:keycloak-core-jaxrs → done
# [889/14309] org.keycloak:keycloak-forms-common-freemarker → done
# [890/14309] org.keycloak:keycloak-audit-api → done
# [891/14309] org.keycloak:keycloak-account-api → done
# [892/14309] org.keycloak:keycloak-email-api → done
# [893/14309] org.keycloak:keycloak-login-api → done
# [894/14309] org.keycloak:keycloak-model-api → done
# [895/14309] org.keycloak:keycloak-social-core → done
# [896/14309] org.keycloak:keycloak-timer-api → done
# [897/14309] org.keycloak:keycloak-timer-basic → done
# [898/14309] org.keycloak:keycloak-authentication-api → done
# [899/14309] org.keycloak:keycloak-export-import-api → done
# [900/14309] org.keycloak:keycloak-picketlink-api → done
# [901/14309] org.keycloak:keycloak-core → done
# [902/14309] org.keycloak:keycloak-core → done
# [903/14309] org.keycloak:keycloak-model-api → done
# [904/14309] org.keycloak:keycloak-model-tests → done
# [905/14309] org.keycloak:keycloak-core → done
# [906/14309] org.keycloak:keycloak-core → done
# [907/14309] org.keycloak:keycloak-adapter-core → done
# [908/14309] org.keycloak:keycloak-as7-adapter → done
# [909/14309] org.keycloak:keycloak-core → done
# [910/14309] org.keycloak:keycloak-adapter-core → done
# ...
# [13916/14309] org.keycloak.testframework:keycloak-test-framework-core → done
# [13917/14309] org.keycloak.testframework:keycloak-test-framework-core → done
# [13918/14309] org.keycloak.testframework:keycloak-test-framework-bom → done
# [13919/14309] org.keycloak.testframework:keycloak-test-framework-example-providers → done
# [13920/14309] org.keycloak.testframework:keycloak-test-framework-bom → done
# [13921/14309] org.keycloak.testframework:keycloak-test-framework-core → done
# [13922/14309] org.keycloak.testframework:keycloak-test-framework-core → done
# [13923/14309] org.keycloak.testframework:keycloak-test-framework-remote-providers → done
# [13924/14309] lightningcss → done
# [13925/14309] vite-plugin-dts → done
# [13926/14309] @patternfly/react-table → done
# [13927/14309] tar-fs → done
# [13928/14309] commander → done
# [13929/14309] fs-extra → done
# [13930/14309] @faker-js/faker → done
# [13931/14309] @types/node → done
# [13932/14309] commander → done
# [13933/14309] @eslint/compat → done
# [13934/14309] eslint-config-prettier → done
# [13935/14309] eslint-plugin-prettier → done
# [13936/14309] @patternfly/react-table → done
# [13937/14309] @testing-library/react → done
# [13938/14309] org.keycloak:keycloak-saml-wildfly-modules → done
# [13939/14309] lint-staged → done
# [13940/14309] vitest → done
# [13941/14309] react-router-dom → done
# [13942/14309] vitest → done
# [13943/14309] cypress → done
# [13944/14309] @types/node → done
# [13945/14309] rollup → done
# [13946/14309] vitest → done
# [13947/14309] @noble/hashes → done
# [13948/14309] eslint-plugin-prettier → done
# [13949/14309] typescript → done
# [13950/14309] commander → done
# [13951/14309] vite → done
# [13952/14309] vite → done
# [13953/14309] vitest → done
# [13954/14309] vite → done
# [13955/14309] @testing-library/cypress → done
# [13956/14309] vite → done
# [13957/14309] vitest → done
# [13958/14309] org.infinispan:infinispan-bom → done
# [13959/14309] org.infinispan:infinispan-core → done
# [13960/14309] @types/node → done
# [13961/14309] mocha → done
# [13962/14309] @types/node → done
# [13963/14309] eslint-plugin-playwright → done
# [13964/14309] lint-staged → done
# [13965/14309] i18next-http-backend → done
# [13966/14309] vite → done
# [13967/14309] @types/node → done
# [13968/14309] eslint-plugin-playwright → done
# [13969/14309] eslint-plugin-playwright → done
# [13970/14309] @patternfly/react-table → done
# [13971/14309] i18next → done
# [13972/14309] i18next-http-backend → done
# [13973/14309] react-hook-form → done
# [13974/14309] react-i18next → done
# [13975/14309] react-router-dom → done
# [13976/14309] @playwright/test → done
# [13977/14309] lightningcss → done
# [13978/14309] vite → done
# [13979/14309] vite-plugin-dts → done
# [13980/14309] rollup → done
# [13981/14309] @eslint/js → done
# [13982/14309] @types/node → done
# [13983/14309] i18next → done
# [13984/14309] vite → done
# [13985/14309] lint-staged → done
# [13986/14309] vitest → done
# [13987/14309] eslint → done
# [13988/14309] io.quarkus.platform:quarkus-bom → done
# [13989/14309] org.jboss.resteasy:resteasy-core → done
# [13990/14309] org.jboss.resteasy:resteasy-core-spi → done
# [13991/14309] org.jboss.resteasy:resteasy-multipart-provider → done
# [13992/14309] org.jboss.resteasy:resteasy-jackson2-provider → done
# [13993/14309] org.jboss.resteasy:resteasy-jaxb-provider → done
# [13994/14309] org.jboss.resteasy:resteasy-client → done
# [13995/14309] org.jboss.resteasy:resteasy-undertow → done
# [13996/14309] org.apache.logging.log4j:log4j-core → done
# [13997/14309] org.apache.logging.log4j:log4j-api → done
# [13998/14309] org.wildfly.security:wildfly-elytron-http-oidc → done
# [13999/14309] i18next → done
# [14000/14309] cypress → done
# [14001/14309] vitest → done
# [14002/14309] rollup → done
# [14003/14309] wireit → done
# [14004/14309] @patternfly/react-core → done
# [14005/14309] typescript-eslint → done
# [14006/14309] @patternfly/react-core → done
# [14007/14309] react-router-dom → done
# [14008/14309] @4tw/cypress-drag-drop → done
# [14009/14309] cypress-axe → done
# [14010/14309] react-router-dom → done
# [14011/14309] @4tw/cypress-drag-drop → done
# [14012/14309] react-router-dom → done
# [14013/14309] @types/node → done
# [14014/14309] vitest → done
# [14015/14309] rollup → done
# [14016/14309] eslint-plugin-react-compiler → done
# [14017/14309] @types/node → done
# [14018/14309] typescript-eslint → done
# [14019/14309] @types/node → done
# [14020/14309] org.keycloak.tests:keycloak-tests-custom-providers → done
# [14021/14309] @4tw/cypress-drag-drop → done
# [14022/14309] cypress → done
# [14023/14309] vitest → done
# [14024/14309] vite → done
# [14025/14309] @eslint/compat → done
# [14026/14309] @types/node → done
# [14027/14309] rollup → done
# [14028/14309] @patternfly/react-core → done
# [14029/14309] i18next → done
# [14030/14309] react-router-dom → done
# [14031/14309] @playwright/test → done
# [14032/14309] vite → done
# [14033/14309] @vitejs/plugin-react-swc → done
# [14034/14309] cypress-split → done
# [14035/14309] vite → done
# [14036/14309] @eslint/js → done
# [14037/14309] eslint → done
# [14038/14309] wireit → done
# [14039/14309] prettier → done
# [14040/14309] @eslint/js → done
# [14041/14309] prettier → done
# [14042/14309] wireit → done
# [14043/14309] rollup → done
# [14044/14309] wireit → done
# [14045/14309] @vitejs/plugin-react-swc → done
# [14046/14309] @eslint/js → done
# [14047/14309] prettier → done
# [14048/14309] typescript-eslint → done
# [14049/14309] org.infinispan:infinispan-bom → done
# [14050/14309] org.infinispan:infinispan-core → done
# [14051/14309] @faker-js/faker → done
# [14052/14309] @types/node → done
# [14053/14309] cypress → done
# [14054/14309] eslint → done
# [14055/14309] org.jgroups:jgroups → done
# [14056/14309] keycloak-js → done
# [14057/14309] org.apache.maven:maven-plugin-api → done
# [14058/14309] org.apache.maven.plugin-tools:maven-plugin-annotations → done
# [14059/14309] org.apache.maven:maven-core → done
# [14060/14309] commons-io:commons-io → done
# [14061/14309] org.junit.jupiter:junit-jupiter-api → done
# [14062/14309] org.hamcrest:hamcrest → done
# [14063/14309] org.wildfly.extras.creaper:creaper-commands → done
# [14064/14309] com.h2database:h2 → done
# [14065/14309] @types/react → done
# [14066/14309] @types/react-dom → done
# [14067/14309] @types/node → done
# [14068/14309] eslint-plugin-react-hooks → done
# [14069/14309] prettier → done
# [14070/14309] rollup → done
# [14071/14309] @octokit/rest → done
# [14072/14309] keycloak-js → done
# [14073/14309] @types/react → done
# [14074/14309] @types/react-dom → done
# [14075/14309] cypress-split → done
# [14076/14309] @types/node → done
# [14077/14309] chai → done
# [14078/14309] io.quarkus.platform:quarkus-bom → done
# [14079/14309] typescript-eslint → done
# [14080/14309] rollup → done
# [14081/14309] io.quarkus.platform:quarkus-bom → done
# [14082/14309] @dagrejs/dagre → done
# [14083/14309] org.keycloak.tests:keycloak-tests-utils-shared → done
# [14084/14309] org.keycloak.testframework:keycloak-test-framework-oauth → done
# [14085/14309] org.keycloak.testframework:keycloak-test-framework-core → done
# [14086/14309] org.keycloak.testframework:keycloak-test-framework-ui → done
# [14087/14309] org.seleniumhq.selenium:selenium-api → done
# [14088/14309] com.googlecode.owasp-java-html-sanitizer:owasp-java-html-sanitizer → done
# [14089/14309] org.apache.commons:commons-text → done
# [14090/14309] @patternfly/react-core → done
# [14091/14309] @patternfly/react-table → done
# [14092/14309] vitest → done
# [14093/14309] uuid → done
# [14094/14309] keycloak-js → done
# [14095/14309] vite → done
# [14096/14309] vite-plugin-checker → done
# [14097/14309] react-i18next → done
# [14098/14309] react-i18next → done
# [14099/14309] vite → done
# [14100/14309] vite-plugin-checker → done
# [14101/14309] vite-plugin-checker → done
# [14102/14309] prettier → done
# [14103/14309] @eslint/js → done
# [14104/14309] @patternfly/react-core → done
# [14105/14309] @patternfly/react-table → done
# [14106/14309] keycloak-js → done
# [14107/14309] react-i18next → done
# [14108/14309] cypress-split → done
# [14109/14309] vite → done
# [14110/14309] vite-plugin-checker → done
# [14111/14309] vitest → done
# [14112/14309] @eslint/compat → done
# [14113/14309] @eslint/eslintrc → done
# [14114/14309] eslint → done
# [14115/14309] @types/node → done
# [14116/14309] @eslint/eslintrc → done
# [14117/14309] @types/node → done
# [14118/14309] com.thoughtworks.xstream:xstream → done
# [14119/14309] io.quarkus.platform:quarkus-bom → done
# [14120/14309] org.postgresql:postgresql → done
# [14121/14309] com.oracle.database.jdbc:ojdbc17 → done
# [14122/14309] react-i18next → done
# [14123/14309] vite → done
# [14124/14309] vitest → done
# [14125/14309] @eslint/eslintrc → done
# [14126/14309] @types/node → done
# [14127/14309] typescript-eslint → done
# [14128/14309] @patternfly/react-table → done
# [14129/14309] @patternfly/react-core → done
# [14130/14309] vite → done
# [14131/14309] @patternfly/react-core → done
# [14132/14309] @patternfly/react-table → done
# [14133/14309] i18next-fetch-backend → done
# [14134/14309] cypress → done
# [14135/14309] vite → done
# [14136/14309] vitest → done
# [14137/14309] org.keycloak.testframework:keycloak-test-framework-oauth-nimbus-poc → done
# [14138/14309] i18next-http-backend → done
# [14139/14309] eslint-config-prettier → done
# [14140/14309] i18next-fetch-backend → done
# [14141/14309] react-router-dom → done
# [14142/14309] org.keycloak.tests:keycloak-tests-utils-shared → done
# [14143/14309] org.infinispan:infinispan-bom → done
# [14144/14309] org.infinispan:infinispan-core → done
# [14145/14309] rollup → done
# [14146/14309] @faker-js/faker → done
# [14147/14309] @types/node → done
# [14148/14309] vite-plugin-dts → done
# [14149/14309] eslint-plugin-react-hooks → done
# [14150/14309] io.quarkus.platform:quarkus-operator-sdk-bom → done
# [14151/14309] io.quarkus.platform:quarkus-operator-sdk-bom → done
# [14152/14309] io.quarkus.platform:quarkus-operator-sdk-bom → done
# [14153/14309] @types/node → done
# [14154/14309] prettier → done
# [14155/14309] typescript-eslint → done
# [14156/14309] prettier → done
# [14157/14309] typescript-eslint → done
# [14158/14309] prettier → done
# [14159/14309] typescript → done
# [14160/14309] typescript-eslint → done
# [14161/14309] io.quarkus.platform:quarkus-bom → done
# [14162/14309] @eslint/js → done
# [14163/14309] eslint-config-prettier → done
# [14164/14309] typescript-eslint → done
# [14165/14309] @eslint/js → done
# [14166/14309] eslint-config-prettier → done
# [14167/14309] @faker-js/faker → done
# [14168/14309] @types/node → done
# [14169/14309] rollup → done
# [14170/14309] @eslint/js → done
# [14171/14309] @patternfly/react-core → done
# [14172/14309] @patternfly/react-table → done
# [14173/14309] i18next-fetch-backend → done
# [14174/14309] keycloak-js → done
# [14175/14309] react-i18next → done
# [14176/14309] react-router-dom → done
# [14177/14309] @playwright/test → done
# [14178/14309] @types/react → done
# [14179/14309] @types/react-dom → done
# [14180/14309] @vitejs/plugin-react-swc → done
# [14181/14309] vite → done
# [14182/14309] vite-plugin-checker → done
# [14183/14309] vite-plugin-dts → done
# [14184/14309] vitest → done
# [14185/14309] @types/node → done
# [14186/14309] eslint-config-prettier → done
# [14187/14309] @rollup/plugin-commonjs → done
# [14188/14309] @types/chai → done
# [14189/14309] @types/node → done
# [14190/14309] lightningcss → done
# [14191/14309] vite-plugin-dts → done
# [14192/14309] vitest → done
# [14193/14309] vite-plugin-dts → done
# [14194/14309] eslint → done
# [14195/14309] @rollup/plugin-node-resolve → done
# [14196/14309] vite → done
# [14197/14309] lint-staged → done
# [14198/14309] org.seleniumhq.selenium:selenium-server → done
# [14199/14309] org.seleniumhq.selenium:selenium-api → done
# [14200/14309] org.seleniumhq.selenium:selenium-java → done
# [14201/14309] org.seleniumhq.selenium:selenium-support → done
# [14202/14309] org.seleniumhq.selenium:selenium-leg-rc → done
# [14203/14309] org.seleniumhq.selenium:lift → done
# [14204/14309] org.seleniumhq.selenium:selenium-manager → done
# [14205/14309] org.seleniumhq.selenium:selenium-chrome-driver → done
# [14206/14309] org.seleniumhq.selenium:selenium-firefox-driver → done
# [14207/14309] org.seleniumhq.selenium:selenium-remote-driver → done
# [14208/14309] org.seleniumhq.selenium:htmlunit3-driver → done
# [14209/14309] org.jboss.arquillian:arquillian-bom → done
# [14210/14309] org.jboss.arquillian.protocol:arquillian-protocol-servlet-jakarta → done
# [14211/14309] com.oracle.database.jdbc:ojdbc17 → done
# [14212/14309] io.quarkus.platform:quarkus-bom → done
# [14213/14309] org.jboss.resteasy:resteasy-core → done
# [14214/14309] org.jboss.resteasy:resteasy-core-spi → done
# [14215/14309] org.jboss.resteasy:resteasy-multipart-provider → done
# [14216/14309] org.jboss.resteasy:resteasy-jackson2-provider → done
# [14217/14309] org.jboss.resteasy:resteasy-jaxb-provider → done
# [14218/14309] org.jboss.resteasy:resteasy-client → done
# [14219/14309] org.jboss.resteasy:resteasy-undertow → done
# [14220/14309] vite → done
# [14221/14309] @axe-core/playwright → done
# [14222/14309] @playwright/test → done
# [14223/14309] lightningcss → done
# [14224/14309] uuid → done
# [14225/14309] vite → done
# [14226/14309] vite-plugin-dts → done
# [14227/14309] i18next → done
# [14228/14309] io.quarkus.platform:quarkus-operator-sdk-bom → done
# [14229/14309] vitest → done
# [14230/14309] rollup → done
# [14231/14309] vite-plugin-checker → done
# [14232/14309] i18next → done
# [14233/14309] @playwright/test → done
# [14234/14309] vite-plugin-checker → done
# [14235/14309] vitest → done
# [14236/14309] @vitejs/plugin-react-swc → done
# [14237/14309] org.keycloak.testframework:keycloak-test-framework-junit5-config → done
# [14238/14309] org.keycloak.testframework:keycloak-test-framework-core → done
# [14239/14309] com.icegreen:greenmail → done
# [14240/14309] com.icegreen:greenmail → done
# [14241/14309] typescript-eslint → done
# [14242/14309] @vitejs/plugin-react-swc → done
# [14243/14309] cross-env → done
# [14244/14309] @eslint/eslintrc → done
# [14245/14309] @eslint/js → done
# [14246/14309] @types/node → done
# [14247/14309] eslint → done
# [14248/14309] @eslint/eslintrc → done
# [14249/14309] @eslint/js → done
# [14250/14309] eslint → done
# [14251/14309] @eslint/eslintrc → done
# [14252/14309] @eslint/js → done
# [14253/14309] @types/node → done
# [14254/14309] eslint → done
# [14255/14309] eslint-plugin-prettier → done
# [14256/14309] typescript-eslint → done
# [14257/14309] rollup → done
# [14258/14309] @types/chai → done
# [14259/14309] @types/node → done
# [14260/14309] vite → done
# [14261/14309] @types/node → done
# [14262/14309] typescript-eslint → done
# [14263/14309] typescript-eslint → done
# [14264/14309] @types/node → done
# [14265/14309] eslint-plugin-prettier → done
# [14266/14309] io.quarkus.platform:quarkus-bom → done
# [14267/14309] @types/node → done
# [14268/14309] vitest → done
# [14269/14309] typescript-eslint → done
# [14270/14309] rollup → done
# [14271/14309] @eslint/compat → done
# [14272/14309] @types/node → done
# [14273/14309] @types/node → done
# [14274/14309] vite → done
# [14275/14309] rollup → done
# [14276/14309] @types/node → done
# [14277/14309] eslint-plugin-prettier → done
# [14278/14309] @testing-library/react → done
# [14279/14309] vite → done
# [14280/14309] vitest → done
# [14281/14309] vite → done
# [14282/14309] eslint-plugin-react → done
# [14283/14309] org.jsoup:jsoup → done
# [14284/14309] @eslint/js → done
# [14285/14309] eslint → done
# [14286/14309] org.postgresql:postgresql → done
# [14287/14309] eslint-config-prettier → done
# [14288/14309] typescript → done
# [14289/14309] typescript-eslint → done
# [14290/14309] wireit → done
# [14291/14309] vite → done
# [14292/14309] vite-plugin-lib-inject-css → done
# [14293/14309] eslint-config-prettier → done
# [14294/14309] typescript-eslint → done
# [14295/14309] wireit → done
# [14296/14309] eslint-config-prettier → done
# [14297/14309] vite → done
# [14298/14309] wireit → done
# [14299/14309] @noble/hashes → done
# [14300/14309] @faker-js/faker → done
# [14301/14309] @types/node → done
# [14302/14309] jsdom → done
# [14303/14309] vite → done
# [14304/14309] @vitejs/plugin-react-swc → done
# [14305/14309] vite → done
# [14306/14309] rollup → done
# [14307/14309] lint-staged → done
# [14308/14309] typescript-eslint → done
# [14309/14309] io.quarkus.platform:quarkus-operator-sdk-bom → done
